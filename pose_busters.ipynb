# %% [markdown]
# # Setting Directories

# %%
wd = "/home/manndo/master_dev"
# autodock_poses_dir = wd + "/docking_ready_mgltools/docking"
# diffdock_poses_dir = wd + "/diffdock_results"
# equibind_guided_poses_dir = wd + "/equibind_pocket_guided"
# equibind_exclusion_poses_dir = wd + "/equibind_spatial_exclusion_poses"
# equibind_docked_poses_dir = wd + "/equibind_docked_poses"
# equibind_docked_poses_dir = wd + "/equibind_docked_poses_2"
diffdock_poses_dir_large_ligands = wd + "/diffdock_results/ligands_sdf_large"

# Setting proteins_dir to the path of the Orai proteins directory for PoseBuster Mode "dock"
proteins_dir = wd + "/Orai"

docking_directories = {
    # "autodock": autodock_poses_dir,
    # "diffdock": diffdock_poses_dir,
    # "equibind_guided": equibind_guided_poses_dir,
    # "equibind_exclusion": equibind_exclusion_poses_dir,
    # "equibind_docked_poses": equibind_docked_poses_dir,
    # "equibind_docked_poses": equibind_docked_poses_dir,
    "diffdock": diffdock_poses_dir_large_ligands
}

# %%
"""
Overview: Pose Counts by Docking Method and Protein-Ligand Combination
This cell analyzes all docking results directories and creates a summary table.
It iterates over `docking_directories` and filters each directory for poses
based on the docking method key.
"""
import pandas as pd
from pathlib import Path
import re


def count_autodock_poses(poses_dir):
    """Count AutoDock Vina poses from PDBQT files"""
    data = []
    base_path = Path(poses_dir)

    for pdbqt_file in base_path.glob("*_vina_out.pdbqt"):
        stem = pdbqt_file.stem.replace("_vina_out", "")
        parts = stem.split("__")

        if len(parts) == 2:
            protein, ligand = parts

            # Count MODEL entries in PDBQT file
            with open(pdbqt_file, 'r') as f:
                content = f.read()
                pose_count = content.count('MODEL')
                if pose_count == 0:
                    pose_count = 1  # Single pose file without MODEL markers

            data.append({
                "Protein": protein,
                "Ligand": ligand,
                "Poses": pose_count
            })

    return pd.DataFrame(data)


def count_diffdock_poses(poses_dir):
    """Count DiffDock poses from SDF files in subdirectories"""
    data = []
    base_path = Path(poses_dir)

    for subdir in base_path.iterdir():
        if not subdir.is_dir():
            continue
        # Skip helper directories
        if "_ligand__" in subdir.name or subdir.name in ["prepared_proteins", "converted_pdbqt", "prepared_ligands", "Orai"]:
            continue

        parts = subdir.name.split("__")
        if len(parts) == 2:
            ligand, protein = parts

            # Count all SDF files in subdirectory (including complex_* folders)
            pose_count = len(list(subdir.glob("**/*.sdf")))

            if pose_count > 0:
                data.append({
                    "Protein": protein,
                    "Ligand": ligand,
                    "Poses": pose_count
                })

    return pd.DataFrame(data)


def count_equibind_poses(poses_dir):
    """Count EquiBind poses from SDF files, supporting spatial_sites directory structure.

    Handles directories named like:
      {ligand}__{protein}_spatial_sites/site_XX/pose_XX.sdf
    as well as flat directories:
      {ligand}__{protein}/*.sdf
    """
    data = []
    base_path = Path(poses_dir)

    for subdir in base_path.iterdir():
        if not subdir.is_dir():
            continue
        # Skip pymol export/fixed variants for main count
        if "_pymol" in subdir.name:
            continue

        dir_name = subdir.name

        # Handle spatial_sites suffix: strip it to extract the protein name
        is_spatial = dir_name.endswith("_spatial_sites")
        if is_spatial:
            dir_name_clean = dir_name.replace("_spatial_sites", "")
        else:
            dir_name_clean = dir_name

        parts = dir_name_clean.split("__")
        if len(parts) == 2:
            ligand, protein = parts

            # Count SDF files recursively (covers site_XX subdirs and flat layouts)
            pose_count = len(list(subdir.glob("**/*.sdf")))

            if pose_count > 0:
                data.append({
                    "Protein": protein,
                    "Ligand": ligand,
                    "Poses": pose_count
                })

    return pd.DataFrame(data)


# Map docking method keys to their counting functions
POSE_COUNTERS = {
    "autodock": count_autodock_poses,
    "diffdock": count_diffdock_poses,
    "equibind_guided": count_equibind_poses,
    "equibind_exclusion": count_equibind_poses,
    "equibind_docked_poses": count_equibind_poses,
}

# Collect pose counts from all methods defined in docking_directories
print("=" * 100)
print("DOCKING POSES OVERVIEW")
print("=" * 100)
print("\nCollecting pose counts from all docking methods...\n")

method_dfs = {}
for method, poses_dir in docking_directories.items():
    counter_fn = POSE_COUNTERS.get(method)
    if counter_fn is None:
        print(f"  WARNING: No pose counter registered for method '{method}', skipping.")
        continue

    if not Path(poses_dir).exists():
        print(f"  WARNING: Directory not found for '{method}': {poses_dir}, skipping.")
        continue

    df = counter_fn(poses_dir)
    # Rename the Poses column to the method name for merging
    col_name = method.replace(" ", "_").title()
    df = df.rename(columns={"Poses": col_name})
    method_dfs[col_name] = df
    print(f"  {col_name}: {len(df)} protein-ligand combinations")

# Merge all method DataFrames into one table
df_combined = pd.DataFrame()
for col_name, df in method_dfs.items():
    if df_combined.empty:
        df_combined = df
    else:
        df_combined = df_combined.merge(df, on=["Protein", "Ligand"], how="outer")

if not df_combined.empty:
    # Fill NaN with 0 and convert pose count columns to int
    method_cols = [c for c in df_combined.columns if c not in ("Protein", "Ligand")]
    df_combined = df_combined.fillna(0)
    for col in method_cols:
        df_combined[col] = df_combined[col].astype(int)

    # Add total column
    df_combined["Total"] = df_combined[method_cols].sum(axis=1)

    # Sort by protein, then ligand
    df_combined = df_combined.sort_values(["Protein", "Ligand"])

    # Display full table
    print("\n" + "=" * 100)
    print("POSE COUNTS BY PROTEIN-LIGAND COMBINATION")
    print("=" * 100)
    print(df_combined.to_string(index=False))

    # Summary statistics
    print("\n" + "=" * 100)
    print("SUMMARY STATISTICS")
    print("=" * 100)
    print(f"\nTotal unique protein-ligand combinations: {len(df_combined)}")
    print(f"\nTotal poses by method:")
    for col in method_cols:
        print(f"  {col}: {df_combined[col].sum():,} poses")
    print(f"  Combined Total: {df_combined['Total'].sum():,} poses")

    print(f"\nUnique proteins: {df_combined['Protein'].nunique()}")
    print(f"Unique ligands: {df_combined['Ligand'].nunique()}")

    # Breakdown by ligand
    print("\n" + "-" * 100)
    print("POSES BY LIGAND")
    print("-" * 100)
    ligand_summary = df_combined.groupby("Ligand")[method_cols + ["Total"]].sum()
    print(ligand_summary.to_string())

    # Breakdown by protein
    print("\n" + "-" * 100)
    print("POSES BY PROTEIN")
    print("-" * 100)
    protein_summary = df_combined.groupby("Protein")[method_cols + ["Total"]].sum()
    print(protein_summary.to_string())

    # Save to CSV
    output_file = Path(wd + "/posebusters_results") / "pose_counts_overview.csv"
    output_file.parent.mkdir(exist_ok=True)
    df_combined.to_csv(output_file, index=False)
    print(f"\n" + "=" * 100)
    print(f"Table saved to: {output_file}")
    print("=" * 100)

else:
    print("\nNo docking results found!")
# Out:
# ====================================================================================================
# DOCKING POSES OVERVIEW
# ====================================================================================================
#
# Collecting pose counts from all docking methods...
#
#   Diffdock: 1071 protein-ligand combinations
#
# ====================================================================================================
# POSE COUNTS BY PROTEIN-LIGAND COMBINATION
# ====================================================================================================
#                      Protein      Ligand  Diffdock  Total
# Orai1WT-MDSnap-Fr300_cleaned   017_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   032_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   04J_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   07J_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   08Y_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   09L_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   0LI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   0RI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   0WM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   0XZ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   10A_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   115_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   116_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   117_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   15M_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   16A_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   1C9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   1E8_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   1II_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   1LT_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   1N1_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   1UN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   2GM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   2K2_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   2R9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   2RC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   2TA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   30B_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   336_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   356_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   3E8_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   3QB_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   4CC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   4DY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   4MK_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   4UH_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   5D5_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   5SF_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   5X6_ideal         6      6
# Orai1WT-MDSnap-Fr300_cleaned   62B_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   69Q_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   6E2_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   6GY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   6I6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   6K9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   6T3_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   6ZV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   6ZZ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   715_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   71R_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   7KD_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   7R3_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   7RU_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   7V7_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   7WT_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   87Q_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   8HO_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   8NU_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   8ZF_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   92S_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   9JI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   9NQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   9SC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   9TP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1AAC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1APA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1B7W_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1CMV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1D5I_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1EAY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1EAZ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1ECE_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1EKL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1EQV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1ESA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1ESZ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1IPH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1IT8_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1IVJ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1IVL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1JRF_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1JS8_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1JTY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1L11_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned A1LXP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   A4I_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   A9L_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AB1_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ACD_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AGG_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AKN_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   ALW_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AOQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AQ4_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AV9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AXI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AY6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   AY7_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   B49_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   BAX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   BBI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   BLM_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   C04_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   C3D_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   C41_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   C6F_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   C87_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CC9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CDC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CE3_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CE9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CHC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CHD_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CLR_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CLS_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CLY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CNY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CP0_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CQA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CU9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   CV6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   D16_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   D2V_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   D7D_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DB8_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DEQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DGX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DID_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DLU_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DME_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DN0_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DOL_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   DR7_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DXC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   DZQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   E6L_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ECT_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   EDS_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   EIC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ELA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   EMH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   EPA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ERG_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ERM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ERY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   EVP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   F9R_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FAD_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FBI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FBX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FFO_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FI8_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   FK5_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   FMM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FMN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   FOL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   G34_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   GBM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   GDS_ideal         6      6
# Orai1WT-MDSnap-Fr300_cleaned   GG2_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   GMJ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   GSH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   GZO_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   GZX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   H56_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   H6U_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   HU5_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   HWL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   HXA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ICQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   IDB_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   IRE_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   IU5_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   IUD_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   IV3_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   J8C_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   JC6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   JEU_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   JHN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   JQ9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   K5O_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   K86_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   KKB_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   KLN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   KLQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   KOV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   KTN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   KTY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   L3R_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   L9P_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   LBH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   LBM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   LE6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   LEV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   LNL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   LYA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   M9B_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MEM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MIX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MK1_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MRC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MRV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MTK_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MTX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MUO_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   MWV_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   N8R_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   N90_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   NAI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   NIL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   NMY_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   NOV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   O31_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   O6P_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   O6U_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   OBN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   OQ4_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   P2E_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   P30_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   P31_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   P5S_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   PAR_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   PL3_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   PLM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   PNT_ideal         6      6
# Orai1WT-MDSnap-Fr300_cleaned   PQN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   PV9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   PX9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   Q4J_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   QCM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   QKM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   QNG_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   QOM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   QOP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   QWP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   R1L_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   R1Q_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   RAL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   RAP_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   RBR_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   RBT_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   REA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   RIT_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   RLT_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ROC_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ROX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   RTL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SAM_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SCK_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SHH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SMX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SPP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SPR_ideal         6      6
# Orai1WT-MDSnap-Fr300_cleaned   SQL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SRY_ideal        11     11
# Orai1WT-MDSnap-Fr300_cleaned   STE_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   STI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   SUE_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   T27_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TA1_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TAO_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TCH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TE4_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TEI_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TEL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   THH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TIQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TLS_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TMQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TPV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TXL_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   TZ0_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   U10_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   U35_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   U7V_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   UGU_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   USS_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   V2H_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VD3_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VDN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VDX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VDY_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VGH_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VH6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VIA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VIS_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VIV_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VLB_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VNZ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VPX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VT1_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   VX7_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   WJX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   WPP_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   WV2_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   X2N_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   X3N_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   X56_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XB7_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XC9_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XEF_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XIN_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XPG_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XQQ_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   XRA_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   Y7W_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   Y9J_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   YG7_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   YHR_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   YLX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   YMX_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   YP4_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   YY3_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   Z6V_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ZD6_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ZIT_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ZLD_ideal        10     10
# Orai1WT-MDSnap-Fr300_cleaned   ZLK_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   017_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   032_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   04J_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   07J_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   08Y_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   09L_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   0LI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   0RI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   0WM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   0XZ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   10A_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   115_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   116_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   117_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   15M_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   16A_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   1C9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   1E8_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   1II_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   1LT_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   1N1_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   1UN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   2GM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   2K2_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   2R9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   2RC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   2TA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   30B_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   336_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   356_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   3E8_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   3QB_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   4CC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   4DY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   4MK_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   4UH_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   5D5_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   5SF_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   5X6_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   62B_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   69Q_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   6E2_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   6GY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   6I6_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   6K9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   6T3_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   6ZV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   6ZZ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   715_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   71R_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   7KD_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   7R3_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   7RU_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   7V7_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   7WT_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   87Q_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   8HO_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   8NU_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   8ZF_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   92S_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   9JI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   9NQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   9SC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   9TP_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1AAC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1APA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1AZ7_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned A1B7W_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1CMV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1D5I_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1EAY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1EAZ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1ECE_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1EKL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1EQV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1ESA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1ESZ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1IPH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1IT8_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1IVJ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1IVL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1JRF_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1JS8_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1JTY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1L11_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned A1LXP_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   A4I_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   A9L_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AB1_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ACD_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AGG_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AKN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ALW_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AOQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AQ4_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AV9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AXI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AY6_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   AY7_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   B49_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   BAX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   BBI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   C04_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   C3D_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   C41_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   C6F_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   C87_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CC9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CDC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CE3_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CE9_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   CHC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CHD_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CLR_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CLS_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CLY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CNY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CP0_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CQA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CU9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   CV6_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   D16_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   D2V_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   D7D_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DB8_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DEQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DLU_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DME_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DN0_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DOL_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   DR7_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DXC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   DZQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   E6L_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ECT_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   EDS_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   EIC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ELA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   EMH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   EPA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ERG_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ERM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ERY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   EVP_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   F9R_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FAD_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FBI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FBX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FFO_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FI8_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   FK5_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   FMM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FMN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   FOL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   G34_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   GBM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   GG2_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   GMJ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   GSH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   GZO_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   GZX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   H56_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   H6U_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   HU5_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   HWL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   HXA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   I0V_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   ICQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   IDB_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   IRE_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   IU5_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   IUD_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   IV3_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   J8C_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   JC6_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   JEU_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   JHN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   JQ9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   K5O_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   K86_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   KKB_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   KLN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   KLQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   KOV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   KTN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   KTY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   L3R_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   L9P_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   LBH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   LBM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   LE6_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   LEV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   LFL_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   LNL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   LYA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   M9B_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MEM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MIX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MK1_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MRC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MRV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MTK_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MTX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   MUO_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   MWV_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   N8R_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   N90_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   NAI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   NIL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   NMY_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   NOV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   O31_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   O6P_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   O6U_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   OBN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   OQ4_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   P2E_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   P30_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   P31_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   P5S_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   PAR_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   PL3_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   PLM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   PQN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   PV9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   PX9_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   Q4J_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   QCM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   QKM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   QNG_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   QOM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   QOP_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   QWP_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   R1L_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   R1Q_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   RAL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   RAP_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   RBR_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   RBT_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   REA_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   RIT_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   RLT_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ROC_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   ROX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   RTL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SAM_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SCK_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SHH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SMX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SPP_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SPR_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   SQL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   STE_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   STI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   SUE_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   T27_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TA1_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TAO_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TCH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TEI_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TEL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   THH_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TIQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TLS_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TMQ_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TPV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TXL_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   TZ0_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   U10_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   U35_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   U7V_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   UGU_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   USS_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   V2H_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VD3_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VDN_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VDX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VDY_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VGH_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   VH6_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   VIS_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VIV_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VT1_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   VX7_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   WJX_ideal        10     10
# Orai1WT-MDSnap-Fr400_cleaned   WPP_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   WV2_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   X2N_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   X3N_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   X56_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XB7_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XC9_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XEF_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XIN_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XPG_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XQQ_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   XRA_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   Y7W_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   Y9J_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   YG7_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   YY3_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   Z6V_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   ZD6_ideal        11     11
# Orai1WT-MDSnap-Fr400_cleaned   ZIT_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   ZLD_ideal         6      6
# Orai1WT-MDSnap-Fr400_cleaned   ZLK_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   017_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   032_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   04J_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   07J_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   08Y_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   09L_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   0LI_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   0RI_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   0WM_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   0XZ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   10A_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   115_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   116_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   117_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   15M_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   16A_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   1C9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   1E8_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   1II_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   1LT_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   1N1_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   1UN_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   2GM_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   2K2_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   2R9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   2RC_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   2TA_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   30B_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   336_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   356_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   3E8_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   3QB_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   4CC_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   4DY_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   4MK_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   4UH_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   5D5_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   5SF_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   5X6_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   62B_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   69Q_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   6E2_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   6GY_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   6I6_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   6K9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   6T3_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   6ZV_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   6ZZ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   715_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   71R_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   7KD_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   7R3_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   7RU_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   7V7_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   7WT_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   87Q_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   8HO_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   8NU_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   8ZF_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   92S_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   9JI_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   9NQ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   9SC_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   9TP_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1AAC_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1APA_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1B7W_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1CMV_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1D5I_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1EAY_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1EAZ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1ECE_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1EKL_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1EQV_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1ESA_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1ESZ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1IPH_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1IT8_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1IVJ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1IVL_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1JRF_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1JS8_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1JTY_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1L11_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned A1LXP_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   A4I_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   A9L_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AB1_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   ACD_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AGG_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AKN_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   ALW_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AOQ_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AQ4_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AV9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AXI_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AY6_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   AY7_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   B49_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   BAX_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   BBI_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   C04_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   C3D_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   C41_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   C6F_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   C87_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CC9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CDC_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CE3_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CE9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CHC_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CHD_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CLR_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CLS_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CLY_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CNY_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CP0_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CQA_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CU9_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   CV6_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   D16_ideal         6      6
# Orai1WT-MDSnap-Fr499_cleaned   DLU_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   DME_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   DN0_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   DOL_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   DR7_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   DXC_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   DZQ_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   E6L_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   EIC_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   ELA_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   EMH_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   EPA_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   ERG_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   ERM_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   ERY_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   EVP_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   F9R_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FAD_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FBI_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FBX_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FFO_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FI8_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FK5_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FMM_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FMN_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   FOL_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   G34_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   GBM_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   GG2_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   GMJ_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   GSH_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   GZO_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   GZX_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   H56_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   H6U_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   HU5_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   HWL_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   HXA_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   ICQ_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   IDB_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   IRE_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   IU5_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   IUD_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   IV3_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   J8C_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   JC6_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   JEU_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   JHN_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   JQ9_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   K5O_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   K86_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   KKB_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   KLN_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   KLQ_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   KOV_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   KTN_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   KTY_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   L3R_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   L9P_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LBH_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LBM_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LE6_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LEV_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LFL_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LNL_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   LYA_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   M9B_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   MEM_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   MIX_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   MK1_ideal        11     11
# Orai1WT-MDSnap-Fr499_cleaned   MRC_ideal        11     11
# ...
#    Orai1WT-START-Fr0_cleaned   7R3_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   7RU_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   7V7_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   7WT_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   87Q_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   8HO_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   8NU_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   8ZF_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   92S_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   9JI_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   9NQ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   9SC_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   9TP_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1AAC_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1APA_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1B7W_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1CMV_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1D5I_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1EAY_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1EAZ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1ECE_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1EKL_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1EQV_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1ESA_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1ESZ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1IPH_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1IT8_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1IVJ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1IVL_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1JRF_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1JS8_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1JTY_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1L11_ideal        11     11
#    Orai1WT-START-Fr0_cleaned A1LXP_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   A4I_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   A9L_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AB1_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ACD_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AGG_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ALW_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AOQ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AQ4_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AV9_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AXI_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AY6_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   AY7_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   B49_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   BAX_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   BBI_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   C04_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   C3D_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   C41_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   C6F_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   C87_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CC9_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CDC_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CE3_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CE9_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CHC_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CHD_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CLR_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CLS_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CLY_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CNY_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CP0_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CQA_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CU9_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   CV6_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   D16_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   D2V_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   D7D_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DB8_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DEQ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DLU_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DME_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DN0_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DOL_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DR7_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DXC_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   DZQ_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   E6L_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ECT_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   EDS_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   EIC_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ELA_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   EMH_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   EPA_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ERG_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ERM_ideal        11     11
#    Orai1WT-START-Fr0_cleaned   ERY_ideal        11     11
#
# ====================================================================================================
# SUMMARY STATISTICS
# ====================================================================================================
#
# Total unique protein-ligand combinations: 1071
#
# Total poses by method:
#   Diffdock: 10,501 poses
#   Combined Total: 10,501 poses
#
# Unique proteins: 4
# Unique ligands: 321
#
# ----------------------------------------------------------------------------------------------------
# POSES BY LIGAND
# ----------------------------------------------------------------------------------------------------
#              Diffdock  Total
# Ligand
# 017_ideal          37     37
# 032_ideal          37     37
# 04J_ideal          37     37
# 07J_ideal          37     37
# 08Y_ideal          37     37
# 09L_ideal          37     37
# 0LI_ideal          37     37
# 0RI_ideal          37     37
# 0WM_ideal          37     37
# 0XZ_ideal          37     37
# 10A_ideal          37     37
# 115_ideal          37     37
# 116_ideal          37     37
# 117_ideal          37     37
# 15M_ideal          37     37
# 16A_ideal          37     37
# 1C9_ideal          37     37
# 1E8_ideal          37     37
# 1II_ideal          37     37
# 1LT_ideal          37     37
# 1N1_ideal          37     37
# 1UN_ideal          37     37
# 2GM_ideal          37     37
# 2K2_ideal          37     37
# 2R9_ideal          37     37
# 2RC_ideal          37     37
# 2TA_ideal          37     37
# 30B_ideal          37     37
# 336_ideal          37     37
# 356_ideal          37     37
# 3E8_ideal          37     37
# 3QB_ideal          37     37
# 4CC_ideal          37     37
# 4DY_ideal          37     37
# 4MK_ideal          37     37
# 4UH_ideal          44     44
# 5D5_ideal          37     37
# 5SF_ideal          37     37
# 5X6_ideal          34     34
# 62B_ideal          37     37
# 69Q_ideal          37     37
# 6E2_ideal          37     37
# 6GY_ideal          37     37
# 6I6_ideal          37     37
# 6K9_ideal          37     37
# 6T3_ideal          44     44
# 6ZV_ideal          37     37
# 6ZZ_ideal          37     37
# 715_ideal          37     37
# 71R_ideal          39     39
# 7KD_ideal          37     37
# 7R3_ideal          37     37
# 7RU_ideal          37     37
# 7V7_ideal          33     33
# 7WT_ideal          37     37
# 87Q_ideal          37     37
# 8HO_ideal          37     37
# 8NU_ideal          37     37
# 8ZF_ideal          37     37
# 92S_ideal          37     37
# 9JI_ideal          37     37
# 9NQ_ideal          37     37
# 9SC_ideal          37     37
# 9TP_ideal          37     37
# A1AAC_ideal        37     37
# A1APA_ideal        37     37
# A1AZ7_ideal        11     11
# A1B7W_ideal        37     37
# A1CMV_ideal        37     37
# A1D5I_ideal        37     37
# A1EAY_ideal        37     37
# A1EAZ_ideal        37     37
# A1ECE_ideal        37     37
# A1EKL_ideal        37     37
# A1EQV_ideal        37     37
# A1ESA_ideal        37     37
# A1ESZ_ideal        37     37
# A1IPH_ideal        37     37
# A1IT8_ideal        37     37
# A1IVJ_ideal        37     37
# A1IVL_ideal        37     37
# A1JRF_ideal        37     37
# A1JS8_ideal        37     37
# A1JTY_ideal        37     37
# A1L11_ideal        37     37
# A1LXP_ideal        43     43
# A4I_ideal          44     44
# A9L_ideal          37     37
# AB1_ideal          37     37
# ACD_ideal          37     37
# AGG_ideal          37     37
# AKN_ideal          32     32
# ALW_ideal          37     37
# AOQ_ideal          37     37
# AQ4_ideal          37     37
# AV9_ideal          37     37
# AXI_ideal          37     37
# AY6_ideal          37     37
# AY7_ideal          37     37
# B49_ideal          37     37
# BAX_ideal          37     37
# BBI_ideal          37     37
# BLM_ideal          11     11
# C04_ideal          37     37
# C3D_ideal          37     37
# C41_ideal          37     37
# C6F_ideal          37     37
# C87_ideal          37     37
# CC9_ideal          37     37
# CDC_ideal          37     37
# CE3_ideal          37     37
# CE9_ideal          33     33
# CHC_ideal          37     37
# CHD_ideal          37     37
# CLR_ideal          37     37
# CLS_ideal          37     37
# CLY_ideal          37     37
# CNY_ideal          37     37
# CP0_ideal          37     37
# CQA_ideal          37     37
# CU9_ideal          37     37
# CV6_ideal          37     37
# D16_ideal          37     37
# D2V_ideal          31     31
# D7D_ideal          31     31
# DB8_ideal          31     31
# DEQ_ideal          31     31
# DGX_ideal          10     10
# DID_ideal          10     10
# DLU_ideal          42     42
# DME_ideal          42     42
# DN0_ideal          42     42
# DOL_ideal          44     44
# DR7_ideal          42     42
# DXC_ideal          42     42
# DZQ_ideal          42     42
# E6L_ideal          42     42
# ECT_ideal          31     31
# EDS_ideal          31     31
# EIC_ideal          42     42
# ELA_ideal          42     42
# EMH_ideal          42     42
# EPA_ideal          42     42
# ERG_ideal          42     42
# ERM_ideal          42     42
# ERY_ideal          42     42
# EVP_ideal          31     31
# F9R_ideal          31     31
# FAD_ideal          31     31
# FBI_ideal          31     31
# FBX_ideal          31     31
# FFO_ideal          31     31
# FI8_ideal          33     33
# FK5_ideal          28     28
# FMM_ideal          31     31
# FMN_ideal          31     31
# FOL_ideal          31     31
# G34_ideal          31     31
# GBM_ideal          31     31
# GDS_ideal           6      6
# GG2_ideal          31     31
# GMJ_ideal          31     31
# GSH_ideal          31     31
# GZO_ideal          31     31
# GZX_ideal          31     31
# H56_ideal          31     31
# H6U_ideal          31     31
# HU5_ideal          31     31
# HWL_ideal          31     31
# HXA_ideal          31     31
# I0V_ideal          11     11
# ICQ_ideal          31     31
# IDB_ideal          31     31
# IRE_ideal          31     31
# IU5_ideal          31     31
# IUD_ideal          31     31
# IV3_ideal          31     31
# J8C_ideal          31     31
# JC6_ideal          31     31
# JEU_ideal          31     31
# JHN_ideal          31     31
# JQ9_ideal          31     31
# K5O_ideal          31     31
# K86_ideal          31     31
# KKB_ideal          31     31
# KLN_ideal          31     31
# KLQ_ideal          31     31
# KOV_ideal          31     31
# KTN_ideal          31     31
# KTY_ideal          31     31
# L3R_ideal          31     31
# L9P_ideal          31     31
# LBH_ideal          31     31
# LBM_ideal          31     31
# LE6_ideal          31     31
# LEV_ideal          31     31
# LFL_ideal          17     17
# LNL_ideal          31     31
# LYA_ideal          31     31
# M9B_ideal          31     31
# MEM_ideal          31     31
# MIX_ideal          31     31
# MK1_ideal          31     31
# MRC_ideal          31     31
# MRV_ideal          31     31
# MTK_ideal          31     31
# MTX_ideal          31     31
# MUO_ideal          32     32
# MWV_ideal          22     22
# N8R_ideal          31     31
# N90_ideal          31     31
# NAI_ideal          31     31
# NIL_ideal          31     31
# NMY_ideal          28     28
# NOV_ideal          31     31
# O31_ideal          31     31
# O6P_ideal          31     31
# O6U_ideal          31     31
# OBN_ideal          31     31
# OQ4_ideal          31     31
# P2E_ideal          31     31
# P30_ideal          31     31
# P31_ideal          31     31
# P5S_ideal          31     31
# PAR_ideal          33     33
# PL3_ideal          31     31
# PLM_ideal          31     31
# PNT_ideal           6      6
# PQN_ideal          31     31
# PV9_ideal          31     31
# PX9_ideal          31     31
# Q4J_ideal          31     31
# QCM_ideal          31     31
# QKM_ideal          31     31
# QNG_ideal          31     31
# QOM_ideal          31     31
# QOP_ideal          31     31
# QWP_ideal          31     31
# R1L_ideal          31     31
# R1Q_ideal          31     31
# RAL_ideal          31     31
# RAP_ideal          33     33
# RBR_ideal          31     31
# RBT_ideal          33     33
# REA_ideal          31     31
# RIT_ideal          31     31
# RLT_ideal          31     31
# ROC_ideal          31     31
# ROX_ideal          31     31
# RTL_ideal          31     31
# SAM_ideal          31     31
# SCK_ideal          31     31
# SHH_ideal          31     31
# SMX_ideal          31     31
# SPP_ideal          31     31
# SPR_ideal          28     28
# SQL_ideal          31     31
# SRY_ideal          22     22
# STE_ideal          31     31
# STI_ideal          31     31
# SUE_ideal          31     31
# T27_ideal          31     31
# TA1_ideal          31     31
# TAO_ideal          31     31
# TCH_ideal          31     31
# TE4_ideal          10     10
# TEI_ideal          31     31
# TEL_ideal          31     31
# THH_ideal          31     31
# TIQ_ideal          31     31
# TLS_ideal          31     31
# TMQ_ideal          31     31
# TPV_ideal          31     31
# TXL_ideal          31     31
# TZ0_ideal          31     31
# U10_ideal          27     27
# U35_ideal          31     31
# U7V_ideal          31     31
# UGU_ideal          31     31
# USS_ideal          31     31
# V2H_ideal          31     31
# VD3_ideal          31     31
# VDN_ideal          31     31
# VDX_ideal          31     31
# VDY_ideal          31     31
# VGH_ideal          32     32
# VH6_ideal          32     32
# VIA_ideal          21     21
# VIS_ideal          31     31
# VIV_ideal          31     31
# VLB_ideal          21     21
# VNZ_ideal          21     21
# VPX_ideal          21     21
# VT1_ideal          31     31
# VX7_ideal          31     31
# WJX_ideal          31     31
# WPP_ideal          27     27
# WV2_ideal          27     27
# X2N_ideal          27     27
# X3N_ideal          27     27
# X56_ideal          27     27
# XB7_ideal          27     27
# XC9_ideal          27     27
# XEF_ideal          27     27
# XIN_ideal          27     27
# XPG_ideal          27     27
# XQQ_ideal          27     27
# XRA_ideal          27     27
# Y7W_ideal          27     27
# Y9J_ideal          27     27
# YG7_ideal          27     27
# YHR_ideal          21     21
# YLX_ideal          21     21
# YMX_ideal          21     21
# YP4_ideal          21     21
# YY3_ideal          32     32
# Z6V_ideal          32     32
# ZD6_ideal          32     32
# ZIT_ideal          27     27
# ZLD_ideal          27     27
# ZLK_ideal          27     27
#
# ----------------------------------------------------------------------------------------------------
# POSES BY PROTEIN
# ----------------------------------------------------------------------------------------------------
#                               Diffdock  Total
# Protein
# Orai1WT-MDSnap-Fr300_cleaned      3179   3179
# Orai1WT-MDSnap-Fr400_cleaned      2975   2975
# Orai1WT-MDSnap-Fr499_cleaned      2796   2796
# Orai1WT-START-Fr0_cleaned         1551   1551
#
# ====================================================================================================
# Table saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
# ====================================================================================================

# %%
"""
Filter Poses: Keep Only Protein-Ligand Combinations Docked in ALL Methods
==========================================================================
This cell filters the results to include only protein-ligand combinations
that have poses from every docking method defined in `docking_directories`.
"""

# ============================================================================
# POSE COLLECTORS — return list of row dicts for each method
# ============================================================================

def collect_autodock_rows(poses_dir):
    """Collect per-file rows from AutoDock Vina PDBQT outputs."""
    rows = []
    base_path = Path(poses_dir)
    for pdbqt_file in base_path.glob("*_vina_out.pdbqt"):
        stem = pdbqt_file.stem.replace("_vina_out", "")
        parts = stem.split("__")
        if len(parts) == 2:
            protein, ligand = parts
            with open(pdbqt_file, 'r') as f:
                content = f.read()
                pose_count = content.count('MODEL')
                if pose_count == 0:
                    pose_count = 1
            rows.append({
                "docking_tool": "autodock",
                "protein": protein,
                "ligand": ligand,
                "file_path": str(pdbqt_file),
                "pose_count": pose_count
            })
    return rows


def collect_diffdock_rows(poses_dir):
    """Collect per-directory rows from DiffDock SDF outputs."""
    rows = []
    base_path = Path(poses_dir)
    for subdir in base_path.iterdir():
        if not subdir.is_dir():
            continue
        if "_ligand__" in subdir.name or subdir.name in [
            "prepared_proteins", "converted_pdbqt", "prepared_ligands", "Orai"
        ]:
            continue
        parts = subdir.name.split("__")
        if len(parts) == 2:
            ligand, protein = parts
            pose_count = len(list(subdir.glob("**/*.sdf")))
            if pose_count > 0:
                rows.append({
                    "docking_tool": "diffdock",
                    "protein": protein,
                    "ligand": ligand,
                    "file_path": str(subdir),
                    "pose_count": pose_count
                })
    return rows


def collect_equibind_rows(poses_dir):
    """Collect per-directory rows from EquiBind SDF outputs."""
    rows = []
    base_path = Path(poses_dir)
    for subdir in base_path.iterdir():
        if not subdir.is_dir() or "_pymol" in subdir.name:
            continue
        dir_name = subdir.name
        if dir_name.endswith("_spatial_sites"):
            dir_name_clean = dir_name.replace("_spatial_sites", "")
        else:
            dir_name_clean = dir_name
        parts = dir_name_clean.split("__")
        if len(parts) == 2:
            ligand, protein = parts
            pose_count = len(list(subdir.glob("**/*.sdf")))
            if pose_count > 0:
                rows.append({
                    "docking_tool": dir_name.split("__")[0] if "__" in dir_name else "equibind",
                    "protein": protein,
                    "ligand": ligand,
                    "file_path": str(subdir),
                    "pose_count": pose_count
                })
    return rows


# Registry: maps docking_directories keys → collector functions
ROW_COLLECTORS = {
    "autodock": collect_autodock_rows,
    "diffdock": collect_diffdock_rows,
    "equibind_guided": collect_equibind_rows,
    "equibind_exclusion": collect_equibind_rows,
    "equibind_docked_poses": collect_equibind_rows,
}

# ============================================================================
# BUILD filtered_poses_df driven by docking_directories
# ============================================================================
rows = []
for method_key, poses_dir in docking_directories.items():
    collector = ROW_COLLECTORS.get(method_key)
    if collector is None:
        print(f"  WARNING: No row collector for '{method_key}', skipping.")
        continue
    if not Path(poses_dir).exists():
        print(f"  WARNING: Directory not found for '{method_key}': {poses_dir}, skipping.")
        continue
    method_rows = collector(poses_dir)
    # Tag every row with the dictionary key as docking_tool
    for r in method_rows:
        r["docking_tool"] = method_key
    rows.extend(method_rows)

filtered_poses_df = pd.DataFrame(rows)
print(f"Total entries: {len(filtered_poses_df)}")
if not filtered_poses_df.empty:
    print(f"Methods found: {filtered_poses_df['docking_tool'].unique().tolist()}")

# ============================================================================
# FILTER: keep only protein-ligand combos present in ALL methods
# ============================================================================
if not filtered_poses_df.empty:
    combos_by_method = {}
    for method in filtered_poses_df["docking_tool"].unique():
        method_df = filtered_poses_df[filtered_poses_df["docking_tool"] == method]
        combos = set(zip(method_df["protein"], method_df["ligand"]))
        combos_by_method[method] = combos

    print("=" * 100)
    print("FILTERING: Keep Only Protein-Ligand Combinations in ALL Methods")
    print("=" * 100)

    print(f"\nProtein-ligand combinations per method:")
    for method, combos in combos_by_method.items():
        print(f"  {method}: {len(combos)} combinations")

    # Intersection across all methods
    all_combo_sets = list(combos_by_method.values())
    common_combos = all_combo_sets[0]
    for s in all_combo_sets[1:]:
        common_combos = common_combos.intersection(s)

    print(f"\nProtein-ligand combinations in ALL methods: {len(common_combos)}")

    if common_combos:
        print("\nCommon combinations:")
        for protein, ligand in sorted(common_combos):
            print(f"  {protein} + {ligand}")

        # Filter to common combos only
        filtered_poses_df = filtered_poses_df[
            filtered_poses_df.apply(
                lambda row: (row["protein"], row["ligand"]) in common_combos,
                axis=1
            )
        ].copy()

        print(f"\n{'-' * 100}")
        print("FILTERED SUBSET (All Methods)")
        print(f"{'-' * 100}")

        for method in filtered_poses_df["docking_tool"].unique():
            method_df = filtered_poses_df[filtered_poses_df["docking_tool"] == method]
            print(f"\n{method}:")
            print(f"  Combinations: {len(method_df)}")
            print(f"  Total poses: {method_df['pose_count'].sum():,}")

        print(f"\n{'=' * 100}")
        print("filtered_poses_df updated to contain only combinations present in all methods")
        print(f"{'=' * 100}")

        # =================================================================
        # DETAILED SUMMARY
        # =================================================================
        print(f"\n{'=' * 100}")
        print("DETAILED SUMMARY: Poses Kept per Combination per Docking Method")
        print(f"{'=' * 100}")

        methods_in_df = sorted(filtered_poses_df["docking_tool"].unique())
        header = f"{'Protein':<35} {'Ligand':<30}" + "".join(f" {m:>15}" for m in methods_in_df) + f" {'Total':>10}"
        print(f"\n{header}")
        print("-" * len(header))

        grand_totals = {m: 0 for m in methods_in_df}
        grand_total_all = 0

        for protein, ligand in sorted(common_combos):
            row_str = f"{protein:<35} {ligand:<30}"
            row_total = 0
            for method in methods_in_df:
                count = filtered_poses_df[
                    (filtered_poses_df["protein"] == protein) &
                    (filtered_poses_df["ligand"] == ligand) &
                    (filtered_poses_df["docking_tool"] == method)
                ]["pose_count"].sum()
                row_str += f" {count:>15,}"
                row_total += count
                grand_totals[method] += count
            row_str += f" {row_total:>10,}"
            grand_total_all += row_total
            print(row_str)

        print("-" * len(header))
        totals_str = f"{'TOTAL':<35} {'':<30}"
        for method in methods_in_df:
            totals_str += f" {grand_totals[method]:>15,}"
        totals_str += f" {grand_total_all:>10,}"
        print(totals_str)

        print(f"\nFinal filtered_poses_df shape: {filtered_poses_df.shape}")
        print(f"Unique combinations kept: {len(common_combos)}")
        print(f"Total poses across all methods: {grand_total_all:,}")
    else:
        print("\nWARNING: No protein-ligand combinations found in all methods!")
        print("Cannot filter further. Keeping current filtered_poses_df.")
else:
    print("filtered_poses_df is empty. Check docking_directories paths.")
# Out:
# Total entries: 1071
# Methods found: ['diffdock']
# ====================================================================================================
# FILTERING: Keep Only Protein-Ligand Combinations in ALL Methods
# ====================================================================================================
#
# Protein-ligand combinations per method:
#   diffdock: 1071 combinations
#
# Protein-ligand combinations in ALL methods: 1071
#
# Common combinations:
#   Orai1WT-MDSnap-Fr300_cleaned + 017_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 032_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 04J_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 07J_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 08Y_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 09L_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 0LI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 0RI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 0WM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 0XZ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 10A_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 115_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 116_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 117_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 15M_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 16A_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 1C9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 1E8_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 1II_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 1LT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 1N1_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 1UN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 2GM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 2K2_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 2R9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 2RC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 2TA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 30B_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 336_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 356_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 3E8_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 3QB_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 4CC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 4DY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 4MK_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 4UH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 5D5_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 5SF_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 5X6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 62B_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 69Q_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6E2_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6GY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6I6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6K9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6T3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6ZV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 6ZZ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 715_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 71R_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 7KD_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 7R3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 7RU_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 7V7_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 7WT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 87Q_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 8HO_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 8NU_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 8ZF_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 92S_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 9JI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 9NQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 9SC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + 9TP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1AAC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1APA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1B7W_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1CMV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1D5I_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1EAY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1EAZ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1ECE_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1EKL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1EQV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1ESA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1ESZ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1IPH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1IT8_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1IVJ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1IVL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1JRF_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1JS8_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1JTY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1L11_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A1LXP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A4I_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + A9L_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AB1_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ACD_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AGG_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AKN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ALW_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AOQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AQ4_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AV9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AXI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AY6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + AY7_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + B49_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + BAX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + BBI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + BLM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + C04_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + C3D_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + C41_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + C6F_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + C87_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CC9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CDC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CE3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CE9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CHC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CHD_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CLR_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CLS_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CLY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CNY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CP0_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CQA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CU9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + CV6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + D16_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + D2V_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + D7D_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DB8_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DEQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DGX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DID_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DLU_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DME_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DN0_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DOL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DR7_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DXC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + DZQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + E6L_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ECT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + EDS_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + EIC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ELA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + EMH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + EPA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ERG_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ERM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ERY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + EVP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + F9R_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FAD_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FBI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FBX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FFO_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FI8_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FK5_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FMM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FMN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + FOL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + G34_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GBM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GDS_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GG2_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GMJ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GSH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GZO_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + GZX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + H56_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + H6U_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + HU5_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + HWL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + HXA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ICQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + IDB_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + IRE_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + IU5_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + IUD_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + IV3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + J8C_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + JC6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + JEU_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + JHN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + JQ9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + K5O_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + K86_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + KKB_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + KLN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + KLQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + KOV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + KTN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + KTY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + L3R_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + L9P_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + LBH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + LBM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + LE6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + LEV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + LNL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + LYA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + M9B_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MEM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MIX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MK1_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MRC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MRV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MTK_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MTX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MUO_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + MWV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + N8R_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + N90_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + NAI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + NIL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + NMY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + NOV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + O31_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + O6P_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + O6U_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + OBN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + OQ4_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + P2E_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + P30_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + P31_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + P5S_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PAR_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PL3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PLM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PNT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PQN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PV9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + PX9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + Q4J_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + QCM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + QKM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + QNG_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + QOM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + QOP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + QWP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + R1L_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + R1Q_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RAL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RAP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RBR_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RBT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + REA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RIT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RLT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ROC_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ROX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + RTL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SAM_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SCK_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SHH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SMX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SPP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SPR_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SQL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SRY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + STE_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + STI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + SUE_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + T27_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TA1_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TAO_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TCH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TE4_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TEI_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TEL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + THH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TIQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TLS_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TMQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TPV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TXL_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + TZ0_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + U10_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + U35_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + U7V_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + UGU_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + USS_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + V2H_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VD3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VDN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VDX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VDY_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VGH_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VH6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VIA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VIS_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VIV_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VLB_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VNZ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VPX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VT1_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + VX7_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + WJX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + WPP_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + WV2_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + X2N_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + X3N_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + X56_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XB7_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XC9_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XEF_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XIN_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XPG_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XQQ_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + XRA_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + Y7W_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + Y9J_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + YG7_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + YHR_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + YLX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + YMX_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + YP4_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + YY3_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + Z6V_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ZD6_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ZIT_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ZLD_ideal
#   Orai1WT-MDSnap-Fr300_cleaned + ZLK_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 017_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 032_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 04J_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 07J_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 08Y_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 09L_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 0LI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 0RI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 0WM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 0XZ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 10A_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 115_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 116_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 117_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 15M_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 16A_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 1C9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 1E8_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 1II_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 1LT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 1N1_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 1UN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 2GM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 2K2_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 2R9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 2RC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 2TA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 30B_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 336_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 356_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 3E8_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 3QB_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 4CC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 4DY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 4MK_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 4UH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 5D5_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 5SF_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 5X6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 62B_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 69Q_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6E2_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6GY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6I6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6K9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6T3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6ZV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 6ZZ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 715_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 71R_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 7KD_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 7R3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 7RU_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 7V7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 7WT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 87Q_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 8HO_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 8NU_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 8ZF_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 92S_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 9JI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 9NQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 9SC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + 9TP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1AAC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1APA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1AZ7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1B7W_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1CMV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1D5I_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1EAY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1EAZ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1ECE_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1EKL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1EQV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1ESA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1ESZ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1IPH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1IT8_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1IVJ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1IVL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1JRF_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1JS8_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1JTY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1L11_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A1LXP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A4I_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + A9L_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AB1_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ACD_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AGG_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AKN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ALW_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AOQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AQ4_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AV9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AXI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AY6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + AY7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + B49_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + BAX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + BBI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + C04_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + C3D_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + C41_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + C6F_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + C87_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CC9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CDC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CE3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CE9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CHC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CHD_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CLR_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CLS_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CLY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CNY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CP0_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CQA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CU9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + CV6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + D16_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + D2V_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + D7D_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DB8_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DEQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DLU_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DME_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DN0_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DOL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DR7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DXC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + DZQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + E6L_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ECT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + EDS_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + EIC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ELA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + EMH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + EPA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ERG_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ERM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ERY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + EVP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + F9R_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FAD_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FBI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FBX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FFO_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FI8_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FK5_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FMM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FMN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + FOL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + G34_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + GBM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + GG2_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + GMJ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + GSH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + GZO_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + GZX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + H56_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + H6U_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + HU5_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + HWL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + HXA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + I0V_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ICQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + IDB_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + IRE_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + IU5_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + IUD_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + IV3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + J8C_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + JC6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + JEU_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + JHN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + JQ9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + K5O_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + K86_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + KKB_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + KLN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + KLQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + KOV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + KTN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + KTY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + L3R_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + L9P_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LBH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LBM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LE6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LEV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LFL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LNL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + LYA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + M9B_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MEM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MIX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MK1_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MRC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MRV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MTK_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MTX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MUO_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + MWV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + N8R_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + N90_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + NAI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + NIL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + NMY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + NOV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + O31_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + O6P_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + O6U_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + OBN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + OQ4_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + P2E_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + P30_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + P31_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + P5S_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + PAR_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + PL3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + PLM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + PQN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + PV9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + PX9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + Q4J_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + QCM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + QKM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + QNG_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + QOM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + QOP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + QWP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + R1L_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + R1Q_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RAL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RAP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RBR_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RBT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + REA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RIT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RLT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ROC_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ROX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + RTL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SAM_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SCK_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SHH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SMX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SPP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SPR_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SQL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + STE_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + STI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + SUE_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + T27_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TA1_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TAO_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TCH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TEI_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TEL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + THH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TIQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TLS_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TMQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TPV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TXL_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + TZ0_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + U10_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + U35_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + U7V_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + UGU_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + USS_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + V2H_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VD3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VDN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VDX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VDY_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VGH_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VH6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VIS_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VIV_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VT1_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + VX7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + WJX_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + WPP_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + WV2_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + X2N_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + X3N_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + X56_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XB7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XC9_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XEF_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XIN_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XPG_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XQQ_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + XRA_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + Y7W_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + Y9J_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + YG7_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + YY3_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + Z6V_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ZD6_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ZIT_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ZLD_ideal
#   Orai1WT-MDSnap-Fr400_cleaned + ZLK_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 017_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 032_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 04J_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 07J_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 08Y_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 09L_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 0LI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 0RI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 0WM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 0XZ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 10A_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 115_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 116_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 117_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 15M_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 16A_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 1C9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 1E8_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 1II_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 1LT_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 1N1_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 1UN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 2GM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 2K2_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 2R9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 2RC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 2TA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 30B_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 336_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 356_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 3E8_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 3QB_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 4CC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 4DY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 4MK_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 4UH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 5D5_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 5SF_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 5X6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 62B_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 69Q_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6E2_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6GY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6I6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6K9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6T3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6ZV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 6ZZ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 715_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 71R_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 7KD_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 7R3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 7RU_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 7V7_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 7WT_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 87Q_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 8HO_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 8NU_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 8ZF_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 92S_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 9JI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 9NQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 9SC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + 9TP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1AAC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1APA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1B7W_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1CMV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1D5I_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1EAY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1EAZ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1ECE_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1EKL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1EQV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1ESA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1ESZ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1IPH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1IT8_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1IVJ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1IVL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1JRF_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1JS8_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1JTY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1L11_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A1LXP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A4I_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + A9L_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AB1_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ACD_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AGG_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AKN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ALW_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AOQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AQ4_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AV9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AXI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AY6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + AY7_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + B49_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + BAX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + BBI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + C04_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + C3D_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + C41_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + C6F_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + C87_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CC9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CDC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CE3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CE9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CHC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CHD_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CLR_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CLS_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CLY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CNY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CP0_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CQA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CU9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + CV6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + D16_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DLU_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DME_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DN0_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DOL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DR7_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DXC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + DZQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + E6L_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + EIC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ELA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + EMH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + EPA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ERG_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ERM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ERY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + EVP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + F9R_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FAD_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FBI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FBX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FFO_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FI8_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FK5_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FMM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FMN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + FOL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + G34_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + GBM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + GG2_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + GMJ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + GSH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + GZO_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + GZX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + H56_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + H6U_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + HU5_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + HWL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + HXA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ICQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + IDB_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + IRE_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + IU5_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + IUD_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + IV3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + J8C_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + JC6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + JEU_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + JHN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + JQ9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + K5O_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + K86_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + KKB_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + KLN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + KLQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + KOV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + KTN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + KTY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + L3R_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + L9P_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LBH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LBM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LE6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LEV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LFL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LNL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + LYA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + M9B_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MEM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MIX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MK1_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MRC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MRV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MTK_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MTX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + MUO_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + N8R_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + N90_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + NAI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + NIL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + NMY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + NOV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + O31_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + O6P_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + O6U_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + OBN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + OQ4_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + P2E_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + P30_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + P31_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + P5S_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + PAR_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + PL3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + PLM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + PQN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + PV9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + PX9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + Q4J_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + QCM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + QKM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + QNG_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + QOM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + QOP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + QWP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + R1L_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + R1Q_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RAL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RAP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RBR_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RBT_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + REA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RIT_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RLT_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ROC_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ROX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + RTL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SAM_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SCK_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SHH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SMX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SPP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SPR_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SQL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SRY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + STE_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + STI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + SUE_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + T27_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TA1_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TAO_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TCH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TEI_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TEL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + THH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TIQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TLS_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TMQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TPV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TXL_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + TZ0_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + U10_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + U35_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + U7V_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + UGU_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + USS_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + V2H_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VD3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VDN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VDX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VDY_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VGH_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VH6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VIA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VIS_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VIV_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VLB_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VNZ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VPX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VT1_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + VX7_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + WJX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + WPP_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + WV2_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + X2N_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + X3N_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + X56_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XB7_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XC9_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XEF_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XIN_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XPG_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XQQ_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + XRA_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + Y7W_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + Y9J_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + YG7_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + YHR_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + YLX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + YMX_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + YP4_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + YY3_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + Z6V_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ZD6_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ZIT_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ZLD_ideal
#   Orai1WT-MDSnap-Fr499_cleaned + ZLK_ideal
#   Orai1WT-START-Fr0_cleaned + 017_ideal
#   Orai1WT-START-Fr0_cleaned + 032_ideal
#   Orai1WT-START-Fr0_cleaned + 04J_ideal
#   Orai1WT-START-Fr0_cleaned + 07J_ideal
#   Orai1WT-START-Fr0_cleaned + 08Y_ideal
#   Orai1WT-START-Fr0_cleaned + 09L_ideal
#   Orai1WT-START-Fr0_cleaned + 0LI_ideal
#   Orai1WT-START-Fr0_cleaned + 0RI_ideal
#   Orai1WT-START-Fr0_cleaned + 0WM_ideal
#   Orai1WT-START-Fr0_cleaned + 0XZ_ideal
#   Orai1WT-START-Fr0_cleaned + 10A_ideal
#   Orai1WT-START-Fr0_cleaned + 115_ideal
#   Orai1WT-START-Fr0_cleaned + 116_ideal
#   Orai1WT-START-Fr0_cleaned + 117_ideal
#   Orai1WT-START-Fr0_cleaned + 15M_ideal
#   Orai1WT-START-Fr0_cleaned + 16A_ideal
#   Orai1WT-START-Fr0_cleaned + 1C9_ideal
#   Orai1WT-START-Fr0_cleaned + 1E8_ideal
#   Orai1WT-START-Fr0_cleaned + 1II_ideal
#   Orai1WT-START-Fr0_cleaned + 1LT_ideal
#   Orai1WT-START-Fr0_cleaned + 1N1_ideal
#   Orai1WT-START-Fr0_cleaned + 1UN_ideal
#   Orai1WT-START-Fr0_cleaned + 2GM_ideal
#   Orai1WT-START-Fr0_cleaned + 2K2_ideal
#   Orai1WT-START-Fr0_cleaned + 2R9_ideal
#   Orai1WT-START-Fr0_cleaned + 2RC_ideal
#   Orai1WT-START-Fr0_cleaned + 2TA_ideal
#   Orai1WT-START-Fr0_cleaned + 30B_ideal
#   Orai1WT-START-Fr0_cleaned + 336_ideal
#   Orai1WT-START-Fr0_cleaned + 356_ideal
#   Orai1WT-START-Fr0_cleaned + 3E8_ideal
#   Orai1WT-START-Fr0_cleaned + 3QB_ideal
#   Orai1WT-START-Fr0_cleaned + 4CC_ideal
#   Orai1WT-START-Fr0_cleaned + 4DY_ideal
#   Orai1WT-START-Fr0_cleaned + 4MK_ideal
#   Orai1WT-START-Fr0_cleaned + 4UH_ideal
#   Orai1WT-START-Fr0_cleaned + 5D5_ideal
#   Orai1WT-START-Fr0_cleaned + 5SF_ideal
#   Orai1WT-START-Fr0_cleaned + 5X6_ideal
#   Orai1WT-START-Fr0_cleaned + 62B_ideal
#   Orai1WT-START-Fr0_cleaned + 69Q_ideal
#   Orai1WT-START-Fr0_cleaned + 6E2_ideal
#   Orai1WT-START-Fr0_cleaned + 6GY_ideal
#   Orai1WT-START-Fr0_cleaned + 6I6_ideal
#   Orai1WT-START-Fr0_cleaned + 6K9_ideal
#   Orai1WT-START-Fr0_cleaned + 6T3_ideal
#   Orai1WT-START-Fr0_cleaned + 6ZV_ideal
#   Orai1WT-START-Fr0_cleaned + 6ZZ_ideal
#   Orai1WT-START-Fr0_cleaned + 715_ideal
#   Orai1WT-START-Fr0_cleaned + 71R_ideal
#   Orai1WT-START-Fr0_cleaned + 7KD_ideal
#   Orai1WT-START-Fr0_cleaned + 7R3_ideal
#   Orai1WT-START-Fr0_cleaned + 7RU_ideal
#   Orai1WT-START-Fr0_cleaned + 7V7_ideal
#   Orai1WT-START-Fr0_cleaned + 7WT_ideal
#   Orai1WT-START-Fr0_cleaned + 87Q_ideal
#   Orai1WT-START-Fr0_cleaned + 8HO_ideal
#   Orai1WT-START-Fr0_cleaned + 8NU_ideal
#   Orai1WT-START-Fr0_cleaned + 8ZF_ideal
#   Orai1WT-START-Fr0_cleaned + 92S_ideal
#   Orai1WT-START-Fr0_cleaned + 9JI_ideal
#   Orai1WT-START-Fr0_cleaned + 9NQ_ideal
#   Orai1WT-START-Fr0_cleaned + 9SC_ideal
#   Orai1WT-START-Fr0_cleaned + 9TP_ideal
#   Orai1WT-START-Fr0_cleaned + A1AAC_ideal
#   Orai1WT-START-Fr0_cleaned + A1APA_ideal
#   Orai1WT-START-Fr0_cleaned + A1B7W_ideal
#   Orai1WT-START-Fr0_cleaned + A1CMV_ideal
#   Orai1WT-START-Fr0_cleaned + A1D5I_ideal
#   Orai1WT-START-Fr0_cleaned + A1EAY_ideal
#   Orai1WT-START-Fr0_cleaned + A1EAZ_ideal
#   Orai1WT-START-Fr0_cleaned + A1ECE_ideal
#   Orai1WT-START-Fr0_cleaned + A1EKL_ideal
#   Orai1WT-START-Fr0_cleaned + A1EQV_ideal
#   Orai1WT-START-Fr0_cleaned + A1ESA_ideal
#   Orai1WT-START-Fr0_cleaned + A1ESZ_ideal
#   Orai1WT-START-Fr0_cleaned + A1IPH_ideal
#   Orai1WT-START-Fr0_cleaned + A1IT8_ideal
#   Orai1WT-START-Fr0_cleaned + A1IVJ_ideal
#   Orai1WT-START-Fr0_cleaned + A1IVL_ideal
#   Orai1WT-START-Fr0_cleaned + A1JRF_ideal
#   Orai1WT-START-Fr0_cleaned + A1JS8_ideal
#   Orai1WT-START-Fr0_cleaned + A1JTY_ideal
#   Orai1WT-START-Fr0_cleaned + A1L11_ideal
#   Orai1WT-START-Fr0_cleaned + A1LXP_ideal
#   Orai1WT-START-Fr0_cleaned + A4I_ideal
#   Orai1WT-START-Fr0_cleaned + A9L_ideal
#   Orai1WT-START-Fr0_cleaned + AB1_ideal
#   Orai1WT-START-Fr0_cleaned + ACD_ideal
#   Orai1WT-START-Fr0_cleaned + AGG_ideal
#   Orai1WT-START-Fr0_cleaned + ALW_ideal
#   Orai1WT-START-Fr0_cleaned + AOQ_ideal
#   Orai1WT-START-Fr0_cleaned + AQ4_ideal
#   Orai1WT-START-Fr0_cleaned + AV9_ideal
#   Orai1WT-START-Fr0_cleaned + AXI_ideal
#   Orai1WT-START-Fr0_cleaned + AY6_ideal
#   Orai1WT-START-Fr0_cleaned + AY7_ideal
#   Orai1WT-START-Fr0_cleaned + B49_ideal
#   Orai1WT-START-Fr0_cleaned + BAX_ideal
#   Orai1WT-START-Fr0_cleaned + BBI_ideal
#   Orai1WT-START-Fr0_cleaned + C04_ideal
#   Orai1WT-START-Fr0_cleaned + C3D_ideal
#   Orai1WT-START-Fr0_cleaned + C41_ideal
#   Orai1WT-START-Fr0_cleaned + C6F_ideal
#   Orai1WT-START-Fr0_cleaned + C87_ideal
#   Orai1WT-START-Fr0_cleaned + CC9_ideal
#   Orai1WT-START-Fr0_cleaned + CDC_ideal
#   Orai1WT-START-Fr0_cleaned + CE3_ideal
#   Orai1WT-START-Fr0_cleaned + CE9_ideal
#   Orai1WT-START-Fr0_cleaned + CHC_ideal
#   Orai1WT-START-Fr0_cleaned + CHD_ideal
#   Orai1WT-START-Fr0_cleaned + CLR_ideal
#   Orai1WT-START-Fr0_cleaned + CLS_ideal
#   Orai1WT-START-Fr0_cleaned + CLY_ideal
#   Orai1WT-START-Fr0_cleaned + CNY_ideal
#   Orai1WT-START-Fr0_cleaned + CP0_ideal
#   Orai1WT-START-Fr0_cleaned + CQA_ideal
#   Orai1WT-START-Fr0_cleaned + CU9_ideal
#   Orai1WT-START-Fr0_cleaned + CV6_ideal
#   Orai1WT-START-Fr0_cleaned + D16_ideal
#   Orai1WT-START-Fr0_cleaned + D2V_ideal
#   Orai1WT-START-Fr0_cleaned + D7D_ideal
#   Orai1WT-START-Fr0_cleaned + DB8_ideal
#   Orai1WT-START-Fr0_cleaned + DEQ_ideal
#   Orai1WT-START-Fr0_cleaned + DLU_ideal
#   Orai1WT-START-Fr0_cleaned + DME_ideal
#   Orai1WT-START-Fr0_cleaned + DN0_ideal
#   Orai1WT-START-Fr0_cleaned + DOL_ideal
#   Orai1WT-START-Fr0_cleaned + DR7_ideal
#   Orai1WT-START-Fr0_cleaned + DXC_ideal
#   Orai1WT-START-Fr0_cleaned + DZQ_ideal
#   Orai1WT-START-Fr0_cleaned + E6L_ideal
#   Orai1WT-START-Fr0_cleaned + ECT_ideal
#   Orai1WT-START-Fr0_cleaned + EDS_ideal
#   Orai1WT-START-Fr0_cleaned + EIC_ideal
#   Orai1WT-START-Fr0_cleaned + ELA_ideal
#   Orai1WT-START-Fr0_cleaned + EMH_ideal
#   Orai1WT-START-Fr0_cleaned + EPA_ideal
#   Orai1WT-START-Fr0_cleaned + ERG_ideal
#   Orai1WT-START-Fr0_cleaned + ERM_ideal
#   Orai1WT-START-Fr0_cleaned + ERY_ideal
#
# ----------------------------------------------------------------------------------------------------
# FILTERED SUBSET (All Methods)
# ----------------------------------------------------------------------------------------------------
#
# diffdock:
#   Combinations: 1071
#   Total poses: 10,501
#
# ====================================================================================================
# filtered_poses_df updated to contain only combinations present in all methods
# ====================================================================================================
#
# ====================================================================================================
# DETAILED SUMMARY: Poses Kept per Combination per Docking Method
# ====================================================================================================
#
# Protein                             Ligand                                diffdock      Total
# ---------------------------------------------------------------------------------------------
# Orai1WT-MDSnap-Fr300_cleaned        017_ideal                                   10         10
# Orai1WT-MDSnap-Fr300_cleaned        032_ideal                                   10         10
# Orai1WT-MDSnap-Fr300_cleaned        04J_ideal                                   10         10
# Orai1WT-MDSnap-Fr300_cleaned        07J_ideal                                   10         10
# Orai1WT-MDSnap-Fr300_cleaned        08Y_ideal                                   10         10
# Orai1WT-MDSnap-Fr300_cleaned        09L_ideal                                   10         10
# Orai1WT-MDSnap-Fr300_cleaned        0LI_ideal                                   10         10
# ...
# Orai1WT-MDSnap-Fr499_cleaned        WJX_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        WPP_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        WV2_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        X2N_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        X3N_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        X56_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XB7_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XC9_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XEF_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XIN_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XPG_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XQQ_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        XRA_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        Y7W_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        Y9J_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        YG7_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        YHR_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        YLX_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        YMX_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        YP4_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        YY3_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        Z6V_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        ZD6_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        ZIT_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        ZLD_ideal                                   11         11
# Orai1WT-MDSnap-Fr499_cleaned        ZLK_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           017_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           032_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           04J_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           07J_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           08Y_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           09L_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           0LI_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           0RI_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           0WM_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           0XZ_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           10A_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           115_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           116_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           117_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           15M_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           16A_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           1C9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           1E8_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           1II_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           1LT_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           1N1_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           1UN_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           2GM_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           2K2_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           2R9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           2RC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           2TA_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           30B_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           336_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           356_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           3E8_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           3QB_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           4CC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           4DY_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           4MK_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           4UH_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           5D5_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           5SF_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           5X6_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           62B_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           69Q_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6E2_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6GY_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6I6_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6K9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6T3_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6ZV_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           6ZZ_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           715_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           71R_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           7KD_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           7R3_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           7RU_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           7V7_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           7WT_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           87Q_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           8HO_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           8NU_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           8ZF_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           92S_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           9JI_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           9NQ_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           9SC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           9TP_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           A1AAC_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1APA_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1B7W_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1CMV_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1D5I_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1EAY_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1EAZ_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1ECE_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1EKL_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1EQV_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1ESA_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1ESZ_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1IPH_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1IT8_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1IVJ_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1IVL_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1JRF_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1JS8_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1JTY_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1L11_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A1LXP_ideal                                 11         11
# Orai1WT-START-Fr0_cleaned           A4I_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           A9L_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AB1_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ACD_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AGG_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ALW_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AOQ_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AQ4_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AV9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AXI_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AY6_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           AY7_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           B49_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           BAX_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           BBI_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           C04_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           C3D_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           C41_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           C6F_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           C87_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CC9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CDC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CE3_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CE9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CHC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CHD_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CLR_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CLS_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CLY_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CNY_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CP0_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CQA_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CU9_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           CV6_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           D16_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           D2V_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           D7D_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DB8_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DEQ_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DLU_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DME_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DN0_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DOL_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DR7_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DXC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           DZQ_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           E6L_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ECT_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           EDS_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           EIC_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ELA_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           EMH_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           EPA_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ERG_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ERM_ideal                                   11         11
# Orai1WT-START-Fr0_cleaned           ERY_ideal                                   11         11
# ---------------------------------------------------------------------------------------------
# TOTAL                                                                       10,501     10,501
#
# Final filtered_poses_df shape: (1071, 5)
# Unique combinations kept: 1071
# Total poses across all methods: 10,501

# %%
"""
PoseBusters Analysis - Validate docked poses from the FILTERED SUBSET only
Checks: molecule validity, stereochemistry, bond geometry, ring flatness, etc.

NOTE: This cell uses the filtered_poses_df from the previous cell to only validate
poses that match the defined prefix/postfix filter criteria.
"""
import os
import subprocess
import re
import pandas as pd
from pathlib import Path
from posebusters import PoseBusters

# ============================================================================
# DISCOVER AVAILABLE PROTEIN FILES
# ============================================================================
proteins_base = Path(proteins_dir)
all_protein_pdbs = sorted(proteins_base.glob("**/*.pdb"))

print("=" * 80)
print("AVAILABLE PROTEIN PDB FILES")
print("=" * 80)
for pdb in all_protein_pdbs:
    print(f"  {pdb.relative_to(proteins_base)}")
print(f"\nTotal: {len(all_protein_pdbs)} PDB files found in {proteins_base}")


def find_protein_file(protein_name: str) -> str | None:
    """
    Find the PDB file for a given protein name by searching the proteins directory.
    """
    # Strategy 1: Exact match
    exact_candidates = [
        proteins_base / f"{protein_name}.pdb",
        proteins_base / f"{protein_name}_protein.pdb",
        proteins_base / f"{protein_name}_clean.pdb",
        proteins_base / f"{protein_name}_receptor.pdb",
    ]
    for candidate in exact_candidates:
        if candidate.exists():
            return str(candidate)

    # Strategy 2: Recursive exact match
    for candidate_name in [
        f"{protein_name}.pdb",
        f"{protein_name}_protein.pdb",
        f"{protein_name}_clean.pdb",
        f"{protein_name}_receptor.pdb",
    ]:
        matches = list(proteins_base.glob(f"**/{candidate_name}"))
        if matches:
            return str(matches[0])

    # Strategy 3: Recursive glob with protein name as prefix
    matches = list(proteins_base.glob(f"**/{protein_name}*.pdb"))
    if matches:
        matches.sort(key=lambda p: len(p.name))
        return str(matches[0])

    # Strategy 4: Fuzzy - check if protein_name is contained in any PDB filename
    for pdb_file in all_protein_pdbs:
        if protein_name.lower() in pdb_file.stem.lower():
            return str(pdb_file)

    # Strategy 5: Normalized matching
    protein_name_normalized = protein_name.replace("-", "_").lower()
    for pdb_file in all_protein_pdbs:
        pdb_stem_normalized = pdb_file.stem.replace("-", "_").lower()
        if protein_name_normalized == pdb_stem_normalized:
            return str(pdb_file)
        if protein_name_normalized in pdb_stem_normalized:
            return str(pdb_file)

    return None


# Pre-build a protein file lookup cache for all unique protein names
print("\n" + "-" * 80)
print("PROTEIN FILE RESOLUTION")
print("-" * 80)

_protein_file_cache = {}

if 'filtered_poses_df' in dir() and not filtered_poses_df.empty:
    unique_proteins = filtered_poses_df["protein"].unique()
    for pname in sorted(unique_proteins):
        pfile = find_protein_file(pname)
        _protein_file_cache[pname] = pfile
        status = f"✓ {Path(pfile).name}" if pfile else "✗ NOT FOUND"
        print(f"  {pname}: {status}")

    n_found = sum(1 for v in _protein_file_cache.values() if v is not None)
    n_missing = sum(1 for v in _protein_file_cache.values() if v is None)
    print(f"\n  Resolved: {n_found}/{len(unique_proteins)} proteins")
    if n_missing > 0:
        print(f"  WARNING: {n_missing} proteins have no matching PDB file!")
        print(f"  These poses will fall back to 'mol' mode (no intermolecular checks)")

# ============================================================================
# PDBQT CONVERSION FUNCTIONS
# ============================================================================

def split_pdbqt_models(pdbqt_file: str) -> list[str]:
    """Split a multi-model PDBQT file into separate model blocks."""
    with open(pdbqt_file, 'r') as f:
        content = f.read()

    models = []
    current_model = []
    in_model = False

    for line in content.split('\n'):
        if line.startswith('MODEL'):
            in_model = True
            current_model = [line]
        elif line.startswith('ENDMDL'):
            current_model.append(line)
            models.append('\n'.join(current_model))
            current_model = []
            in_model = False
        elif in_model:
            current_model.append(line)

    if not models and content.strip():
        models = [content]

    return models

def convert_pdbqt_to_sdf_files(pdbqt_file: str, output_dir: Path) -> list[str]:
    """
    Convert a multi-pose PDBQT file to multiple SDF files.
    Uses RDKit's AssignBondOrdersFromTemplate to fix bond orders.
    """
    from rdkit import Chem
    from rdkit.Chem import AllChem, rdmolops

    pdbqt_path = Path(pdbqt_file)
    base_name = pdbqt_path.stem

    models = split_pdbqt_models(pdbqt_file)
    if not models:
        print(f"  Warning: No models found in {pdbqt_file}")
        return []

    # Try to find the original ligand SDF to use as bond-order template
    stem_clean = base_name.replace("_vina_out", "")
    parts = stem_clean.split("__")
    template_mol = None

    if len(parts) == 2:
        protein_name, ligand_name = parts
        ligand_search_dirs = [
            Path(wd) / "ligands",
            Path(wd) / "Ligands",
            Path(wd) / "docking_ready_mgltools",
            Path(wd) / "docking_ready_mgltools" / "ligands",
            Path(wd),
        ]

        for search_dir in ligand_search_dirs:
            if not search_dir.exists():
                continue
            for pattern in [
                f"{ligand_name}.sdf",
                f"{ligand_name}_*.sdf",
                f"*{ligand_name}*.sdf",
            ]:
                matches = list(search_dir.glob(pattern))
                if matches:
                    try:
                        template_mol = Chem.MolFromMolFile(str(matches[0]), removeHs=True, sanitize=True)
                        if template_mol is not None:
                            print(f"    Using bond-order template: {matches[0].name}")
                            break
                    except:
                        pass
            if template_mol is not None:
                break

    converted_files = []

    for i, model_content in enumerate(models, start=1):
        temp_pdbqt = output_dir / f"{base_name}_model{i}.pdbqt"
        temp_pdb = output_dir / f"{base_name}_model{i}.pdb"
        output_sdf = output_dir / f"{base_name}_model{i}.sdf"

        if output_sdf.exists():
            converted_files.append(str(output_sdf))
            continue

        with open(temp_pdbqt, 'w') as f:
            f.write(model_content)

        mol_final = None

        # Strategy 1: obabel PDBQT→PDB, then RDKit with template
        if template_mol is not None:
            try:
                result = subprocess.run(
                    ['obabel', str(temp_pdbqt), '-O', str(temp_pdb)],
                    capture_output=True, text=True
                )
                if result.returncode == 0 and temp_pdb.exists():
                    raw_mol = Chem.MolFromPDBFile(str(temp_pdb), removeHs=True, sanitize=False)
                    if raw_mol is not None:
                        try:
                            mol_final = AllChem.AssignBondOrdersFromTemplate(template_mol, raw_mol)
                            Chem.SanitizeMol(mol_final)
                        except Exception as e:
                            print(f"    Template assignment failed for model {i}: {e}")
                            mol_final = None
                if temp_pdb.exists():
                    temp_pdb.unlink()
            except FileNotFoundError:
                pass

        # Strategy 2: Direct obabel PDBQT→SDF (fallback)
        if mol_final is None:
            try:
                result = subprocess.run(
                    ['obabel', str(temp_pdbqt), '-O', str(output_sdf)],
                    capture_output=True, text=True
                )
                if result.returncode == 0 and output_sdf.exists():
                    if template_mol is not None:
                        try:
                            raw_mol = Chem.MolFromMolFile(str(output_sdf), removeHs=True, sanitize=False)
                            if raw_mol is not None:
                                mol_final = AllChem.AssignBondOrdersFromTemplate(template_mol, raw_mol)
                                Chem.SanitizeMol(mol_final)
                        except:
                            converted_files.append(str(output_sdf))
                            if temp_pdbqt.exists():
                                temp_pdbqt.unlink()
                            continue
                    else:
                        converted_files.append(str(output_sdf))
                        if temp_pdbqt.exists():
                            temp_pdbqt.unlink()
                        continue
            except FileNotFoundError:
                try:
                    raw_mol = Chem.MolFromPDBFile(str(temp_pdbqt), removeHs=True, sanitize=False)
                    if raw_mol is not None and template_mol is not None:
                        mol_final = AllChem.AssignBondOrdersFromTemplate(template_mol, raw_mol)
                        Chem.SanitizeMol(mol_final)
                    elif raw_mol is not None:
                        try:
                            Chem.SanitizeMol(raw_mol)
                        except:
                            pass
                        mol_final = raw_mol
                except Exception as e:
                    print(f"    RDKit fallback failed for model {i}: {e}")

        if mol_final is not None:
            writer = Chem.SDWriter(str(output_sdf))
            writer.write(mol_final)
            writer.close()
            if output_sdf.exists():
                converted_files.append(str(output_sdf))
        elif not output_sdf.exists():
            print(f"    Warning: Could not convert model {i} from {pdbqt_path.name}")

        if temp_pdbqt.exists():
            temp_pdbqt.unlink()

    return converted_files


# ============================================================================
# POSE COLLECTION — method-specific logic for gathering individual pose files
# ============================================================================

def collect_autodock_pose_files(row, converted_dir):
    """Collect individual pose files from an AutoDock Vina PDBQT result."""
    poses = []
    file_path = Path(row["file_path"])
    protein = row["protein"]
    ligand = row["ligand"]
    method_key = row["docking_tool"]

    if file_path.exists() and file_path.suffix == ".pdbqt":
        print(f"  Converting {file_path.name} to SDF...")
        sdf_files = convert_pdbqt_to_sdf_files(str(file_path), converted_dir)
        for sdf_file in sdf_files:
            sdf_path = Path(sdf_file)
            model_num = sdf_path.stem.split("_model")[-1] if "_model" in sdf_path.stem else "1"
            poses.append({
                "method": method_key,
                "protein": protein,
                "ligand": ligand,
                "pose_file": sdf_file,
                "pose_name": f"{protein}__{ligand}_pose{model_num}",
                "original_pdbqt": str(file_path),
                "file_format": "sdf"
            })
    return poses


def collect_diffdock_pose_files(row, converted_dir):
    """Collect individual pose files from a DiffDock result directory."""
    poses = []
    file_path = Path(row["file_path"])
    protein = row["protein"]
    ligand = row["ligand"]
    method_key = row["docking_tool"]

    if file_path.is_dir():
        for sdf_file in sorted(file_path.glob("**/*.sdf")):
            confidence = None
            if "confidence" in sdf_file.stem.lower():
                match = re.search(r'confidence[_-]?([\d.]+)', sdf_file.stem, re.IGNORECASE)
                if match:
                    try:
                        confidence = float(match.group(1))
                    except ValueError:
                        pass
            try:
                relative_path = sdf_file.relative_to(file_path)
                pose_name_suffix = str(relative_path)
            except ValueError:
                pose_name_suffix = sdf_file.name

            pose_info = {
                "method": method_key,
                "protein": protein,
                "ligand": ligand,
                "pose_file": str(sdf_file),
                "pose_name": f"{ligand}__{protein}/{pose_name_suffix}",
                "file_format": "sdf"
            }
            if confidence is not None:
                pose_info["confidence"] = confidence
            poses.append(pose_info)
    return poses


def collect_equibind_pose_files(row, converted_dir):
    """Collect individual pose files from an EquiBind result directory."""
    poses = []
    file_path = Path(row["file_path"])
    protein = row["protein"]
    ligand = row["ligand"]
    method_key = row["docking_tool"]

    if file_path.is_dir():
        for sdf_file in sorted(file_path.glob("**/*.sdf")):
            try:
                relative_path = sdf_file.relative_to(file_path)
                pose_name_suffix = str(relative_path)
            except ValueError:
                pose_name_suffix = sdf_file.name

            poses.append({
                "method": method_key,
                "protein": protein,
                "ligand": ligand,
                "pose_file": str(sdf_file),
                "pose_name": f"{ligand}__{protein}/{pose_name_suffix}",
                "file_format": "sdf"
            })
    return poses


# Registry: maps docking_directories keys → pose file collectors
POSE_FILE_COLLECTORS = {
    "autodock": collect_autodock_pose_files,
    "diffdock": collect_diffdock_pose_files,
    "equibind_guided": collect_equibind_pose_files,
    "equibind_exclusion": collect_equibind_pose_files,
    "equibind_docked_poses": collect_equibind_pose_files,
}


def collect_poses_from_filtered_subset(filtered_df: pd.DataFrame) -> list[dict]:
    """
    Collect all individual pose files from the filtered subset DataFrame.
    Dispatches to the correct collector based on the docking_tool column,
    which matches the keys in docking_directories.

    Args:
        filtered_df: DataFrame with columns: docking_tool, protein, ligand, file_path, pose_count

    Returns:
        List of dicts with pose information ready for PoseBusters analysis
    """
    all_poses = []

    for _, row in filtered_df.iterrows():
        method_key = row["docking_tool"]
        collector = POSE_FILE_COLLECTORS.get(method_key)
        if collector is None:
            print(f"  WARNING: No pose file collector for method '{method_key}', skipping.")
            continue
        all_poses.extend(collector(row, converted_dir))

    return all_poses
# Out:
# ================================================================================
# AVAILABLE PROTEIN PDB FILES
# ================================================================================
#   Orai1WT-MDSnap-Fr300_cleaned.pdb
#   Orai1WT-MDSnap-Fr400_cleaned.pdb
#   Orai1WT-MDSnap-Fr499_cleaned.pdb
#   Orai1WT-START-Fr0_cleaned.pdb
#   Original/Orai1WT-MDSnap-Fr300.pdb
#   Original/Orai1WT-MDSnap-Fr400.pdb
#   Original/Orai1WT-MDSnap-Fr499.pdb
#   Original/Orai1WT-START-Fr0.pdb
#   stroed/Orai1WT-MDSnap-Fr300.pdb
#   stroed/Orai1WT-MDSnap-Fr400.pdb
#   stroed/Orai1WT-MDSnap-Fr499.pdb
#   stroed/Orai1WT-START-Fr0.pdb
#
# Total: 12 PDB files found in /home/manndo/master_dev/Orai
#
# --------------------------------------------------------------------------------
# PROTEIN FILE RESOLUTION
# --------------------------------------------------------------------------------
#   Orai1WT-MDSnap-Fr300_cleaned: ✓ Orai1WT-MDSnap-Fr300_cleaned.pdb
#   Orai1WT-MDSnap-Fr400_cleaned: ✓ Orai1WT-MDSnap-Fr400_cleaned.pdb
#   Orai1WT-MDSnap-Fr499_cleaned: ✓ Orai1WT-MDSnap-Fr499_cleaned.pdb
#   Orai1WT-START-Fr0_cleaned: ✓ Orai1WT-START-Fr0_cleaned.pdb
#
#   Resolved: 4/4 proteins

# %% [markdown]
# # PoseBuster Config

# %%
# ============================================================================
# CONFIGURATION
# ============================================================================
# Use "dock" mode (with protein for intermolecular checks) or "mol" mode (ligand only)
CONFIG_MODE = "dock"  # Options: "dock" (with protein), "mol" (ligand only)

# Output directory for results (organized by mode: dock or mol)
output_base_dir = Path(wd) / "posebusters_results"
output_base_dir.mkdir(exist_ok=True)

# Mode-specific output directory
output_dir = output_base_dir / CONFIG_MODE
output_dir.mkdir(exist_ok=True)

# Temporary directory for converted PDBQT files
converted_dir = output_dir / "converted_pdbqt"
converted_dir.mkdir(exist_ok=True)

# Incremental save interval (save results every N poses)
SAVE_INTERVAL = 100

# Set to True to discard previous results and re-run all poses from scratch
OVERWRITE = False

# %% [markdown]
# # PoseBuster Function

# %%
def analyze_poses_with_posebusters(
    poses_list: list[dict],
    config: str = "mol",
    output_file: Path | None = None,
    save_interval: int = 100,
    overwrite: bool = False,
) -> pd.DataFrame:
    """
    Run PoseBusters validation on a list of poses with incremental checkpointing.

    - Saves results to `output_file` every `save_interval` poses.
    - On restart, loads the existing CSV and skips poses already processed
      (matched by `pose_file`), unless `overwrite=True`.
    - If `overwrite=True`, deletes any existing results and starts fresh.

    Args:
        poses_list:    List of dicts with 'pose_file', 'method', 'protein', 'ligand' keys
        config:        PoseBusters config mode ("mol" or "dock")
        output_file:   Path for the results CSV (used for checkpointing)
        save_interval: Save accumulated results every N poses (default 100)
        overwrite:     If True, ignore/delete previous results and re-run everything

    Returns:
        DataFrame with PoseBusters results merged with pose metadata
    """
    if not poses_list:
        print("No poses to analyze!")
        return pd.DataFrame()

    # ------------------------------------------------------------------
    # Handle existing results: resume or overwrite
    # ------------------------------------------------------------------
    previous_results = pd.DataFrame()
    already_done: set[str] = set()

    if output_file is not None and output_file.exists():
        if overwrite:
            print(f"  OVERWRITE enabled — deleting previous results: {output_file.name}")
            output_file.unlink()
        else:
            previous_results = pd.read_csv(output_file)
            if "pose_file" in previous_results.columns:
                already_done = set(previous_results["pose_file"].dropna().astype(str))
            print(f"  Loaded {len(previous_results)} previous results from {output_file.name}")
            print(f"  {len(already_done)} unique pose files already inspected — will skip them")

    # Filter out already-processed poses
    pending_poses = [
        p for p in poses_list if str(p["pose_file"]) not in already_done
    ]

    n_skipped = len(poses_list) - len(pending_poses)
    if n_skipped > 0:
        print(f"  Skipping {n_skipped} already-inspected poses")
    if not pending_poses:
        print("  All poses already inspected — nothing to do.")
        return previous_results

    # ------------------------------------------------------------------
    # Initialise PoseBusters
    # ------------------------------------------------------------------
    if config == "dock":
        print("Initializing PoseBusters in 'dock' mode (with protein)...")
        buster_dock = PoseBusters(config="dock")
    else:
        print("Initializing PoseBusters in 'mol' mode (ligand only)...")
    buster_mol = PoseBusters(config="mol")  # always available as fallback

    all_results: list[pd.DataFrame] = []
    if not previous_results.empty:
        all_results.append(previous_results)

    total = len(pending_poses)
    n_new = 0      # newly processed in this run
    n_dock = 0
    n_mol_fallback = 0
    n_errors = 0

    print(f"\n  {total} poses remaining to process (save every {save_interval})...\n")

    for idx, pose_info in enumerate(pending_poses, 1):
        pose_file = pose_info["pose_file"]
        protein_name = pose_info["protein"]

        # Progress indicator
        if idx % 10 == 0 or idx == 1:
            print(f"  Processing pose {idx}/{total}  "
                  f"(overall {len(already_done) + n_new + 1}/{len(poses_list)})...")

        if not os.path.exists(pose_file):
            print(f"  Warning: File not found: {pose_file}")
            continue

        try:
            protein_file = None
            used_mode = config

            if config == "dock":
                protein_file = _protein_file_cache.get(protein_name)
                if protein_file is None:
                    protein_file = find_protein_file(protein_name)

                if protein_file is not None and Path(protein_file).exists():
                    df = buster_dock.bust(
                        pose_file, None, protein_file, full_report=True
                    )
                    n_dock += 1
                    used_mode = "dock"
                else:
                    print(f"  Warning: No protein PDB for '{protein_name}' "
                          f"— using 'mol' mode for {Path(pose_file).name}")
                    df = buster_mol.bust(pose_file, None, None, full_report=True)
                    n_mol_fallback += 1
                    used_mode = "mol (fallback)"
            else:
                df = buster_mol.bust(pose_file, None, None, full_report=True)
                used_mode = "mol"

            # Attach metadata
            df["docking_method"] = pose_info["method"]
            df["protein"] = protein_name
            df["ligand"] = pose_info["ligand"]
            df["pose_file"] = pose_info["pose_file"]
            df["pose_name"] = pose_info["pose_name"]
            df["file_format"] = pose_info.get("file_format", "sdf")
            df["protein_file_used"] = protein_file if protein_file else "none"
            df["posebusters_mode"] = used_mode
            if "confidence" in pose_info:
                df["diffdock_confidence"] = pose_info["confidence"]

            all_results.append(df)
            n_new += 1

        except Exception as e:
            n_errors += 1
            print(f"  Error processing {Path(pose_file).name}: {e}")

        # ----------------------------------------------------------
        # Checkpoint: save every save_interval new results
        # ----------------------------------------------------------
        if output_file is not None and n_new > 0 and n_new % save_interval == 0:
            _save_checkpoint(all_results, output_file, n_new, len(already_done), total)

    # Final save
    if output_file is not None and all_results:
        _save_checkpoint(all_results, output_file, n_new, len(already_done), total, final=True)

    # Summary
    print(f"\n  Processing complete:")
    print(f"    Newly processed:  {n_new}")
    print(f"    Previously done:  {n_skipped}")
    print(f"    Total in CSV:     {len(already_done) + n_new}")
    if config == "dock":
        print(f"    Dock mode (with protein): {n_dock}")
        print(f"    Mol mode (fallback):      {n_mol_fallback}")
    print(f"    Errors: {n_errors}")

    if all_results:
        return pd.concat(all_results, ignore_index=True)
    else:
        return pd.DataFrame()


def _save_checkpoint(
    result_frames: list[pd.DataFrame],
    output_file: Path,
    n_new: int,
    n_prev: int,
    n_pending: int,
    final: bool = False,
):
    """Concatenate accumulated frames and write to CSV."""
    df_out = pd.concat(result_frames, ignore_index=True)
    df_out.to_csv(output_file, index=False)
    tag = "FINAL SAVE" if final else "CHECKPOINT"
    print(f"    [{tag}] {n_new}/{n_pending} new poses saved  |  "
          f"total rows in CSV: {len(df_out)}  →  {output_file.name}")

# %%
# ============================================================================
# MAIN ANALYSIS - USING FILTERED SUBSET ONLY
# ============================================================================
print("\n" + "=" * 80)
print("PoseBusters Pose Validation - FILTERED SUBSET ONLY")
print("=" * 80)

results_csv_path = output_dir / "posebusters_filtered_results.csv"

if OVERWRITE:
    print("\n  *** OVERWRITE mode is ON — all poses will be re-inspected ***")
else:
    print(f"\n  Resume mode: will skip poses already in {results_csv_path.name}")

# Check if filtered_poses_df exists from previous cell
if 'filtered_poses_df' not in dir() or filtered_poses_df.empty:
    print("\nERROR: No filtered poses available!")
    print("Please run the filtering cell first to create filtered_poses_df")
    results_df = pd.DataFrame()
else:
    print(f"\nUsing filtered subset with {len(filtered_poses_df)} protein-ligand combinations")
    print(f"Expected total poses: {filtered_poses_df['pose_count'].sum():,}")

    # Show breakdown by docking tool
    print("\n" + "-" * 80)
    print("FILTERED SUBSET BREAKDOWN:")
    print("-" * 80)
    for tool in filtered_poses_df["docking_tool"].unique():
        tool_df = filtered_poses_df[filtered_poses_df["docking_tool"] == tool]
        print(f"  {tool}: {len(tool_df)} combinations, ~{tool_df['pose_count'].sum()} poses")

    # Collect all poses from the filtered subset
    print("\n" + "-" * 80)
    print("1. Collecting poses from filtered subset...")
    print("-" * 80)

    all_poses = collect_poses_from_filtered_subset(filtered_poses_df)
    print(f"\n   TOTAL: {len(all_poses)} individual poses to analyze")

    # Count by method
    method_counts = {}
    for pose in all_poses:
        method = pose["method"]
        method_counts[method] = method_counts.get(method, 0) + 1

    print("\n   Poses by method:")
    for method, count in sorted(method_counts.items()):
        print(f"      {method}: {count} poses")

    # Run PoseBusters analysis (with checkpointing + resume)
    print(f"\n" + "-" * 80)
    print(f"2. Running PoseBusters validation (config='{CONFIG_MODE}', "
          f"save_interval={SAVE_INTERVAL}, overwrite={OVERWRITE})...")
    print("-" * 80)

    results_df = analyze_poses_with_posebusters(
        all_poses,
        config=CONFIG_MODE,
        output_file=results_csv_path,
        save_interval=SAVE_INTERVAL,
        overwrite=OVERWRITE,
    )

    # Final summary
    if not results_df.empty:
        print(f"\n" + "-" * 80)
        print(f"3. Results saved to: {results_csv_path}")
        print("-" * 80)
        print(f"   Total rows: {len(results_df)}")
        print(f"\n   Columns: {list(results_df.columns[:15])}...")

        if "posebusters_mode" in results_df.columns:
            print(f"\n   Mode breakdown:")
            print(results_df["posebusters_mode"].value_counts().to_string(header=False))
    else:
        print("\n   No results to save!")

print("\n" + "=" * 80)
print("Done!")
print("=" * 80)
# Out:
# ================================================================================
# PoseBusters Pose Validation - FILTERED SUBSET ONLY
# ================================================================================
#
#   Resume mode: will skip poses already in posebusters_filtered_results.csv
#
# Using filtered subset with 1071 protein-ligand combinations
# Expected total poses: 10,501
#
# --------------------------------------------------------------------------------
# FILTERED SUBSET BREAKDOWN:
# --------------------------------------------------------------------------------
#   diffdock: 1071 combinations, ~10501 poses
#
# --------------------------------------------------------------------------------
# 1. Collecting poses from filtered subset...
# --------------------------------------------------------------------------------
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
#    TOTAL: 10501 individual poses to analyze
#
#    Poses by method:
#       diffdock: 10501 poses
#
# --------------------------------------------------------------------------------
# 2. Running PoseBusters validation (config='dock', save_interval=100, overwrite=False)...
# --------------------------------------------------------------------------------
#   Loaded 10174 previous results from posebusters_filtered_results.csv
#   10174 unique pose files already inspected — will skip them
#   Skipping 10174 already-inspected poses
# Initializing PoseBusters in 'dock' mode (with protein)...
#
#   327 poses remaining to process (save every 100)...
#
#   Processing pose 1/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:32] ERROR: Cannot process coordinates on line 5
# [11:02:32] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 10/327  (overall 10175/10501)...
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 20/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 30/327  (overall 10175/10501)...
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 40/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 50/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:33] ERROR: Cannot process coordinates on line 5
# [11:02:33] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 60/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 70/327  (overall 10175/10501)...
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
#   Error processing rank9_confidence-6.19.sdf: tuple index out of range
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 80/327  (overall 10175/10501)...
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 90/327  (overall 10175/10501)...
#   Error processing rank4_confidence-5.02.sdf: tuple index out of range
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
#   Error processing rank2_confidence-4.94.sdf: tuple index out of range
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 100/327  (overall 10175/10501)...
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
# [11:02:34] ERROR: Cannot process coordinates on line 5
# [11:02:34] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-5.68.sdf: tuple index out of range
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 110/327  (overall 10175/10501)...
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 120/327  (overall 10175/10501)...
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-5.11.sdf: tuple index out of range
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-6.01.sdf: tuple index out of range
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 130/327  (overall 10175/10501)...
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 140/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:35] ERROR: Cannot process coordinates on line 5
# [11:02:35] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 150/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 160/327  (overall 10175/10501)...
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 170/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
# [11:02:36] ERROR: Cannot process coordinates on line 5
# [11:02:36] ERROR: moving to the beginning of the next molecule
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 180/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-5.33.sdf: tuple index out of range
#   Error processing rank4_confidence-5.30.sdf: tuple index out of range
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 190/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 200/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 210/327  (overall 10175/10501)...
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 220/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:37] ERROR: Cannot process coordinates on line 5
# [11:02:37] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 230/327  (overall 10175/10501)...
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# ...
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 250/327  (overall 10175/10501)...
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 260/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 270/327  (overall 10175/10501)...
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-5.55.sdf: tuple index out of range
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:38] ERROR: moving to the beginning of the next molecule
# [11:02:38] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 280/327  (overall 10175/10501)...
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 290/327  (overall 10175/10501)...
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 300/327  (overall 10175/10501)...
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank2_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 310/327  (overall 10175/10501)...
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank3_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank4_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank6_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank7_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Processing pose 320/327  (overall 10175/10501)...
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
# [11:02:39] ERROR: Cannot process coordinates on line 5
# [11:02:39] ERROR: moving to the beginning of the next molecule
#   Error processing rank8_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank5_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank9_confidence-1000.00.sdf: Could not load molecule.
#   Error processing rank10_confidence-5.45.sdf: tuple index out of range
#     [FINAL SAVE] 0/327 new poses saved  |  total rows in CSV: 10174  →  posebusters_filtered_results.csv
#
#   Processing complete:
#     Newly processed:  0
#     Previously done:  10174
#     Total in CSV:     10174
#     Dock mode (with protein): 0
#     Mol mode (fallback):      0
#     Errors: 327
#
# --------------------------------------------------------------------------------
# 3. Results saved to: /home/manndo/master_dev/posebusters_results/dock/posebusters_filtered_results.csv
# --------------------------------------------------------------------------------
#    Total rows: 10174
#
#    Columns: ['mol_pred_loaded', 'mol_cond_loaded', 'sanitization', 'inchi_convertible', 'all_atoms_connected', 'no_radicals', 'bond_lengths', 'bond_angles', 'internal_steric_clash', 'aromatic_ring_flatness', 'non-aromatic_ring_non-flatness', 'double_bond_flatness', 'internal_energy', 'protein-ligand_maximum_distance', 'minimum_distance_to_protein']...
#
#    Mode breakdown:
# dock              6490
# mol (fallback)    3684
#
# ================================================================================
# Done!
# ================================================================================

# %%
# Quick diagnostic: which methods fail which tests?
df_pb = pd.read_csv(output_dir / "posebusters_filtered_results.csv")

bottleneck_tests = ['no_radicals', 'non-aromatic_ring_non-flatness', 'internal_steric_clash']
for test in bottleneck_tests:
    if test in df_pb.columns:
        print(f"\n{test} pass rate by method:")
        print(df_pb.groupby('docking_method')[test].mean().round(3) * 100)
# Out:
# no_radicals pass rate by method:
# docking_method
# diffdock    100.0
# Name: no_radicals, dtype: float64
#
# non-aromatic_ring_non-flatness pass rate by method:
# docking_method
# diffdock    99.7
# Name: non-aromatic_ring_non-flatness, dtype: float64
#
# internal_steric_clash pass rate by method:
# docking_method
# diffdock    87.5
# Name: internal_steric_clash, dtype: float64

# %% [markdown]
# # Results

# %%
"""
CELL: Copy PoseBusters-Proved Poses to Organized Folders
==========================================================
Copy all poses that passed ALL PoseBusters tests into:
  posebuster_proved/
    ├── <method_1>/
    ├── <method_2>/
    └── ...
Folders are created dynamically from the docking_directories keys.
"""

import pandas as pd
import shutil
from pathlib import Path

# ============================================================================
# CONFIGURATION
# ============================================================================
wd_path = Path(wd)
posebusters_results_dir = output_dir
output_base = wd_path / "posebuster_proved" / CONFIG_MODE

# Build method → folder mapping dynamically from docking_directories
folders = {key: output_base / key for key in docking_directories}

# ============================================================================
# STEP 1: LOAD POSEBUSTERS RESULTS
# ============================================================================
results_csv = posebusters_results_dir / "posebusters_filtered_results.csv"

if not results_csv.exists():
    # Search for any CSV that might contain posebusters results
    csvs = list(posebusters_results_dir.glob("*.csv"))
    if csvs:
        print("Available CSVs in posebusters_results/:")
        for c in csvs:
            print(f"  {c.name}")
        for c in csvs:
            if 'result' in c.name.lower() or 'posebust' in c.name.lower():
                results_csv = c
                break
        if not results_csv.exists():
            results_csv = csvs[0]
        print(f"\nUsing: {results_csv.name}")
    else:
        raise FileNotFoundError(
            f"No PoseBusters results CSV found in {posebusters_results_dir}.\n"
            f"Please check the directory or update the path."
        )

print("=" * 100)
print(f"Loading PoseBusters results from: {results_csv}")
print("=" * 100)

df_pb = pd.read_csv(results_csv, low_memory=False)
print(f"\nTotal entries: {len(df_pb)}")
print(f"Columns: {list(df_pb.columns)}")

# ============================================================================
# STEP 2: IDENTIFY TEST COLUMNS AND FILTER PASSED POSES
# ============================================================================
metadata_cols = {
    'file_path', 'filepath', 'file', 'path', 'sdf_file', 'sdf_path',
    'method', 'docking_method', 'protein', 'ligand', 'pose_rank', 'rank',
    'molecule', 'mol_name', 'name', 'complex', 'protein_path', 'ligand_path',
    'mol_pred', 'mol_true', 'mol_cond',
}

exclude_cols = {
    'mol_true_loaded', 'mol_cond_loaded',
    'number_short_outlier_bonds', 'number_long_outlier_bonds',
    'number_outlier_angles', 'number_clashes',
    'number_non-aromatic_rings_pass', 'number_aromatic_rings_pass',
    'number_non-aromatic_rings_checked', 'number_aromatic_rings_checked',
    'number_double_bonds_checked', 'number_double_bonds_pass',
    'number_valid_bonds', 'number_valid_angles', 'number_valid_noncov_pairs',
    'number_noncov_pairs', 'number_bonds', 'number_angles',
    'num_h_added', 
    'not_too_far_away_organic_cofactors', ## Fails always because not in pdb file
    'not_too_far_away_inorganic_cofactors', ## Fails always because not in pdb file
    'not_too_far_away_waters', ## Fails always because not in pdb file
    # Cofactor/water clash sub-columns — always NaN when no cofactors/waters present
    'smallest_distance_organic_cofactors',
    'most_extreme_ligand_atom_id_organic_cofactors',
    'most_extreme_protein_atom_id_organic_cofactors',
    'most_extreme_ligand_element_organic_cofactors',
    'most_extreme_protein_element_organic_cofactors',
    'most_extreme_ligand_vdw_organic_cofactors',
    'most_extreme_protein_vdw_organic_cofactors',
    'most_extreme_sum_radii_organic_cofactors',
    'most_extreme_distance_organic_cofactors',
    'most_extreme_sum_radii_scaled_organic_cofactors',
    'most_extreme_relative_distance_organic_cofactors',
    'most_extreme_clash_organic_cofactors',
    'smallest_distance_inorganic_cofactors',
    'most_extreme_ligand_atom_id_inorganic_cofactors',
    'most_extreme_protein_atom_id_inorganic_cofactors',
    'most_extreme_ligand_element_inorganic_cofactors',
    'most_extreme_protein_element_inorganic_cofactors',
    'most_extreme_ligand_vdw_inorganic_cofactors',
    'most_extreme_protein_vdw_inorganic_cofactors',
    'most_extreme_sum_radii_inorganic_cofactors',
    'most_extreme_distance_inorganic_cofactors',
    'most_extreme_sum_radii_scaled_inorganic_cofactors',
    'most_extreme_relative_distance_inorganic_cofactors',
    'most_extreme_clash_inorganic_cofactors',
    'smallest_distance_waters',
    'most_extreme_ligand_atom_id_waters',
    'most_extreme_protein_atom_id_waters',
    'most_extreme_ligand_element_waters',
    'most_extreme_protein_element_waters',
    'most_extreme_ligand_vdw_waters',
    'most_extreme_protein_vdw_waters',
    'most_extreme_sum_radii_waters',
    'most_extreme_distance_waters',
    'most_extreme_sum_radii_scaled_waters',
    'most_extreme_relative_distance_waters',
    'most_extreme_clash_waters',
    'volume_overlap_organic_cofactors',
    'volume_overlap_inorganic_cofactors',
    'volume_overlap_waters',
}

test_cols = []
for col in df_pb.columns:
    col_lower = col.lower().strip()
    if col_lower in metadata_cols:
        continue
    if col in exclude_cols or col_lower in exclude_cols:
        continue
    if col_lower.startswith('number_') or col_lower.startswith('num_'):
        continue
    unique_vals = df_pb[col].dropna().unique()
    if set(unique_vals).issubset({True, False, 1, 0, 1.0, 0.0, 'True', 'False', 'true', 'false'}):
        test_cols.append(col)

if not test_cols:
    test_cols = [c for c in df_pb.columns if df_pb[c].dtype == bool]

if not test_cols:
    print("\nWARNING: Could not auto-detect test columns. Showing all columns and dtypes:")
    for col in df_pb.columns:
        print(f"  {col}: {df_pb[col].dtype}, unique values: {df_pb[col].nunique()}")
    raise ValueError("Cannot identify PoseBusters test columns automatically.")

# ============================================================================
# ROBUST BOOLEAN CONVERSION: handle bool, string, and NaN correctly
# NaN values are treated as FAILED (False), not passed.
# ============================================================================
def to_bool_safe(series: pd.Series) -> pd.Series:
    """Convert a column to boolean, treating NaN as False."""
    if series.dtype == bool:
        return series
    # Map all recognized truthy/falsy representations; unmatched → NaN
    bool_map = {
        True: True, False: False,
        1: True, 0: False,
        1.0: True, 0.0: False,
        'True': True, 'true': True, 'TRUE': True,
        'False': False, 'false': False, 'FALSE': False,
    }
    return series.map(bool_map).fillna(False).astype(bool)

for tc in test_cols:
    df_pb[tc] = to_bool_safe(df_pb[tc])

print(f"\nIdentified {len(test_cols)} PoseBusters test columns:")
for tc in test_cols:
    n_pass = df_pb[tc].sum()
    print(f"  {tc}: {n_pass}/{len(df_pb)} passed ({100*n_pass/len(df_pb):.1f}%)")

excluded_found = [col for col in df_pb.columns if col in exclude_cols or col.lower() in exclude_cols
                  or col.lower().startswith('number_') or col.lower().startswith('num_')]
if excluded_found:
    print(f"\nExcluded {len(excluded_found)} non-test columns (counts, always-false indicators):")
    for ec in excluded_found:
        print(f"  ✗ {ec}")

df_pb["all_passed"] = df_pb[test_cols].all(axis=1)
df_passed = df_pb[df_pb["all_passed"]].copy()

print(f"\n{'=' * 100}")
print(f"POSES THAT PASSED ALL {len(test_cols)} POSEBUSTERS TESTS: "
      f"{len(df_passed)} / {len(df_pb)} ({100*len(df_passed)/len(df_pb):.1f}%)")
print(f"{'=' * 100}")

print(f"\nBottleneck tests (lowest pass rates):")
pass_rates = {tc: df_pb[tc].sum() / len(df_pb) * 100 for tc in test_cols}
for tc, rate in sorted(pass_rates.items(), key=lambda x: x[1]):
    if rate < 99.0:
        print(f"  {tc}: {rate:.1f}%")

# ============================================================================
# STEP 3: IDENTIFY FILE PATH AND METHOD COLUMNS
# ============================================================================
file_col = None
for candidate in ['file_path', 'filepath', 'sdf_file', 'sdf_path', 'path', 'file',
                   'mol_pred', 'File', 'FILE_PATH', 'pose_file']:
    if candidate in df_passed.columns:
        file_col = candidate
        break
if file_col is None:
    for col in df_passed.columns:
        if 'path' in col.lower() or 'file' in col.lower():
            file_col = col
            break

method_col = None
for candidate in ['method', 'docking_method', 'Method', 'DOCKING_METHOD']:
    if candidate in df_passed.columns:
        method_col = candidate
        break

if file_col is None:
    print("\nAvailable columns:", list(df_passed.columns))
    raise ValueError("Cannot find file path column. Please update the script.")

print(f"\nFile path column: '{file_col}'")
print(f"Method column:    '{method_col}'" if method_col else "Method column: NOT FOUND (will infer from path)")

# ============================================================================
# STEP 4: DETERMINE METHOD FROM FILE PATH (IF NO METHOD COLUMN)
# ============================================================================

def infer_method(filepath):
    """Infer docking method from file path using docking_directories paths."""
    fp = str(filepath)
    # Check against actual directory paths in docking_directories
    for method_key, dir_path in docking_directories.items():
        if dir_path in fp or Path(dir_path).name in fp:
            return method_key
    # Fallback heuristics
    fp_lower = fp.lower()
    if any(x in fp_lower for x in ['autodock', 'vina', '_vina_', 'converted_pdbqt']):
        return "autodock"
    elif any(x in fp_lower for x in ['diffdock', 'diff_dock']):
        return "diffdock"
    elif any(x in fp_lower for x in ['equibind', 'equi_bind', 'euqibind']):
        # Try to distinguish guided vs exclusion
        if 'exclusion' in fp_lower or 'spatial' in fp_lower:
            return next((k for k in docking_directories if 'exclusion' in k), "equibind_exclusion")
        return next((k for k in docking_directories if 'guided' in k), "equibind_guided")
    return "unknown"


if method_col:
    df_passed["_method"] = df_passed[method_col]
else:
    df_passed["_method"] = df_passed[file_col].apply(infer_method)

print(f"\nPassed poses by method:")
for method, count in df_passed["_method"].value_counts().items():
    print(f"  {method}: {count}")

# ============================================================================
# STEP 5: CREATE FOLDER STRUCTURE AND COPY FILES
# ============================================================================
for folder in folders.values():
    folder.mkdir(parents=True, exist_ok=True)

copied_count = {key: 0 for key in docking_directories}
copied_count["unknown"] = 0
skipped_count = {"not_found": 0, "unknown_method": 0}

print(f"\n{'=' * 100}")
print("COPYING POSEBUSTERS-PROVED POSES...")
print(f"{'=' * 100}")

for _, row in df_passed.iterrows():
    src_path = Path(str(row[file_col]))
    method = row["_method"]

    # Get protein/ligand info for filename prefix
    protein_name = str(row["protein"]) if "protein" in row.index and pd.notna(row.get("protein")) else ""
    ligand_name = str(row["ligand"]) if "ligand" in row.index and pd.notna(row.get("ligand")) else ""

    if not src_path.is_absolute():
        src_path = wd_path / src_path

    if not src_path.exists():
        alt_paths = [
            posebusters_results_dir / src_path.name,
            posebusters_results_dir / "converted_pdbqt" / src_path.name,
            wd_path / "posebusters_results" / "converted_pdbqt" / src_path.name,
        ]
        found = False
        for alt in alt_paths:
            if alt.exists():
                src_path = alt
                found = True
                break
        if not found:
            skipped_count["not_found"] += 1
            continue

    if method in folders:
        dest_dir = folders[method]
    else:
        skipped_count["unknown_method"] += 1
        print(f"  WARNING: Unknown method '{method}' for {src_path.name}")
        continue

    # Add protein__ligand__ prefix for files that don't already have it
    # This ensures pose_clustering.py can parse protein/ligand from ALL filenames
    if protein_name and ligand_name and "__" not in src_path.name:
        dest_name = f"{protein_name}__{ligand_name}__{src_path.name}"
    else:
        dest_name = src_path.name

    dest_file = dest_dir / dest_name

    if dest_file.exists():
        stem = dest_file.stem
        suffix = dest_file.suffix
        counter = 1
        while dest_file.exists():
            dest_file = dest_dir / f"{stem}_dup{counter}{suffix}"
            counter += 1

    shutil.copy2(str(src_path), str(dest_file))
    copied_count[method] = copied_count.get(method, 0) + 1

# ============================================================================
# STEP 6: REPORT
# ============================================================================
print(f"\n{'=' * 100}")
print("COPY COMPLETE — SUMMARY")
print(f"{'=' * 100}")
print(f"\n  Output directory: {output_base}")
print(f"\n  Files copied per method:")
total_copied = 0
for method_key, count in copied_count.items():
    if count > 0:
        folder_path = folders.get(method_key, "N/A")
        print(f"    {method_key:>25}: {count:>4} files  →  {folder_path}")
        total_copied += count

print(f"\n  Total files copied: {total_copied}")

if skipped_count["not_found"] > 0:
    print(f"\n  WARNING: {skipped_count['not_found']} files skipped (source not found)")
if skipped_count["unknown_method"] > 0:
    print(f"  WARNING: {skipped_count['unknown_method']} files skipped (unknown method)")

print(f"\n  Directory contents:")
for method_name, folder_path in folders.items():
    n_files = len(list(folder_path.glob("*")))
    print(f"    {folder_path.relative_to(wd_path)}: {n_files} files")

manifest_cols = [file_col, "_method"]
for extra_col in ["protein", "ligand"]:
    if extra_col in df_passed.columns:
        manifest_cols.append(extra_col)
manifest_cols += test_cols
manifest = df_passed[manifest_cols].copy()
manifest.rename(columns={"_method": "docking_method"}, inplace=True)
manifest_path = output_base / "posebuster_proved_manifest.csv"
manifest.to_csv(manifest_path, index=False)
print(f"\n  Manifest saved: {manifest_path}")

print(f"\n{'=' * 100}")
# Out:
# ====================================================================================================
# Loading PoseBusters results from: /home/manndo/master_dev/posebusters_results/dock/posebusters_filtered_results.csv
# ====================================================================================================
#
# Total entries: 10174
# Columns: ['mol_pred_loaded', 'mol_cond_loaded', 'sanitization', 'inchi_convertible', 'all_atoms_connected', 'no_radicals', 'bond_lengths', 'bond_angles', 'internal_steric_clash', 'aromatic_ring_flatness', 'non-aromatic_ring_non-flatness', 'double_bond_flatness', 'internal_energy', 'protein-ligand_maximum_distance', 'minimum_distance_to_protein', 'minimum_distance_to_organic_cofactors', 'minimum_distance_to_inorganic_cofactors', 'minimum_distance_to_waters', 'volume_overlap_with_protein', 'volume_overlap_with_organic_cofactors', 'volume_overlap_with_inorganic_cofactors', 'volume_overlap_with_waters', 'mol_true_loaded', 'passes_valence_checks', 'passes_kekulization', 'no_radicals_before_sanitization', 'number_bonds', 'shortest_bond_relative_length', 'longest_bond_relative_length', 'number_short_outlier_bonds', 'number_long_outlier_bonds', 'number_angles', 'most_extreme_relative_angle', 'number_outlier_angles', 'number_noncov_pairs', 'shortest_noncovalent_relative_distance', 'number_clashes', 'number_valid_bonds', 'number_valid_angles', 'number_valid_noncov_pairs', 'number_aromatic_rings_checked', 'number_aromatic_rings_pass', 'aromatic_ring_maximum_distance_from_plane', 'number_non-aromatic_rings_checked', 'number_non-aromatic_rings_pass', 'non-aromatic_ring_maximum_distance_from_plane', 'number_double_bonds_checked', 'number_double_bonds_pass', 'double_bond_maximum_distance_from_plane', 'num_h_added', 'mol_pred_energy', 'ensemble_avg_energy', 'energy_ratio', 'smallest_distance_protein', 'num_pairwise_clashes_protein', 'most_extreme_ligand_atom_id_protein', 'most_extreme_protein_atom_id_protein', 'most_extreme_ligand_element_protein', 'most_extreme_protein_element_protein', 'most_extreme_ligand_vdw_protein', 'most_extreme_protein_vdw_protein', 'most_extreme_sum_radii_protein', 'most_extreme_distance_protein', 'most_extreme_sum_radii_scaled_protein', 'most_extreme_relative_distance_protein', 'most_extreme_clash_protein', 'smallest_distance_organic_cofactors', 'not_too_far_away_organic_cofactors', 'num_pairwise_clashes_organic_cofactors', 'most_extreme_ligand_atom_id_organic_cofactors', 'most_extreme_protein_atom_id_organic_cofactors', 'most_extreme_ligand_element_organic_cofactors', 'most_extreme_protein_element_organic_cofactors', 'most_extreme_ligand_vdw_organic_cofactors', 'most_extreme_protein_vdw_organic_cofactors', 'most_extreme_sum_radii_organic_cofactors', 'most_extreme_distance_organic_cofactors', 'most_extreme_sum_radii_scaled_organic_cofactors', 'most_extreme_relative_distance_organic_cofactors', 'most_extreme_clash_organic_cofactors', 'smallest_distance_inorganic_cofactors', 'not_too_far_away_inorganic_cofactors', 'num_pairwise_clashes_inorganic_cofactors', 'most_extreme_ligand_atom_id_inorganic_cofactors', 'most_extreme_protein_atom_id_inorganic_cofactors', 'most_extreme_ligand_element_inorganic_cofactors', 'most_extreme_protein_element_inorganic_cofactors', 'most_extreme_ligand_vdw_inorganic_cofactors', 'most_extreme_protein_vdw_inorganic_cofactors', 'most_extreme_sum_radii_inorganic_cofactors', 'most_extreme_distance_inorganic_cofactors', 'most_extreme_sum_radii_scaled_inorganic_cofactors', 'most_extreme_relative_distance_inorganic_cofactors', 'most_extreme_clash_inorganic_cofactors', 'smallest_distance_waters', 'not_too_far_away_waters', 'num_pairwise_clashes_waters', 'most_extreme_ligand_atom_id_waters', 'most_extreme_protein_atom_id_waters', 'most_extreme_ligand_element_waters', 'most_extreme_protein_element_waters', 'most_extreme_ligand_vdw_waters', 'most_extreme_protein_vdw_waters', 'most_extreme_sum_radii_waters', 'most_extreme_distance_waters', 'most_extreme_sum_radii_scaled_waters', 'most_extreme_relative_distance_waters', 'most_extreme_clash_waters', 'volume_overlap_protein', 'volume_overlap_organic_cofactors', 'volume_overlap_inorganic_cofactors', 'volume_overlap_waters', 'docking_method', 'protein', 'ligand', 'pose_file', 'pose_name', 'file_format', 'protein_file_used', 'posebusters_mode', 'diffdock_conf ...
#
# Identified 25 PoseBusters test columns:
#   mol_pred_loaded: 10174/10174 passed (100.0%)
#   sanitization: 10174/10174 passed (100.0%)
#   inchi_convertible: 10174/10174 passed (100.0%)
#   all_atoms_connected: 10174/10174 passed (100.0%)
#   no_radicals: 10174/10174 passed (100.0%)
#   bond_lengths: 10094/10174 passed (99.2%)
#   bond_angles: 10110/10174 passed (99.4%)
#   internal_steric_clash: 8900/10174 passed (87.5%)
#   aromatic_ring_flatness: 10153/10174 passed (99.8%)
#   non-aromatic_ring_non-flatness: 10148/10174 passed (99.7%)
#   double_bond_flatness: 10127/10174 passed (99.5%)
#   internal_energy: 9710/10174 passed (95.4%)
#   protein-ligand_maximum_distance: 6043/10174 passed (59.4%)
#   minimum_distance_to_protein: 792/10174 passed (7.8%)
#   minimum_distance_to_organic_cofactors: 6490/10174 passed (63.8%)
#   minimum_distance_to_inorganic_cofactors: 6490/10174 passed (63.8%)
#   minimum_distance_to_waters: 6490/10174 passed (63.8%)
#   volume_overlap_with_protein: 2775/10174 passed (27.3%)
#   volume_overlap_with_organic_cofactors: 6490/10174 passed (63.8%)
#   volume_overlap_with_inorganic_cofactors: 6490/10174 passed (63.8%)
#   volume_overlap_with_waters: 6490/10174 passed (63.8%)
#   passes_valence_checks: 10174/10174 passed (100.0%)
#   passes_kekulization: 10174/10174 passed (100.0%)
#   no_radicals_before_sanitization: 10174/10174 passed (100.0%)
#   most_extreme_clash_protein: 5698/10174 passed (56.0%)
#
# Excluded 65 non-test columns (counts, always-false indicators):
#   ✗ mol_cond_loaded
#   ✗ mol_true_loaded
#   ✗ number_bonds
#   ✗ number_short_outlier_bonds
#   ✗ number_long_outlier_bonds
#   ✗ number_angles
#   ✗ number_outlier_angles
#   ✗ number_noncov_pairs
#   ✗ number_clashes
#   ✗ number_valid_bonds
#   ✗ number_valid_angles
#   ✗ number_valid_noncov_pairs
#   ✗ number_aromatic_rings_checked
#   ✗ number_aromatic_rings_pass
#   ✗ number_non-aromatic_rings_checked
#   ✗ number_non-aromatic_rings_pass
#   ✗ number_double_bonds_checked
#   ✗ number_double_bonds_pass
#   ✗ num_h_added
#   ✗ num_pairwise_clashes_protein
#   ✗ smallest_distance_organic_cofactors
#   ✗ not_too_far_away_organic_cofactors
#   ✗ num_pairwise_clashes_organic_cofactors
#   ✗ most_extreme_ligand_atom_id_organic_cofactors
#   ✗ most_extreme_protein_atom_id_organic_cofactors
#   ✗ most_extreme_ligand_element_organic_cofactors
#   ✗ most_extreme_protein_element_organic_cofactors
#   ✗ most_extreme_ligand_vdw_organic_cofactors
#   ✗ most_extreme_protein_vdw_organic_cofactors
#   ✗ most_extreme_sum_radii_organic_cofactors
#   ✗ most_extreme_distance_organic_cofactors
#   ✗ most_extreme_sum_radii_scaled_organic_cofactors
#   ✗ most_extreme_relative_distance_organic_cofactors
#   ✗ most_extreme_clash_organic_cofactors
#   ✗ smallest_distance_inorganic_cofactors
#   ✗ not_too_far_away_inorganic_cofactors
#   ✗ num_pairwise_clashes_inorganic_cofactors
#   ✗ most_extreme_ligand_atom_id_inorganic_cofactors
#   ✗ most_extreme_protein_atom_id_inorganic_cofactors
#   ✗ most_extreme_ligand_element_inorganic_cofactors
#   ✗ most_extreme_protein_element_inorganic_cofactors
#   ✗ most_extreme_ligand_vdw_inorganic_cofactors
#   ✗ most_extreme_protein_vdw_inorganic_cofactors
#   ✗ most_extreme_sum_radii_inorganic_cofactors
#   ✗ most_extreme_distance_inorganic_cofactors
#   ✗ most_extreme_sum_radii_scaled_inorganic_cofactors
#   ✗ most_extreme_relative_distance_inorganic_cofactors
#   ✗ most_extreme_clash_inorganic_cofactors
#   ✗ smallest_distance_waters
#   ✗ not_too_far_away_waters
#   ✗ num_pairwise_clashes_waters
#   ✗ most_extreme_ligand_atom_id_waters
#   ✗ most_extreme_protein_atom_id_waters
#   ✗ most_extreme_ligand_element_waters
#   ✗ most_extreme_protein_element_waters
#   ✗ most_extreme_ligand_vdw_waters
#   ✗ most_extreme_protein_vdw_waters
#   ✗ most_extreme_sum_radii_waters
#   ✗ most_extreme_distance_waters
#   ✗ most_extreme_sum_radii_scaled_waters
#   ✗ most_extreme_relative_distance_waters
#   ✗ most_extreme_clash_waters
#   ✗ volume_overlap_organic_cofactors
#   ✗ volume_overlap_inorganic_cofactors
#   ✗ volume_overlap_waters
#
# ====================================================================================================
# POSES THAT PASSED ALL 25 POSEBUSTERS TESTS: 0 / 10174 (0.0%)
# ====================================================================================================
#
# Bottleneck tests (lowest pass rates):
#   minimum_distance_to_protein: 7.8%
#   volume_overlap_with_protein: 27.3%
#   most_extreme_clash_protein: 56.0%
#   protein-ligand_maximum_distance: 59.4%
#   minimum_distance_to_organic_cofactors: 63.8%
#   minimum_distance_to_inorganic_cofactors: 63.8%
#   minimum_distance_to_waters: 63.8%
#   volume_overlap_with_organic_cofactors: 63.8%
#   volume_overlap_with_inorganic_cofactors: 63.8%
#   volume_overlap_with_waters: 63.8%
#   internal_steric_clash: 87.5%
#   internal_energy: 95.4%
#
# File path column: 'pose_file'
# Method column:    'docking_method'
#
# Passed poses by method:
#
# ====================================================================================================
# COPYING POSEBUSTERS-PROVED POSES...
# ====================================================================================================
#
# ====================================================================================================
# COPY COMPLETE — SUMMARY
# ====================================================================================================
#
#   Output directory: /home/manndo/master_dev/posebuster_proved/dock
#
#   Files copied per method:
#
#   Total files copied: 0
#
#   Directory contents:
#     posebuster_proved/dock/diffdock: 9106 files
#
#   Manifest saved: /home/manndo/master_dev/posebuster_proved/dock/posebuster_proved_manifest.csv
#
# ====================================================================================================
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1403547646.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)

# %%
"""
Graphical Representation of PoseBusters Results
=================================================
Comprehensive visualizations of validation test pass rates,
per-method breakdowns, and overall quality profiles.
Methods and colors are derived dynamically from the results.
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.colors import LinearSegmentedColormap
from pathlib import Path

# ============================================================================
# LOAD DATA
# ============================================================================
pb_csv = output_dir / "posebusters_filtered_results.csv"
plot_output_dir = output_dir
df = pd.read_csv(pb_csv, low_memory=False)

# Identify boolean test columns (same logic as manifest cell)
exclude_cols = {
    'mol_true_loaded', 'mol_cond_loaded',
    'number_short_outlier_bonds', 'number_long_outlier_bonds',
    'number_outlier_angles', 'number_clashes',
    'number_non-aromatic_rings_pass', 'number_aromatic_rings_pass',
    'number_non-aromatic_rings_checked', 'number_aromatic_rings_checked',
    'number_double_bonds_checked', 'number_double_bonds_pass',
    'number_valid_bonds', 'number_valid_angles', 'number_valid_noncov_pairs',
    'number_noncov_pairs', 'number_bonds', 'number_angles',
    'num_h_added',
    # Cofactor/water clash sub-columns — always NaN when no cofactors/waters present
    'not_too_far_away_organic_cofactors',
    'not_too_far_away_inorganic_cofactors',
    'not_too_far_away_waters',
    'smallest_distance_organic_cofactors',
    'most_extreme_ligand_atom_id_organic_cofactors',
    'most_extreme_protein_atom_id_organic_cofactors',
    'most_extreme_ligand_element_organic_cofactors',
    'most_extreme_protein_element_organic_cofactors',
    'most_extreme_ligand_vdw_organic_cofactors',
    'most_extreme_protein_vdw_organic_cofactors',
    'most_extreme_sum_radii_organic_cofactors',
    'most_extreme_distance_organic_cofactors',
    'most_extreme_sum_radii_scaled_organic_cofactors',
    'most_extreme_relative_distance_organic_cofactors',
    'most_extreme_clash_organic_cofactors',
    'smallest_distance_inorganic_cofactors',
    'most_extreme_ligand_atom_id_inorganic_cofactors',
    'most_extreme_protein_atom_id_inorganic_cofactors',
    'most_extreme_ligand_element_inorganic_cofactors',
    'most_extreme_protein_element_inorganic_cofactors',
    'most_extreme_ligand_vdw_inorganic_cofactors',
    'most_extreme_protein_vdw_inorganic_cofactors',
    'most_extreme_sum_radii_inorganic_cofactors',
    'most_extreme_distance_inorganic_cofactors',
    'most_extreme_sum_radii_scaled_inorganic_cofactors',
    'most_extreme_relative_distance_inorganic_cofactors',
    'most_extreme_clash_inorganic_cofactors',
    'smallest_distance_waters',
    'most_extreme_ligand_atom_id_waters',
    'most_extreme_protein_atom_id_waters',
    'most_extreme_ligand_element_waters',
    'most_extreme_protein_element_waters',
    'most_extreme_ligand_vdw_waters',
    'most_extreme_protein_vdw_waters',
    'most_extreme_sum_radii_waters',
    'most_extreme_distance_waters',
    'most_extreme_sum_radii_scaled_waters',
    'most_extreme_relative_distance_waters',
    'most_extreme_clash_waters',
    'volume_overlap_organic_cofactors',
    'volume_overlap_inorganic_cofactors',
    'volume_overlap_waters',
}
metadata_cols = {
    'file_path', 'filepath', 'file', 'path', 'sdf_file', 'sdf_path',
    'method', 'docking_method', 'protein', 'ligand', 'pose_rank', 'rank',
    'molecule', 'mol_name', 'name', 'complex', 'protein_path', 'ligand_path',
    'mol_pred', 'mol_true', 'mol_cond',
}

test_cols = []
for col in df.columns:
    cl = col.lower().strip()
    if cl in metadata_cols or col in exclude_cols:
        continue
    if cl.startswith('number_') or cl.startswith('num_'):
        continue
    uv = set(df[col].dropna().unique())
    if uv.issubset({True, False, 1, 0, 1.0, 0.0, 'True', 'False', 'true', 'false'}):
        test_cols.append(col)

# Robust boolean conversion: handle bool, string, and NaN correctly
# NaN values are treated as FAILED (False), not passed.
def to_bool_safe(series: pd.Series) -> pd.Series:
    """Convert a column to boolean, treating NaN as False."""
    if series.dtype == bool:
        return series
    bool_map = {
        True: True, False: False,
        1: True, 0: False,
        1.0: True, 0.0: False,
        'True': True, 'true': True, 'TRUE': True,
        'False': False, 'false': False, 'FALSE': False,
    }
    return series.map(bool_map).fillna(False).astype(bool)

for tc in test_cols:
    df[tc] = to_bool_safe(df[tc])

df["all_passed"] = df[test_cols].all(axis=1)

# Friendly display names for tests
TEST_DISPLAY = {
    'mol_pred_loaded': 'Molecule Loaded',
    'sanitization': 'Sanitization',
    'inchi_convertible': 'InChI Convertible',
    'all_atoms_connected': 'All Atoms Connected',
    'no_radicals': 'No Radicals',
    'bond_lengths': 'Bond Lengths',
    'bond_angles': 'Bond Angles',
    'internal_steric_clash': 'No Steric Clash',
    'aromatic_ring_flatness': 'Aromatic Flatness',
    'non-aromatic_ring_non-flatness': 'Non-Arom. Ring Shape',
    'double_bond_flatness': 'Double Bond Flatness',
    'internal_energy': 'Internal Energy',
    'passes_valence_checks': 'Valence Checks',
    'passes_kekulization': 'Kekulization',
    'no_radicals_before_sanitization': 'No Pre-Sanit. Radicals',
}

# Generate colors dynamically for all methods found in the data
_COLOR_PALETTE = [
    '#3498db', '#e74c3c', '#2ecc71', '#9b59b6', '#f39c12',
    '#1abc9c', '#e67e22', '#34495e', '#d35400', '#8e44ad',
]

methods = sorted(df['docking_method'].unique())
METHOD_COLORS = {m: _COLOR_PALETTE[i % len(_COLOR_PALETTE)] for i, m in enumerate(methods)}

n_total = len(df)
n_passed = df['all_passed'].sum()

print(f"PoseBusters Results: {n_total} total poses, {n_passed} passed all tests ({n_passed/n_total*100:.1f}%)")
for m in methods:
    g = df[df['docking_method'] == m]
    print(f"  {m}: {g['all_passed'].sum()}/{len(g)} passed ({g['all_passed'].mean()*100:.1f}%)")

# ============================================================================
# FIGURE 1: Overall pass rate heatmap (methods × tests)
# ============================================================================
variable_tests = [t for t in test_cols if df[t].mean() < 1.0]
trivial_tests = [t for t in test_cols if t not in variable_tests]

pass_rates = df.groupby('docking_method')[test_cols].mean() * 100
pass_rates_var = pass_rates[variable_tests] if variable_tests else pass_rates

fig1, ax1 = plt.subplots(figsize=(max(10, len(test_cols) * 0.8), max(4, len(methods) * 0.8)))

cmap = LinearSegmentedColormap.from_list('ryg', ['#e74c3c', '#f39c12', '#27ae60'])

im = ax1.imshow(pass_rates_var.values, cmap=cmap, aspect='auto', vmin=50, vmax=100)

ax1.set_yticks(range(len(pass_rates_var.index)))
ax1.set_yticklabels(pass_rates_var.index, fontsize=11, fontweight='bold')
ax1.set_xticks(range(len(pass_rates_var.columns)))
xlabels = [TEST_DISPLAY.get(c, c.replace('_', ' ').title()) for c in pass_rates_var.columns]
ax1.set_xticklabels(xlabels, rotation=45, ha='right', fontsize=10)

for i in range(pass_rates_var.shape[0]):
    for j in range(pass_rates_var.shape[1]):
        val = pass_rates_var.values[i, j]
        color = 'white' if val < 75 else 'black'
        ax1.text(j, i, f'{val:.1f}%', ha='center', va='center', fontsize=10,
                fontweight='bold', color=color)

cbar = plt.colorbar(im, ax=ax1, shrink=0.8, pad=0.02)
cbar.set_label('Pass Rate (%)', fontsize=11)

if trivial_tests:
    trivial_str = ', '.join(TEST_DISPLAY.get(t, t) for t in trivial_tests)
    ax1.set_xlabel(f'Tests at 100% (not shown): {trivial_str}', fontsize=8, style='italic')

ax1.set_title('PoseBusters Test Pass Rates by Docking Method', fontsize=14, fontweight='bold', pad=12)
fig1.tight_layout()
fig1.savefig(plot_output_dir / "pb_passrate_heatmap.png", dpi=200, bbox_inches='tight')
plt.show()

# ============================================================================
# FIGURE 2: Stacked bar — pass / fail counts per method
# ============================================================================
fig2, ax2 = plt.subplots(figsize=(max(7, len(methods) * 2), 5))

counts = df.groupby('docking_method')['all_passed'].value_counts().unstack(fill_value=0)
if True not in counts.columns:
    counts[True] = 0
if False not in counts.columns:
    counts[False] = 0
counts = counts[[True, False]].rename(columns={True: 'Passed All', False: 'Failed ≥1'})

bars_pass = ax2.bar(range(len(counts)), counts['Passed All'],
                    color=[METHOD_COLORS.get(m, '#888') for m in counts.index],
                    edgecolor='white', linewidth=1.5, label='Passed All Tests')
bars_fail = ax2.bar(range(len(counts)), counts['Failed ≥1'],
                    bottom=counts['Passed All'],
                    color=[METHOD_COLORS.get(m, '#888') for m in counts.index],
                    alpha=0.3, edgecolor='white', linewidth=1.5, hatch='///',
                    label='Failed ≥1 Test')

for i, (m, row) in enumerate(counts.iterrows()):
    total = row.sum()
    pct = row['Passed All'] / total * 100
    ax2.text(i, total + 5, f'{int(row["Passed All"])}/{int(total)}\n({pct:.1f}%)',
             ha='center', va='bottom', fontsize=11, fontweight='bold')

ax2.set_xticks(range(len(counts)))
ax2.set_xticklabels(counts.index, fontsize=12, fontweight='bold')
ax2.set_ylabel('Number of Poses', fontsize=12)
ax2.set_title('PoseBusters Validation Summary by Docking Method', fontsize=14, fontweight='bold')
ax2.legend(loc='upper right', fontsize=10)
ax2.set_ylim(0, counts.sum(axis=1).max() * 1.25)
ax2.grid(axis='y', alpha=0.3)
fig2.tight_layout()
fig2.savefig(plot_output_dir / "pb_pass_fail_bars.png", dpi=200, bbox_inches='tight')
plt.show()

# ============================================================================
# FIGURE 3: Per-test failure rate comparison (grouped bar chart)
# ============================================================================
if variable_tests:
    fail_rates = (1 - df.groupby('docking_method')[variable_tests].mean()) * 100

    fig3, ax3 = plt.subplots(figsize=(max(10, len(variable_tests) * 1.5), 5))

    x = np.arange(len(variable_tests))
    width = 0.8 / len(methods)

    for i, m in enumerate(methods):
        vals = fail_rates.loc[m].values
        bars = ax3.bar(x + i * width - 0.4 + width / 2, vals, width,
                       label=m, color=METHOD_COLORS.get(m, '#888'), edgecolor='white')
        for j, v in enumerate(vals):
            if v > 2:
                ax3.text(x[j] + i * width - 0.4 + width / 2, v + 0.5,
                         f'{v:.1f}%', ha='center', va='bottom', fontsize=8, fontweight='bold')

    ax3.set_xticks(x)
    xlabels3 = [TEST_DISPLAY.get(c, c.replace('_', ' ').title()) for c in variable_tests]
    ax3.set_xticklabels(xlabels3, rotation=40, ha='right', fontsize=10)
    ax3.set_ylabel('Failure Rate (%)', fontsize=12)
    ax3.set_title('PoseBusters Failure Rates by Test and Method', fontsize=14, fontweight='bold')
    ax3.legend(fontsize=10)
    ax3.grid(axis='y', alpha=0.3)
    fig3.tight_layout()
    fig3.savefig(plot_output_dir / "pb_failure_rates.png", dpi=200, bbox_inches='tight')
    plt.show()

# ============================================================================
# FIGURE 4: Per protein-ligand pass rate (faceted by method)
# ============================================================================
n_methods = len(methods)
fig4, axes4 = plt.subplots(1, n_methods, figsize=(6 * n_methods, 5), sharey=True,
                            squeeze=False)
axes4 = axes4.flatten()

for ax, m in zip(axes4, methods):
    sub = df[df['docking_method'] == m]
    combo_pass = sub.groupby(['protein', 'ligand'])['all_passed'].mean() * 100
    combo_pass = combo_pass.sort_values(ascending=True)

    labels = [f'{p}\n{l}' for p, l in combo_pass.index]
    colors = [('#27ae60' if v >= 75 else '#f39c12' if v >= 50 else '#e74c3c') for v in combo_pass.values]

    ax.barh(range(len(combo_pass)), combo_pass.values, color=colors, edgecolor='white')
    ax.set_yticks(range(len(combo_pass)))
    ax.set_yticklabels(labels, fontsize=8)
    ax.set_xlabel('Pass Rate (%)', fontsize=11)
    ax.set_title(m, fontsize=13, fontweight='bold', color=METHOD_COLORS.get(m, 'black'))
    ax.set_xlim(0, 105)
    ax.axvline(75, color='gray', linestyle='--', alpha=0.5)
    ax.grid(axis='x', alpha=0.3)

    for i, v in enumerate(combo_pass.values):
        ax.text(v + 1, i, f'{v:.0f}%', va='center', fontsize=9)

fig4.suptitle('PoseBusters Pass Rate by Protein–Ligand Combination', fontsize=14, fontweight='bold')
fig4.tight_layout()
fig4.savefig(plot_output_dir / "pb_pass_by_combo.png", dpi=200, bbox_inches='tight')
plt.show()

# ============================================================================
# FIGURE 5: Number of tests failed distribution (violin + strip)
# ============================================================================
df['n_failed'] = df[test_cols].apply(lambda row: (~row).sum(), axis=1)

fig5, ax5 = plt.subplots(figsize=(max(8, len(methods) * 2.5), 5))

for i, m in enumerate(methods):
    vals = df[df['docking_method'] == m]['n_failed']
    parts = ax5.violinplot([vals], positions=[i], showmedians=True, widths=0.7)
    for pc in parts['bodies']:
        pc.set_facecolor(METHOD_COLORS.get(m, '#888'))
        pc.set_alpha(0.4)
    for key in ['cbars', 'cmins', 'cmaxes', 'cmedians']:
        parts[key].set_color(METHOD_COLORS.get(m, '#888'))
    jitter = np.random.normal(0, 0.08, len(vals))
    ax5.scatter(np.full(len(vals), i) + jitter, vals, s=10, alpha=0.3,
                color=METHOD_COLORS.get(m, '#888'))

ax5.set_xticks(range(len(methods)))
ax5.set_xticklabels(methods, fontsize=12, fontweight='bold')
ax5.set_ylabel('Number of Tests Failed', fontsize=12)
ax5.set_title('Distribution of Failed Tests per Pose', fontsize=14, fontweight='bold')
ax5.set_ylim(-0.5, df['n_failed'].max() + 1)
ax5.grid(axis='y', alpha=0.3)

for i, m in enumerate(methods):
    med = df[df['docking_method'] == m]['n_failed'].median()
    ax5.text(i, med + 0.3, f'median={med:.0f}', ha='center', fontsize=9, fontweight='bold')

fig5.tight_layout()
fig5.savefig(plot_output_dir / "pb_nfailed_violin.png", dpi=200, bbox_inches='tight')
plt.show()

print(f"\nAll figures saved to: {plot_output_dir}")
print("  pb_passrate_heatmap.png  — Test pass rate heatmap (methods × tests)")
print("  pb_pass_fail_bars.png    — Pass/fail stacked bars per method")
print("  pb_failure_rates.png     — Per-test failure rates (grouped bars)")
print("  pb_pass_by_combo.png     — Pass rate by protein–ligand combination")
print("  pb_nfailed_violin.png    — Distribution of #tests failed per pose")
# Out:
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# PoseBusters Results: 10174 total poses, 0 passed all tests (0.0%)
#   diffdock: 0/10174 passed (0.0%)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# /tmp/ipykernel_2529232/1012583707.py:108: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   return series.map(bool_map).fillna(False).astype(bool)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2529232/1012583707.py in ?()
#     197 if True not in counts.columns:
#     198     counts[True] = 0
#     199 if False not in counts.columns:
#     200     counts[False] = 0
# --> 201 counts = counts[[True, False]].rename(columns={True: 'Passed All', False: 'Failed ≥1'})
#     202
#     203 bars_pass = ax2.bar(range(len(counts)), counts['Passed All'],
#     204                     color=[METHOD_COLORS.get(m, '#888') for m in counts.index],
#
# ~/anaconda3/envs/vina/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key)
#    4100             return self.where(key)
#    4101
#    4102         # Do we have a (boolean) 1d indexer?
#    4103         if com.is_bool_indexer(key):
# -> 4104             return self._getitem_bool_array(key)
#    4105
#    4106         # We are left with two options: a single key, and a collection of keys,
#    4107         # We interpret tuples as collections only for non-MultiIndex
#
# ~/anaconda3/envs/vina/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key)
#    4150                 UserWarning,
#    4151                 stacklevel=find_stack_level(),
#    4152             )
#    4153         elif len(key) != len(self.index):
# -> 4154             raise ValueError(
#    4155                 f"Item wrong length {len(key)} instead of {len(self.index)}."
#    4156             )
#    4157
#
# ValueError: Item wrong length 2 instead of 1.
