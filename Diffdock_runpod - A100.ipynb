# %%
from __future__ import annotations

import csv
import inspect
import json
import os
import shutil
import subprocess
import threading
import time
from collections import defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed
from dataclasses import dataclass, field
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import pandas as pd
import yaml
from IPython.display import display
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski, rdMolDescriptors

# %% [markdown]
# # Config

# %%
# Paths
workspace_root = Path("/workspace")
receptors_dir = workspace_root / "master_dev/Orai"

# List of ligand directories — each gets its own output folder, error log, and summary
drugs_dirs = [
    Path("/root/workspace/storage/ligands_sdf_large_approvedA100"),
    Path("/root/workspace/storage/ligands_sdf_small_symmetric_approved/")
]

# DiffDock paths
DIFFDOCK_DIR = Path("/workspace/DiffDock")
DIFFDOCK_CONDA_ENV = "diffdock"

# Python executable — MUST be the diffdock conda env, not the notebook kernel
DIFFDOCK_PYTHON = os.path.expanduser("~/anaconda3/envs/diffdock/bin/python")

# Number of samples (poses) DiffDock generates per complex
NUM_SAMPLES: int = 10

# Device for DiffDock (cpu or cuda:0)
DIFFDOCK_DEVICE = "cuda:0"  # Change to "cpu" if you don't have a compatible GPU

# Per-complex time limit in seconds (kills subprocess if exceeded)
TIMEOUT_PER_COMPLEX: int = 300  # 15 minutes per complex; set to 0 for no limit

# Number of denoising steps DiffDock uses (default 20; fewer = faster, lower quality)
INFERENCE_STEPS: int = 20  # Try 10 for faster runs, 20 for best quality

# Base output directory — each drugs_dir gets a subfolder named after it
DIFFDOCK_OUTPUT_BASE = workspace_root / "diffdock_results"
DIFFDOCK_OUTPUT_BASE.mkdir(parents=True, exist_ok=True)

# Overwrite settings
OVERWRITE_EXISTING = False  # Set to True to re-dock existing combinations
OVERWRITE_ERROR_LOG = True  # Set to True to retry previously failed ligands

# Error log filename (one per output directory)
ERROR_LOG_FILENAME = "failed_docking.json"

# ── Performance settings ──
# Use CSV batch mode: submits all complexes in one DiffDock call (much faster)
USE_BATCH_MODE = True

# Batch size: how many complexes per DiffDock subprocess call in batch mode
# Sweet spot: 50 balances model-load overhead vs preprocessing time
# Set to 0 for all-in-one (risky with large runs — long preprocessing stalls GPU)
BATCH_SIZE: int = 15

# Number of parallel workers for single-complex fallback mode (USE_BATCH_MODE=False)
# Only used when USE_BATCH_MODE is False. Set to 1 for sequential.
# On GPU, keep at 1 (GPU can't run multiple DiffDock in parallel).
# On CPU, try 2-4 depending on cores.
NUM_WORKERS: int = 1

# Validate directories
for drugs_dir in drugs_dirs:
    if not drugs_dir.exists():
        raise FileNotFoundError(f"Ligand directory missing: {drugs_dir}")
if not receptors_dir.exists():
    raise FileNotFoundError(f"Receptor directory missing: {receptors_dir}")

print("=" * 80)
print("DiffDock Batch Docking Configuration")
print("=" * 80)
print(f"Number of samples per complex: {NUM_SAMPLES}")
print(f"Inference steps: {INFERENCE_STEPS}")
print(f"Timeout per complex: {TIMEOUT_PER_COMPLEX}s ({TIMEOUT_PER_COMPLEX/60:.0f} min)" if TIMEOUT_PER_COMPLEX else "Timeout per complex: unlimited")
print(f"DiffDock directory: {DIFFDOCK_DIR}")
print(f"DiffDock conda env: {DIFFDOCK_CONDA_ENV}")
print(f"DiffDock device: {DIFFDOCK_DEVICE}")
print(f"Output base directory: {DIFFDOCK_OUTPUT_BASE}")
print(f"Overwrite existing: {OVERWRITE_EXISTING}")
print(f"Batch mode: {USE_BATCH_MODE} (batch size: {'all' if BATCH_SIZE == 0 else BATCH_SIZE})")
if not USE_BATCH_MODE:
    print(f"Parallel workers: {NUM_WORKERS}")
print(f"\nLigand directories ({len(drugs_dirs)}):")
for d in drugs_dirs:
    n_files = len(list(d.glob("*.sdf")) + list(d.glob("*.mol2")) + list(d.glob("*.pdb")))
    output_dir = DIFFDOCK_OUTPUT_BASE / d.name
    print(f"  • {d.name:30s} → output: {output_dir.name}/  ({n_files} ligand files)")
print()

# Validate DiffDock installation
if not DIFFDOCK_DIR.exists():
    print(f"⚠️  WARNING: DiffDock directory not found at {DIFFDOCK_DIR}")
    print("   Please update DIFFDOCK_DIR to point to your DiffDock installation")
else:
    print(f"✓ DiffDock directory found")
# Out:
# ================================================================================
# DiffDock Batch Docking Configuration
# ================================================================================
# Number of samples per complex: 10
# Inference steps: 20
# Timeout per complex: 300s (5 min)
# DiffDock directory: /workspace/DiffDock
# DiffDock conda env: diffdock
# DiffDock device: cuda:0
# Output base directory: /workspace/diffdock_results
# Overwrite existing: False
# Batch mode: True (batch size: 15)
#
# Ligand directories (2):
#   • ligands_sdf_large_approvedA100 → output: ligands_sdf_large_approvedA100/  (600 ligand files)
#   • ligands_sdf_small_symmetric_approved → output: ligands_sdf_small_symmetric_approved/  (596 ligand files)
#
# ✓ DiffDock directory found

# %% [markdown]
# # Helper Functions & Data Classes

# %%
@dataclass
class DockingResult:
    """Result of docking a protein-ligand combination."""
    protein_name: str
    ligand_name: str
    protein_path: Path
    ligand_path: Path
    output_dir: Path
    status: str  # "success", "failed", "skipped"
    num_poses: int = 0
    pose_files: List[Path] = field(default_factory=list)
    error_message: str = ""
    elapsed_time: float = 0.0
    
    def to_dict(self) -> dict:
        return {
            "protein_name": self.protein_name,
            "ligand_name": self.ligand_name,
            "protein_path": str(self.protein_path),
            "ligand_path": str(self.ligand_path),
            "output_dir": str(self.output_dir),
            "status": self.status,
            "num_poses": self.num_poses,
            "pose_files": [str(p) for p in self.pose_files],
            "error_message": self.error_message,
            "elapsed_time": self.elapsed_time,
        }


def get_file_stem(path: Path) -> str:
    """Get clean filename stem without extension."""
    return path.stem.replace("_ligand", "").replace("_protein", "")


def collect_files(root: Path, extensions: List[str]) -> List[Path]:
    """Return files with given extensions located directly inside root (no recursion)."""
    files = []
    for ext in extensions:
        files.extend(sorted(p for p in root.glob(f"*{ext}") if p.is_file()))
    return sorted(set(files))


def extract_confidence_from_filename(filename: str) -> float:
    """Extract confidence score from DiffDock output filename (e.g., rank1_confidence-0.85.sdf)."""
    try:
        if "confidence" in filename.lower():
            parts = filename.lower().split("confidence")
            if len(parts) > 1:
                conf_str = parts[1].replace("-", "").replace("_", "").replace(".sdf", "")
                return float(conf_str)
    except:
        pass
    return 0.0


def extract_rank_from_filename(filename: str) -> int:
    """Extract rank from DiffDock output filename (e.g., rank1_confidence-0.85.sdf)."""
    try:
        if "rank" in filename.lower():
            parts = filename.lower().split("rank")
            if len(parts) > 1:
                rank_str = ""
                for c in parts[1]:
                    if c.isdigit():
                        rank_str += c
                    else:
                        break
                if rank_str:
                    return int(rank_str)
    except:
        pass
    return 0


def prepare_protein_for_diffdock(input_pdb: Path, output_dir: Path) -> Path:
    """
    Prepare a protein PDB file for DiffDock by fixing common issues.
    """
    if input_pdb.is_dir():
        pdb_files = sorted(input_pdb.glob("*.pdb"))
        if not pdb_files:
            raise FileNotFoundError(f"No .pdb files found in directory: {input_pdb}")
        print(f"Preparing {len(pdb_files)} PDB files from {input_pdb.name}/")
        for pdb in pdb_files:
            prepared = _prepare_single_protein(pdb, output_dir)
            print(f"  ✓ {prepared.name}")
        return output_dir
    else:
        return _prepare_single_protein(input_pdb, output_dir)


def _prepare_single_protein(input_pdb: Path, output_dir: Path) -> Path:
    """Prepare a single PDB file for DiffDock."""
    output_dir.mkdir(parents=True, exist_ok=True)
    output_pdb = output_dir / f"{input_pdb.stem}_prepared.pdb"
    
    residue_mapping = {
        'HSD': 'HIS', 'HSE': 'HIS', 'HSP': 'HIS',
        'HIE': 'HIS', 'HID': 'HIS', 'HIP': 'HIS',
    }
    
    with open(input_pdb, 'r') as f_in, open(output_pdb, 'w') as f_out:
        for line in f_in:
            if line.startswith('ATOM'):
                res_name = line[17:20].strip()
                if res_name in residue_mapping:
                    new_res = residue_mapping[res_name]
                    line = line[:17] + f"{new_res:>3}" + line[20:]
                f_out.write(line)
            elif line.startswith(('END', 'TER')):
                f_out.write(line)
    
    return output_pdb


def prepare_ligand_for_diffdock(input_sdf: Path, output_dir: Path) -> Path:
    """Prepare a ligand SDF file for DiffDock by fixing valence/charge issues."""
    output_dir.mkdir(parents=True, exist_ok=True)
    output_sdf = output_dir / f"{input_sdf.stem}_prepared.sdf"
    
    default_valence = {
        'C': 4, 'N': 3, 'O': 2, 'S': 2, 'P': 3,
        'F': 1, 'Cl': 1, 'Br': 1, 'I': 1, 'B': 3,
    }
    
    try:
        with open(input_sdf, 'r') as f:
            lines = f.readlines()
        
        if len(lines) < 5:
            return input_sdf
        
        counts_line = lines[3]
        try:
            num_atoms = int(counts_line[:3])
            num_bonds = int(counts_line[3:6])
        except ValueError:
            return input_sdf
        
        if len(lines) < 4 + num_atoms + num_bonds:
            return input_sdf
        
        atom_symbols = []
        explicit_valences = []
        
        for i in range(4, 4 + num_atoms):
            line = lines[i]
            parts = line.split()
            if len(parts) >= 10:
                symbol = parts[3]
                atom_symbols.append(symbol)
                try:
                    val = int(parts[9])
                except (ValueError, IndexError):
                    val = 0
                explicit_valences.append(val)
            else:
                atom_symbols.append('?')
                explicit_valences.append(0)
        
        bond_counts = [0] * num_atoms
        for i in range(4 + num_atoms, 4 + num_atoms + num_bonds):
            line = lines[i]
            parts = line.split()
            if len(parts) >= 3:
                try:
                    a1 = int(parts[0]) - 1
                    a2 = int(parts[1]) - 1
                    bond_order = int(parts[2])
                except ValueError:
                    continue
                if 0 <= a1 < num_atoms and 0 <= a2 < num_atoms:
                    bond_counts[a1] += bond_order
                    bond_counts[a2] += bond_order
        
        charges_to_add = {}
        for idx in range(num_atoms):
            symbol = atom_symbols[idx]
            if symbol not in default_valence:
                continue
            dv = default_valence[symbol]
            bc = bond_counts[idx]
            ev = explicit_valences[idx]
            if bc > dv and ev > 0:
                charge = bc - dv
                charges_to_add[idx + 1] = charge
        
        if not charges_to_add:
            return input_sdf
        
        charge_atoms = list(charges_to_add.items())
        chg_line = f"M  CHG  {len(charge_atoms)}"
        for atom_idx, charge in charge_atoms:
            chg_line += f"  {atom_idx:3d}  {charge:3d}"
        chg_line += "\n"
        
        with open(output_sdf, 'w') as f:
            for line in lines:
                if line.strip() == "M  END":
                    f.write(chg_line)
                f.write(line)
        
        fixed_atoms = ", ".join(f"atom #{k} ({atom_symbols[k-1]}) -> +{v}" for k, v in charges_to_add.items())
        print(f"  ⚠ Fixed missing charges in {input_sdf.name}: {fixed_atoms}")
        
        return output_sdf
    
    except Exception as e:
        print(f"  ⚠ Could not parse {input_sdf.name} for charge fixing ({e}), using original")
        return input_sdf


def load_error_log(output_dir: Path) -> Dict[str, dict]:
    """Load the error log for a given output directory."""
    error_log_path = output_dir / ERROR_LOG_FILENAME
    if error_log_path.exists():
        try:
            with open(error_log_path, 'r') as f:
                return json.load(f)
        except (json.JSONDecodeError, Exception) as e:
            print(f"  ⚠ Could not read error log {error_log_path}: {e}")
    return {}


def save_error_log(output_dir: Path, error_log: Dict[str, dict]):
    """Save the error log for a given output directory."""
    error_log_path = output_dir / ERROR_LOG_FILENAME
    output_dir.mkdir(parents=True, exist_ok=True)
    with open(error_log_path, 'w') as f:
        json.dump(error_log, f, indent=2)


def record_failure(output_dir: Path, combo_name: str, result: "DockingResult"):
    """Record a single failure to the error log."""
    error_log = load_error_log(output_dir)
    error_log[combo_name] = {
        "error": result.error_message,
        "timestamp": datetime.now().isoformat(),
        "protein": result.protein_name,
        "ligand": result.ligand_name,
        "elapsed_time": round(result.elapsed_time, 2),
    }
    save_error_log(output_dir, error_log)


def is_known_failure(output_dir: Path, combo_name: str, error_log: Optional[Dict] = None) -> bool:
    """Check if a combination is in the error log."""
    if error_log is None:
        error_log = load_error_log(output_dir)
    return combo_name in error_log

# %% [markdown]
# # Docking Log & Molecular Properties

# %%
DOCKING_LOG_FILENAME = "docking_log.csv"

DOCKING_LOG_COLUMNS = [
    "timestamp", "combo_name", "protein_name", "ligand_name",
    "status", "error_reason", "num_poses", "elapsed_time_s",
    # Ligand properties
    "lig_molecular_weight", "lig_heavy_atoms", "lig_total_atoms",
    "lig_rotatable_bonds", "lig_num_rings", "lig_aromatic_rings",
    "lig_hbd", "lig_hba", "lig_tpsa", "lig_logp", "lig_formula",
    # Protein properties
    "prot_num_residues", "prot_num_atoms", "prot_num_chains",
    # Config & hardware
    "num_samples", "inference_steps", "device", "gpu_model",
    # Best pose confidence
    "best_confidence",
]


def get_gpu_model() -> str:
    """Return the GPU model name via nvidia-smi, or 'N/A' if unavailable."""
    try:
        result = subprocess.run(
            ["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"],
            capture_output=True, text=True, timeout=5,
        )
        names = [line.strip() for line in result.stdout.strip().splitlines() if line.strip()]
        return names[0] if names else "N/A"
    except Exception:
        return "N/A"


def get_ligand_properties(sdf_path: Path) -> Dict:
    """Extract molecular properties from a ligand SDF file using RDKit."""
    props = {
        "lig_molecular_weight": None, "lig_heavy_atoms": None,
        "lig_total_atoms": None, "lig_rotatable_bonds": None,
        "lig_num_rings": None, "lig_aromatic_rings": None,
        "lig_hbd": None, "lig_hba": None, "lig_tpsa": None,
        "lig_logp": None, "lig_formula": None,
    }
    try:
        supplier = Chem.SDMolSupplier(str(sdf_path), sanitize=False, removeHs=False)
        mol = next(iter(supplier), None)
        if mol is None:
            return props
        try:
            Chem.SanitizeMol(mol)
        except Exception:
            pass

        props["lig_molecular_weight"] = round(Descriptors.MolWt(mol), 2)
        props["lig_heavy_atoms"] = mol.GetNumHeavyAtoms()
        props["lig_total_atoms"] = mol.GetNumAtoms()
        props["lig_rotatable_bonds"] = rdMolDescriptors.CalcNumRotatableBonds(mol)
        ri = mol.GetRingInfo()
        props["lig_num_rings"] = ri.NumRings()
        props["lig_aromatic_rings"] = rdMolDescriptors.CalcNumAromaticRings(mol)
        props["lig_hbd"] = Lipinski.NumHDonors(mol)
        props["lig_hba"] = Lipinski.NumHAcceptors(mol)
        props["lig_tpsa"] = round(Descriptors.TPSA(mol), 2)
        props["lig_logp"] = round(Descriptors.MolLogP(mol), 2)
        props["lig_formula"] = rdMolDescriptors.CalcMolFormula(mol)
    except Exception as e:
        print(f"  ⚠ Could not compute ligand properties for {sdf_path.name}: {e}")
    return props


def get_protein_properties(pdb_path: Path) -> Dict:
    """Extract basic protein properties by parsing PDB ATOM records."""
    props = {"prot_num_residues": None, "prot_num_atoms": None, "prot_num_chains": None}
    try:
        residues = set()
        chains = set()
        atom_count = 0
        with open(pdb_path, 'r') as f:
            for line in f:
                if line.startswith("ATOM"):
                    atom_count += 1
                    chain_id = line[21]
                    res_seq = line[22:27].strip()
                    residues.add((chain_id, res_seq))
                    chains.add(chain_id)
        props["prot_num_residues"] = len(residues)
        props["prot_num_atoms"] = atom_count
        props["prot_num_chains"] = len(chains)
    except Exception as e:
        print(f"  ⚠ Could not parse protein {pdb_path.name}: {e}")
    return props


def ligand_props_valid(props: Dict) -> bool:
    """Return True if at least one key ligand property was computed successfully."""
    return props.get("lig_heavy_atoms") is not None


def precompute_properties(
    proteins: List[Path],
    ligands: List[Path],
) -> Tuple[Dict[Path, Dict], Dict[Path, Dict]]:
    """Pre-compute molecular properties for all proteins and ligands before docking.

    Returns (lig_props_cache, prot_props_cache) keyed by file path.
    """
    lig_props_cache: Dict[Path, Dict] = {}
    prot_props_cache: Dict[Path, Dict] = {}

    print("Pre-computing ligand properties...")
    for lig in ligands:
        lig_props_cache[lig] = get_ligand_properties(lig)
    print(f"  {len(lig_props_cache)} ligands analysed")

    print("Pre-computing protein properties...")
    for prot in proteins:
        prot_props_cache[prot] = get_protein_properties(prot)
    print(f"  {len(prot_props_cache)} proteins analysed")

    return lig_props_cache, prot_props_cache


# Detect GPU once at definition time — reused for every log row
_GPU_MODEL = get_gpu_model()
print(f"GPU detected: {_GPU_MODEL}")


def _build_log_row(
    result: "DockingResult",
    lig_props: Dict,
    prot_props: Dict,
    samples: int,
    steps: int,
    device: str,
) -> Dict:
    """Build a single row dict for the docking log CSV."""
    best_conf = 0.0
    if result.pose_files:
        confs = [extract_confidence_from_filename(p.name) for p in result.pose_files]
        best_conf = max(confs) if confs else 0.0

    row = {
        "timestamp": datetime.now().isoformat(),
        "combo_name": f"{result.ligand_name}__{result.protein_name}",
        "protein_name": result.protein_name,
        "ligand_name": result.ligand_name,
        "status": result.status,
        "error_reason": result.error_message if result.status == "failed" else "",
        "num_poses": result.num_poses,
        "elapsed_time_s": round(result.elapsed_time, 2),
        "best_confidence": round(best_conf, 4),
        "num_samples": samples,
        "inference_steps": steps,
        "device": device,
        "gpu_model": _GPU_MODEL,
    }
    row.update(lig_props)
    row.update(prot_props)
    return row


def init_docking_log(output_dir: Path) -> Tuple[Path, set]:
    """Initialise the docking log CSV and return (log_path, existing_combo_names).

    Creates the file with a header row if it does not yet exist.
    """
    log_path = output_dir / DOCKING_LOG_FILENAME
    existing_combos: set = set()

    if log_path.exists():
        try:
            df = pd.read_csv(log_path)
            existing_combos = set(df["combo_name"])
        except Exception:
            pass
    else:
        pd.DataFrame(columns=DOCKING_LOG_COLUMNS).to_csv(log_path, index=False)

    return log_path, existing_combos


def append_log_rows(
    results: List["DockingResult"],
    log_path: Path,
    existing_combos: set,
    lig_props_cache: Dict[Path, Dict],
    prot_props_cache: Dict[Path, Dict],
    samples: int = NUM_SAMPLES,
    steps: int = INFERENCE_STEPS,
    device: str = DIFFDOCK_DEVICE,
) -> None:
    """Append log rows for a batch of results to the CSV, skipping duplicates."""
    rows = []
    for r in results:
        combo = f"{r.ligand_name}__{r.protein_name}"
        if combo in existing_combos:
            continue
        lig_props = lig_props_cache.get(r.ligand_path, get_ligand_properties(r.ligand_path))
        prot_props = prot_props_cache.get(r.protein_path, get_protein_properties(r.protein_path))
        rows.append(_build_log_row(r, lig_props, prot_props, samples, steps, device))
        existing_combos.add(combo)

    if not rows:
        return

    df = pd.DataFrame(rows, columns=DOCKING_LOG_COLUMNS)

    df.to_csv(log_path, mode='a', header=False, index=False)
    print("Docking log functions defined.")

    print(f"  📝 Appended {len(rows)} entries to {log_path.name} ({len(existing_combos)} total)")
# Out:
# GPU detected: NVIDIA A100-SXM4-80GB

# %% [markdown]
# # Summary & Reporting

# %%
def generate_summary(results: List[DockingResult]) -> Dict:
    """Generate summary of docking results."""
    summary = {
        "timestamp": datetime.now().isoformat(),
        "configuration": {
            "num_samples": NUM_SAMPLES,
            "device": DIFFDOCK_DEVICE,
            "diffdock_dir": str(DIFFDOCK_DIR),
        },
        "overall": {
            "total_combinations": len(results),
            "successful": sum(1 for r in results if r.status == "success"),
            "failed": sum(1 for r in results if r.status == "failed"),
            "skipped": sum(1 for r in results if r.status == "skipped"),
            "total_poses": sum(r.num_poses for r in results),
            "total_time_seconds": sum(r.elapsed_time for r in results),
        },
        "by_protein": defaultdict(lambda: {"combinations": 0, "poses": 0, "success": 0}),
        "by_ligand": defaultdict(lambda: {"combinations": 0, "poses": 0, "success": 0}),
        "combinations": [],
    }
    
    for r in results:
        summary["by_protein"][r.protein_name]["combinations"] += 1
        summary["by_protein"][r.protein_name]["poses"] += r.num_poses
        if r.status == "success":
            summary["by_protein"][r.protein_name]["success"] += 1
            
        summary["by_ligand"][r.ligand_name]["combinations"] += 1
        summary["by_ligand"][r.ligand_name]["poses"] += r.num_poses
        if r.status == "success":
            summary["by_ligand"][r.ligand_name]["success"] += 1
        
        summary["combinations"].append({
            "protein": r.protein_name,
            "ligand": r.ligand_name,
            "status": r.status,
            "num_poses": r.num_poses,
            "time_seconds": round(r.elapsed_time, 2),
            "error": r.error_message if r.error_message else None,
        })
    
    summary["by_protein"] = dict(summary["by_protein"])
    summary["by_ligand"] = dict(summary["by_ligand"])
    
    return summary


def print_summary(summary: Dict):
    """Print formatted docking summary."""
    print("\n" + "=" * 80)
    print("DIFFDOCK DOCKING SUMMARY")
    print("=" * 80)
    
    overall = summary["overall"]
    print(f"\nOverall Statistics:")
    print(f"  Total combinations: {overall['total_combinations']}")
    print(f"  Successful: {overall['successful']}")
    print(f"  Failed: {overall['failed']}")
    print(f"  Skipped: {overall['skipped']}")
    print(f"  Total poses generated: {overall['total_poses']}")
    print(f"  Total time: {overall['total_time_seconds']:.1f}s ({overall['total_time_seconds']/60:.1f} min)")
    
    print("\n" + "-" * 80)
    print("Results by Protein:")
    print("-" * 80)
    for protein, stats in sorted(summary["by_protein"].items()):
        print(f"  {protein:40s} | Combos: {stats['combinations']:3d} | Poses: {stats['poses']:4d}")
    
    print("\n" + "-" * 80)
    print("Results by Ligand:")
    print("-" * 80)
    for ligand, stats in sorted(summary["by_ligand"].items()):
        print(f"  {ligand:40s} | Combos: {stats['combinations']:3d} | Poses: {stats['poses']:4d}")

# %% [markdown]
# # DiffDock Inference Engine

# %%
def _build_diffdock_config(samples: int, steps: int, output_dir: Path) -> Path:
    """Create a runtime config YAML that merges DiffDock defaults with our settings."""
    default_yaml = DIFFDOCK_DIR / "default_inference_args.yaml"
    with open(default_yaml) as f:
        config = yaml.safe_load(f)

    config["samples_per_complex"] = samples
    config["inference_steps"] = steps
    config["actual_steps"] = steps - 1

    output_dir.mkdir(parents=True, exist_ok=True)
    custom_yaml = output_dir / "custom_inference_args.yaml"
    with open(custom_yaml, "w") as f:
        yaml.dump(config, f, default_flow_style=False)

    return custom_yaml


def _collect_ranked_poses(output_dir: Path) -> List[Path]:
    """Collect only the actual ranked pose SDF files from DiffDock output."""
    output_sdfs = list(output_dir.rglob("rank*_confidence*.sdf"))
    output_sdfs = [s for s in output_sdfs if s.stat().st_size > 0]
    return sorted(output_sdfs, key=lambda p: extract_rank_from_filename(p.name))


def _write_batch_csv(
    combos: List[Tuple[str, Path, Path]],
    csv_path: Path,
) -> Path:
    """Write a protein_ligand_csv for DiffDock batch inference.

    combos: list of (complex_name, prepared_protein_path, prepared_ligand_path)
    """
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['complex_name', 'protein_path', 'ligand_description', 'protein_sequence'])
        for name, prot, lig in combos:
            writer.writerow([name, str(prot.absolute()), str(lig.absolute()), ''])
    return csv_path


def _run_diffdock_batch_subprocess(
    csv_path: Path,
    out_dir: Path,
    config_yaml: Path,
    samples: int,
    device: str,
    timeout: int,
) -> subprocess.CompletedProcess:
    """Run DiffDock in CSV batch mode — streams stdout/stderr to log files."""
    cmd = [
        DIFFDOCK_PYTHON, "-m", "inference",
        "--config", str(config_yaml),
        "--protein_ligand_csv", str(csv_path),
        "--out_dir", str(out_dir),
        "--samples_per_complex", str(samples),
        "--no_final_step_noise",
    ]

    env = os.environ.copy()
    if device == "cpu":
        env["CUDA_VISIBLE_DEVICES"] = ""

    effective_timeout = timeout if timeout > 0 else None

    log_dir = out_dir / "_batch_logs"
    log_dir.mkdir(exist_ok=True)
    stdout_log = log_dir / f"batch_{csv_path.stem}_stdout.log"
    stderr_log = log_dir / f"batch_{csv_path.stem}_stderr.log"

    with open(stdout_log, "w") as fout, open(stderr_log, "w") as ferr:
        result = subprocess.run(
            cmd,
            stdout=fout,
            stderr=ferr,
            text=True,
            timeout=effective_timeout,
            cwd=str(DIFFDOCK_DIR),
            env=env,
        )

    result.stdout = stdout_log.read_text() if stdout_log.stat().st_size < 5_000_000 else f"[see {stdout_log}]"
    result.stderr = stderr_log.read_text() if stderr_log.stat().st_size < 5_000_000 else f"[see {stderr_log}]"

    return result


def create_protein_ligand_csv(
    proteins: List[Path],
    ligands: List[Path],
    output_csv: Path,
    prepare: bool = True,
) -> List[Tuple[str, Path, Path]]:
    """Create a CSV file for DiffDock batch inference."""
    combinations = []

    prepared_protein_cache: Dict[Path, Path] = {}
    prepared_ligand_cache: Dict[Path, Path] = {}
    if prepare:
        prepared_prot_dir = output_csv.parent / "prepared_proteins"
        for protein in proteins:
            if protein not in prepared_protein_cache:
                prepared_protein_cache[protein] = prepare_protein_for_diffdock(protein, prepared_prot_dir)
                print(f"  Prepared protein: {prepared_protein_cache[protein].name}")

        prepared_lig_dir = output_csv.parent / "prepared_ligands"
        for ligand in ligands:
            if ligand not in prepared_ligand_cache:
                if ligand.suffix.lower() == ".sdf":
                    prepared_ligand_cache[ligand] = prepare_ligand_for_diffdock(ligand, prepared_lig_dir)
                else:
                    prepared_ligand_cache[ligand] = ligand

    with open(output_csv, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['complex_name', 'protein_path', 'ligand_description', 'protein_sequence'])

        for protein in proteins:
            protein_name = get_file_stem(protein)
            protein_to_use = prepared_protein_cache.get(protein, protein)
            for ligand in ligands:
                ligand_name = get_file_stem(ligand)
                ligand_to_use = prepared_ligand_cache.get(ligand, ligand)
                complex_name = f"{ligand_name}__{protein_name}"

                writer.writerow([
                    complex_name,
                    str(protein_to_use.absolute()),
                    str(ligand_to_use.absolute()),
                    ''
                ])
                combinations.append((complex_name, protein, ligand))

    print(f"Created CSV with {len(combinations)} combinations: {output_csv}")
    return combinations


def _run_diffdock_subprocess(
    protein_path: Path,
    ligand_path: Path,
    output_dir: Path,
    output_base_dir: Path,
    samples: int,
    steps: int,
    device: str,
    timeout: int,
) -> Tuple[subprocess.CompletedProcess, List[Path]]:
    """Run DiffDock subprocess for a single complex."""
    config_yaml = _build_diffdock_config(samples, steps, output_base_dir)

    cmd = [
        DIFFDOCK_PYTHON, "-m", "inference",
        "--config", str(config_yaml),
        "--protein_path", str(protein_path),
        "--ligand_description", str(ligand_path),
        "--out_dir", str(output_dir),
        "--samples_per_complex", str(samples),
        "--no_final_step_noise",
    ]

    env = os.environ.copy()
    if device == "cpu":
        env["CUDA_VISIBLE_DEVICES"] = ""

    effective_timeout = timeout if timeout > 0 else None

    result = subprocess.run(
        cmd,
        capture_output=True,
        text=True,
        timeout=effective_timeout,
        cwd=str(DIFFDOCK_DIR),
        env=env,
    )

    output_sdfs = _collect_ranked_poses(output_dir)
    return result, output_sdfs


def run_diffdock_single(
    protein_path: Path,
    ligand_path: Path,
    output_dir: Path,
    output_base_dir: Path,
    samples: int = NUM_SAMPLES,
    steps: int = INFERENCE_STEPS,
    device: str = DIFFDOCK_DEVICE,
    timeout: int = TIMEOUT_PER_COMPLEX,
) -> Tuple[bool, List[Path], str]:
    """Run DiffDock inference for a single protein-ligand pair (with CUDA OOM fallback)."""
    output_dir.mkdir(parents=True, exist_ok=True)

    try:
        result, output_sdfs = _run_diffdock_subprocess(
            protein_path, ligand_path, output_dir, output_base_dir,
            samples, steps, device, timeout,
        )

        if output_sdfs:
            return True, output_sdfs, ""

        stderr = result.stderr or ""
        if ("OutOfMemoryError" in stderr or "CUDA out of memory" in stderr) and device != "cpu":
            print(f"  ⚠ CUDA OOM — retrying on CPU...")
            if output_dir.exists():
                shutil.rmtree(output_dir)
            output_dir.mkdir(parents=True, exist_ok=True)

            result, output_sdfs = _run_diffdock_subprocess(
                protein_path, ligand_path, output_dir, output_base_dir,
                samples, steps, "cpu", timeout,
            )

            if output_sdfs:
                return True, output_sdfs, ""

            return False, [], f"CPU fallback also failed. stderr: {result.stderr[-500:] if result.stderr else ''}"

        return False, [], f"No output SDF files found. stderr: {stderr[-500:]}"

    except subprocess.TimeoutExpired:
        return False, [], f"Docking timeout ({timeout}s)"
    except Exception as e:
        return False, [], str(e)


def _prepare_all_inputs(
    proteins: List[Path],
    ligands: List[Path],
    output_base_dir: Path,
) -> Tuple[Dict[Path, Path], Dict[Path, Path]]:
    """Prepare all proteins and ligands upfront (cached). Returns two caches."""
    prepared_prot_dir = output_base_dir / "prepared_proteins"
    prepared_lig_dir = output_base_dir / "prepared_ligands"

    prot_cache: Dict[Path, Path] = {}
    for protein in proteins:
        if protein not in prot_cache:
            prot_cache[protein] = prepare_protein_for_diffdock(protein, prepared_prot_dir)
    print(f"  Prepared {len(prot_cache)} proteins (cached in {prepared_prot_dir.name}/)")

    lig_cache: Dict[Path, Path] = {}
    for ligand in ligands:
        if ligand not in lig_cache:
            if ligand.suffix.lower() == ".sdf":
                lig_cache[ligand] = prepare_ligand_for_diffdock(ligand, prepared_lig_dir)
            else:
                lig_cache[ligand] = ligand
    print(f"  Prepared {len(lig_cache)} ligands (cached in {prepared_lig_dir.name}/)")

    return prot_cache, lig_cache

# %% [markdown]
# # Batch Docking Pipeline

# %%
def dock_single_combination(
    protein_path: Path,
    ligand_path: Path,
    output_base_dir: Path,
    prot_cache: Optional[Dict[Path, Path]] = None,
    lig_cache: Optional[Dict[Path, Path]] = None,
    samples: int = NUM_SAMPLES,
    steps: int = INFERENCE_STEPS,
    device: str = DIFFDOCK_DEVICE,
    timeout: int = TIMEOUT_PER_COMPLEX,
    error_log: Optional[Dict[str, dict]] = None,
) -> DockingResult:
    """Dock a single protein-ligand combination (uses caches if provided)."""
    protein_name = get_file_stem(protein_path)
    ligand_name = get_file_stem(ligand_path)
    combo_name = f"{ligand_name}__{protein_name}"
    output_dir = output_base_dir / combo_name
    
    result = DockingResult(
        protein_name=protein_name,
        ligand_name=ligand_name,
        protein_path=protein_path,
        ligand_path=ligand_path,
        output_dir=output_dir,
        status="pending",
    )
    
    if not OVERWRITE_ERROR_LOG and error_log and combo_name in error_log:
        prev = error_log[combo_name]
        result.status = "skipped"
        result.error_message = f"Previously failed: {prev.get('error', 'unknown')}"
        return result
    
    if not OVERWRITE_EXISTING and output_dir.exists():
        existing_sdfs = _collect_ranked_poses(output_dir)
        if existing_sdfs:
            result.status = "skipped"
            result.num_poses = len(existing_sdfs)
            result.pose_files = existing_sdfs
            return result
    
    start_time = time.time()
    
    if prot_cache and protein_path in prot_cache:
        prepared_protein = prot_cache[protein_path]
    else:
        prepared_dir = output_base_dir / "prepared_proteins"
        prepared_protein = prepare_protein_for_diffdock(protein_path, prepared_dir)
    
    if lig_cache and ligand_path in lig_cache:
        prepared_ligand = lig_cache[ligand_path]
    else:
        prepared_ligand_dir = output_base_dir / "prepared_ligands"
        if ligand_path.suffix.lower() == ".sdf":
            prepared_ligand = prepare_ligand_for_diffdock(ligand_path, prepared_ligand_dir)
        else:
            prepared_ligand = ligand_path
    
    success, pose_files, error = run_diffdock_single(
        protein_path=prepared_protein,
        ligand_path=prepared_ligand,
        output_dir=output_dir,
        output_base_dir=output_base_dir,
        samples=samples,
        steps=steps,
        device=device,
        timeout=timeout,
    )
    
    result.elapsed_time = time.time() - start_time
    
    if success and pose_files:
        result.status = "success"
        result.num_poses = len(pose_files)
        result.pose_files = pose_files
    else:
        result.status = "failed"
        result.error_message = error
        record_failure(output_base_dir, combo_name, result)
    
    return result


def _run_batch_csv_mode(
    combos_to_dock: List[Tuple[str, Path, Path, Path, Path]],
    output_dir: Path,
    prot_cache: Dict[Path, Path],
    lig_cache: Dict[Path, Path],
    samples: int,
    steps: int,
    device: str,
    timeout: int,
    error_log: Dict[str, dict],
    log_path: Optional[Path] = None,
    existing_combos: Optional[set] = None,
    lig_props_cache: Optional[Dict[Path, Dict]] = None,
    prot_props_cache: Optional[Dict[Path, Dict]] = None,
) -> List[DockingResult]:
    """
    Run DiffDock in CSV batch mode — one subprocess handles many complexes.
    Writes docking log incrementally after each batch.
    
    combos_to_dock: list of (combo_name, protein_path, ligand_path, orig_prot, orig_lig)
    """
    results = []
    
    if not combos_to_dock:
        return results
    
    batch_size = BATCH_SIZE if BATCH_SIZE > 0 else len(combos_to_dock)
    batches = [combos_to_dock[i:i + batch_size] for i in range(0, len(combos_to_dock), batch_size)]
    
    config_yaml = _build_diffdock_config(samples, steps, output_dir)
    
    combos_completed = 0
    total_combos = len(combos_to_dock)
    
    progress_file = output_dir / "_batch_logs" / "_progress.txt"
    progress_file.parent.mkdir(exist_ok=True)
    
    for batch_idx, batch in enumerate(batches):
        batch_start_idx = batch_idx * batch_size
        batch_end_idx = min(batch_start_idx + len(batch), total_combos)
        
        print(f"\n  ── Batch {batch_idx + 1}/{len(batches)} ({len(batch)} complexes) "
              f"[{batch_start_idx + 1}–{batch_end_idx} of {total_combos}] ──")
        
        for j, (combo_name, _, _, orig_prot, orig_lig) in enumerate(batch):
            prot_name = get_file_stem(orig_prot)
            lig_name = get_file_stem(orig_lig)
            print(f"    {batch_start_idx + j + 1:>4}/{total_combos}  {lig_name} + {prot_name}")
        
        progress_file.write_text(
            f"{combos_completed}/{total_combos}|batch {batch_idx + 1}/{len(batches)}|"
            + "|".join(f"{get_file_stem(op)}+{get_file_stem(ol)}" for _, _, _, op, ol in batch)
        )
        
        batch_start = time.time()
        batch_results = []
        
        csv_rows = []
        for combo_name, prot_path, lig_path, orig_prot, orig_lig in batch:
            prepared_prot = prot_cache.get(orig_prot, prot_path)
            prepared_lig = lig_cache.get(orig_lig, lig_path)
            csv_rows.append((combo_name, prepared_prot, prepared_lig))
        
        csv_path = output_dir / f"_batch_{batch_idx}.csv"
        _write_batch_csv(csv_rows, csv_path)
        
        batch_timeout = timeout * len(batch) if timeout > 0 else 0
        
        try:
            proc = _run_diffdock_batch_subprocess(
                csv_path=csv_path,
                out_dir=output_dir,
                config_yaml=config_yaml,
                samples=samples,
                device=device,
                timeout=batch_timeout,
            )
            
            batch_elapsed = time.time() - batch_start
            stderr = proc.stderr or ""
            
            batch_log_dir = output_dir / "_batch_logs"
            batch_log_dir.mkdir(exist_ok=True)
            if stderr:
                (batch_log_dir / f"batch_{batch_idx}_stderr.log").write_text(stderr)
            if proc.stdout:
                (batch_log_dir / f"batch_{batch_idx}_stdout.log").write_text(proc.stdout)
            
            if proc.returncode != 0:
                print(f"  ⚠ Batch subprocess exit code {proc.returncode}")
                error_lines = [l for l in stderr.splitlines() if any(k in l.lower() for k in ['error', 'exception', 'traceback', 'failed', 'cannot', 'no module'])]
                if error_lines:
                    for line in error_lines[:5]:
                        print(f"    {line.strip()[:200]}")
            
            if ("OutOfMemoryError" in stderr or "CUDA out of memory" in stderr) and device != "cpu":
                # Halve the batch and retry on GPU; fall back to CPU only at size 1
                sub_batches = [batch]
                retry_size = max(1, len(batch) // 2)
                while retry_size >= 1:
                    sub_batches = [batch[i:i + retry_size] for i in range(0, len(batch), retry_size)]
                    print(f"  ⚠ CUDA OOM on batch {batch_idx + 1} — retrying with sub-batch size {retry_size} on GPU...")
                    oom_again = False
                    for sb_idx, sub_batch in enumerate(sub_batches):
                        sub_csv_rows = [(cn, prot_cache.get(op, pp), lig_cache.get(ol, lp))
                                        for cn, pp, lp, op, ol in sub_batch]
                        sub_csv_path = output_dir / f"_batch_{batch_idx}_sub{sb_idx}.csv"
                        _write_batch_csv(sub_csv_rows, sub_csv_path)
                        sub_timeout = timeout * len(sub_batch) if timeout > 0 else 0
                        try:
                            proc = _run_diffdock_batch_subprocess(
                                csv_path=sub_csv_path,
                                out_dir=output_dir,
                                config_yaml=config_yaml,
                                samples=samples,
                                device=device,
                                timeout=sub_timeout,
                            )
                            sub_stderr = proc.stderr or ""
                            if "OutOfMemoryError" in sub_stderr or "CUDA out of memory" in sub_stderr:
                                oom_again = True
                                break
                        finally:
                            if sub_csv_path.exists():
                                sub_csv_path.unlink()
                    if not oom_again:
                        break
                    if retry_size == 1:
                        # GPU OOM even at size 1 — last resort: CPU
                        print(f"  ⚠ CUDA OOM even at batch size 1 — falling back to CPU...")
                        for sb_idx, sub_batch in enumerate(sub_batches):
                            sub_csv_rows = [(cn, prot_cache.get(op, pp), lig_cache.get(ol, lp))
                                            for cn, pp, lp, op, ol in sub_batch]
                            sub_csv_path = output_dir / f"_batch_{batch_idx}_cpu{sb_idx}.csv"
                            _write_batch_csv(sub_csv_rows, sub_csv_path)
                            sub_timeout = timeout * len(sub_batch) if timeout > 0 else 0
                            try:
                                proc = _run_diffdock_batch_subprocess(
                                    csv_path=sub_csv_path,
                                    out_dir=output_dir,
                                    config_yaml=config_yaml,
                                    samples=samples,
                                    device="cpu",
                                    timeout=sub_timeout,
                                )
                            finally:
                                if sub_csv_path.exists():
                                    sub_csv_path.unlink()
                        break
                    retry_size = max(1, retry_size // 2)
                batch_elapsed = time.time() - batch_start
                stderr = proc.stderr or ""
            
            for combo_name, prot_path, lig_path, orig_prot, orig_lig in batch:
                combo_dir = output_dir / combo_name
                pose_files = _collect_ranked_poses(combo_dir) if combo_dir.exists() else []
                
                r = DockingResult(
                    protein_name=get_file_stem(orig_prot),
                    ligand_name=get_file_stem(orig_lig),
                    protein_path=orig_prot,
                    ligand_path=orig_lig,
                    output_dir=combo_dir,
                    status="success" if pose_files else "failed",
                    num_poses=len(pose_files),
                    pose_files=pose_files,
                    error_message="" if pose_files else f"No poses from batch. stderr tail: {stderr[-300:]}",
                    elapsed_time=batch_elapsed / len(batch),
                )
                
                if r.status == "failed":
                    record_failure(output_dir, combo_name, r)
                    error_log[combo_name] = {
                        "error": r.error_message,
                        "timestamp": datetime.now().isoformat(),
                        "protein": r.protein_name,
                        "ligand": r.ligand_name,
                        "elapsed_time": round(r.elapsed_time, 2),
                    }
                
                batch_results.append(r)
                status_icon = "✓" if r.status == "success" else "✗"
                print(f"    {status_icon} {combo_name}: {r.num_poses} poses")
            
            combos_completed += len(batch)
            print(f"  Batch {batch_idx + 1} done in {batch_elapsed:.1f}s "
                  f"({batch_elapsed/len(batch):.1f}s/complex) "
                  f"— {combos_completed}/{total_combos} total")
        
        except subprocess.TimeoutExpired:
            print(f"  ✗ Batch {batch_idx + 1} timed out ({batch_timeout}s)")
            for combo_name, prot_path, lig_path, orig_prot, orig_lig in batch:
                r = DockingResult(
                    protein_name=get_file_stem(orig_prot),
                    ligand_name=get_file_stem(orig_lig),
                    protein_path=orig_prot,
                    ligand_path=orig_lig,
                    output_dir=output_dir / combo_name,
                    status="failed",
                    error_message=f"Batch timeout ({batch_timeout}s)",
                )
                record_failure(output_dir, combo_name, r)
                batch_results.append(r)
        
        except Exception as e:
            print(f"  ✗ Batch {batch_idx + 1} error: {e}")
            for combo_name, prot_path, lig_path, orig_prot, orig_lig in batch:
                r = DockingResult(
                    protein_name=get_file_stem(orig_prot),
                    ligand_name=get_file_stem(orig_lig),
                    protein_path=orig_prot,
                    ligand_path=orig_lig,
                    output_dir=output_dir / combo_name,
                    status="failed",
                    error_message=str(e),
                )
                record_failure(output_dir, combo_name, r)
                batch_results.append(r)
        
        finally:
            if csv_path.exists():
                csv_path.unlink()
        
        # Write log incrementally after each batch
        results.extend(batch_results)
        if log_path is not None and existing_combos is not None:
            append_log_rows(
                batch_results, log_path, existing_combos,
                lig_props_cache or {}, prot_props_cache or {},
                samples, steps, device,
            )
    
    if progress_file.exists():
        progress_file.unlink()
    
    return results


def run_diffdock_sequential(
    proteins: List[Path],
    ligands: List[Path],
    output_dir: Path,
    samples: int = NUM_SAMPLES,
    steps: int = INFERENCE_STEPS,
    device: str = DIFFDOCK_DEVICE,
    timeout: int = TIMEOUT_PER_COMPLEX,
) -> List[DockingResult]:
    """Run DiffDock for all protein-ligand combinations.
    
    Supports three modes:
      - USE_BATCH_MODE=True:  CSV batch (fastest — one DiffDock call per batch)
      - NUM_WORKERS>1:        parallel single-complex subprocesses (CPU only)
      - else:                 sequential single-complex subprocesses
    
    Molecular properties are pre-computed before docking starts and the
    docking log is written incrementally after each batch / result.
    """
    total = len(proteins) * len(ligands)
    results = []
    
    error_log = load_error_log(output_dir)
    if OVERWRITE_ERROR_LOG:
        error_log = {}
        save_error_log(output_dir, error_log)
        print("Error log cleared (OVERWRITE_ERROR_LOG=True)")
    
    num_prev_failed = len(error_log)
    
    print("=" * 80)
    print("DiffDock Docking")
    print("=" * 80)
    mode_str = "CSV batch" if USE_BATCH_MODE else (f"parallel ({NUM_WORKERS} workers)" if NUM_WORKERS > 1 else "sequential")
    print(f"Mode: {mode_str}")
    print(f"Output directory: {output_dir}")
    print(f"Proteins: {len(proteins)}  |  Ligands: {len(ligands)}  |  Total: {total}")
    print(f"Previously failed (will skip): {num_prev_failed}")
    print(f"Samples: {samples}  |  Steps: {steps}  |  Timeout: {timeout}s")
    
    if num_prev_failed > 0:
        print(f"\nPreviously failed (from {ERROR_LOG_FILENAME}):")
        for i, (name, info) in enumerate(sorted(error_log.items())):
            if i < 10:
                print(f"  ✗ {name}: {info.get('error', 'unknown')[:80]}")
        if num_prev_failed > 10:
            print(f"  ... and {num_prev_failed - 10} more")

    # ── Pre-compute molecular properties before docking ──
    lig_props_cache, prot_props_cache = precompute_properties(proteins, ligands)

    # ── Exclude ligands that RDKit cannot parse (all properties None) ──
    invalid_ligs = [lig for lig in ligands if not ligand_props_valid(lig_props_cache.get(lig, {}))]
    if invalid_ligs:
        print(f"\n  ⚠ Excluding {len(invalid_ligs)} unreadable ligand(s):")
        for lig in invalid_ligs:
            print(f"    ✗ {lig.name}")
        ligands = [lig for lig in ligands if ligand_props_valid(lig_props_cache.get(lig, {}))]
        total = len(proteins) * len(ligands)
        print(f"  Remaining: {len(ligands)} ligands × {len(proteins)} proteins = {total} combinations")

    # ── Initialise docking log (create CSV header if needed) ──
    log_path, existing_combos = init_docking_log(output_dir)
    print(f"Docking log: {log_path} ({len(existing_combos)} existing entries)")

    # ── Prepare all inputs upfront (shared cache) ──
    print("\nPreparing inputs...")
    prot_cache, lig_cache = _prepare_all_inputs(proteins, ligands, output_dir)
    
    # ── Classify combos: skip vs dock ──
    combos_to_dock = []
    skipped_results = []
    
    for protein in proteins:
        for ligand in ligands:
            prot_stem = get_file_stem(protein)
            lig_stem = get_file_stem(ligand)
            combo_name = f"{lig_stem}__{prot_stem}"
            combo_dir = output_dir / combo_name
            
            if not OVERWRITE_ERROR_LOG and combo_name in error_log:
                skipped_results.append(DockingResult(
                    protein_name=prot_stem, ligand_name=lig_stem,
                    protein_path=protein, ligand_path=ligand,
                    output_dir=combo_dir, status="skipped",
                    error_message=f"Previously failed: {error_log[combo_name].get('error', 'unknown')[:100]}",
                ))
                continue
            
            if not OVERWRITE_EXISTING and combo_dir.exists():
                existing = _collect_ranked_poses(combo_dir)
                if existing:
                    skipped_results.append(DockingResult(
                        protein_name=prot_stem, ligand_name=lig_stem,
                        protein_path=protein, ligand_path=ligand,
                        output_dir=combo_dir, status="skipped",
                        num_poses=len(existing), pose_files=existing,
                    ))
                    continue
            
            prepared_prot = prot_cache.get(protein, protein)
            prepared_lig = lig_cache.get(ligand, ligand)
            combos_to_dock.append((combo_name, prepared_prot, prepared_lig, protein, ligand))
    
    results.extend(skipped_results)
    n_skip_fail = sum(1 for r in skipped_results if r.error_message.startswith("Previously"))
    n_skip_done = len(skipped_results) - n_skip_fail
    print(f"\nSkipping {n_skip_done} already docked + {n_skip_fail} previously failed = {len(skipped_results)} total")
    print(f"Will dock: {len(combos_to_dock)} combinations")

    # Log skipped results immediately so they appear in the CSV
    if skipped_results:
        append_log_rows(
            skipped_results, log_path, existing_combos,
            lig_props_cache, prot_props_cache,
            samples, steps, device,
        )
    
    if not combos_to_dock:
        print("Nothing to dock!")
        save_error_log(output_dir, error_log)
        return results
    
    # ── Dock ──
    start_all = time.time()
    
    if USE_BATCH_MODE:
        batch_results = _run_batch_csv_mode(
            combos_to_dock=combos_to_dock,
            output_dir=output_dir,
            prot_cache=prot_cache,
            lig_cache=lig_cache,
            samples=samples,
            steps=steps,
            device=device,
            timeout=timeout,
            error_log=error_log,
            log_path=log_path,
            existing_combos=existing_combos,
            lig_props_cache=lig_props_cache,
            prot_props_cache=prot_props_cache,
        )
        results.extend(batch_results)
    
    elif NUM_WORKERS > 1:
        print(f"\nRunning {len(combos_to_dock)} complexes with {NUM_WORKERS} parallel workers...")
        
        def _dock_one(args):
            combo_name, prep_prot, prep_lig, orig_prot, orig_lig = args
            combo_dir = output_dir / combo_name
            combo_dir.mkdir(parents=True, exist_ok=True)
            t0 = time.time()
            success, poses, err = run_diffdock_single(
                prep_prot, prep_lig, combo_dir, output_dir,
                samples, steps, device, timeout,
            )
            elapsed = time.time() - t0
            r = DockingResult(
                protein_name=get_file_stem(orig_prot),
                ligand_name=get_file_stem(orig_lig),
                protein_path=orig_prot, ligand_path=orig_lig,
                output_dir=combo_dir,
                status="success" if success else "failed",
                num_poses=len(poses), pose_files=poses,
                error_message=err, elapsed_time=elapsed,
            )
            return combo_name, r
        
        with ThreadPoolExecutor(max_workers=NUM_WORKERS) as executor:
            futures = {executor.submit(_dock_one, c): c[0] for c in combos_to_dock}
            batch_buffer = []
            for i, future in enumerate(as_completed(futures), 1):
                combo_name, r = future.result()
                results.append(r)
                batch_buffer.append(r)
                if r.status == "failed":
                    record_failure(output_dir, combo_name, r)
                    error_log[combo_name] = {
                        "error": r.error_message,
                        "timestamp": datetime.now().isoformat(),
                        "protein": r.protein_name,
                        "ligand": r.ligand_name,
                        "elapsed_time": round(r.elapsed_time, 2),
                    }
                icon = "✓" if r.status == "success" else "✗"
                print(f"  [{i}/{len(combos_to_dock)}] {icon} {combo_name}: {r.num_poses} poses ({r.elapsed_time:.1f}s)")
                # Flush to log every BATCH_SIZE results (or at the end)
                if len(batch_buffer) >= BATCH_SIZE or i == len(combos_to_dock):
                    append_log_rows(
                        batch_buffer, log_path, existing_combos,
                        lig_props_cache, prot_props_cache,
                        samples, steps, device,
                    )
                    batch_buffer = []
    
    else:
        for i, (combo_name, _, _, orig_prot, orig_lig) in enumerate(combos_to_dock, 1):
            print(f"\n[{i}/{len(combos_to_dock)}] {get_file_stem(orig_lig)} + {get_file_stem(orig_prot)}")
            
            r = dock_single_combination(
                protein_path=orig_prot,
                ligand_path=orig_lig,
                output_base_dir=output_dir,
                prot_cache=prot_cache,
                lig_cache=lig_cache,
                samples=samples, steps=steps,
                device=device, timeout=timeout,
                error_log=error_log,
            )
            
            if r.status == "failed":
                error_log[combo_name] = {
                    "error": r.error_message,
                    "timestamp": datetime.now().isoformat(),
                    "protein": r.protein_name,
                    "ligand": r.ligand_name,
                    "elapsed_time": round(r.elapsed_time, 2),
                }
            
            results.append(r)
            icon = {"success": "✓", "failed": "✗", "skipped": "⊘"}.get(r.status, "?")
            print(f"  {icon} {r.status} | Poses: {r.num_poses} | Time: {r.elapsed_time:.1f}s")
            if r.error_message:
                print(f"    Error: {r.error_message[:200]}")
            
            # Write to log after each individual docking
            append_log_rows(
                [r], log_path, existing_combos,
                lig_props_cache, prot_props_cache,
                samples, steps, device,
            )
    
    total_time = time.time() - start_all
    n_success = sum(1 for r in results if r.status == "success")
    n_failed = sum(1 for r in results if r.status == "failed")

    print(f"\nDocking complete in {total_time:.1f}s ({total_time/60:.1f} min)")
    print("Batch docking functions defined.")

    print(f"  Success: {n_success}  |  Failed: {n_failed}  |  Skipped: {len(skipped_results)}")

    

    save_error_log(output_dir, error_log)    
    return results

    print(f"Error log saved: {output_dir / ERROR_LOG_FILENAME} ({len(error_log)} entries)")
    print(f"Docking log: {log_path} ({len(existing_combos)} entries)")

# %% [markdown]
# # Pre-flight Check

# %%
errors = []

# Check DiffDock directory + config
if not DIFFDOCK_DIR.exists():
    errors.append(f"✗ DiffDock dir missing: {DIFFDOCK_DIR}")
default_yaml = DIFFDOCK_DIR / "default_inference_args.yaml"
if not default_yaml.exists():
    errors.append(f"✗ DiffDock config missing: {default_yaml}")

# Check Python executable
if not Path(DIFFDOCK_PYTHON).exists():
    errors.append(f"✗ DiffDock Python not found: {DIFFDOCK_PYTHON}")

# Check that key functions are the correct (latest) versions
src = inspect.getsource(_run_diffdock_subprocess)
if "subprocess.run" not in src:
    errors.append("✗ _run_diffdock_subprocess is incomplete (missing subprocess.run) — re-run the correct cell")
if "sys.executable" in src:
    errors.append("⚠ _run_diffdock_subprocess uses sys.executable instead of DIFFDOCK_PYTHON")

# Check inputs exist
for drugs_dir in drugs_dirs:
    proteins = collect_files(receptors_dir, [".pdb"])
    ligands = collect_files(drugs_dir, [".sdf", ".mol2"])
    print(f"  {drugs_dir.name}: {len(proteins)} proteins, {len(ligands)} ligands")
    if not proteins:
        errors.append(f"✗ No .pdb files in {receptors_dir}")
    if not ligands:
        errors.append(f"✗ No .sdf/.mol2 files in {drugs_dir}")

if errors:
    print("\n⚠ ISSUES FOUND:")
    for e in errors:
        print(f"  {e}")
    print("\nFix these before running docking.")
else:
    print("\n✓ All checks passed — ready to dock.")
# Out:
#   ligands_sdf_large_approvedA100: 4 proteins, 600 ligands
#   ligands_sdf_small_symmetric_approved: 4 proteins, 596 ligands
#
# ✓ All checks passed — ready to dock.

# %%
def _monitor_progress(output_dir: Path, stop_event: threading.Event, poll_interval: float = 10.0):
    """Background thread that periodically prints docking progress."""
    log_dir = output_dir / "_batch_logs"
    progress_file = log_dir / "_progress.txt"
    start_time = time.time()
    
    while not stop_event.is_set():
        stop_event.wait(poll_interval)
        if stop_event.is_set():
            break
        
        elapsed = time.time() - start_time
        
        # Count completed poses (directories with rank1 SDF files)
        rank1_files = list(output_dir.glob("*/rank1_*.sdf"))
        n_done = len(rank1_files)
        
        # Count empty dirs (in-progress or failed)
        all_combo_dirs = [d for d in output_dir.iterdir() 
                         if d.is_dir() and not d.name.startswith("_") 
                         and d.name not in ("prepared_proteins", "prepared_ligands")]
        n_empty = sum(1 for d in all_combo_dirs if not list(d.glob("rank1_*.sdf")))
        
        # Read progress file written by batch mode
        current_batch_info = ""
        current_combos = ""
        if progress_file.exists():
            try:
                parts = progress_file.read_text().strip().split("|")
                if len(parts) >= 2:
                    current_batch_info = f"[{parts[0]} combos] {parts[1]}"
                if len(parts) >= 3:
                    current_combos = ", ".join(parts[2:6])  # show up to 4 current combos
                    if len(parts) > 6:
                        current_combos += f" (+{len(parts) - 6} more)"
            except Exception:
                pass
        
        # GPU utilization
        try:
            gpu_info = subprocess.run(
                ["nvidia-smi", "--query-gpu=utilization.gpu,memory.used,memory.total", "--format=csv,noheader,nounits"],
                capture_output=True, text=True, timeout=5
            )
            gpu_line = gpu_info.stdout.strip()
        except Exception:
            gpu_line = "N/A"
        
        # Read last line of stdout log for DiffDock's own progress
        diffdock_status = ""
        log_files = sorted(log_dir.glob("batch_*_stdout.log")) if log_dir.exists() else []
        if log_files:
            try:
                with open(log_files[-1], 'r') as f:
                    lines = f.readlines()
                    for line in reversed(lines):
                        stripped = line.strip()
                        if stripped:
                            diffdock_status = stripped[:120]
                            break
            except Exception:
                pass
        
        # stderr last meaningful line (skip noise)
        STDERR_SKIP = {"FutureWarning", "DeprecationWarning", "KeyboardInterrupt", "UserWarning"}
        stderr_status = ""
        stderr_files = sorted(log_dir.glob("batch_*_stderr.log")) if log_dir.exists() else []
        if stderr_files:
            try:
                with open(stderr_files[-1], 'r') as f:
                    lines = f.readlines()
                    for line in reversed(lines):
                        stripped = line.strip()
                        if stripped and not any(skip in stripped for skip in STDERR_SKIP):
                            stderr_status = stripped[:120]
                            break
            except Exception:
                pass
        
        mins, secs = divmod(int(elapsed), 60)
        hrs, mins = divmod(mins, 60)
        time_str = f"{hrs}h{mins:02d}m{secs:02d}s" if hrs else f"{mins}m{secs:02d}s"
        
        line1 = f"  ⏱ {time_str} | ✓ {n_done} done | ⏳ {n_empty} pending | GPU: {gpu_line}"
        if current_batch_info:
            line1 += f" | {current_batch_info}"
        print(line1)
        if current_combos:
            print(f"    Docking: {current_combos}")
        if diffdock_status:
            print(f"    DiffDock: {diffdock_status}")
        if stderr_status:
            print(f"    Status:   {stderr_status}")


all_diffdock_results = []

for drugs_dir in drugs_dirs:
    DIFFDOCK_OUTPUT_DIR = DIFFDOCK_OUTPUT_BASE / drugs_dir.name
    DIFFDOCK_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    
    print(f"\n{'=' * 80}")
    print(f"Processing ligand directory: {drugs_dir.name}")
    print(f"Output: {DIFFDOCK_OUTPUT_DIR}")
    print(f"{'=' * 80}")
    
    # Collect input files
    proteins = collect_files(receptors_dir, [".pdb"])
    ligands = collect_files(drugs_dir, [".sdf", ".mol2"])
    
    print(f"Found {len(proteins)} proteins and {len(ligands)} ligands")
    
    if not proteins or not ligands:
        print("⚠ No proteins or ligands found, skipping.")
        continue
    
    # Start progress monitor
    stop_monitor = threading.Event()
    monitor_thread = threading.Thread(
        target=_monitor_progress,
        args=(DIFFDOCK_OUTPUT_DIR, stop_monitor, 15),
        daemon=True,
    )
    monitor_thread.start()
    
    try:
        # Run docking
        results = run_diffdock_sequential(
            proteins=proteins,
            ligands=ligands,
            output_dir=DIFFDOCK_OUTPUT_DIR,
        )
    finally:
        stop_monitor.set()
        monitor_thread.join(timeout=5)
    
    all_diffdock_results.extend(results)
    
    # Generate and print summary
    summary = generate_summary(results)
    print_summary(summary)
    
    # Save summary JSON
    summary_path = DIFFDOCK_OUTPUT_DIR / "docking_summary.json"
    with open(summary_path, 'w') as f:
        json.dump(summary, f, indent=2, default=str)
    print(f"\nSummary saved: {summary_path}")
    
    # Docking log was written incrementally during docking — no final write needed

diffdock_results = all_diffdock_results
print(f"\n{'=' * 80}")
print(f"ALL DONE — {len(diffdock_results)} total results across {len(drugs_dirs)} ligand directories")
print(f"{'=' * 80}")
# Out:
# ================================================================================
# Processing ligand directory: ligands_sdf_large_approvedA100
# Output: /workspace/diffdock_results/ligands_sdf_large_approvedA100
# ================================================================================
# Found 4 proteins and 600 ligands
# Error log cleared (OVERWRITE_ERROR_LOG=True)
# ================================================================================
# DiffDock Docking
# ================================================================================
# Mode: CSV batch
# Output directory: /workspace/diffdock_results/ligands_sdf_large_approvedA100
# Proteins: 4  |  Ligands: 600  |  Total: 2400
# Previously failed (will skip): 0
# Samples: 10  |  Steps: 20  |  Timeout: 300s
# Pre-computing ligand properties...
#   600 ligands analysed
# Pre-computing protein properties...
#   4 proteins analysed
# Docking log: /workspace/diffdock_results/ligands_sdf_large_approvedA100/docking_log.csv (2400 existing entries)
#
# Preparing inputs...
#   Prepared 4 proteins (cached in prepared_proteins/)
#   Prepared 600 ligands (cached in prepared_ligands/)
#
# Skipping 2142 already docked + 0 previously failed = 2142 total
# Will dock: 258 combinations
#
#   ── Batch 1/18 (15 complexes) [1–15 of 258] ──
#        1/258  10A_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        2/258  138_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        3/258  16A_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        4/258  3PC_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        5/258  6F6_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        6/258  74T_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        7/258  88Z_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        8/258  8DZ_ideal + Orai1WT-MDSnap-Fr300_cleaned
#        9/258  98I_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       10/258  A1JSO_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       11/258  A1LVF_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       12/258  A1LY1_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       13/258  AGH_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       14/258  BV4_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       15/258  BY6_ideal + Orai1WT-MDSnap-Fr300_cleaned
#   ⏱ 0m15s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 1, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 0m42s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 5, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 1m08s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 5, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 1m36s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 5, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 2m03s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 3857, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 2m30s | ✓ 2142 done | ⏳ 258 pending | GPU: 100, 28779, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 2m57s | ✓ 2142 done | ⏳ 258 pending | GPU: 100, 38575, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 3m23s | ✓ 2142 done | ⏳ 258 pending | GPU: 99, 50611, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 3m49s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 50611, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 4m15s | ✓ 2142 done | ⏳ 258 pending | GPU: 100, 75203, 81920 | [0/258 combos] batch 1/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+10A_ideal, Orai1WT-MDSnap-Fr300_cleaned+138_ideal, Orai1WT-MDSnap-Fr300_cleaned+16A_ideal, Orai1WT-MDSnap-Fr300_cleaned+3PC_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#     ✗ 10A_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 138_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 16A_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 3PC_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 6F6_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 74T_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 88Z_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 8DZ_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 98I_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ A1JSO_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ A1LVF_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ A1LY1_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ AGH_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ BV4_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ BY6_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#   Batch 1 done in 243.8s (16.3s/complex) — 15/258 total
#
#   ── Batch 2/18 (15 complexes) [16–30 of 258] ──
#       16/258  CBD_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       17/258  CDL_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       18/258  CPL_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       19/258  DDT_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       20/258  DGX_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       21/258  DLP_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       22/258  DR6_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       23/258  DRB_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       24/258  DSO_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       25/258  E55_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       26/258  EH5_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       27/258  GAH_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       28/258  GBM_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       29/258  IB2_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       30/258  J12_ideal + Orai1WT-MDSnap-Fr300_cleaned
#   ⏱ 4m40s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 5, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 5m06s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 5, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 5m34s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 5, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 5m58s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 3857, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 6m23s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 25489, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 6m49s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44107, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 7m15s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44109, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 7m41s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 8m07s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 8m34s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 9m00s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 9m27s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 9m55s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 10m21s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 10m48s | ✓ 2142 done | ⏳ 258 pending | GPU: 0, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 11m15s | ✓ 2142 done | ⏳ 258 pending | GPU: 2, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 11m42s | ✓ 2142 done | ⏳ 258 pending | GPU: 62, 44111, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 12m08s | ✓ 2143 done | ⏳ 257 pending | GPU: 0, 44113, 81920 | [15/258 combos] batch 2/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr300_cleaned+CDL_ideal, Orai1WT-MDSnap-Fr300_cleaned+CPL_ideal, Orai1WT-MDSnap-Fr300_cleaned+DDT_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#     ✗ CBD_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ CDL_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ CPL_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ DDT_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ DGX_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ DLP_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ DR6_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ DRB_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ DSO_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✓ E55_ideal__Orai1WT-MDSnap-Fr300_cleaned: 10 poses
#     ✗ EH5_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ GAH_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ GBM_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ IB2_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✓ J12_ideal__Orai1WT-MDSnap-Fr300_cleaned: 10 poses
#   Batch 2 done in 488.1s (32.5s/complex) — 30/258 total
#
#   ── Batch 3/18 (15 complexes) [31–45 of 258] ──
#       31/258  JT1_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       32/258  L2P_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       33/258  LBM_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       34/258  LK4_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       35/258  LPE_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       36/258  MS1_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       37/258  N3C_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       38/258  NHM_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       39/258  P0E_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       40/258  PCF_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       41/258  PCW_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       42/258  PEE_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       43/258  PEF_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       44/258  PFS_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       45/258  PLC_ideal + Orai1WT-MDSnap-Fr300_cleaned
#   ⏱ 12m34s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 13m00s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 13m30s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 13m56s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 3873, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 14m22s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 36145, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 14m48s | ✓ 2144 done | ⏳ 256 pending | GPU: 100, 36145, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 15m16s | ✓ 2144 done | ⏳ 256 pending | GPU: 99, 36145, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 15m45s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 36145, 81920 | [30/258 combos] batch 3/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+JT1_ideal, Orai1WT-MDSnap-Fr300_cleaned+L2P_ideal, Orai1WT-MDSnap-Fr300_cleaned+LBM_ideal, Orai1WT-MDSnap-Fr300_cleaned+LK4_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#     ✗ JT1_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ L2P_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ LBM_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ LK4_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ LPE_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ MS1_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ N3C_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ NHM_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ P0E_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ PCF_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ PCW_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ PEE_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ PEF_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ PFS_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ PLC_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#   Batch 3 done in 208.7s (13.9s/complex) — 45/258 total
#
#   ── Batch 4/18 (15 complexes) [46–60 of 258] ──
#       46/258  RIF_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       47/258  RR6_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       48/258  RXP_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       49/258  SFP_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       50/258  SFT_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       51/258  SVR_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       52/258  TDT_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       53/258  U10_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       54/258  VL1_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       55/258  XPG_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       56/258  YIS_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       57/258  YMA_ideal + Orai1WT-MDSnap-Fr300_cleaned
#       58/258  10A_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       59/258  138_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       60/258  16A_ideal + Orai1WT-MDSnap-Fr400_cleaned
#   ⏱ 16m11s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 16m40s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 17m07s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 17m36s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 18m03s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 18m29s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 18m58s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 19m24s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 19m50s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 20m16s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 3857, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 20m45s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 41009, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 21m13s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 55871, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 21m41s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 55871, 81920 | [45/258 combos] batch 4/18
#     Docking: Orai1WT-MDSnap-Fr300_cleaned+RIF_ideal, Orai1WT-MDSnap-Fr300_cleaned+RR6_ideal, Orai1WT-MDSnap-Fr300_cleaned+RXP_ideal, Orai1WT-MDSnap-Fr300_cleaned+SFP_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#     ✗ RIF_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ RR6_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ RXP_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ SFP_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ SFT_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ SVR_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ TDT_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ U10_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ VL1_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ XPG_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ YIS_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ YMA_ideal__Orai1WT-MDSnap-Fr300_cleaned: 0 poses
#     ✗ 10A_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ 138_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ 16A_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#   Batch 4 done in 371.6s (24.8s/complex) — 60/258 total
#
#   ── Batch 5/18 (15 complexes) [61–75 of 258] ──
#       61/258  2ED_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       62/258  385_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       63/258  3PC_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       64/258  6F6_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       65/258  7AK_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       66/258  88Z_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       67/258  98I_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       68/258  A00_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       69/258  A1CB7_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       70/258  A1JSR_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       71/258  A1LVF_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       72/258  A1LY1_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       73/258  AGH_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       74/258  BLM_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       75/258  BV3_ideal + Orai1WT-MDSnap-Fr400_cleaned
#   ⏱ 22m08s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 22m38s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 23m02s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 23m28s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 23m54s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 24m23s | ✓ 2144 done | ⏳ 256 pending | GPU: 0, 5, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 24m50s | ✓ 2144 done | ⏳ 256 pending | GPU: 21, 22267, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 25m18s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 34959, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 25m46s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 46851, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 26m14s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 64317, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 26m40s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 64317, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 27m06s | ✓ 2146 done | ⏳ 254 pending | GPU: 98, 44119, 81920 | [60/258 combos] batch 5/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+2ED_ideal, Orai1WT-MDSnap-Fr400_cleaned+385_ideal, Orai1WT-MDSnap-Fr400_cleaned+3PC_ideal, Orai1WT-MDSnap-Fr400_cleaned+6F6_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#     ✓ 2ED_ideal__Orai1WT-MDSnap-Fr400_cleaned: 10 poses
#     ✓ 385_ideal__Orai1WT-MDSnap-Fr400_cleaned: 10 poses
#     ✗ 3PC_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ 6F6_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ 7AK_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ 88Z_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ 98I_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ A00_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ A1CB7_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ A1JSR_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ A1LVF_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ A1LY1_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ AGH_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ BLM_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#     ✗ BV3_ideal__Orai1WT-MDSnap-Fr400_cleaned: 0 poses
#   Batch 5 done in 305.5s (20.4s/complex) — 75/258 total
#
#   ── Batch 6/18 (15 complexes) [76–90 of 258] ──
#       76/258  BV4_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       77/258  BY6_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       78/258  CBD_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       79/258  CDL_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       80/258  CIS_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       81/258  CPL_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       82/258  DDT_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       83/258  DEO_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       84/258  DGD_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       85/258  DGX_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       86/258  DLP_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       87/258  DRB_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       88/258  DSO_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       89/258  DVP_ideal + Orai1WT-MDSnap-Fr400_cleaned
#       90/258  E55_ideal + Orai1WT-MDSnap-Fr400_cleaned
#   ⏱ 27m34s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 28m02s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 28m29s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 28m56s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 29m22s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 29m48s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 30m14s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 30m42s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 31m10s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 31m39s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 32m07s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 5, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 32m33s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 3857, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 33m00s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 34353, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 33m28s | ✓ 2146 done | ⏳ 254 pending | GPU: 100, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 33m54s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 34m20s | ✓ 2146 done | ⏳ 254 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 34m50s | ✓ 2146 done | ⏳ 254 pending | GPU: 18, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 35m16s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 35m44s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 36m12s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 36m36s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 37m03s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 37m31s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 37m58s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 38m25s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 38m51s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 39m18s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 39m43s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 40m09s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 40m35s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 41m01s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 41m29s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 41m57s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 42m23s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 42m51s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 43m18s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 43m45s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 44m13s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
#     Status:   Skipped 0 / 35 complexes.
#   ⏱ 44m41s | ✓ 2147 done | ⏳ 253 pending | GPU: 0, 34359, 81920 | [75/258 combos] batch 6/18
#     Docking: Orai1WT-MDSnap-Fr400_cleaned+BV4_ideal, Orai1WT-MDSnap-Fr400_cleaned+BY6_ideal, Orai1WT-MDSnap-Fr400_cleaned+CBD_ideal, Orai1WT-MDSnap-Fr400_cleaned+CDL_ideal (+11 more)
#     DiffDock: Processing 12 of 12 batches (12 sequences)
# ...
#   MDD_ideal                                | Combos:   4 | Poses:   40
#   MDN_ideal                                | Combos:   4 | Poses:   40
#   MES_ideal                                | Combos:   4 | Poses:   40
#   MF3_ideal                                | Combos:   4 | Poses:   40
#   MFG_ideal                                | Combos:   4 | Poses:   40
#   MGR_ideal                                | Combos:   4 | Poses:   40
#   MLA_ideal                                | Combos:   4 | Poses:   40
#   MLI_ideal                                | Combos:   4 | Poses:   40
#   MM3_ideal                                | Combos:   4 | Poses:   40
#   MMQ_ideal                                | Combos:   4 | Poses:   30
#   MNN_ideal                                | Combos:   4 | Poses:   40
#   MNY_ideal                                | Combos:   4 | Poses:   40
#   MOO_ideal                                | Combos:   4 | Poses:   40
#   MOS_ideal                                | Combos:   4 | Poses:   40
#   MPB_ideal                                | Combos:   4 | Poses:   40
#   MPO_ideal                                | Combos:   4 | Poses:   40
#   MPX_ideal                                | Combos:   4 | Poses:   40
#   MR4_ideal                                | Combos:   4 | Poses:   40
#   MR5_ideal                                | Combos:   4 | Poses:   40
#   MR6_ideal                                | Combos:   4 | Poses:   40
#   MRE_ideal                                | Combos:   4 | Poses:   40
#   MSB_ideal                                | Combos:   4 | Poses:   40
#   MSR_ideal                                | Combos:   4 | Poses:   40
#   MTN_ideal                                | Combos:   4 | Poses:   40
#   MXT_ideal                                | Combos:   4 | Poses:   40
#   N2P_ideal                                | Combos:   4 | Poses:   40
#   N4E_ideal                                | Combos:   4 | Poses:   40
#   N5B_ideal                                | Combos:   4 | Poses:   40
#   N6W_ideal                                | Combos:   4 | Poses:   40
#   NAF_ideal                                | Combos:   4 | Poses:   40
#   NBU_ideal                                | Combos:   4 | Poses:   40
#   NDD_ideal                                | Combos:   4 | Poses:   40
#   NEN_ideal                                | Combos:   4 | Poses:   40
#   NEQ_ideal                                | Combos:   4 | Poses:   40
#   NET_ideal                                | Combos:   4 | Poses:   30
#   NFA_ideal                                | Combos:   4 | Poses:   40
#   NHE_ideal                                | Combos:   4 | Poses:   40
#   NIN_ideal                                | Combos:   4 | Poses:   40
#   NIZ_ideal                                | Combos:   4 | Poses:   40
#   NNB_ideal                                | Combos:   4 | Poses:   40
#   NNC_ideal                                | Combos:   4 | Poses:   40
#   NNI_ideal                                | Combos:   4 | Poses:   40
#   NO3_ideal                                | Combos:   4 | Poses:   40
#   NPO_ideal                                | Combos:   4 | Poses:   40
#   NR2_ideal                                | Combos:   4 | Poses:   10
#   NTD_ideal                                | Combos:   4 | Poses:   40
#   NYL_ideal                                | Combos:   4 | Poses:   40
#   ODS_ideal                                | Combos:   4 | Poses:   40
#   OMO_ideal                                | Combos:   4 | Poses:   30
#   OPP_ideal                                | Combos:   4 | Poses:   40
#   OSP_ideal                                | Combos:   4 | Poses:   40
#   OX3_ideal                                | Combos:   4 | Poses:   40
#   OX5_ideal                                | Combos:   4 | Poses:   40
#   OX6_ideal                                | Combos:   4 | Poses:   40
#   OX7_ideal                                | Combos:   4 | Poses:   40
#   OXC_ideal                                | Combos:   4 | Poses:   40
#   OXD_ideal                                | Combos:   4 | Poses:   40
#   P2Z_ideal                                | Combos:   4 | Poses:   40
#   PAB_ideal                                | Combos:   4 | Poses:   40
#   PAC_ideal                                | Combos:   4 | Poses:   40
#   PB2_ideal                                | Combos:   4 | Poses:   40
#   PBA_ideal                                | Combos:   4 | Poses:   40
#   PBC_ideal                                | Combos:   4 | Poses:   40
#   PBN_ideal                                | Combos:   4 | Poses:   40
#   PBR_ideal                                | Combos:   4 | Poses:   40
#   PCB_ideal                                | Combos:   4 | Poses:   40
#   PCQ_ideal                                | Combos:   4 | Poses:   40
#   PCR_ideal                                | Combos:   4 | Poses:   40
#   PCS_ideal                                | Combos:   4 | Poses:   40
#   PC_ideal                                 | Combos:   4 | Poses:   40
#   PDC_ideal                                | Combos:   4 | Poses:   40
#   PDO_ideal                                | Combos:   4 | Poses:   40
#   PEA_ideal                                | Combos:   4 | Poses:   40
#   PEL_ideal                                | Combos:   4 | Poses:   40
#   PFB_ideal                                | Combos:   4 | Poses:   40
#   PFL_ideal                                | Combos:   4 | Poses:   40
#   PH3_ideal                                | Combos:   4 | Poses:   40
#   PHB_ideal                                | Combos:   4 | Poses:   40
#   PHE_ideal                                | Combos:   4 | Poses:   40
#   PHI_ideal                                | Combos:   4 | Poses:   40
#   PHJ_ideal                                | Combos:   4 | Poses:   40
#   PHK_ideal                                | Combos:   4 | Poses:   40
#   PHL_ideal                                | Combos:   4 | Poses:   40
#   PHN_ideal                                | Combos:   4 | Poses:   40
#   PHQ_ideal                                | Combos:   4 | Poses:   30
#   PHT_ideal                                | Combos:   4 | Poses:   40
#   PIH_ideal                                | Combos:   4 | Poses:   40
#   PIM_ideal                                | Combos:   4 | Poses:   40
#   PIT_ideal                                | Combos:   4 | Poses:   40
#   PIU_ideal                                | Combos:   4 | Poses:   40
#   PLU_ideal                                | Combos:   4 | Poses:   40
#   PMA_ideal                                | Combos:   4 | Poses:   40
#   PMB_ideal                                | Combos:   4 | Poses:   40
#   PMS_ideal                                | Combos:   4 | Poses:   40
#   PN6_ideal                                | Combos:   4 | Poses:   40
#   PO4_ideal                                | Combos:   4 | Poses:   40
#   PP1_ideal                                | Combos:   4 | Poses:   40
#   PP2_ideal                                | Combos:   4 | Poses:   40
#   PPK_ideal                                | Combos:   4 | Poses:   40
#   PPT_ideal                                | Combos:   4 | Poses:   40
#   PPV_ideal                                | Combos:   4 | Poses:   40
#   PPY_ideal                                | Combos:   4 | Poses:   40
#   PRA_ideal                                | Combos:   4 | Poses:   40
#   PRL_ideal                                | Combos:   4 | Poses:   40
#   PS5_ideal                                | Combos:   4 | Poses:   40
#   PS9_ideal                                | Combos:   4 | Poses:   20
#   PSY_ideal                                | Combos:   4 | Poses:   40
#   PTD_ideal                                | Combos:   4 | Poses:   40
#   PTU_ideal                                | Combos:   4 | Poses:   40
#   PUT_ideal                                | Combos:   4 | Poses:   40
#   PYE_ideal                                | Combos:   4 | Poses:   40
#   PYU_ideal                                | Combos:   4 | Poses:   40
#   PZE_ideal                                | Combos:   4 | Poses:   40
#   QA9_ideal                                | Combos:   4 | Poses:   40
#   R1F_ideal                                | Combos:   4 | Poses:   40
#   RCO_ideal                                | Combos:   4 | Poses:   40
#   RCX_ideal                                | Combos:   4 | Poses:   40
#   RE2_ideal                                | Combos:   4 | Poses:   40
#   RF1_ideal                                | Combos:   4 | Poses:   40
#   RF2_ideal                                | Combos:   4 | Poses:   40
#   RIS_ideal                                | Combos:   4 | Poses:   40
#   RJ6_ideal                                | Combos:   4 | Poses:   40
#   RMN_ideal                                | Combos:   4 | Poses:   40
#   RNO_ideal                                | Combos:   4 | Poses:   40
#   ROK_ideal                                | Combos:   4 | Poses:   40
#   RSO_ideal                                | Combos:   4 | Poses:   40
#   S3V_ideal                                | Combos:   4 | Poses:   40
#   SAN_ideal                                | Combos:   4 | Poses:   40
#   SBE_ideal                                | Combos:   4 | Poses:   40
#   SBN_ideal                                | Combos:   4 | Poses:   40
#   SBO_ideal                                | Combos:   4 | Poses:   40
#   SBZ_ideal                                | Combos:   4 | Poses:   40
#   SE4_ideal                                | Combos:   4 | Poses:   40
#   SFY_ideal                                | Combos:   4 | Poses:   40
#   SIF_ideal                                | Combos:   4 | Poses:   40
#   SIN_ideal                                | Combos:   4 | Poses:   40
#   SMN_ideal                                | Combos:   4 | Poses:   40
#   SNO_ideal                                | Combos:   4 | Poses:   40
#   SO2_ideal                                | Combos:   4 | Poses:   40
#   SO4_ideal                                | Combos:   4 | Poses:   40
#   SS2_ideal                                | Combos:   4 | Poses:   40
#   STC_ideal                                | Combos:   4 | Poses:   40
#   STF_ideal                                | Combos:   4 | Poses:   40
#   STL_ideal                                | Combos:   4 | Poses:   40
#   SVA_ideal                                | Combos:   4 | Poses:   40
#   SXX_ideal                                | Combos:   4 | Poses:   40
#   SYR_ideal                                | Combos:   4 | Poses:   40
#   T13_ideal                                | Combos:   4 | Poses:   40
#   T2D_ideal                                | Combos:   4 | Poses:   40
#   T2M_ideal                                | Combos:   4 | Poses:   40
#   TAR_ideal                                | Combos:   4 | Poses:   40
#   TAS_ideal                                | Combos:   4 | Poses:   40
#   TBF_ideal                                | Combos:   4 | Poses:   40
#   TBP_ideal                                | Combos:   4 | Poses:   40
#   TBU_ideal                                | Combos:   4 | Poses:   40
#   TCA_ideal                                | Combos:   4 | Poses:   40
#   TCO_ideal                                | Combos:   4 | Poses:   40
#   TCV_ideal                                | Combos:   4 | Poses:   40
#   TCZ_ideal                                | Combos:   4 | Poses:   40
#   TF4_ideal                                | Combos:   4 | Poses:   40
#   TF9_ideal                                | Combos:   4 | Poses:   40
#   TFL_ideal                                | Combos:   4 | Poses:   40
#   TFM_ideal                                | Combos:   4 | Poses:   40
#   TFQ_ideal                                | Combos:   4 | Poses:   40
#   TIK_ideal                                | Combos:   4 | Poses:   40
#   TLA_ideal                                | Combos:   4 | Poses:   40
#   TMA_ideal                                | Combos:   4 | Poses:   40
#   TMM_ideal                                | Combos:   4 | Poses:   40
#   TNE_ideal                                | Combos:   4 | Poses:   40
#   TNF_ideal                                | Combos:   4 | Poses:   40
#   TNL_ideal                                | Combos:   4 | Poses:   40
#   TP0_ideal                                | Combos:   4 | Poses:   40
#   TPA_ideal                                | Combos:   4 | Poses:   40
#   TPB_ideal                                | Combos:   4 | Poses:   40
#   TPR_ideal                                | Combos:   4 | Poses:   40
#   TQ5_ideal                                | Combos:   4 | Poses:   40
#   TRI_ideal                                | Combos:   4 | Poses:   40
#   TRS_ideal                                | Combos:   4 | Poses:   40
#   TRU_ideal                                | Combos:   4 | Poses:    0
#   TSU_ideal                                | Combos:   4 | Poses:   40
#   TTN_ideal                                | Combos:   4 | Poses:   40
#   TYB_ideal                                | Combos:   4 | Poses:   40
#   TYC_ideal                                | Combos:   4 | Poses:   40
#   TYI_ideal                                | Combos:   4 | Poses:   40
#   TYL_ideal                                | Combos:   4 | Poses:   40
#   TYR_ideal                                | Combos:   4 | Poses:   40
#   TYZ_ideal                                | Combos:   4 | Poses:   40
#   U32_ideal                                | Combos:   4 | Poses:   40
#   U55_ideal                                | Combos:   4 | Poses:   40
#   UA5_ideal                                | Combos:   4 | Poses:   40
#   UAS_ideal                                | Combos:   4 | Poses:   40
#   UN3_ideal                                | Combos:   4 | Poses:   40
#   UQA_ideal                                | Combos:   4 | Poses:   40
#   URE_ideal                                | Combos:   4 | Poses:   40
#   URS_ideal                                | Combos:   4 | Poses:   40
#   V35_ideal                                | Combos:   4 | Poses:   40
#   V36_ideal                                | Combos:   4 | Poses:   40
#   V4O_ideal                                | Combos:   4 | Poses:   40
#   VES_ideal                                | Combos:   4 | Poses:   40
#   VII_ideal                                | Combos:   4 | Poses:   40
#   VSO_ideal                                | Combos:   4 | Poses:   40
#   VVM_ideal                                | Combos:   4 | Poses:   40
#   W1P_ideal                                | Combos:   4 | Poses:   40
#   WSK_ideal                                | Combos:   4 | Poses:   40
#   WWZ_ideal                                | Combos:   4 | Poses:   40
#   WYB_ideal                                | Combos:   4 | Poses:   40
#   XB2_ideal                                | Combos:   4 | Poses:   40
#   XEW_ideal                                | Combos:   4 | Poses:   30
#   XP1_ideal                                | Combos:   4 | Poses:   40
#   XQZ_ideal                                | Combos:   4 | Poses:   40
#   XZ5_ideal                                | Combos:   4 | Poses:   40
#   YAN_ideal                                | Combos:   4 | Poses:   40
#   YPQ_ideal                                | Combos:   4 | Poses:   40
#   YRL_ideal                                | Combos:   4 | Poses:   40
#   YTT_ideal                                | Combos:   4 | Poses:   40
#   YTZ_ideal                                | Combos:   4 | Poses:   40
#   ZHZ_ideal                                | Combos:   4 | Poses:   40
#   ZOL_ideal                                | Combos:   4 | Poses:   40
#   ZYS_ideal                                | Combos:   4 | Poses:   40
#   ZYX_ideal                                | Combos:   4 | Poses:   40
#
# Summary saved: /workspace/diffdock_results/ligands_sdf_small_symmetric_approved/docking_summary.json
#
# ================================================================================
# ALL DONE — 4784 total results across 2 ligand directories
# ================================================================================

# %% [markdown]
# # Results

# %%
# Convert results to DataFrame
results_data = []
for r in diffdock_results: 
    for i, pose_file in enumerate(r.pose_files):
        confidence = extract_confidence_from_filename(pose_file.name)
        rank = extract_rank_from_filename(pose_file.name)
        results_data.append({
            "protein": r.protein_name,
            "ligand": r.ligand_name,
            "rank": rank if rank > 0 else i + 1,
            "confidence": confidence,
            "sdf_path": str(pose_file),
            "status": r.status,
        })

results_df = pd.DataFrame(results_data)

print("=" * 80)
print("DOCKING RESULTS DATAFRAME")
print("=" * 80)
print(f"\nTotal poses: {len(results_df)}")

if not results_df.empty:
    print("\nPoses per protein-ligand combination:")
    pose_counts = results_df.groupby(["protein", "ligand"]).agg({
        "rank": "count",
        "confidence": "mean",
    }).reset_index()
    pose_counts.columns = ["protein", "ligand", "num_poses", "avg_confidence"]
    display(pose_counts)
    
    print("\nConfidence score distribution:")
    if results_df['confidence'].sum() > 0:
        print(f"  Mean confidence: {results_df['confidence'].mean():.3f}")
        print(f"  Max confidence: {results_df['confidence'].max():.3f}")
        print(f"  Min confidence: {results_df['confidence'].min():.3f}")

# Save to CSV
csv_path = DIFFDOCK_OUTPUT_DIR / "diffdock_poses.csv"
results_df.to_csv(csv_path, index=False)
print(f"\nResults saved to: {csv_path}")
# Out:
# ================================================================================
# DOCKING RESULTS DATAFRAME
# ================================================================================
#
# Total poses: 45030
#
# Poses per protein-ligand combination:
#                            protein     ligand  num_poses  avg_confidence
# 0     Orai1WT-MDSnap-Fr300_cleaned  007_ideal         10           1.700
# 1     Orai1WT-MDSnap-Fr300_cleaned  010_ideal         10           1.191
# 2     Orai1WT-MDSnap-Fr300_cleaned  05J_ideal         10         601.260
# 3     Orai1WT-MDSnap-Fr300_cleaned  07J_ideal         10           3.317
# 4     Orai1WT-MDSnap-Fr300_cleaned  08D_ideal         10           2.819
# ...                            ...        ...        ...             ...
# 4498     Orai1WT-START-Fr0_cleaned  ZHZ_ideal         10           3.330
# 4499     Orai1WT-START-Fr0_cleaned  ZIY_ideal         10           3.927
# 4500     Orai1WT-START-Fr0_cleaned  ZOL_ideal         10           4.064
# 4501     Orai1WT-START-Fr0_cleaned  ZYS_ideal         10           2.014
# 4502     Orai1WT-START-Fr0_cleaned  ZYX_ideal         10           3.314
#
# [4503 rows x 4 columns]
# Confidence score distribution:
#   Mean confidence: 93.361
#   Max confidence: 1000.000
#   Min confidence: 0.000
#
# Results saved to: /workspace/diffdock_results/ligands_sdf_small_symmetric_approved/diffdock_poses.csv

# %%
# ============================================================================
# LIST ALL GENERATED POSES
# ============================================================================

def list_pose_files(output_dir: Path) -> Dict[str, List[Path]]:
    """List all generated pose files organized by combination."""
    poses_by_combo = {}
    
    if not output_dir.exists():
        return poses_by_combo
    
    for combo_dir in sorted(output_dir.iterdir()):
        if not combo_dir.is_dir():
            continue
        
        # Only count actual ranked poses (rank*_confidence*.sdf)
        pose_files = sorted(
            _collect_ranked_poses(combo_dir),
            key=lambda p: extract_rank_from_filename(p.name),
        )
        if pose_files:
            poses_by_combo[combo_dir.name] = pose_files
    
    return poses_by_combo


pose_files = list_pose_files(DIFFDOCK_OUTPUT_DIR)

print("=" * 80)
print("GENERATED POSE FILES")
print("=" * 80)
print(f"\nOutput directory: {DIFFDOCK_OUTPUT_DIR}")
print(f"Total combinations with poses: {len(pose_files)}")
print()

total_poses = 0
for combo_name, files in pose_files.items():
    print(f"\n{combo_name}/")
    for f in files[:5]:  # Show first 5 poses per combination
        conf = extract_confidence_from_filename(f.name)
        print(f"  └── {f.name} (confidence: {conf:.3f})")
    if len(files) > 5:
        print(f"  └── ... and {len(files) - 5} more")
    total_poses += len(files)

print("\n" + "-" * 80)
print(f"TOTAL POSES GENERATED: {total_poses}")
print("-" * 80)
# Out:
# ================================================================================
# GENERATED POSE FILES
# ================================================================================
#
# Output directory: /workspace/diffdock_results/ligands_sdf_small_symmetric_approved
# Total combinations with poses: 2333
#
#
# 007_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.15.sdf (confidence: 0.150)
#   └── rank2_confidence-0.45.sdf (confidence: 0.450)
#   └── rank3_confidence-0.54.sdf (confidence: 0.540)
#   └── rank4_confidence-0.64.sdf (confidence: 0.640)
#   └── rank5_confidence-0.79.sdf (confidence: 0.790)
#   └── ... and 5 more
#
# 007_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.75.sdf (confidence: 0.750)
#   └── rank2_confidence-0.82.sdf (confidence: 0.820)
#   └── rank3_confidence-0.83.sdf (confidence: 0.830)
#   └── rank4_confidence-1.05.sdf (confidence: 1.050)
#   └── rank5_confidence-2.26.sdf (confidence: 2.260)
#   └── ... and 5 more
#
# 007_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.07.sdf (confidence: 0.070)
#   └── rank2_confidence-0.25.sdf (confidence: 0.250)
#   └── rank3_confidence-0.37.sdf (confidence: 0.370)
#   └── rank4_confidence-0.70.sdf (confidence: 0.700)
#   └── rank5_confidence-1.03.sdf (confidence: 1.030)
#   └── ... and 5 more
#
# 007_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.06.sdf (confidence: 1.060)
#   └── rank2_confidence-1.18.sdf (confidence: 1.180)
#   └── rank3_confidence-2.12.sdf (confidence: 2.120)
#   └── rank4_confidence-2.20.sdf (confidence: 2.200)
#   └── rank5_confidence-2.40.sdf (confidence: 2.400)
#   └── ... and 5 more
#
# 010_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.48.sdf (confidence: 0.480)
#   └── rank2_confidence-0.57.sdf (confidence: 0.570)
#   └── rank3_confidence-0.70.sdf (confidence: 0.700)
#   └── rank4_confidence-1.00.sdf (confidence: 1.000)
#   └── rank5_confidence-1.18.sdf (confidence: 1.180)
#   └── ... and 5 more
#
# 010_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.44.sdf (confidence: 0.440)
#   └── rank2_confidence-0.96.sdf (confidence: 0.960)
#   └── rank3_confidence-1.08.sdf (confidence: 1.080)
#   └── rank4_confidence-2.24.sdf (confidence: 2.240)
#   └── rank5_confidence-2.76.sdf (confidence: 2.760)
#   └── ... and 5 more
#
# 010_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.10.sdf (confidence: 0.100)
#   └── rank2_confidence-0.16.sdf (confidence: 0.160)
#   └── rank3_confidence-0.59.sdf (confidence: 0.590)
#   └── rank4_confidence-0.62.sdf (confidence: 0.620)
#   └── rank5_confidence-0.87.sdf (confidence: 0.870)
#   └── ... and 5 more
#
# 010_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.61.sdf (confidence: 1.610)
#   └── rank2_confidence-2.13.sdf (confidence: 2.130)
#   └── rank3_confidence-2.21.sdf (confidence: 2.210)
#   └── rank4_confidence-2.44.sdf (confidence: 2.440)
#   └── rank5_confidence-2.51.sdf (confidence: 2.510)
#   └── ... and 5 more
#
# 08D_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.82.sdf (confidence: 0.820)
#   └── rank2_confidence-1.96.sdf (confidence: 1.960)
#   └── rank3_confidence-2.06.sdf (confidence: 2.060)
#   └── rank4_confidence-2.23.sdf (confidence: 2.230)
#   └── rank5_confidence-2.25.sdf (confidence: 2.250)
#   └── ... and 5 more
#
# 08D_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.66.sdf (confidence: 0.660)
#   └── rank2_confidence-0.68.sdf (confidence: 0.680)
#   └── rank3_confidence-0.76.sdf (confidence: 0.760)
#   └── rank4_confidence-1.01.sdf (confidence: 1.010)
#   └── rank5_confidence-1.14.sdf (confidence: 1.140)
#   └── ... and 5 more
#
# 08D_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.85.sdf (confidence: 0.850)
#   └── rank2_confidence-0.95.sdf (confidence: 0.950)
#   └── rank3_confidence-1.03.sdf (confidence: 1.030)
#   └── rank4_confidence-1.05.sdf (confidence: 1.050)
#   └── rank5_confidence-1.09.sdf (confidence: 1.090)
#   └── ... and 5 more
#
# 08D_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.85.sdf (confidence: 2.850)
#   └── rank2_confidence-3.34.sdf (confidence: 3.340)
#   └── rank3_confidence-3.40.sdf (confidence: 3.400)
#   └── rank4_confidence-3.73.sdf (confidence: 3.730)
#   └── rank5_confidence-3.96.sdf (confidence: 3.960)
#   └── ... and 5 more
#
# 0A9_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.03.sdf (confidence: 1.030)
#   └── rank2_confidence-1.68.sdf (confidence: 1.680)
#   └── rank3_confidence-3.10.sdf (confidence: 3.100)
#   └── rank4_confidence-4.64.sdf (confidence: 4.640)
#   └── rank5_confidence-4.72.sdf (confidence: 4.720)
#   └── ... and 5 more
#
# 0A9_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.97.sdf (confidence: 0.970)
#   └── rank2_confidence-0.99.sdf (confidence: 0.990)
#   └── rank3_confidence-1.26.sdf (confidence: 1.260)
#   └── rank4_confidence-1.62.sdf (confidence: 1.620)
#   └── rank5_confidence-2.17.sdf (confidence: 2.170)
#   └── ... and 5 more
#
# 0A9_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.46.sdf (confidence: 1.460)
#   └── rank2_confidence-1.74.sdf (confidence: 1.740)
#   └── rank3_confidence-1.84.sdf (confidence: 1.840)
#   └── rank4_confidence-1.87.sdf (confidence: 1.870)
#   └── rank5_confidence-1.94.sdf (confidence: 1.940)
#   └── ... and 5 more
#
# 0A9_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.93.sdf (confidence: 1.930)
#   └── rank2_confidence-2.84.sdf (confidence: 2.840)
#   └── rank3_confidence-2.84.sdf (confidence: 2.840)
#   └── rank4_confidence-2.95.sdf (confidence: 2.950)
#   └── rank5_confidence-3.08.sdf (confidence: 3.080)
#   └── ... and 5 more
#
# 13X_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.04.sdf (confidence: 1.040)
#   └── rank2_confidence-1.09.sdf (confidence: 1.090)
#   └── rank3_confidence-1.09.sdf (confidence: 1.090)
#   └── rank4_confidence-1.21.sdf (confidence: 1.210)
#   └── rank5_confidence-1.36.sdf (confidence: 1.360)
#   └── ... and 5 more
#
# 13X_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.97.sdf (confidence: 0.970)
#   └── rank2_confidence-1.13.sdf (confidence: 1.130)
#   └── rank3_confidence-1.54.sdf (confidence: 1.540)
#   └── rank4_confidence-2.85.sdf (confidence: 2.850)
#   └── rank5_confidence-2.92.sdf (confidence: 2.920)
#   └── ... and 5 more
#
# 13X_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.66.sdf (confidence: 0.660)
#   └── rank2_confidence-0.74.sdf (confidence: 0.740)
#   └── rank3_confidence-0.83.sdf (confidence: 0.830)
#   └── rank4_confidence-0.91.sdf (confidence: 0.910)
#   └── rank5_confidence-1.12.sdf (confidence: 1.120)
#   └── ... and 5 more
#
# 13X_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.07.sdf (confidence: 1.070)
#   └── rank2_confidence-1.11.sdf (confidence: 1.110)
#   └── rank3_confidence-1.12.sdf (confidence: 1.120)
#   └── rank4_confidence-1.16.sdf (confidence: 1.160)
#   └── rank5_confidence-1.22.sdf (confidence: 1.220)
#   └── ... and 5 more
#
# 144_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.55.sdf (confidence: 0.550)
#   └── rank2_confidence-0.71.sdf (confidence: 0.710)
#   └── rank3_confidence-0.73.sdf (confidence: 0.730)
#   └── rank4_confidence-0.91.sdf (confidence: 0.910)
#   └── rank5_confidence-1.09.sdf (confidence: 1.090)
#   └── ... and 5 more
#
# 144_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.77.sdf (confidence: 0.770)
#   └── rank2_confidence-0.86.sdf (confidence: 0.860)
#   └── rank3_confidence-0.97.sdf (confidence: 0.970)
#   └── rank4_confidence-0.99.sdf (confidence: 0.990)
#   └── rank5_confidence-1.07.sdf (confidence: 1.070)
#   └── ... and 5 more
#
# 144_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.53.sdf (confidence: 0.530)
#   └── rank2_confidence-0.53.sdf (confidence: 0.530)
#   └── rank3_confidence-0.59.sdf (confidence: 0.590)
#   └── rank4_confidence-0.60.sdf (confidence: 0.600)
#   └── rank5_confidence-0.70.sdf (confidence: 0.700)
#   └── ... and 5 more
#
# 144_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.69.sdf (confidence: 1.690)
#   └── rank2_confidence-1.70.sdf (confidence: 1.700)
#   └── rank3_confidence-1.74.sdf (confidence: 1.740)
#   └── rank4_confidence-2.08.sdf (confidence: 2.080)
#   └── rank5_confidence-2.16.sdf (confidence: 2.160)
#   └── ... and 5 more
#
# 150_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.60.sdf (confidence: 0.600)
#   └── rank2_confidence-0.61.sdf (confidence: 0.610)
#   └── rank3_confidence-0.80.sdf (confidence: 0.800)
#   └── rank4_confidence-0.95.sdf (confidence: 0.950)
#   └── rank5_confidence-1.63.sdf (confidence: 1.630)
#   └── ... and 5 more
#
# 150_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.53.sdf (confidence: 0.530)
#   └── rank2_confidence-1.20.sdf (confidence: 1.200)
#   └── rank3_confidence-1.31.sdf (confidence: 1.310)
#   └── rank4_confidence-1.37.sdf (confidence: 1.370)
#   └── rank5_confidence-1.56.sdf (confidence: 1.560)
#   └── ... and 5 more
#
# 150_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.65.sdf (confidence: 0.650)
#   └── rank2_confidence-0.67.sdf (confidence: 0.670)
#   └── rank3_confidence-1.42.sdf (confidence: 1.420)
#   └── rank4_confidence-2.03.sdf (confidence: 2.030)
#   └── rank5_confidence-2.62.sdf (confidence: 2.620)
#   └── ... and 5 more
#
# 150_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.01.sdf (confidence: 1.010)
#   └── rank2_confidence-1.01.sdf (confidence: 1.010)
#   └── rank3_confidence-1.40.sdf (confidence: 1.400)
#   └── rank4_confidence-2.03.sdf (confidence: 2.030)
#   └── rank5_confidence-2.14.sdf (confidence: 2.140)
#   └── ... and 5 more
#
# 152_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.38.sdf (confidence: 1.380)
#   └── rank2_confidence-1.40.sdf (confidence: 1.400)
#   └── rank3_confidence-1.42.sdf (confidence: 1.420)
#   └── rank4_confidence-1.78.sdf (confidence: 1.780)
#   └── rank5_confidence-1.89.sdf (confidence: 1.890)
#   └── ... and 5 more
#
# 152_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.98.sdf (confidence: 0.980)
#   └── rank2_confidence-1.25.sdf (confidence: 1.250)
#   └── rank3_confidence-1.48.sdf (confidence: 1.480)
#   └── rank4_confidence-1.52.sdf (confidence: 1.520)
#   └── rank5_confidence-1.56.sdf (confidence: 1.560)
#   └── ... and 5 more
#
# 152_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.27.sdf (confidence: 0.270)
#   └── rank2_confidence-0.38.sdf (confidence: 0.380)
#   └── rank3_confidence-0.57.sdf (confidence: 0.570)
#   └── rank4_confidence-0.81.sdf (confidence: 0.810)
#   └── rank5_confidence-1.25.sdf (confidence: 1.250)
#   └── ... and 5 more
#
# 152_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.18.sdf (confidence: 2.180)
#   └── rank2_confidence-2.22.sdf (confidence: 2.220)
#   └── rank3_confidence-2.98.sdf (confidence: 2.980)
#   └── rank4_confidence-3.49.sdf (confidence: 3.490)
#   └── rank5_confidence-3.56.sdf (confidence: 3.560)
#   └── ... and 5 more
#
# 171_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.46.sdf (confidence: 0.460)
#   └── rank2_confidence-0.47.sdf (confidence: 0.470)
#   └── rank3_confidence-0.62.sdf (confidence: 0.620)
#   └── rank4_confidence-0.70.sdf (confidence: 0.700)
#   └── rank5_confidence-0.71.sdf (confidence: 0.710)
#   └── ... and 5 more
#
# 171_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.21.sdf (confidence: 1.210)
#   └── rank2_confidence-1.44.sdf (confidence: 1.440)
#   └── rank3_confidence-1.57.sdf (confidence: 1.570)
#   └── rank4_confidence-1.68.sdf (confidence: 1.680)
#   └── rank5_confidence-1.86.sdf (confidence: 1.860)
#   └── ... and 5 more
#
# 171_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.51.sdf (confidence: 0.510)
#   └── rank2_confidence-0.53.sdf (confidence: 0.530)
#   └── rank3_confidence-0.73.sdf (confidence: 0.730)
#   └── rank4_confidence-0.83.sdf (confidence: 0.830)
#   └── rank5_confidence-0.95.sdf (confidence: 0.950)
#   └── ... and 5 more
#
# 171_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.18.sdf (confidence: 2.180)
#   └── rank2_confidence-2.48.sdf (confidence: 2.480)
#   └── rank3_confidence-2.53.sdf (confidence: 2.530)
#   └── rank4_confidence-3.02.sdf (confidence: 3.020)
#   └── rank5_confidence-3.09.sdf (confidence: 3.090)
#   └── ... and 5 more
#
# 173_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.43.sdf (confidence: 0.430)
#   └── rank2_confidence-0.74.sdf (confidence: 0.740)
#   └── rank3_confidence-1.15.sdf (confidence: 1.150)
#   └── rank4_confidence-1.21.sdf (confidence: 1.210)
#   └── rank5_confidence-1.23.sdf (confidence: 1.230)
#   └── ... and 5 more
#
# 173_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.94.sdf (confidence: 0.940)
#   └── rank2_confidence-0.96.sdf (confidence: 0.960)
#   └── rank3_confidence-1.03.sdf (confidence: 1.030)
#   └── rank4_confidence-1.03.sdf (confidence: 1.030)
#   └── rank5_confidence-1.13.sdf (confidence: 1.130)
#   └── ... and 5 more
#
# 173_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.15.sdf (confidence: 0.150)
#   └── rank2_confidence-0.26.sdf (confidence: 0.260)
#   └── rank3_confidence-0.36.sdf (confidence: 0.360)
#   └── rank4_confidence-0.39.sdf (confidence: 0.390)
#   └── rank5_confidence-0.60.sdf (confidence: 0.600)
#   └── ... and 5 more
#
# 173_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-0.88.sdf (confidence: 0.880)
#   └── rank2_confidence-1.67.sdf (confidence: 1.670)
#   └── rank3_confidence-2.78.sdf (confidence: 2.780)
#   └── rank4_confidence-2.96.sdf (confidence: 2.960)
#   └── rank5_confidence-2.97.sdf (confidence: 2.970)
#   └── ... and 5 more
#
# 174_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.76.sdf (confidence: 0.760)
#   └── rank2_confidence-0.84.sdf (confidence: 0.840)
#   └── rank3_confidence-0.88.sdf (confidence: 0.880)
#   └── rank4_confidence-0.91.sdf (confidence: 0.910)
#   └── rank5_confidence-0.92.sdf (confidence: 0.920)
#   └── ... and 5 more
#
# 174_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.83.sdf (confidence: 0.830)
#   └── rank2_confidence-0.87.sdf (confidence: 0.870)
#   └── rank3_confidence-0.88.sdf (confidence: 0.880)
#   └── rank4_confidence-0.98.sdf (confidence: 0.980)
#   └── rank5_confidence-0.98.sdf (confidence: 0.980)
#   └── ... and 5 more
#
# 174_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.10.sdf (confidence: 0.100)
#   └── rank2_confidence-0.25.sdf (confidence: 0.250)
#   └── rank3_confidence-0.46.sdf (confidence: 0.460)
#   └── rank4_confidence-0.48.sdf (confidence: 0.480)
#   └── rank5_confidence-0.56.sdf (confidence: 0.560)
#   └── ... and 5 more
#
# 174_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.48.sdf (confidence: 1.480)
#   └── rank2_confidence-2.53.sdf (confidence: 2.530)
#   └── rank3_confidence-2.99.sdf (confidence: 2.990)
#   └── rank4_confidence-3.17.sdf (confidence: 3.170)
#   └── rank5_confidence-3.74.sdf (confidence: 3.740)
#   └── ... and 5 more
#
# 178_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.35.sdf (confidence: 1.350)
#   └── rank2_confidence-1.38.sdf (confidence: 1.380)
#   └── rank3_confidence-1.42.sdf (confidence: 1.420)
#   └── rank4_confidence-1.47.sdf (confidence: 1.470)
#   └── rank5_confidence-1.48.sdf (confidence: 1.480)
#   └── ... and 5 more
#
# 178_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-2.12.sdf (confidence: 2.120)
#   └── rank2_confidence-2.22.sdf (confidence: 2.220)
#   └── rank3_confidence-2.31.sdf (confidence: 2.310)
#   └── rank4_confidence-2.36.sdf (confidence: 2.360)
#   └── rank5_confidence-2.37.sdf (confidence: 2.370)
#   └── ... and 5 more
#
# 178_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.53.sdf (confidence: 1.530)
#   └── rank2_confidence-1.63.sdf (confidence: 1.630)
#   └── rank3_confidence-1.76.sdf (confidence: 1.760)
#   └── rank4_confidence-2.09.sdf (confidence: 2.090)
#   └── rank5_confidence-2.86.sdf (confidence: 2.860)
#   └── ... and 5 more
#
# 178_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.66.sdf (confidence: 1.660)
#   └── rank2_confidence-2.06.sdf (confidence: 2.060)
#   └── rank3_confidence-2.31.sdf (confidence: 2.310)
#   └── rank4_confidence-2.40.sdf (confidence: 2.400)
#   └── rank5_confidence-2.44.sdf (confidence: 2.440)
#   └── ... and 5 more
#
# 1AL_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.77.sdf (confidence: 0.770)
#   └── rank2_confidence-0.93.sdf (confidence: 0.930)
#   └── rank3_confidence-1.66.sdf (confidence: 1.660)
#   └── rank4_confidence-2.13.sdf (confidence: 2.130)
#   └── rank5_confidence-2.15.sdf (confidence: 2.150)
#   └── ... and 5 more
#
# 1AL_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.62.sdf (confidence: 1.620)
#   └── rank2_confidence-1.77.sdf (confidence: 1.770)
#   └── rank3_confidence-2.01.sdf (confidence: 2.010)
#   └── rank4_confidence-2.17.sdf (confidence: 2.170)
#   └── rank5_confidence-2.46.sdf (confidence: 2.460)
#   └── ... and 5 more
#
# 1AL_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.56.sdf (confidence: 0.560)
#   └── rank2_confidence-0.84.sdf (confidence: 0.840)
#   └── rank3_confidence-0.92.sdf (confidence: 0.920)
#   └── rank4_confidence-0.94.sdf (confidence: 0.940)
#   └── rank5_confidence-1.60.sdf (confidence: 1.600)
#   └── ... and 5 more
#
# 1AL_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-5.01.sdf (confidence: 5.010)
#   └── rank2_confidence-5.28.sdf (confidence: 5.280)
#   └── rank3_confidence-5.29.sdf (confidence: 5.290)
#   └── rank4_confidence-1000.00.sdf (confidence: 1000.000)
#   └── rank5_confidence-1000.00.sdf (confidence: 1000.000)
#   └── ... and 5 more
#
# 1BN_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.40.sdf (confidence: 0.400)
#   └── rank2_confidence-0.53.sdf (confidence: 0.530)
#   └── rank3_confidence-0.62.sdf (confidence: 0.620)
#   └── rank4_confidence-0.69.sdf (confidence: 0.690)
#   └── rank5_confidence-0.70.sdf (confidence: 0.700)
#   └── ... and 5 more
#
# 1BN_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.74.sdf (confidence: 0.740)
#   └── rank2_confidence-0.80.sdf (confidence: 0.800)
#   └── rank3_confidence-0.91.sdf (confidence: 0.910)
#   └── rank4_confidence-0.92.sdf (confidence: 0.920)
#   └── rank5_confidence-1.01.sdf (confidence: 1.010)
#   └── ... and 5 more
#
# 1BN_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.09.sdf (confidence: 0.090)
#   └── rank2_confidence-0.37.sdf (confidence: 0.370)
#   └── rank3_confidence-0.45.sdf (confidence: 0.450)
#   └── rank4_confidence-0.49.sdf (confidence: 0.490)
#   └── rank5_confidence-0.51.sdf (confidence: 0.510)
#   └── ... and 5 more
#
# 1BN_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.59.sdf (confidence: 2.590)
#   └── rank2_confidence-2.60.sdf (confidence: 2.600)
#   └── rank3_confidence-3.04.sdf (confidence: 3.040)
#   └── rank4_confidence-3.36.sdf (confidence: 3.360)
#   └── rank5_confidence-3.37.sdf (confidence: 3.370)
#   └── ... and 5 more
#
# 1CM_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.00.sdf (confidence: 1.000)
#   └── rank2_confidence-1.07.sdf (confidence: 1.070)
#   └── rank3_confidence-1.26.sdf (confidence: 1.260)
#   └── rank4_confidence-1.33.sdf (confidence: 1.330)
#   └── rank5_confidence-1.80.sdf (confidence: 1.800)
#   └── ... and 5 more
#
# 1CM_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.95.sdf (confidence: 0.950)
#   └── rank2_confidence-1.00.sdf (confidence: 1.000)
#   └── rank3_confidence-1.61.sdf (confidence: 1.610)
#   └── rank4_confidence-2.09.sdf (confidence: 2.090)
#   └── rank5_confidence-2.14.sdf (confidence: 2.140)
#   └── ... and 5 more
#
# 1CM_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.15.sdf (confidence: 1.150)
#   └── rank2_confidence-1.60.sdf (confidence: 1.600)
#   └── rank3_confidence-1.75.sdf (confidence: 1.750)
#   └── rank4_confidence-2.17.sdf (confidence: 2.170)
#   └── rank5_confidence-2.44.sdf (confidence: 2.440)
#   └── ... and 5 more
#
# 1CM_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.86.sdf (confidence: 1.860)
#   └── rank2_confidence-2.06.sdf (confidence: 2.060)
#   └── rank3_confidence-2.21.sdf (confidence: 2.210)
#   └── rank4_confidence-2.36.sdf (confidence: 2.360)
#   └── rank5_confidence-2.40.sdf (confidence: 2.400)
#   └── ... and 5 more
#
# 1CY_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.63.sdf (confidence: 0.630)
#   └── rank2_confidence-0.70.sdf (confidence: 0.700)
#   └── rank3_confidence-0.84.sdf (confidence: 0.840)
#   └── rank4_confidence-0.86.sdf (confidence: 0.860)
#   └── rank5_confidence-1.04.sdf (confidence: 1.040)
#   └── ... and 5 more
#
# 1CY_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.81.sdf (confidence: 0.810)
#   └── rank2_confidence-1.08.sdf (confidence: 1.080)
#   └── rank3_confidence-1.33.sdf (confidence: 1.330)
#   └── rank4_confidence-1.63.sdf (confidence: 1.630)
#   └── rank5_confidence-1.69.sdf (confidence: 1.690)
#   └── ... and 5 more
#
# 1CY_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.62.sdf (confidence: 0.620)
#   └── rank2_confidence-0.67.sdf (confidence: 0.670)
#   └── rank3_confidence-0.93.sdf (confidence: 0.930)
#   └── rank4_confidence-0.93.sdf (confidence: 0.930)
#   └── rank5_confidence-0.97.sdf (confidence: 0.970)
#   └── ... and 5 more
#
# 1CY_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.22.sdf (confidence: 1.220)
#   └── rank2_confidence-2.04.sdf (confidence: 2.040)
#   └── rank3_confidence-2.23.sdf (confidence: 2.230)
#   └── rank4_confidence-2.39.sdf (confidence: 2.390)
#   └── rank5_confidence-2.49.sdf (confidence: 2.490)
#   └── ... and 5 more
#
# 1JZ_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.60.sdf (confidence: 0.600)
#   └── rank2_confidence-0.71.sdf (confidence: 0.710)
#   └── rank3_confidence-0.82.sdf (confidence: 0.820)
#   └── rank4_confidence-0.91.sdf (confidence: 0.910)
#   └── rank5_confidence-0.96.sdf (confidence: 0.960)
#   └── ... and 5 more
#
# 1JZ_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.31.sdf (confidence: 1.310)
#   └── rank2_confidence-1.59.sdf (confidence: 1.590)
#   └── rank3_confidence-1.74.sdf (confidence: 1.740)
#   └── rank4_confidence-3.23.sdf (confidence: 3.230)
#   └── rank5_confidence-3.32.sdf (confidence: 3.320)
#   └── ... and 5 more
#
# 1JZ_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.47.sdf (confidence: 0.470)
#   └── rank2_confidence-0.52.sdf (confidence: 0.520)
#   └── rank3_confidence-0.59.sdf (confidence: 0.590)
#   └── rank4_confidence-0.60.sdf (confidence: 0.600)
#   └── rank5_confidence-0.75.sdf (confidence: 0.750)
#   └── ... and 5 more
#
# 1JZ_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.82.sdf (confidence: 2.820)
#   └── rank2_confidence-3.06.sdf (confidence: 3.060)
#   └── rank3_confidence-3.19.sdf (confidence: 3.190)
#   └── rank4_confidence-3.37.sdf (confidence: 3.370)
#   └── rank5_confidence-3.58.sdf (confidence: 3.580)
#   └── ... and 5 more
#
# 1K5_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.74.sdf (confidence: 0.740)
#   └── rank2_confidence-0.78.sdf (confidence: 0.780)
#   └── rank3_confidence-0.84.sdf (confidence: 0.840)
#   └── rank4_confidence-0.92.sdf (confidence: 0.920)
#   └── rank5_confidence-0.93.sdf (confidence: 0.930)
#   └── ... and 5 more
#
# 1K5_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.62.sdf (confidence: 0.620)
#   └── rank2_confidence-0.66.sdf (confidence: 0.660)
#   └── rank3_confidence-0.66.sdf (confidence: 0.660)
#   └── rank4_confidence-0.68.sdf (confidence: 0.680)
#   └── rank5_confidence-0.68.sdf (confidence: 0.680)
#   └── ... and 5 more
#
# 1K5_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.59.sdf (confidence: 0.590)
#   └── rank2_confidence-0.96.sdf (confidence: 0.960)
#   └── rank3_confidence-1.02.sdf (confidence: 1.020)
#   └── rank4_confidence-2.60.sdf (confidence: 2.600)
#   └── rank5_confidence-2.79.sdf (confidence: 2.790)
#   └── ... and 5 more
#
# 1K5_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.48.sdf (confidence: 2.480)
#   └── rank2_confidence-2.58.sdf (confidence: 2.580)
#   └── rank3_confidence-2.72.sdf (confidence: 2.720)
#   └── rank4_confidence-2.95.sdf (confidence: 2.950)
#   └── rank5_confidence-3.42.sdf (confidence: 3.420)
#   └── ... and 5 more
#
# 1OH_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.28.sdf (confidence: 1.280)
#   └── rank2_confidence-1.51.sdf (confidence: 1.510)
#   └── rank3_confidence-1.51.sdf (confidence: 1.510)
#   └── rank4_confidence-1.63.sdf (confidence: 1.630)
#   └── rank5_confidence-1.63.sdf (confidence: 1.630)
#   └── ... and 5 more
#
# 1OH_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.78.sdf (confidence: 0.780)
#   └── rank2_confidence-1.03.sdf (confidence: 1.030)
#   └── rank3_confidence-1.05.sdf (confidence: 1.050)
#   └── rank4_confidence-1.26.sdf (confidence: 1.260)
#   └── rank5_confidence-1.35.sdf (confidence: 1.350)
#   └── ... and 5 more
#
# 1OH_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.66.sdf (confidence: 0.660)
#   └── rank2_confidence-0.67.sdf (confidence: 0.670)
#   └── rank3_confidence-0.74.sdf (confidence: 0.740)
#   └── rank4_confidence-1.28.sdf (confidence: 1.280)
#   └── rank5_confidence-1.30.sdf (confidence: 1.300)
#   └── ... and 5 more
#
# 1OH_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.60.sdf (confidence: 2.600)
#   └── rank2_confidence-2.61.sdf (confidence: 2.610)
#   └── rank3_confidence-2.70.sdf (confidence: 2.700)
#   └── rank4_confidence-2.75.sdf (confidence: 2.750)
#   └── rank5_confidence-2.81.sdf (confidence: 2.810)
#   └── ... and 5 more
#
# 1PC_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.61.sdf (confidence: 0.610)
#   └── rank2_confidence-0.71.sdf (confidence: 0.710)
#   └── rank3_confidence-2.25.sdf (confidence: 2.250)
#   └── rank4_confidence-2.72.sdf (confidence: 2.720)
#   └── rank5_confidence-3.08.sdf (confidence: 3.080)
#   └── ... and 5 more
#
# 1PC_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.45.sdf (confidence: 0.450)
#   └── rank2_confidence-0.53.sdf (confidence: 0.530)
#   └── rank3_confidence-0.61.sdf (confidence: 0.610)
#   └── rank4_confidence-0.64.sdf (confidence: 0.640)
#   └── rank5_confidence-1.24.sdf (confidence: 1.240)
#   └── ... and 5 more
#
# 1PC_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.01.sdf (confidence: 1.010)
#   └── rank2_confidence-1.05.sdf (confidence: 1.050)
#   └── rank3_confidence-1.47.sdf (confidence: 1.470)
#   └── rank4_confidence-1.51.sdf (confidence: 1.510)
#   └── rank5_confidence-1.59.sdf (confidence: 1.590)
#   └── ... and 5 more
#
# 1PC_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.15.sdf (confidence: 1.150)
#   └── rank2_confidence-1.20.sdf (confidence: 1.200)
#   └── rank3_confidence-1.94.sdf (confidence: 1.940)
#   └── rank4_confidence-1.96.sdf (confidence: 1.960)
#   └── rank5_confidence-2.15.sdf (confidence: 2.150)
#   └── ... and 5 more
#
# 1WE_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.71.sdf (confidence: 0.710)
#   └── rank2_confidence-1.06.sdf (confidence: 1.060)
#   └── rank3_confidence-1.16.sdf (confidence: 1.160)
#   └── rank4_confidence-1.21.sdf (confidence: 1.210)
#   └── rank5_confidence-1.40.sdf (confidence: 1.400)
#   └── ... and 5 more
#
# 1WE_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.79.sdf (confidence: 0.790)
#   └── rank2_confidence-0.85.sdf (confidence: 0.850)
#   └── rank3_confidence-0.87.sdf (confidence: 0.870)
#   └── rank4_confidence-1.04.sdf (confidence: 1.040)
#   └── rank5_confidence-1.82.sdf (confidence: 1.820)
#   └── ... and 5 more
#
# 1WE_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.15.sdf (confidence: 0.150)
#   └── rank2_confidence-0.65.sdf (confidence: 0.650)
#   └── rank3_confidence-0.85.sdf (confidence: 0.850)
#   └── rank4_confidence-0.93.sdf (confidence: 0.930)
#   └── rank5_confidence-1.29.sdf (confidence: 1.290)
#   └── ... and 5 more
#
# 1WE_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.68.sdf (confidence: 1.680)
#   └── rank2_confidence-2.54.sdf (confidence: 2.540)
#   └── rank3_confidence-2.67.sdf (confidence: 2.670)
#   └── rank4_confidence-2.77.sdf (confidence: 2.770)
#   └── rank5_confidence-2.86.sdf (confidence: 2.860)
#   └── ... and 5 more
#
# 201_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.54.sdf (confidence: 0.540)
#   └── rank2_confidence-0.61.sdf (confidence: 0.610)
#   └── rank3_confidence-0.76.sdf (confidence: 0.760)
#   └── rank4_confidence-0.77.sdf (confidence: 0.770)
#   └── rank5_confidence-1.06.sdf (confidence: 1.060)
#   └── ... and 5 more
#
# 201_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.81.sdf (confidence: 0.810)
#   └── rank2_confidence-1.45.sdf (confidence: 1.450)
#   └── rank3_confidence-1.65.sdf (confidence: 1.650)
#   └── rank4_confidence-2.01.sdf (confidence: 2.010)
#   └── rank5_confidence-2.34.sdf (confidence: 2.340)
#   └── ... and 5 more
#
# 201_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.39.sdf (confidence: 0.390)
#   └── rank2_confidence-0.49.sdf (confidence: 0.490)
#   └── rank3_confidence-0.56.sdf (confidence: 0.560)
#   └── rank4_confidence-0.60.sdf (confidence: 0.600)
#   └── rank5_confidence-0.81.sdf (confidence: 0.810)
#   └── ... and 5 more
#
# 201_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.19.sdf (confidence: 2.190)
#   └── rank2_confidence-2.27.sdf (confidence: 2.270)
#   └── rank3_confidence-2.43.sdf (confidence: 2.430)
#   └── rank4_confidence-2.47.sdf (confidence: 2.470)
#   └── rank5_confidence-2.80.sdf (confidence: 2.800)
#   └── ... and 5 more
#
# 205_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.72.sdf (confidence: 0.720)
#   └── rank2_confidence-0.75.sdf (confidence: 0.750)
#   └── rank3_confidence-0.79.sdf (confidence: 0.790)
#   └── rank4_confidence-0.83.sdf (confidence: 0.830)
#   └── rank5_confidence-0.87.sdf (confidence: 0.870)
#   └── ... and 5 more
#
# 205_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.93.sdf (confidence: 0.930)
#   └── rank2_confidence-0.97.sdf (confidence: 0.970)
#   └── rank3_confidence-1.00.sdf (confidence: 1.000)
#   └── rank4_confidence-1.01.sdf (confidence: 1.010)
#   └── rank5_confidence-1.05.sdf (confidence: 1.050)
#   └── ... and 5 more
#
# 205_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.34.sdf (confidence: 0.340)
#   └── rank2_confidence-0.37.sdf (confidence: 0.370)
#   └── rank3_confidence-0.57.sdf (confidence: 0.570)
#   └── rank4_confidence-0.66.sdf (confidence: 0.660)
#   └── rank5_confidence-0.66.sdf (confidence: 0.660)
#   └── ... and 5 more
#
# 205_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.72.sdf (confidence: 2.720)
#   └── rank2_confidence-2.75.sdf (confidence: 2.750)
#   └── rank3_confidence-2.81.sdf (confidence: 2.810)
#   └── rank4_confidence-2.89.sdf (confidence: 2.890)
#   └── rank5_confidence-2.91.sdf (confidence: 2.910)
#   └── ... and 5 more
#
# 210_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.75.sdf (confidence: 1.750)
#   └── rank2_confidence-1.76.sdf (confidence: 1.760)
#   └── rank3_confidence-1.90.sdf (confidence: 1.900)
#   └── rank4_confidence-2.01.sdf (confidence: 2.010)
#   └── rank5_confidence-2.11.sdf (confidence: 2.110)
#   └── ... and 5 more
#
# 210_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.41.sdf (confidence: 1.410)
#   └── rank2_confidence-1.66.sdf (confidence: 1.660)
#   └── rank3_confidence-1.79.sdf (confidence: 1.790)
#   └── rank4_confidence-1.96.sdf (confidence: 1.960)
#   └── rank5_confidence-2.30.sdf (confidence: 2.300)
#   └── ... and 5 more
#
# 210_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.66.sdf (confidence: 1.660)
#   └── rank2_confidence-5.00.sdf (confidence: 5.000)
#   └── rank3_confidence-5.02.sdf (confidence: 5.020)
#   └── rank4_confidence-5.05.sdf (confidence: 5.050)
#   └── rank5_confidence-5.06.sdf (confidence: 5.060)
#   └── ... and 5 more
#
# 210_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.52.sdf (confidence: 2.520)
#   └── rank2_confidence-2.60.sdf (confidence: 2.600)
#   └── rank3_confidence-3.63.sdf (confidence: 3.630)
#   └── rank4_confidence-1000.00.sdf (confidence: 1000.000)
#   └── rank5_confidence-1000.00.sdf (confidence: 1000.000)
#   └── ... and 5 more
#
# 21B_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.54.sdf (confidence: 0.540)
#   └── rank2_confidence-0.59.sdf (confidence: 0.590)
#   └── rank3_confidence-1.58.sdf (confidence: 1.580)
#   └── rank4_confidence-1.67.sdf (confidence: 1.670)
#   └── rank5_confidence-1.85.sdf (confidence: 1.850)
#   └── ... and 5 more
#
# 21B_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.54.sdf (confidence: 0.540)
#   └── rank2_confidence-1.06.sdf (confidence: 1.060)
#   └── rank3_confidence-1.43.sdf (confidence: 1.430)
#   └── rank4_confidence-1.86.sdf (confidence: 1.860)
#   └── rank5_confidence-1.96.sdf (confidence: 1.960)
#   └── ... and 5 more
#
# 21B_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.30.sdf (confidence: 1.300)
#   └── rank2_confidence-1.95.sdf (confidence: 1.950)
#   └── rank3_confidence-2.09.sdf (confidence: 2.090)
#   └── rank4_confidence-2.67.sdf (confidence: 2.670)
#   └── rank5_confidence-2.81.sdf (confidence: 2.810)
#   └── ... and 5 more
#
# 21B_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.75.sdf (confidence: 1.750)
#   └── rank2_confidence-2.03.sdf (confidence: 2.030)
#   └── rank3_confidence-2.19.sdf (confidence: 2.190)
#   └── rank4_confidence-2.24.sdf (confidence: 2.240)
#   └── rank5_confidence-2.37.sdf (confidence: 2.370)
#   └── ... and 5 more
#
# 221_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.88.sdf (confidence: 0.880)
#   └── rank2_confidence-0.89.sdf (confidence: 0.890)
#   └── rank3_confidence-1.03.sdf (confidence: 1.030)
#   └── rank4_confidence-1.27.sdf (confidence: 1.270)
#   └── rank5_confidence-1.37.sdf (confidence: 1.370)
#   └── ... and 5 more
#
# 221_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.13.sdf (confidence: 1.130)
#   └── rank2_confidence-1.17.sdf (confidence: 1.170)
#   └── rank3_confidence-1.31.sdf (confidence: 1.310)
#   └── rank4_confidence-1.34.sdf (confidence: 1.340)
#   └── rank5_confidence-1.41.sdf (confidence: 1.410)
#   └── ... and 5 more
#
# 221_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.18.sdf (confidence: 1.180)
#   └── rank2_confidence-1.76.sdf (confidence: 1.760)
#   └── rank3_confidence-2.42.sdf (confidence: 2.420)
#   └── rank4_confidence-3.06.sdf (confidence: 3.060)
#   └── rank5_confidence-3.14.sdf (confidence: 3.140)
#   └── ... and 5 more
#
# 221_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.95.sdf (confidence: 1.950)
#   └── rank2_confidence-2.15.sdf (confidence: 2.150)
#   └── rank3_confidence-2.21.sdf (confidence: 2.210)
#   └── rank4_confidence-2.30.sdf (confidence: 2.300)
#   └── rank5_confidence-2.36.sdf (confidence: 2.360)
#   └── ... and 5 more
#
# 22F_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.42.sdf (confidence: 0.420)
#   └── rank2_confidence-0.56.sdf (confidence: 0.560)
#   └── rank3_confidence-0.68.sdf (confidence: 0.680)
#   └── rank4_confidence-0.70.sdf (confidence: 0.700)
#   └── rank5_confidence-0.78.sdf (confidence: 0.780)
#   └── ... and 5 more
#
# 22F_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.41.sdf (confidence: 0.410)
#   └── rank2_confidence-0.47.sdf (confidence: 0.470)
#   └── rank3_confidence-0.56.sdf (confidence: 0.560)
#   └── rank4_confidence-0.67.sdf (confidence: 0.670)
#   └── rank5_confidence-0.71.sdf (confidence: 0.710)
#   └── ... and 5 more
#
# 22F_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.16.sdf (confidence: 0.160)
#   └── rank2_confidence-0.32.sdf (confidence: 0.320)
#   └── rank3_confidence-0.38.sdf (confidence: 0.380)
#   └── rank4_confidence-0.40.sdf (confidence: 0.400)
#   └── rank5_confidence-0.43.sdf (confidence: 0.430)
#   └── ... and 5 more
#
# 22F_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.73.sdf (confidence: 2.730)
#   └── rank2_confidence-2.79.sdf (confidence: 2.790)
#   └── rank3_confidence-3.12.sdf (confidence: 3.120)
#   └── rank4_confidence-3.16.sdf (confidence: 3.160)
#   └── rank5_confidence-3.27.sdf (confidence: 3.270)
#   └── ... and 5 more
#
# 231_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence0.01.sdf (confidence: 0.010)
#   └── rank2_confidence-0.12.sdf (confidence: 0.120)
#   └── rank3_confidence-0.20.sdf (confidence: 0.200)
#   └── rank4_confidence-0.73.sdf (confidence: 0.730)
#   └── rank5_confidence-0.79.sdf (confidence: 0.790)
#   └── ... and 5 more
#
# 231_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.46.sdf (confidence: 0.460)
#   └── rank2_confidence-0.60.sdf (confidence: 0.600)
#   └── rank3_confidence-0.73.sdf (confidence: 0.730)
#   └── rank4_confidence-0.86.sdf (confidence: 0.860)
#   └── rank5_confidence-1.50.sdf (confidence: 1.500)
#   └── ... and 5 more
#
# 231_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence0.32.sdf (confidence: 0.320)
#   └── rank2_confidence0.32.sdf (confidence: 0.320)
#   └── rank3_confidence0.32.sdf (confidence: 0.320)
#   └── rank4_confidence0.29.sdf (confidence: 0.290)
#   └── rank5_confidence0.28.sdf (confidence: 0.280)
#   └── ... and 5 more
#
# 231_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.32.sdf (confidence: 2.320)
#   └── rank2_confidence-2.35.sdf (confidence: 2.350)
#   └── rank3_confidence-2.60.sdf (confidence: 2.600)
#   └── rank4_confidence-2.60.sdf (confidence: 2.600)
#   └── rank5_confidence-3.04.sdf (confidence: 3.040)
#   └── ... and 5 more
#
# 23F_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.74.sdf (confidence: 0.740)
#   └── rank2_confidence-0.77.sdf (confidence: 0.770)
#   └── rank3_confidence-1.00.sdf (confidence: 1.000)
#   └── rank4_confidence-1.04.sdf (confidence: 1.040)
#   └── rank5_confidence-1.61.sdf (confidence: 1.610)
#   └── ... and 5 more
#
# 23F_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.72.sdf (confidence: 0.720)
#   └── rank2_confidence-0.80.sdf (confidence: 0.800)
#   └── rank3_confidence-0.89.sdf (confidence: 0.890)
#   └── rank4_confidence-0.91.sdf (confidence: 0.910)
#   └── rank5_confidence-0.92.sdf (confidence: 0.920)
#   └── ... and 5 more
#
# 23F_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.20.sdf (confidence: 0.200)
#   └── rank2_confidence-0.22.sdf (confidence: 0.220)
#   └── rank3_confidence-0.29.sdf (confidence: 0.290)
#   └── rank4_confidence-0.29.sdf (confidence: 0.290)
#   └── rank5_confidence-0.33.sdf (confidence: 0.330)
#   └── ... and 5 more
#
# 23F_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.09.sdf (confidence: 2.090)
#   └── rank2_confidence-2.22.sdf (confidence: 2.220)
#   └── rank3_confidence-2.27.sdf (confidence: 2.270)
#   └── rank4_confidence-2.39.sdf (confidence: 2.390)
#   └── rank5_confidence-2.57.sdf (confidence: 2.570)
#   └── ... and 5 more
#
# 251_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.57.sdf (confidence: 0.570)
#   └── rank2_confidence-0.95.sdf (confidence: 0.950)
#   └── rank3_confidence-1.07.sdf (confidence: 1.070)
#   └── rank4_confidence-1.21.sdf (confidence: 1.210)
#   └── rank5_confidence-1.34.sdf (confidence: 1.340)
#   └── ... and 5 more
#
# 251_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.81.sdf (confidence: 0.810)
#   └── rank2_confidence-0.90.sdf (confidence: 0.900)
#   └── rank3_confidence-0.92.sdf (confidence: 0.920)
#   └── rank4_confidence-1.04.sdf (confidence: 1.040)
#   └── rank5_confidence-1.07.sdf (confidence: 1.070)
#   └── ... and 5 more
#
# 251_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.57.sdf (confidence: 0.570)
#   └── rank2_confidence-0.58.sdf (confidence: 0.580)
#   └── rank3_confidence-0.59.sdf (confidence: 0.590)
#   └── rank4_confidence-0.72.sdf (confidence: 0.720)
#   └── rank5_confidence-0.74.sdf (confidence: 0.740)
#   └── ... and 5 more
#
# 251_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.17.sdf (confidence: 2.170)
#   └── rank2_confidence-2.47.sdf (confidence: 2.470)
#   └── rank3_confidence-2.64.sdf (confidence: 2.640)
#   └── rank4_confidence-2.64.sdf (confidence: 2.640)
#   └── rank5_confidence-2.73.sdf (confidence: 2.730)
#   └── ... and 5 more
#
# 256_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.41.sdf (confidence: 0.410)
#   └── rank2_confidence-0.80.sdf (confidence: 0.800)
#   └── rank3_confidence-1.71.sdf (confidence: 1.710)
#   └── rank4_confidence-1.89.sdf (confidence: 1.890)
#   └── rank5_confidence-1.92.sdf (confidence: 1.920)
#   └── ... and 5 more
#
# 256_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.56.sdf (confidence: 1.560)
#   └── rank2_confidence-1.78.sdf (confidence: 1.780)
#   └── rank3_confidence-1.84.sdf (confidence: 1.840)
#   └── rank4_confidence-1.98.sdf (confidence: 1.980)
#   └── rank5_confidence-2.69.sdf (confidence: 2.690)
#   └── ... and 5 more
#
# 256_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.31.sdf (confidence: 0.310)
#   └── rank2_confidence-1.05.sdf (confidence: 1.050)
#   └── rank3_confidence-1.16.sdf (confidence: 1.160)
#   └── rank4_confidence-1.41.sdf (confidence: 1.410)
#   └── rank5_confidence-1.47.sdf (confidence: 1.470)
#   └── ... and 5 more
#
# 256_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-3.18.sdf (confidence: 3.180)
#   └── rank2_confidence-3.18.sdf (confidence: 3.180)
#   └── rank3_confidence-3.35.sdf (confidence: 3.350)
#   └── rank4_confidence-3.39.sdf (confidence: 3.390)
#   └── rank5_confidence-3.52.sdf (confidence: 3.520)
#   └── ... and 5 more
#
# 268_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.06.sdf (confidence: 0.060)
#   └── rank2_confidence-0.40.sdf (confidence: 0.400)
#   └── rank3_confidence-0.51.sdf (confidence: 0.510)
#   └── rank4_confidence-0.60.sdf (confidence: 0.600)
#   └── rank5_confidence-0.62.sdf (confidence: 0.620)
#   └── ... and 5 more
#
# 268_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.06.sdf (confidence: 0.060)
#   └── rank2_confidence-0.52.sdf (confidence: 0.520)
#   └── rank3_confidence-0.54.sdf (confidence: 0.540)
#   └── rank4_confidence-0.70.sdf (confidence: 0.700)
#   └── rank5_confidence-0.81.sdf (confidence: 0.810)
#   └── ... and 5 more
#
# 268_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence0.05.sdf (confidence: 0.050)
#   └── rank2_confidence0.01.sdf (confidence: 0.010)
#   └── rank3_confidence-0.02.sdf (confidence: 0.020)
#   └── rank4_confidence-0.10.sdf (confidence: 0.100)
#   └── rank5_confidence-0.17.sdf (confidence: 0.170)
#   └── ... and 5 more
#
# 268_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.62.sdf (confidence: 1.620)
#   └── rank2_confidence-1.92.sdf (confidence: 1.920)
#   └── rank3_confidence-2.36.sdf (confidence: 2.360)
#   └── rank4_confidence-2.71.sdf (confidence: 2.710)
#   └── rank5_confidence-2.99.sdf (confidence: 2.990)
#   └── ... and 5 more
#
# 269_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.72.sdf (confidence: 1.720)
#   └── rank2_confidence-3.67.sdf (confidence: 3.670)
#   └── rank3_confidence-4.96.sdf (confidence: 4.960)
#   └── rank4_confidence-5.03.sdf (confidence: 5.030)
#   └── rank5_confidence-5.20.sdf (confidence: 5.200)
#   └── ... and 5 more
#
# 269_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.80.sdf (confidence: 0.800)
#   └── rank2_confidence-4.98.sdf (confidence: 4.980)
#   └── rank3_confidence-4.98.sdf (confidence: 4.980)
#   └── rank4_confidence-5.00.sdf (confidence: 5.000)
#   └── rank5_confidence-5.07.sdf (confidence: 5.070)
#   └── ... and 5 more
#
# 269_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-3.58.sdf (confidence: 3.580)
#   └── rank2_confidence-4.95.sdf (confidence: 4.950)
#   └── rank3_confidence-5.01.sdf (confidence: 5.010)
#   └── rank4_confidence-5.04.sdf (confidence: 5.040)
#   └── rank5_confidence-5.12.sdf (confidence: 5.120)
#   └── ... and 5 more
#
# 26C_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.56.sdf (confidence: 0.560)
#   └── rank2_confidence-0.58.sdf (confidence: 0.580)
#   └── rank3_confidence-0.76.sdf (confidence: 0.760)
#   └── rank4_confidence-0.85.sdf (confidence: 0.850)
#   └── rank5_confidence-0.93.sdf (confidence: 0.930)
#   └── ... and 5 more
#
# 26C_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.69.sdf (confidence: 0.690)
#   └── rank2_confidence-0.76.sdf (confidence: 0.760)
#   └── rank3_confidence-0.78.sdf (confidence: 0.780)
#   └── rank4_confidence-0.82.sdf (confidence: 0.820)
#   └── rank5_confidence-0.83.sdf (confidence: 0.830)
#   └── ... and 5 more
#
# 26C_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.55.sdf (confidence: 0.550)
#   └── rank2_confidence-0.56.sdf (confidence: 0.560)
#   └── rank3_confidence-0.65.sdf (confidence: 0.650)
#   └── rank4_confidence-0.66.sdf (confidence: 0.660)
#   └── rank5_confidence-0.67.sdf (confidence: 0.670)
#   └── ... and 5 more
#
# 26C_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.77.sdf (confidence: 2.770)
#   └── rank2_confidence-2.97.sdf (confidence: 2.970)
#   └── rank3_confidence-3.03.sdf (confidence: 3.030)
#   └── rank4_confidence-3.06.sdf (confidence: 3.060)
#   └── rank5_confidence-3.16.sdf (confidence: 3.160)
#   └── ... and 5 more
#
# 270_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.42.sdf (confidence: 0.420)
#   └── rank2_confidence-0.61.sdf (confidence: 0.610)
#   └── rank3_confidence-0.91.sdf (confidence: 0.910)
#   └── rank4_confidence-0.93.sdf (confidence: 0.930)
#   └── rank5_confidence-1.19.sdf (confidence: 1.190)
#   └── ... and 5 more
#
# 270_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.54.sdf (confidence: 0.540)
#   └── rank2_confidence-0.58.sdf (confidence: 0.580)
#   └── rank3_confidence-0.67.sdf (confidence: 0.670)
#   └── rank4_confidence-0.70.sdf (confidence: 0.700)
#   └── rank5_confidence-0.80.sdf (confidence: 0.800)
#   └── ... and 5 more
#
# 270_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.11.sdf (confidence: 0.110)
#   └── rank2_confidence-0.66.sdf (confidence: 0.660)
#   └── rank3_confidence-0.68.sdf (confidence: 0.680)
#   └── rank4_confidence-0.79.sdf (confidence: 0.790)
#   └── rank5_confidence-0.83.sdf (confidence: 0.830)
#   └── ... and 5 more
#
# 270_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.22.sdf (confidence: 1.220)
#   └── rank2_confidence-1.26.sdf (confidence: 1.260)
#   └── rank3_confidence-1.41.sdf (confidence: 1.410)
#   └── rank4_confidence-1.63.sdf (confidence: 1.630)
#   └── rank5_confidence-1.78.sdf (confidence: 1.780)
#   └── ... and 5 more
#
# 283_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.02.sdf (confidence: 1.020)
#   └── rank2_confidence-1.29.sdf (confidence: 1.290)
#   └── rank3_confidence-1.31.sdf (confidence: 1.310)
#   └── rank4_confidence-1.34.sdf (confidence: 1.340)
#   └── rank5_confidence-1.40.sdf (confidence: 1.400)
#   └── ... and 5 more
#
# 283_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.30.sdf (confidence: 1.300)
#   └── rank2_confidence-1.35.sdf (confidence: 1.350)
#   └── rank3_confidence-1.54.sdf (confidence: 1.540)
#   └── rank4_confidence-1.58.sdf (confidence: 1.580)
#   └── rank5_confidence-1.62.sdf (confidence: 1.620)
#   └── ... and 5 more
#
# 283_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.76.sdf (confidence: 0.760)
#   └── rank2_confidence-0.77.sdf (confidence: 0.770)
#   └── rank3_confidence-0.90.sdf (confidence: 0.900)
#   └── rank4_confidence-1.23.sdf (confidence: 1.230)
#   └── rank5_confidence-1.63.sdf (confidence: 1.630)
#   └── ... and 5 more
#
# 283_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.54.sdf (confidence: 2.540)
#   └── rank2_confidence-2.91.sdf (confidence: 2.910)
#   └── rank3_confidence-3.04.sdf (confidence: 3.040)
#   └── rank4_confidence-3.07.sdf (confidence: 3.070)
#   └── rank5_confidence-3.15.sdf (confidence: 3.150)
#   └── ... and 5 more
#
# 299_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.35.sdf (confidence: 1.350)
#   └── rank2_confidence-1.38.sdf (confidence: 1.380)
#   └── rank3_confidence-1.65.sdf (confidence: 1.650)
#   └── rank4_confidence-1.95.sdf (confidence: 1.950)
#   └── rank5_confidence-1.97.sdf (confidence: 1.970)
#   └── ... and 5 more
#
# 299_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.24.sdf (confidence: 1.240)
#   └── rank2_confidence-1.30.sdf (confidence: 1.300)
#   └── rank3_confidence-1.61.sdf (confidence: 1.610)
#   └── rank4_confidence-1.61.sdf (confidence: 1.610)
#   └── rank5_confidence-1.62.sdf (confidence: 1.620)
#   └── ... and 5 more
#
# 299_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.51.sdf (confidence: 1.510)
#   └── rank2_confidence-1.60.sdf (confidence: 1.600)
#   └── rank3_confidence-1.67.sdf (confidence: 1.670)
#   └── rank4_confidence-1.94.sdf (confidence: 1.940)
#   └── rank5_confidence-1.96.sdf (confidence: 1.960)
#   └── ... and 5 more
#
# 299_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-3.01.sdf (confidence: 3.010)
#   └── rank2_confidence-3.39.sdf (confidence: 3.390)
#   └── rank3_confidence-3.39.sdf (confidence: 3.390)
#   └── rank4_confidence-3.86.sdf (confidence: 3.860)
#   └── rank5_confidence-3.87.sdf (confidence: 3.870)
#   └── ... and 5 more
#
# 2C7_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.46.sdf (confidence: 0.460)
#   └── rank2_confidence-0.73.sdf (confidence: 0.730)
#   └── rank3_confidence-0.76.sdf (confidence: 0.760)
#   └── rank4_confidence-0.86.sdf (confidence: 0.860)
#   └── rank5_confidence-1.05.sdf (confidence: 1.050)
# ...
#
# XEW_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.46.sdf (confidence: 1.460)
#   └── rank2_confidence-5.33.sdf (confidence: 5.330)
#   └── rank3_confidence-1000.00.sdf (confidence: 1000.000)
#   └── rank4_confidence-1000.00.sdf (confidence: 1000.000)
#   └── rank5_confidence-1000.00.sdf (confidence: 1000.000)
#   └── ... and 5 more
#
# XP1_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.43.sdf (confidence: 0.430)
#   └── rank2_confidence-0.50.sdf (confidence: 0.500)
#   └── rank3_confidence-0.52.sdf (confidence: 0.520)
#   └── rank4_confidence-0.75.sdf (confidence: 0.750)
#   └── rank5_confidence-0.78.sdf (confidence: 0.780)
#   └── ... and 5 more
#
# XP1_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.52.sdf (confidence: 0.520)
#   └── rank2_confidence-0.56.sdf (confidence: 0.560)
#   └── rank3_confidence-0.57.sdf (confidence: 0.570)
#   └── rank4_confidence-0.58.sdf (confidence: 0.580)
#   └── rank5_confidence-0.65.sdf (confidence: 0.650)
#   └── ... and 5 more
#
# XP1_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.41.sdf (confidence: 0.410)
#   └── rank2_confidence-0.54.sdf (confidence: 0.540)
#   └── rank3_confidence-0.55.sdf (confidence: 0.550)
#   └── rank4_confidence-0.57.sdf (confidence: 0.570)
#   └── rank5_confidence-0.65.sdf (confidence: 0.650)
#   └── ... and 5 more
#
# XP1_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.98.sdf (confidence: 2.980)
#   └── rank2_confidence-3.04.sdf (confidence: 3.040)
#   └── rank3_confidence-3.28.sdf (confidence: 3.280)
#   └── rank4_confidence-3.42.sdf (confidence: 3.420)
#   └── rank5_confidence-3.43.sdf (confidence: 3.430)
#   └── ... and 5 more
#
# XQZ_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.10.sdf (confidence: 0.100)
#   └── rank2_confidence-0.13.sdf (confidence: 0.130)
#   └── rank3_confidence-0.18.sdf (confidence: 0.180)
#   └── rank4_confidence-0.22.sdf (confidence: 0.220)
#   └── rank5_confidence-0.25.sdf (confidence: 0.250)
#   └── ... and 5 more
#
# XQZ_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.19.sdf (confidence: 0.190)
#   └── rank2_confidence-0.45.sdf (confidence: 0.450)
#   └── rank3_confidence-0.55.sdf (confidence: 0.550)
#   └── rank4_confidence-0.74.sdf (confidence: 0.740)
#   └── rank5_confidence-0.80.sdf (confidence: 0.800)
#   └── ... and 5 more
#
# XQZ_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.07.sdf (confidence: 0.070)
#   └── rank2_confidence-0.08.sdf (confidence: 0.080)
#   └── rank3_confidence-0.12.sdf (confidence: 0.120)
#   └── rank4_confidence-0.14.sdf (confidence: 0.140)
#   └── rank5_confidence-0.14.sdf (confidence: 0.140)
#   └── ... and 5 more
#
# XQZ_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-0.19.sdf (confidence: 0.190)
#   └── rank2_confidence-1.16.sdf (confidence: 1.160)
#   └── rank3_confidence-1.22.sdf (confidence: 1.220)
#   └── rank4_confidence-1.45.sdf (confidence: 1.450)
#   └── rank5_confidence-1.46.sdf (confidence: 1.460)
#   └── ... and 5 more
#
# XZ5_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.03.sdf (confidence: 0.030)
#   └── rank2_confidence-0.15.sdf (confidence: 0.150)
#   └── rank3_confidence-0.17.sdf (confidence: 0.170)
#   └── rank4_confidence-0.35.sdf (confidence: 0.350)
#   └── rank5_confidence-0.43.sdf (confidence: 0.430)
#   └── ... and 5 more
#
# XZ5_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.02.sdf (confidence: 0.020)
#   └── rank2_confidence-0.13.sdf (confidence: 0.130)
#   └── rank3_confidence-0.18.sdf (confidence: 0.180)
#   └── rank4_confidence-0.20.sdf (confidence: 0.200)
#   └── rank5_confidence-0.29.sdf (confidence: 0.290)
#   └── ... and 5 more
#
# XZ5_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence0.02.sdf (confidence: 0.020)
#   └── rank2_confidence-0.04.sdf (confidence: 0.040)
#   └── rank3_confidence-0.12.sdf (confidence: 0.120)
#   └── rank4_confidence-0.19.sdf (confidence: 0.190)
#   └── rank5_confidence-0.30.sdf (confidence: 0.300)
#   └── ... and 5 more
#
# XZ5_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-0.36.sdf (confidence: 0.360)
#   └── rank2_confidence-0.73.sdf (confidence: 0.730)
#   └── rank3_confidence-1.18.sdf (confidence: 1.180)
#   └── rank4_confidence-1.26.sdf (confidence: 1.260)
#   └── rank5_confidence-1.28.sdf (confidence: 1.280)
#   └── ... and 5 more
#
# YAN_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.96.sdf (confidence: 0.960)
#   └── rank2_confidence-1.33.sdf (confidence: 1.330)
#   └── rank3_confidence-1.35.sdf (confidence: 1.350)
#   └── rank4_confidence-1.49.sdf (confidence: 1.490)
#   └── rank5_confidence-1.69.sdf (confidence: 1.690)
#   └── ... and 5 more
#
# YAN_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.31.sdf (confidence: 0.310)
#   └── rank2_confidence-1.17.sdf (confidence: 1.170)
#   └── rank3_confidence-1.34.sdf (confidence: 1.340)
#   └── rank4_confidence-1.37.sdf (confidence: 1.370)
#   └── rank5_confidence-1.89.sdf (confidence: 1.890)
#   └── ... and 5 more
#
# YAN_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.65.sdf (confidence: 0.650)
#   └── rank2_confidence-0.65.sdf (confidence: 0.650)
#   └── rank3_confidence-0.76.sdf (confidence: 0.760)
#   └── rank4_confidence-1.22.sdf (confidence: 1.220)
#   └── rank5_confidence-1.57.sdf (confidence: 1.570)
#   └── ... and 5 more
#
# YAN_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.21.sdf (confidence: 1.210)
#   └── rank2_confidence-1.29.sdf (confidence: 1.290)
#   └── rank3_confidence-1.65.sdf (confidence: 1.650)
#   └── rank4_confidence-1.99.sdf (confidence: 1.990)
#   └── rank5_confidence-2.18.sdf (confidence: 2.180)
#   └── ... and 5 more
#
# YPQ_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.46.sdf (confidence: 0.460)
#   └── rank2_confidence-0.62.sdf (confidence: 0.620)
#   └── rank3_confidence-0.80.sdf (confidence: 0.800)
#   └── rank4_confidence-1.49.sdf (confidence: 1.490)
#   └── rank5_confidence-1.68.sdf (confidence: 1.680)
#   └── ... and 5 more
#
# YPQ_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.96.sdf (confidence: 0.960)
#   └── rank2_confidence-1.02.sdf (confidence: 1.020)
#   └── rank3_confidence-1.56.sdf (confidence: 1.560)
#   └── rank4_confidence-2.42.sdf (confidence: 2.420)
#   └── rank5_confidence-2.75.sdf (confidence: 2.750)
#   └── ... and 5 more
#
# YPQ_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.34.sdf (confidence: 0.340)
#   └── rank2_confidence-0.47.sdf (confidence: 0.470)
#   └── rank3_confidence-0.91.sdf (confidence: 0.910)
#   └── rank4_confidence-1.66.sdf (confidence: 1.660)
#   └── rank5_confidence-2.04.sdf (confidence: 2.040)
#   └── ... and 5 more
#
# YPQ_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-0.74.sdf (confidence: 0.740)
#   └── rank2_confidence-1.04.sdf (confidence: 1.040)
#   └── rank3_confidence-1.32.sdf (confidence: 1.320)
#   └── rank4_confidence-2.10.sdf (confidence: 2.100)
#   └── rank5_confidence-2.15.sdf (confidence: 2.150)
#   └── ... and 5 more
#
# YRL_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.33.sdf (confidence: 0.330)
#   └── rank2_confidence-0.35.sdf (confidence: 0.350)
#   └── rank3_confidence-0.36.sdf (confidence: 0.360)
#   └── rank4_confidence-0.58.sdf (confidence: 0.580)
#   └── rank5_confidence-0.74.sdf (confidence: 0.740)
#   └── ... and 5 more
#
# YRL_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.69.sdf (confidence: 0.690)
#   └── rank2_confidence-0.81.sdf (confidence: 0.810)
#   └── rank3_confidence-1.23.sdf (confidence: 1.230)
#   └── rank4_confidence-1.26.sdf (confidence: 1.260)
#   └── rank5_confidence-1.29.sdf (confidence: 1.290)
#   └── ... and 5 more
#
# YRL_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.19.sdf (confidence: 0.190)
#   └── rank2_confidence-0.27.sdf (confidence: 0.270)
#   └── rank3_confidence-0.29.sdf (confidence: 0.290)
#   └── rank4_confidence-0.74.sdf (confidence: 0.740)
#   └── rank5_confidence-0.83.sdf (confidence: 0.830)
#   └── ... and 5 more
#
# YRL_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.41.sdf (confidence: 2.410)
#   └── rank2_confidence-2.44.sdf (confidence: 2.440)
#   └── rank3_confidence-2.44.sdf (confidence: 2.440)
#   └── rank4_confidence-2.52.sdf (confidence: 2.520)
#   └── rank5_confidence-2.60.sdf (confidence: 2.600)
#   └── ... and 5 more
#
# YTT_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.57.sdf (confidence: 0.570)
#   └── rank2_confidence-1.16.sdf (confidence: 1.160)
#   └── rank3_confidence-1.16.sdf (confidence: 1.160)
#   └── rank4_confidence-1.24.sdf (confidence: 1.240)
#   └── rank5_confidence-1.32.sdf (confidence: 1.320)
#   └── ... and 5 more
#
# YTT_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.78.sdf (confidence: 0.780)
#   └── rank2_confidence-0.84.sdf (confidence: 0.840)
#   └── rank3_confidence-0.98.sdf (confidence: 0.980)
#   └── rank4_confidence-1.00.sdf (confidence: 1.000)
#   └── rank5_confidence-1.06.sdf (confidence: 1.060)
#   └── ... and 5 more
#
# YTT_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.57.sdf (confidence: 0.570)
#   └── rank2_confidence-0.80.sdf (confidence: 0.800)
#   └── rank3_confidence-0.82.sdf (confidence: 0.820)
#   └── rank4_confidence-0.83.sdf (confidence: 0.830)
#   └── rank5_confidence-1.03.sdf (confidence: 1.030)
#   └── ... and 5 more
#
# YTT_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.52.sdf (confidence: 1.520)
#   └── rank2_confidence-1.65.sdf (confidence: 1.650)
#   └── rank3_confidence-1.70.sdf (confidence: 1.700)
#   └── rank4_confidence-1.79.sdf (confidence: 1.790)
#   └── rank5_confidence-1.80.sdf (confidence: 1.800)
#   └── ... and 5 more
#
# YTZ_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.78.sdf (confidence: 0.780)
#   └── rank2_confidence-0.81.sdf (confidence: 0.810)
#   └── rank3_confidence-1.47.sdf (confidence: 1.470)
#   └── rank4_confidence-1.63.sdf (confidence: 1.630)
#   └── rank5_confidence-1.65.sdf (confidence: 1.650)
#   └── ... and 5 more
#
# YTZ_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.06.sdf (confidence: 1.060)
#   └── rank2_confidence-1.06.sdf (confidence: 1.060)
#   └── rank3_confidence-1.40.sdf (confidence: 1.400)
#   └── rank4_confidence-1.48.sdf (confidence: 1.480)
#   └── rank5_confidence-1.50.sdf (confidence: 1.500)
#   └── ... and 5 more
#
# YTZ_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.70.sdf (confidence: 0.700)
#   └── rank2_confidence-0.76.sdf (confidence: 0.760)
#   └── rank3_confidence-0.81.sdf (confidence: 0.810)
#   └── rank4_confidence-0.93.sdf (confidence: 0.930)
#   └── rank5_confidence-1.14.sdf (confidence: 1.140)
#   └── ... and 5 more
#
# YTZ_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-0.76.sdf (confidence: 0.760)
#   └── rank2_confidence-3.49.sdf (confidence: 3.490)
#   └── rank3_confidence-3.73.sdf (confidence: 3.730)
#   └── rank4_confidence-3.89.sdf (confidence: 3.890)
#   └── rank5_confidence-3.90.sdf (confidence: 3.900)
#   └── ... and 5 more
#
# ZHZ_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.51.sdf (confidence: 0.510)
#   └── rank2_confidence-0.67.sdf (confidence: 0.670)
#   └── rank3_confidence-0.79.sdf (confidence: 0.790)
#   └── rank4_confidence-0.80.sdf (confidence: 0.800)
#   └── rank5_confidence-0.97.sdf (confidence: 0.970)
#   └── ... and 5 more
#
# ZHZ_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.70.sdf (confidence: 0.700)
#   └── rank2_confidence-0.71.sdf (confidence: 0.710)
#   └── rank3_confidence-1.16.sdf (confidence: 1.160)
#   └── rank4_confidence-1.36.sdf (confidence: 1.360)
#   └── rank5_confidence-1.74.sdf (confidence: 1.740)
#   └── ... and 5 more
#
# ZHZ_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.06.sdf (confidence: 0.060)
#   └── rank2_confidence-0.10.sdf (confidence: 0.100)
#   └── rank3_confidence-0.13.sdf (confidence: 0.130)
#   └── rank4_confidence-0.20.sdf (confidence: 0.200)
#   └── rank5_confidence-0.21.sdf (confidence: 0.210)
#   └── ... and 5 more
#
# ZHZ_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.67.sdf (confidence: 2.670)
#   └── rank2_confidence-2.90.sdf (confidence: 2.900)
#   └── rank3_confidence-2.98.sdf (confidence: 2.980)
#   └── rank4_confidence-3.12.sdf (confidence: 3.120)
#   └── rank5_confidence-3.20.sdf (confidence: 3.200)
#   └── ... and 5 more
#
# ZOL_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-1.33.sdf (confidence: 1.330)
#   └── rank2_confidence-1.44.sdf (confidence: 1.440)
#   └── rank3_confidence-1.61.sdf (confidence: 1.610)
#   └── rank4_confidence-1.69.sdf (confidence: 1.690)
#   └── rank5_confidence-1.76.sdf (confidence: 1.760)
#   └── ... and 5 more
#
# ZOL_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.32.sdf (confidence: 1.320)
#   └── rank2_confidence-1.73.sdf (confidence: 1.730)
#   └── rank3_confidence-1.76.sdf (confidence: 1.760)
#   └── rank4_confidence-1.79.sdf (confidence: 1.790)
#   └── rank5_confidence-1.82.sdf (confidence: 1.820)
#   └── ... and 5 more
#
# ZOL_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-1.24.sdf (confidence: 1.240)
#   └── rank2_confidence-1.27.sdf (confidence: 1.270)
#   └── rank3_confidence-1.32.sdf (confidence: 1.320)
#   └── rank4_confidence-1.44.sdf (confidence: 1.440)
#   └── rank5_confidence-1.47.sdf (confidence: 1.470)
#   └── ... and 5 more
#
# ZOL_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-2.54.sdf (confidence: 2.540)
#   └── rank2_confidence-2.94.sdf (confidence: 2.940)
#   └── rank3_confidence-3.20.sdf (confidence: 3.200)
#   └── rank4_confidence-3.20.sdf (confidence: 3.200)
#   └── rank5_confidence-3.59.sdf (confidence: 3.590)
#   └── ... and 5 more
#
# ZYS_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.54.sdf (confidence: 0.540)
#   └── rank2_confidence-0.57.sdf (confidence: 0.570)
#   └── rank3_confidence-0.67.sdf (confidence: 0.670)
#   └── rank4_confidence-0.68.sdf (confidence: 0.680)
#   └── rank5_confidence-0.95.sdf (confidence: 0.950)
#   └── ... and 5 more
#
# ZYS_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-0.55.sdf (confidence: 0.550)
#   └── rank2_confidence-0.64.sdf (confidence: 0.640)
#   └── rank3_confidence-0.85.sdf (confidence: 0.850)
#   └── rank4_confidence-0.92.sdf (confidence: 0.920)
#   └── rank5_confidence-1.05.sdf (confidence: 1.050)
#   └── ... and 5 more
#
# ZYS_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.66.sdf (confidence: 0.660)
#   └── rank2_confidence-0.70.sdf (confidence: 0.700)
#   └── rank3_confidence-0.77.sdf (confidence: 0.770)
#   └── rank4_confidence-0.78.sdf (confidence: 0.780)
#   └── rank5_confidence-0.81.sdf (confidence: 0.810)
#   └── ... and 5 more
#
# ZYS_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.70.sdf (confidence: 1.700)
#   └── rank2_confidence-1.71.sdf (confidence: 1.710)
#   └── rank3_confidence-1.74.sdf (confidence: 1.740)
#   └── rank4_confidence-1.79.sdf (confidence: 1.790)
#   └── rank5_confidence-1.93.sdf (confidence: 1.930)
#   └── ... and 5 more
#
# ZYX_ideal__Orai1WT-MDSnap-Fr300_cleaned/
#   └── rank1_confidence-0.40.sdf (confidence: 0.400)
#   └── rank2_confidence-0.67.sdf (confidence: 0.670)
#   └── rank3_confidence-0.75.sdf (confidence: 0.750)
#   └── rank4_confidence-0.77.sdf (confidence: 0.770)
#   └── rank5_confidence-0.77.sdf (confidence: 0.770)
#   └── ... and 5 more
#
# ZYX_ideal__Orai1WT-MDSnap-Fr400_cleaned/
#   └── rank1_confidence-1.60.sdf (confidence: 1.600)
#   └── rank2_confidence-1.82.sdf (confidence: 1.820)
#   └── rank3_confidence-2.72.sdf (confidence: 2.720)
#   └── rank4_confidence-2.86.sdf (confidence: 2.860)
#   └── rank5_confidence-2.87.sdf (confidence: 2.870)
#   └── ... and 5 more
#
# ZYX_ideal__Orai1WT-MDSnap-Fr499_cleaned/
#   └── rank1_confidence-0.29.sdf (confidence: 0.290)
#   └── rank2_confidence-0.32.sdf (confidence: 0.320)
#   └── rank3_confidence-0.41.sdf (confidence: 0.410)
#   └── rank4_confidence-0.56.sdf (confidence: 0.560)
#   └── rank5_confidence-0.58.sdf (confidence: 0.580)
#   └── ... and 5 more
#
# ZYX_ideal__Orai1WT-START-Fr0_cleaned/
#   └── rank1_confidence-1.46.sdf (confidence: 1.460)
#   └── rank2_confidence-3.06.sdf (confidence: 3.060)
#   └── rank3_confidence-3.31.sdf (confidence: 3.310)
#   └── rank4_confidence-3.43.sdf (confidence: 3.430)
#   └── rank5_confidence-3.44.sdf (confidence: 3.440)
#   └── ... and 5 more
#
# --------------------------------------------------------------------------------
# TOTAL POSES GENERATED: 23330
# --------------------------------------------------------------------------------

# %% [markdown]
# # Docking Log

# %%
log_path = DIFFDOCK_OUTPUT_DIR / DOCKING_LOG_FILENAME

if log_path.exists():
    docking_log_df = pd.read_csv(log_path)
    
    print("=" * 80)
    print("DOCKING LOG")
    print("=" * 80)
    print(f"\nLog file: {log_path}")
    print(f"Total entries: {len(docking_log_df)}")
    
    # Status breakdown
    status_counts = docking_log_df["status"].value_counts()
    print(f"\nStatus breakdown:")
    for status, count in status_counts.items():
        print(f"  {status}: {count}")
    
    # Show failed entries with reasons
    failed = docking_log_df[docking_log_df["status"] == "failed"]
    if not failed.empty:
        print(f"\n{'─' * 80}")
        print(f"FAILED DOCKINGS ({len(failed)}):")
        print(f"{'─' * 80}")
        for _, row in failed.iterrows():
            reason = row["error_reason"][:120] if pd.notna(row["error_reason"]) else "unknown"
            print(f"  ✗ {row['combo_name']}: {reason}")
    
    # Ligand property summary
    lig_cols = ["ligand_name", "lig_molecular_weight", "lig_heavy_atoms", "lig_total_atoms",
                "lig_rotatable_bonds", "lig_num_rings", "lig_aromatic_rings",
                "lig_hbd", "lig_hba", "lig_tpsa", "lig_logp", "lig_formula"]
    lig_summary = docking_log_df[lig_cols].drop_duplicates(subset=["ligand_name"]).sort_values("ligand_name")
    print(f"\n{'─' * 80}")
    print("LIGAND PROPERTIES:")
    print(f"{'─' * 80}")
    display(lig_summary.reset_index(drop=True))
    
    # Protein property summary
    prot_cols = ["protein_name", "prot_num_residues", "prot_num_atoms", "prot_num_chains"]
    prot_summary = docking_log_df[prot_cols].drop_duplicates(subset=["protein_name"]).sort_values("protein_name")
    print(f"\n{'─' * 80}")
    print("PROTEIN PROPERTIES:")
    print(f"{'─' * 80}")
    display(prot_summary.reset_index(drop=True))
    
    # Timing summary
    docked = docking_log_df[docking_log_df["status"].isin(["success", "failed"])]
    if not docked.empty:
        print(f"\n{'─' * 80}")
        print("TIMING:")
        print(f"{'─' * 80}")
        print(f"  Mean time per complex: {docked['elapsed_time_s'].mean():.1f}s")
        print(f"  Max time: {docked['elapsed_time_s'].max():.1f}s")
        print(f"  Total: {docked['elapsed_time_s'].sum():.1f}s ({docked['elapsed_time_s'].sum()/60:.1f} min)")
else:
    print(f"No docking log found at {log_path}. Run docking first.")
# Out:
# ================================================================================
# DOCKING LOG
# ================================================================================
#
# Log file: /workspace/diffdock_results/ligands_sdf_small_symmetric_approved/docking_log.csv
# Total entries: 2384
#
# Status breakdown:
#   success: 2230
#   failed: 85
#   skipped: 69
#
# ────────────────────────────────────────────────────────────────────────────────
# FAILED DOCKINGS (85):
# ────────────────────────────────────────────────────────────────────────────────
#   ✗ ACH_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: Fr300_cleaned'], ValueError('No edges and no nodes'))
#
# 31it [10:35, 28.54s/it]
# 32it [1
#   ✗ B1T_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: Fr300_cleaned'], ValueError('No edges and no nodes'))
#
# 31it [10:35, 28.54s/it]
# 32it [1
#   ✗ CLX_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 21:10:17 UTC] WARNING -Complex ['DBE_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ DCE_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 21:31:49 UTC] WARNING -Complex ['DZ2_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ DCO_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 21:31:49 UTC] WARNING -Complex ['DZ2_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ DTT_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 21:31:49 UTC] WARNING -Complex ['DZ2_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ DTV_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 21:31:49 UTC] WARNING -Complex ['DZ2_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ ETM_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 1.52s/it][2026-Mar-19 21:53:47 UTC] WARNING -Complex ['G1L_ideal__Orai1WT-MDSnap-Fr300
#   ✗ GOL_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 15:01 UTC] WARNING -Complex ['HPH_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Infere
#   ✗ HFZ_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 15:01 UTC] WARNING -Complex ['HPH_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Infere
#   ✗ HGI_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 15:01 UTC] WARNING -Complex ['HPH_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Infere
#   ✗ HLT_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 15:01 UTC] WARNING -Complex ['HPH_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Infere
#   ✗ ICF_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 22:38:48 UTC] WARNING -Complex ['L02_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ MBR_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 00:28 UTC] WARNING -Complex ['MLI_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Infere
#   ✗ MCH_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: 00:28 UTC] WARNING -Complex ['MLI_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Infere
#   ✗ MOS_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: Batch 1 Inference Iteration 18: 3 / 10 samples failed
#
# 31it [18:10, 16.38s/it]
# 32it [1
#   ✗ NET_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: Batch 1 Inference Iteration 18: 3 / 10 samples failed
#
# 31it [18:10, 16.38s/it]
# 32it [1
#   ✗ NR2_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail: lex ['PH3_ideal__Orai1WT-MDSnap-Fr300_cleaned'] Batch 1 Inference Iteration 18: 1 / 10
#   ✗ PS9_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-19 23:57:14 UTC] WARNING -Complex ['QA9_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ TCV_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 00:30:06 UTC] WARNING -Complex ['TYI_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ TF4_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 00:30:06 UTC] WARNING -Complex ['TYI_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ TRU_ideal__Orai1WT-MDSnap-Fr300_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 00:30:06 UTC] WARNING -Complex ['TYI_ideal__Orai1WT-MDSnap-Fr300_
#   ✗ ACH_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: H_ideal__Orai1WT-MDSnap-Fr400_cleaned'], ValueError('No edges and no nodes'))
#
# 32it [1
#   ✗ B1T_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: plex ['BFL_ideal__Orai1WT-MDSnap-Fr400_cleaned'] Batch 1 Inference Iteration 0: 1 / 10
#   ✗ CEQ_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 5.00s/it][2026-Mar-20 12:10:15 UTC] WARNING -Complex ['CIU_ideal__Orai1WT-MDSnap-Fr400
#   ✗ CLX_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 5.91s/it][2026-Mar-20 12:23:34 UTC] WARNING -Complex ['DIF_ideal__Orai1WT-MDSnap-Fr400
#   ✗ DCE_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 5.91s/it][2026-Mar-20 12:23:34 UTC] WARNING -Complex ['DIF_ideal__Orai1WT-MDSnap-Fr400
#   ✗ DTT_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: name"], e)
# Message: 'Failed on'
# Arguments: (['EOU_ideal__Orai1WT-MDSnap-Fr400_cleaned'
#   ✗ DTV_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: name"], e)
# Message: 'Failed on'
# Arguments: (['EOU_ideal__Orai1WT-MDSnap-Fr400_cleaned'
#   ✗ EOU_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: name"], e)
# Message: 'Failed on'
# Arguments: (['EOU_ideal__Orai1WT-MDSnap-Fr400_cleaned'
#   ✗ HFZ_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 3.52s/it][2026-Mar-20 13:04:38 UTC] WARNING -Complex ['IC1_ideal__Orai1WT-MDSnap-Fr400
#   ✗ HGI_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 3.52s/it][2026-Mar-20 13:04:38 UTC] WARNING -Complex ['IC1_ideal__Orai1WT-MDSnap-Fr400
#   ✗ MBR_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 37:21 UTC] WARNING -Complex ['MR6_ideal__Orai1WT-MDSnap-Fr400_cleaned'] Batch 1 Infere
#   ✗ MCH_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 37:21 UTC] WARNING -Complex ['MR6_ideal__Orai1WT-MDSnap-Fr400_cleaned'] Batch 1 Infere
#   ✗ MOS_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 37:21 UTC] WARNING -Complex ['MR6_ideal__Orai1WT-MDSnap-Fr400_cleaned'] Batch 1 Infere
#   ✗ NR2_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: ailed
#
# 29it [11:36, 30.45s/it]
# 30it [12:01, 28.99s/it]
# 31it [14:22, 62.40s/it]
# 32it [1
#   ✗ OMO_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: ailed
#
# 29it [11:36, 30.45s/it]
# 30it [12:01, 28.99s/it]
# 31it [14:22, 62.40s/it]
# 32it [1
#   ✗ PS9_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: 21:31 UTC] WARNING -Complex ['ROK_ideal__Orai1WT-MDSnap-Fr400_cleaned'] Batch 1 Infere
#   ✗ TRU_ideal__Orai1WT-MDSnap-Fr400_cleaned: No poses from batch. stderr tail: _ideal__Orai1WT-MDSnap-Fr400_cleaned'], ValueError('No edges and no nodes'))
#
# 32it [02
#   ✗ 269_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail: 10:25 UTC] WARNING -Complex ['3IM_ideal__Orai1WT-MDSnap-Fr499_cleaned'] Batch 1 Infere
#   ✗ 9Y6_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 17:32:39 UTC] WARNING -Complex ['AL2_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ B1T_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail: ailed
#
# 29it [07:09, 14.33s/it]
# 30it [07:24, 14.37s/it]
# 31it [07:40, 14.84s/it]
# 32it [0
#   ✗ CEQ_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 17:51:12 UTC] WARNING -Complex ['CLT_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ CLX_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail: 3.57s/it][2026-Mar-20 17:59:26 UTC] WARNING -Complex ['DIO_ideal__Orai1WT-MDSnap-Fr499
#   ✗ DCE_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail: 3.57s/it][2026-Mar-20 17:59:26 UTC] WARNING -Complex ['DIO_ideal__Orai1WT-MDSnap-Fr499
#   ✗ DTT_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:07:32 UTC] WARNING -Complex ['ETM_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ DTV_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:07:32 UTC] WARNING -Complex ['ETM_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ EOU_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:07:32 UTC] WARNING -Complex ['ETM_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ GOL_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:16:28 UTC] WARNING -Complex ['GUA_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ HFZ_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:26:12 UTC] WARNING -Complex ['IET_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ HGI_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:26:12 UTC] WARNING -Complex ['IET_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ ICF_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:26:12 UTC] WARNING -Complex ['IET_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ MBR_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:47:21 UTC] WARNING -Complex ['MSR_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ MCH_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:47:21 UTC] WARNING -Complex ['MSR_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ MOS_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:47:21 UTC] WARNING -Complex ['MSR_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ NET_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:56:47 UTC] WARNING -Complex ['P2Z_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ NR2_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:56:47 UTC] WARNING -Complex ['P2Z_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ OMO_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 18:56:47 UTC] WARNING -Complex ['P2Z_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ PS9_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail: -MDSnap-Fr499_cleaned'] Batch 1 Inference Iteration 18: 1 / 10 samples failed
#
# 32it [0
#   ✗ TBP_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 19:26:16 UTC] WARNING -Complex ['TFM_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ TRU_ideal__Orai1WT-MDSnap-Fr499_cleaned: No poses from batch. stderr tail:  failed
# [2026-Mar-20 19:35:17 UTC] WARNING -Complex ['V4O_ideal__Orai1WT-MDSnap-Fr499_
#   ✗ 269_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: les failed
# [2026-Mar-20 19:56:00 UTC] WARNING -Complex ['3IM_ideal__Orai1WT-START-Fr0_
#   ✗ CLX_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Complex ['DHR_ideal__Orai1WT-START-Fr0_cleaned'] Batch 1 Inference Iteration 1: 1 / 10
#   ✗ DCE_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Complex ['DHR_ideal__Orai1WT-START-Fr0_cleaned'] Batch 1 Inference Iteration 1: 1 / 10
#   ✗ DEP_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Complex ['DHR_ideal__Orai1WT-START-Fr0_cleaned'] Batch 1 Inference Iteration 1: 1 / 10
#   ✗ DTL_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: les failed
# [2026-Mar-20 21:01:04 UTC] WARNING -Complex ['ETF_ideal__Orai1WT-START-Fr0_
#   ✗ DTT_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: les failed
# [2026-Mar-20 21:01:04 UTC] WARNING -Complex ['ETF_ideal__Orai1WT-START-Fr0_
#   ✗ DTV_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: les failed
# [2026-Mar-20 21:01:04 UTC] WARNING -Complex ['ETF_ideal__Orai1WT-START-Fr0_
#   ✗ DXE_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: les failed
# [2026-Mar-20 21:01:04 UTC] WARNING -Complex ['ETF_ideal__Orai1WT-START-Fr0_
#   ✗ EDN_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: les failed
# [2026-Mar-20 21:01:04 UTC] WARNING -Complex ['ETF_ideal__Orai1WT-START-Fr0_
#   ✗ ETM_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: 21:12:48 UTC] WARNING -Complex ['GOL_ideal__Orai1WT-START-Fr0_cleaned'] Batch 1 Infere
#   ✗ HFZ_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: d on", orig_complex_graph["name"], e)
# Message: 'Failed on'
# Arguments: (['ICF_ideal__Or
#   ✗ HGI_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: d on", orig_complex_graph["name"], e)
# Message: 'Failed on'
# Arguments: (['ICF_ideal__Or
#   ✗ HLT_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: d on", orig_complex_graph["name"], e)
# Message: 'Failed on'
# Arguments: (['ICF_ideal__Or
#   ✗ ICF_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: d on", orig_complex_graph["name"], e)
# Message: 'Failed on'
# Arguments: (['ICF_ideal__Or
#   ✗ MBR_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Batch 1 Inference Iteration 18: 1 / 10 samples failed
#
# 31it [07:16, 15.77s/it]
# 32it [0
#   ✗ MCH_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Batch 1 Inference Iteration 18: 1 / 10 samples failed
#
# 31it [07:16, 15.77s/it]
# 32it [0
#   ✗ MMQ_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Batch 1 Inference Iteration 18: 1 / 10 samples failed
#
# 31it [07:16, 15.77s/it]
# 32it [0
#   ✗ NBU_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: 2s/it]
# 29it [07:25, 15.01s/it]
# 30it [07:43, 15.99s/it]
# 31it [08:01, 16.53s/it]
# 32it [0
#   ✗ PDO_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: 4s/it]
# 29it [06:47, 11.91s/it]
# 30it [07:00, 12.25s/it]
# 31it [07:15, 13.17s/it]
# 32it [0
#   ✗ PHQ_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: 4s/it]
# 29it [06:47, 11.91s/it]
# 30it [07:00, 12.25s/it]
# 31it [07:15, 13.17s/it]
# 32it [0
#   ✗ TCV_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Failed on'
# Arguments: (['TF4_ideal__Orai1WT-START-Fr0_cleaned'], ValueError('No edges
#   ✗ TF4_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: Failed on'
# Arguments: (['TF4_ideal__Orai1WT-START-Fr0_cleaned'], ValueError('No edges
#   ✗ TRU_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail:  Batch 1 Inference Iteration 5: 1 / 10 samples failed
#
# 31it [07:55, 16.86s/it]
# 32it [0
#   ✗ XEW_ideal__Orai1WT-START-Fr0_cleaned: No poses from batch. stderr tail: 9s/it]
# 17it [04:21, 14.73s/it]
# 18it [04:43, 16.78s/it]
# 19it [05:00, 16.91s/it]
# 20it [0
#
# ────────────────────────────────────────────────────────────────────────────────
# LIGAND PROPERTIES:
# ────────────────────────────────────────────────────────────────────────────────
#     ligand_name  lig_molecular_weight  lig_heavy_atoms  lig_total_atoms  \
# 0     007_ideal                175.28               13               30
# 1     010_ideal                108.14                8               16
# 2     08D_ideal                253.28               17               28
# 3     0A9_ideal                179.22               13               26
# 4     13X_ideal                126.11                9               15
# ..          ...                   ...              ...              ...
# 591   YTZ_ideal                255.32               16               25
# 592   ZHZ_ideal                165.19               12               23
# 593   ZOL_ideal                272.09               16               26
# 594   ZYS_ideal                275.38               19               36
# 595   ZYX_ideal                200.26               13               25
#
#      lig_rotatable_bonds  lig_num_rings  lig_aromatic_rings  lig_hbd  lig_hba  \
# 0                      3              2                   1        1        1
# 1                      2              1                   1        1        1
# 2                      5              2                   2        2        5
# 3                      5              1                   1        1        3
# 4                      3              1                   1        3        3
# ..                   ...            ...                 ...      ...      ...
# 591                    4              2                   2        2        5
# 592                    4              1                   1        1        2
# 593                    9              1                   1        5        9
# 594                    4              2                   2        2        5
# 595                    5              1                   1        2        3
#
#      lig_tpsa  lig_logp  lig_formula
# 0       26.02      2.46      C12H17N
# 1       20.23      1.18        C7H8O
# 2       98.22      1.37  C10H11N3O3S
# 3       52.32      0.73    C10H13NO2
# 4       60.69      0.80       C6H6O3
# ..        ...       ...          ...
# 591     85.08      1.53   C9H9N3O2S2
# 592     52.32      0.72     C9H11NO2
# 593    153.11     -1.12  C5H10N2O7P2
# 594     68.01      3.17   C14H17N3OS
# 595     86.18     -0.16   C8H12N2O2S
#
# [596 rows x 12 columns]
# ────────────────────────────────────────────────────────────────────────────────
# PROTEIN PROPERTIES:
# ────────────────────────────────────────────────────────────────────────────────
#                    protein_name  prot_num_residues  prot_num_atoms  \
# 0  Orai1WT-MDSnap-Fr300_cleaned                223           21026
# 1  Orai1WT-MDSnap-Fr400_cleaned                223           21026
# 2  Orai1WT-MDSnap-Fr499_cleaned                223           21026
# 3     Orai1WT-START-Fr0_cleaned                223           21026
#
#    prot_num_chains
# 0                1
# 1                1
# 2                1
# 3                1
# ────────────────────────────────────────────────────────────────────────────────
# TIMING:
# ────────────────────────────────────────────────────────────────────────────────
#   Mean time per complex: 23.1s
#   Max time: 52.6s
#   Total: 53562.8s (892.7 min)
