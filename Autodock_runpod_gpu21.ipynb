# %%
from __future__ import annotations

import csv
import itertools
import json
import os
import re
import shutil
import subprocess
import threading
import time
from collections import defaultdict
from dataclasses import dataclass, field
from datetime import datetime
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import numpy as np
import pandas as pd
from IPython.display import display
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski, rdMolDescriptors

# %%
# # Verify we are running inside the vina-gpu conda environment
# import sys, subprocess
# 
# env_name = sys.executable
# print(f"Python executable: {env_name}")
# assert "vina-gpu" in env_name, (
#     f"This notebook requires the 'vina-gpu' conda environment.\n"
#     f"Select it via: Kernel → Change Kernel → vina-gpu\n"
#     f"Current interpreter: {env_name}"
# )
# 
# # Verify the Vina-GPU binary is available
# vina_gpu_bin = "/workspace/Vina-GPU-2.1/AutoDock-Vina-GPU-2.1/AutoDock-Vina-GPU-2-1"
# result = subprocess.run([vina_gpu_bin, "--version"], capture_output=True, text=True, timeout=10)
# print(f"Vina-GPU binary: {vina_gpu_bin}")
# print(f"Version output: {result.stdout.strip() or result.stderr.strip()}")
# 
# # Verify GPU is available
# gpu_check = subprocess.run(
#     ["nvidia-smi", "--query-gpu=gpu_name,memory.total", "--format=csv,noheader"],
#     capture_output=True, text=True, timeout=10,
# )
# print(f"GPU: {gpu_check.stdout.strip()}")
# print("\n✓ vina-gpu environment verified")

# %%
# Batch clean directory
from Scripts.clean_pdb_like_pymol import batch_clean_pdbs
batch_clean_pdbs('Orai/', pattern='*.pdb', fix_histidines=True)
# Out:
# Cleaning 4 PDB files from Orai/
# ============================================================
#
# ✓ Successfully cleaned 0/4 files (0 skipped, already existed)
# []

# %% [markdown]
# # Config

# %%
from Scripts.prep_docking import run_workflow

# ── Paths ──
workspace_root = Path("/workspace")
wd = workspace_root / "master_dev"
wdlogs = wd / "logs"

orai_folder = wd / "Orai"
receptors_dir = orai_folder  # alias for consistency with DiffDock naming

# List of ligand directories — each gets its own output folder, error log, and summary
drugs_dirs: List[Path] = [
    Path("/workspace/storage/ligands_sdf_large_approved")
    # Path("/workspace/storage/ligands_sdf_small_symmetric_approved"),  # not present on this pod
]

# ── Vina-CUDA executable ──
VINA_CUDA_DIR: Path = Path("/workspace/Vina-CUDA/Vina-CUDA_v1.1")
VINA_BIN: Path = VINA_CUDA_DIR / "Vina-GPU-2-1-CUDA"

# ── Vina-CUDA docking parameters ──
THREAD: int = 8000           # number of GPU computing lanes (higher = more GPU usage)
SEARCH_DEPTH: int = 32       # Monte-Carlo search depth (replaces CPU exhaustiveness)
NUM_MODES: int = 10          # Number of binding modes to output per ligand-receptor pair
ENERGY_RANGE: int = 3
SEED: Optional[int] = None
TIMEOUT_PER_COMPLEX: int = 600  # seconds; set to 0 for no limit

# ── Box splitting for Vina-CUDA limitations ──
# Vina-CUDA v1.1 compiled with -DLARGE_BOX supports up to 100×100×100 Å
# (MAX_NUM_OF_GRID = 300, MAX_NUM_OF_ATOM_RELATION_COUNT = 38000).
# If the atom-relation count overflows for very large proteins, lower this
# back to 70 Å.  Batch --ligand_directory mode computes the grid once per sub-box.
MAX_BOX_SIZE: float = 99.0  # Maximum box dimension (Å) per sub-box
BOX_OVERLAP: float = 15.0    # Overlap between adjacent sub-boxes (Å)

# ── Output ──
VINA_OUTPUT_BASE = workspace_root / "vina_results"
VINA_OUTPUT_BASE.mkdir(parents=True, exist_ok=True)

# ── Overwrite settings ──
OVERWRITE_EXISTING: bool = False  # Set to True to re-dock existing combinations
OVERWRITE_ERROR_LOG: bool = False  # Set to True to retry previously failed ligands

# ── Log filenames ──
ERROR_LOG_FILENAME = "failed_docking.json"
DOCKING_LOG_FILENAME = "docking_log.csv"

# ── Preparation folders ──
# output_folder_mgltools = Path("docking_ready_mgltools")
# output_folder_obabel = Path("docking_read_obabel")
output_folder_meeko = Path("docking_ready_meeko")

# output_folder_mgltools.mkdir(parents=True, exist_ok=True)
output_folder_meeko.mkdir(parents=True, exist_ok=True)
# output_folder_obabel.mkdir(parents=True, exist_ok=True)
wdlogs.mkdir(parents=True, exist_ok=True)

# ── Validate directories ──
for drugs_dir in drugs_dirs:
    if not drugs_dir.exists():
        raise FileNotFoundError(f"Ligand directory missing: {drugs_dir}")
if not receptors_dir.exists():
    raise FileNotFoundError(f"Receptor directory missing: {receptors_dir}")

print("=" * 80)
print("AutoDock Vina-CUDA Batch Docking Configuration")
print("=" * 80)
print(f"Vina-CUDA executable: {VINA_BIN}")
print(f"GPU threads: {THREAD}")
print(f"Search depth: {SEARCH_DEPTH}")
print(f"Num modes: {NUM_MODES}")
print(f"Energy range: {ENERGY_RANGE} kcal/mol")
print(f"Max box size: {MAX_BOX_SIZE}Å (overlap: {BOX_OVERLAP}Å)")
print(f"Timeout per complex: {TIMEOUT_PER_COMPLEX}s ({TIMEOUT_PER_COMPLEX/60:.0f} min)" if TIMEOUT_PER_COMPLEX else "Timeout per complex: unlimited")
print(f"Output base directory: {VINA_OUTPUT_BASE}")
print(f"Overwrite existing: {OVERWRITE_EXISTING}")
print(f"\nLigand directories ({len(drugs_dirs)}):")
for d in drugs_dirs:
    n_files = len(list(d.glob("*.pdbqt")))
    output_dir = VINA_OUTPUT_BASE / d.name
    print(f"  • {d.name:30s} → output: {output_dir.name}/  ({n_files} ligand files)")
print()
# Out:
# ================================================================================
# AutoDock Vina-CUDA Batch Docking Configuration
# ================================================================================
# Vina-CUDA executable: /workspace/Vina-CUDA/Vina-CUDA_v1.1/Vina-GPU-2-1-CUDA
# GPU threads: 8000
# Search depth: 32
# Num modes: 10
# Energy range: 3 kcal/mol
# Max box size: 99.0Å (overlap: 15.0Å)
# Timeout per complex: 600s (10 min)
# Output base directory: /workspace/vina_results
# Overwrite existing: False
#
# Ligand directories (1):
#   • ligands_sdf_large_approved     → output: ligands_sdf_large_approved/  (0 ligand files)

# %% [markdown]
# # Helper Functions & Data Classes

# %%
@dataclass
class DockingResult:
    """Result of docking a protein-ligand combination."""
    protein_name: str
    ligand_name: str
    protein_path: Path
    ligand_path: Path
    output_dir: Path
    status: str  # "success", "failed", "skipped"
    num_poses: int = 0
    pose_files: List[Path] = field(default_factory=list)
    best_affinity: Optional[float] = None
    error_message: str = ""
    elapsed_time: float = 0.0

    def to_dict(self) -> dict:
        return {
            "protein_name": self.protein_name,
            "ligand_name": self.ligand_name,
            "protein_path": str(self.protein_path),
            "ligand_path": str(self.ligand_path),
            "output_dir": str(self.output_dir),
            "status": self.status,
            "num_poses": self.num_poses,
            "pose_files": [str(p) for p in self.pose_files],
            "best_affinity": self.best_affinity,
            "error_message": self.error_message,
            "elapsed_time": self.elapsed_time,
        }


def get_file_stem(path: Path) -> str:
    """Get clean filename stem without extension."""
    return path.stem.replace("_ligand", "").replace("_protein", "")


def collect_files(root: Path, extensions: List[str]) -> List[Path]:
    """Return files with given extensions located directly inside root (no recursion)."""
    files = []
    for ext in extensions:
        files.extend(sorted(p for p in root.glob(f"*{ext}") if p.is_file()))
    return sorted(set(files))


def parse_vina_affinities(log_text: str) -> List[dict]:
    """Parse Vina stdout/log text to extract affinity scores for each mode."""
    modes: List[dict] = []
    mode_pattern = r'^\s*(\d+)\s+([-\d.]+)\s+([\d.]+)\s+([\d.]+)\s*$'
    for m in re.finditer(mode_pattern, log_text, re.MULTILINE):
        modes.append({
            'mode': int(m.group(1)),
            'affinity': float(m.group(2)),
            'rmsd_lb': float(m.group(3)),
            'rmsd_ub': float(m.group(4)),
        })
    return modes


def load_error_log(output_dir: Path) -> Dict[str, dict]:
    """Load the error log for a given output directory."""
    error_log_path = output_dir / ERROR_LOG_FILENAME
    if error_log_path.exists():
        try:
            with open(error_log_path, 'r') as f:
                return json.load(f)
        except (json.JSONDecodeError, Exception) as e:
            print(f"  ⚠ Could not read error log {error_log_path}: {e}")
    return {}


def save_error_log(output_dir: Path, error_log: Dict[str, dict]):
    """Save the error log for a given output directory."""
    error_log_path = output_dir / ERROR_LOG_FILENAME
    output_dir.mkdir(parents=True, exist_ok=True)
    with open(error_log_path, 'w') as f:
        json.dump(error_log, f, indent=2)


def record_failure(output_dir: Path, combo_name: str, result: DockingResult):
    """Record a single failure to the error log."""
    error_log = load_error_log(output_dir)
    error_log[combo_name] = {
        "error": result.error_message,
        "timestamp": datetime.now().isoformat(),
        "protein": result.protein_name,
        "ligand": result.ligand_name,
        "elapsed_time": round(result.elapsed_time, 2),
    }
    save_error_log(output_dir, error_log)


def is_known_failure(output_dir: Path, combo_name: str, error_log: Optional[Dict] = None) -> bool:
    """Check if a combination is in the error log."""
    if error_log is None:
        error_log = load_error_log(output_dir)
    return combo_name in error_log

# %% [markdown]
# # Docking Log & Molecular Properties

# %%
DOCKING_LOG_COLUMNS = [
    "timestamp", "combo_name", "protein_name", "ligand_name",
    "status", "error_reason", "num_poses", "elapsed_time_s",
    # Ligand properties
    "lig_molecular_weight", "lig_heavy_atoms", "lig_total_atoms",
    "lig_rotatable_bonds", "lig_num_rings", "lig_aromatic_rings",
    "lig_hbd", "lig_hba", "lig_tpsa", "lig_logp", "lig_formula",
    # Protein properties
    "prot_num_residues", "prot_num_atoms", "prot_num_chains",
    # Config & hardware
    "search_depth", "thread", "num_modes", "energy_range", "gpu_model",
    # Best pose affinity
    "best_affinity_kcal",
]


def get_gpu_model() -> str:
    """Return the GPU model name via nvidia-smi, or 'N/A' if unavailable."""
    try:
        result = subprocess.run(
            ["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"],
            capture_output=True, text=True, timeout=5,
        )
        names = [line.strip() for line in result.stdout.strip().splitlines() if line.strip()]
        return names[0] if names else "N/A"
    except Exception:
        return "N/A"


def get_ligand_properties_from_sdf(sdf_path: Path) -> Dict:
    """Extract molecular properties from a ligand SDF file using RDKit."""
    props = {
        "lig_molecular_weight": None, "lig_heavy_atoms": None,
        "lig_total_atoms": None, "lig_rotatable_bonds": None,
        "lig_num_rings": None, "lig_aromatic_rings": None,
        "lig_hbd": None, "lig_hba": None, "lig_tpsa": None,
        "lig_logp": None, "lig_formula": None,
    }
    try:
        supplier = Chem.SDMolSupplier(str(sdf_path), sanitize=False, removeHs=False)
        mol = next(iter(supplier), None)
        if mol is None:
            return props
        try:
            Chem.SanitizeMol(mol)
        except Exception:
            pass

        props["lig_molecular_weight"] = round(Descriptors.MolWt(mol), 2)
        props["lig_heavy_atoms"] = mol.GetNumHeavyAtoms()
        props["lig_total_atoms"] = mol.GetNumAtoms()
        props["lig_rotatable_bonds"] = rdMolDescriptors.CalcNumRotatableBonds(mol)
        ri = mol.GetRingInfo()
        props["lig_num_rings"] = ri.NumRings()
        props["lig_aromatic_rings"] = rdMolDescriptors.CalcNumAromaticRings(mol)
        props["lig_hbd"] = Lipinski.NumHDonors(mol)
        props["lig_hba"] = Lipinski.NumHAcceptors(mol)
        props["lig_tpsa"] = round(Descriptors.TPSA(mol), 2)
        props["lig_logp"] = round(Descriptors.MolLogP(mol), 2)
        props["lig_formula"] = rdMolDescriptors.CalcMolFormula(mol)
    except Exception as e:
        print(f"  ⚠ Could not compute ligand properties for {sdf_path.name}: {e}")
    return props


def get_ligand_properties_from_pdbqt(pdbqt_path: Path) -> Dict:
    """Extract basic ligand properties by parsing a PDBQT file (fallback when no SDF)."""
    props = {
        "lig_molecular_weight": None, "lig_heavy_atoms": None,
        "lig_total_atoms": None, "lig_rotatable_bonds": None,
        "lig_num_rings": None, "lig_aromatic_rings": None,
        "lig_hbd": None, "lig_hba": None, "lig_tpsa": None,
        "lig_logp": None, "lig_formula": None,
    }
    try:
        atom_count = 0
        heavy_count = 0
        rotatable = 0
        with open(pdbqt_path, 'r') as f:
            for line in f:
                if line.startswith(("ATOM", "HETATM")):
                    atom_count += 1
                    element = line[77:79].strip() if len(line) > 77 else ""
                    if element and element not in ("H", "HD"):
                        heavy_count += 1
                elif line.startswith("BRANCH"):
                    rotatable += 1
        props["lig_total_atoms"] = atom_count
        props["lig_heavy_atoms"] = heavy_count if heavy_count > 0 else None
        props["lig_rotatable_bonds"] = rotatable // 2 if rotatable > 0 else None
    except Exception as e:
        print(f"  ⚠ Could not parse PDBQT ligand {pdbqt_path.name}: {e}")
    return props


def get_ligand_properties(lig_path: Path) -> Dict:
    """Get ligand properties — prefer SDF, fall back to PDBQT parsing."""
    if lig_path.suffix.lower() in (".sdf", ".mol2"):
        return get_ligand_properties_from_sdf(lig_path)
    return get_ligand_properties_from_pdbqt(lig_path)


def get_protein_properties(pdb_path: Path) -> Dict:
    """Extract basic protein properties by parsing PDB/PDBQT ATOM records."""
    props = {"prot_num_residues": None, "prot_num_atoms": None, "prot_num_chains": None}
    try:
        residues = set()
        chains = set()
        atom_count = 0
        with open(pdb_path, 'r') as f:
            for line in f:
                if line.startswith("ATOM"):
                    atom_count += 1
                    chain_id = line[21]
                    res_seq = line[22:27].strip()
                    residues.add((chain_id, res_seq))
                    chains.add(chain_id)
        props["prot_num_residues"] = len(residues)
        props["prot_num_atoms"] = atom_count
        props["prot_num_chains"] = len(chains)
    except Exception as e:
        print(f"  ⚠ Could not parse protein {pdb_path.name}: {e}")
    return props


def ligand_props_valid(props: Dict) -> bool:
    """Return True if at least one key ligand property was computed successfully."""
    return props.get("lig_heavy_atoms") is not None or props.get("lig_total_atoms") is not None


def precompute_properties(
    proteins: List[Path],
    ligands: List[Path],
) -> Tuple[Dict[Path, Dict], Dict[Path, Dict]]:
    """Pre-compute molecular properties for all proteins and ligands before docking."""
    lig_props_cache: Dict[Path, Dict] = {}
    prot_props_cache: Dict[Path, Dict] = {}

    print("Pre-computing ligand properties...")
    for lig in ligands:
        lig_props_cache[lig] = get_ligand_properties(lig)
    print(f"  {len(lig_props_cache)} ligands analysed")

    print("Pre-computing protein properties...")
    for prot in proteins:
        prot_props_cache[prot] = get_protein_properties(prot)
    print(f"  {len(prot_props_cache)} proteins analysed")

    return lig_props_cache, prot_props_cache


_GPU_MODEL = get_gpu_model()
print(f"GPU detected: {_GPU_MODEL}")


def _build_log_row(
    result: DockingResult,
    lig_props: Dict,
    prot_props: Dict,
) -> Dict:
    """Build a single row dict for the docking log CSV."""
    row = {
        "timestamp": datetime.now().isoformat(),
        "combo_name": f"{result.ligand_name}__{result.protein_name}",
        "protein_name": result.protein_name,
        "ligand_name": result.ligand_name,
        "status": result.status,
        "error_reason": result.error_message if result.status == "failed" else "",
        "num_poses": result.num_poses,
        "elapsed_time_s": round(result.elapsed_time, 2),
        "best_affinity_kcal": result.best_affinity,
        "search_depth": SEARCH_DEPTH,
        "thread": THREAD,
        "num_modes": NUM_MODES,
        "energy_range": ENERGY_RANGE,
        "gpu_model": _GPU_MODEL,
    }
    row.update(lig_props)
    row.update(prot_props)
    return row


def init_docking_log(output_dir: Path) -> Tuple[Path, set]:
    """Initialise the docking log CSV and return (log_path, existing_combo_names)."""
    log_path = output_dir / DOCKING_LOG_FILENAME
    existing_combos: set = set()

    if log_path.exists():
        try:
            df = pd.read_csv(log_path)
            existing_combos = set(df["combo_name"])
        except Exception:
            pass
    else:
        pd.DataFrame(columns=DOCKING_LOG_COLUMNS).to_csv(log_path, index=False)

    return log_path, existing_combos


def append_log_rows(
    results: List[DockingResult],
    log_path: Path,
    existing_combos: set,
    lig_props_cache: Dict[Path, Dict],
    prot_props_cache: Dict[Path, Dict],
) -> None:
    """Append log rows for a batch of results to the CSV, skipping duplicates."""
    rows = []
    for r in results:
        combo = f"{r.ligand_name}__{r.protein_name}"
        if combo in existing_combos:
            continue
        lig_props = lig_props_cache.get(r.ligand_path, get_ligand_properties(r.ligand_path))
        prot_props = prot_props_cache.get(r.protein_path, get_protein_properties(r.protein_path))
        rows.append(_build_log_row(r, lig_props, prot_props))
        existing_combos.add(combo)

    if not rows:
        return

    df = pd.DataFrame(rows, columns=DOCKING_LOG_COLUMNS)
    df.to_csv(log_path, mode='a', header=False, index=False)
    print(f"  📝 Appended {len(rows)} entries to {log_path.name} ({len(existing_combos)} total)")


print("Docking log functions defined.")
# Out:
# GPU detected: NVIDIA A100-SXM4-80GB
# Docking log functions defined.

# %% [markdown]
# # Summary & Reporting

# %%
def generate_summary(results: List[DockingResult]) -> Dict:
    """Generate summary of docking results."""
    summary = {
        "timestamp": datetime.now().isoformat(),
        "configuration": {
            "search_depth": SEARCH_DEPTH,
            "thread": THREAD,
            "num_modes": NUM_MODES,
            "energy_range": ENERGY_RANGE,
            "vina_bin": str(VINA_BIN),
        },
        "overall": {
            "total_combinations": len(results),
            "successful": sum(1 for r in results if r.status == "success"),
            "failed": sum(1 for r in results if r.status == "failed"),
            "skipped": sum(1 for r in results if r.status == "skipped"),
            "total_poses": sum(r.num_poses for r in results),
            "total_time_seconds": sum(r.elapsed_time for r in results),
        },
        "by_protein": defaultdict(lambda: {"combinations": 0, "poses": 0, "success": 0}),
        "by_ligand": defaultdict(lambda: {"combinations": 0, "poses": 0, "success": 0}),
        "combinations": [],
    }

    for r in results:
        summary["by_protein"][r.protein_name]["combinations"] += 1
        summary["by_protein"][r.protein_name]["poses"] += r.num_poses
        if r.status == "success":
            summary["by_protein"][r.protein_name]["success"] += 1

        summary["by_ligand"][r.ligand_name]["combinations"] += 1
        summary["by_ligand"][r.ligand_name]["poses"] += r.num_poses
        if r.status == "success":
            summary["by_ligand"][r.ligand_name]["success"] += 1

        summary["combinations"].append({
            "protein": r.protein_name,
            "ligand": r.ligand_name,
            "status": r.status,
            "num_poses": r.num_poses,
            "time_seconds": round(r.elapsed_time, 2),
            "best_affinity": r.best_affinity,
            "error": r.error_message if r.error_message else None,
        })

    summary["by_protein"] = dict(summary["by_protein"])
    summary["by_ligand"] = dict(summary["by_ligand"])
    return summary


def print_summary(summary: Dict):
    """Print formatted docking summary."""
    print("\n" + "=" * 80)
    print("AUTODOCK VINA-CUDA DOCKING SUMMARY")
    print("=" * 80)

    overall = summary["overall"]
    print(f"\nOverall Statistics:")
    print(f"  Total combinations: {overall['total_combinations']}")
    print(f"  Successful: {overall['successful']}")
    print(f"  Failed: {overall['failed']}")
    print(f"  Skipped: {overall['skipped']}")
    print(f"  Total poses generated: {overall['total_poses']}")
    print(f"  Total time: {overall['total_time_seconds']:.1f}s ({overall['total_time_seconds']/60:.1f} min)")

    print("\n" + "-" * 80)
    print("Results by Protein:")
    print("-" * 80)
    for protein, stats in sorted(summary["by_protein"].items()):
        print(f"  {protein:40s} | Combos: {stats['combinations']:3d} | Poses: {stats['poses']:4d}")

    print("\n" + "-" * 80)
    print("Results by Ligand:")
    print("-" * 80)
    for ligand, stats in sorted(summary["by_ligand"].items()):
        print(f"  {ligand:40s} | Combos: {stats['combinations']:3d} | Poses: {stats['poses']:4d}")

# %% [markdown]
# # Autodock Vina-CUDA Function

# %%
# ── Box splitting utilities for Vina-CUDA ──────────────────────────────────
# Vina-CUDA LARGE_BOX atom-relation array (38000) overflows for large
# proteins when box > ~70 Å.  Sub-boxes of 70 Å with 15 Å overlap keep
# the relation count safe.  Results are merged per ligand.

# Meeko assigns extended atom types (CG0, CG1, CG2, G0, G1, G2, Si, B)
# that Vina-CUDA does not recognise.  Remap them to the closest AD4 type.
_MEEKO_AD4_TYPE_MAP: Dict[str, str] = {
    "CG0": "C",  "CG1": "C",  "CG2": "C",
    "G0":  "C",  "G1":  "C",  "G2":  "C",
    "Si":  "S",  "B":   "C",
}


def sanitize_pdbqt_atom_types(
    pdbqt_path: Path,
    type_map: Dict[str, str] | None = None,
) -> int:
    """Remap non-standard atom types in a PDBQT file in-place.

    Returns the number of atoms that were remapped.
    """
    if type_map is None:
        type_map = _MEEKO_AD4_TYPE_MAP

    text = pdbqt_path.read_text()
    lines = text.splitlines(keepends=True)
    n_fixed = 0

    for i, line in enumerate(lines):
        if not (line.startswith("ATOM") or line.startswith("HETATM")):
            continue
        if len(line.rstrip()) < 78:
            continue
        atype = line[77:].strip()
        if atype in type_map:
            new_type = type_map[atype]
            padded = new_type.ljust(len(line.rstrip()) - 77)
            lines[i] = line[:77] + padded + "\n"
            n_fixed += 1

    if n_fixed:
        pdbqt_path.write_text("".join(lines))

    return n_fixed


def sanitize_ligand_pdbqts(ligand_paths: list[Path]) -> int:
    """Sanitize all ligand PDBQT files, return total atoms remapped."""
    total = 0
    for p in ligand_paths:
        total += sanitize_pdbqt_atom_types(p)
    return total


def parse_box_file(box_path: Path) -> Dict[str, float]:
    """Parse a Vina box configuration file → {center_x, center_y, …, size_z}."""
    params: Dict[str, float] = {}
    with open(box_path, 'r') as f:
        for line in f:
            line = line.strip()
            if '=' in line:
                key, value = line.split('=', 1)
                key = key.strip()
                if key in ('center_x', 'center_y', 'center_z',
                           'size_x', 'size_y', 'size_z'):
                    params[key] = float(value.strip())
    return params


def write_box_file(box_path: Path, params: Dict[str, float]) -> None:
    """Write a Vina-style box configuration file from parameters."""
    with open(box_path, 'w') as f:
        for key in ('center_x', 'center_y', 'center_z',
                     'size_x', 'size_y', 'size_z'):
            if key in params:
                f.write(f"{key} = {params[key]:.3f}\n")


def split_box(
    params: Dict[str, float],
    max_size: float = MAX_BOX_SIZE,
    overlap: float = BOX_OVERLAP,
) -> List[Dict[str, float]]:
    """Split a bounding box into sub-boxes so every dimension ≤ *max_size*.

    Adjacent sub-boxes overlap by *overlap* Å along each split axis.
    Returns a list of box-parameter dicts (length 1 when no split is needed).
    """
    axes = ('x', 'y', 'z')
    step = max_size - overlap  # non-overlapping advance per sub-box

    axis_splits: List[List[Tuple[float, float]]] = []
    for ax in axes:
        total_size = params[f'size_{ax}']
        center = params[f'center_{ax}']

        if total_size <= max_size:
            axis_splits.append([(center, total_size)])
        else:
            box_min = center - total_size / 2
            box_max = center + total_size / 2
            splits: List[Tuple[float, float]] = []
            current_min = box_min
            while current_min + max_size < box_max:
                sub_center = current_min + max_size / 2
                splits.append((sub_center, max_size))
                current_min += step
            # Last sub-box: aligned to the right edge
            last_min = box_max - max_size
            last_center = last_min + max_size / 2
            # Avoid duplicating if it matches the previous split
            if not splits or abs(last_center - splits[-1][0]) > 0.01:
                splits.append((last_center, max_size))
            axis_splits.append(splits)

    # Cartesian product across all three axes
    sub_boxes: List[Dict[str, float]] = []
    for combo in itertools.product(*axis_splits):
        sub: Dict[str, float] = {}
        for i, ax in enumerate(axes):
            sub[f'center_{ax}'] = combo[i][0]
            sub[f'size_{ax}'] = combo[i][1]
        sub_boxes.append(sub)

    return sub_boxes


def parse_vina_pdbqt_models(pdbqt_path: Path) -> List[Tuple[float, str]]:
    """Parse a Vina output PDBQT → list of (affinity, model_block_text)."""
    models: List[Tuple[float, str]] = []
    if not pdbqt_path.exists():
        return models
    text = pdbqt_path.read_text()
    current_lines: List[str] = []
    current_aff: Optional[float] = None

    for line in text.splitlines(keepends=True):
        if line.startswith('MODEL'):
            current_lines = [line]
            current_aff = None
        elif line.startswith('ENDMDL'):
            current_lines.append(line)
            if current_aff is not None:
                models.append((current_aff, ''.join(current_lines)))
            current_lines = []
        else:
            current_lines.append(line)
            if line.startswith('REMARK VINA RESULT:'):
                parts = line.split()
                try:
                    current_aff = float(parts[3])
                except (IndexError, ValueError):
                    pass
    return models


def merge_vina_outputs(
    sub_box_outputs: List[Path],
    final_output: Path,
    max_modes: int = 10,
) -> Tuple[List[dict], Optional[float]]:
    """Merge MODEL blocks from multiple sub-box PDBQT outputs.

    Keeps the *max_modes* poses with the best (most negative) affinity,
    renumbers them 1..N, and writes them to *final_output*.

    Returns (modes_list, best_affinity) compatible with parse_vina_affinities.
    """
    all_models: List[Tuple[float, str]] = []
    for out_path in sub_box_outputs:
        all_models.extend(parse_vina_pdbqt_models(out_path))

    if not all_models:
        return [], None

    # Best (most negative) first
    all_models.sort(key=lambda x: x[0])
    top = all_models[:max_modes]

    with open(final_output, 'w') as f:
        for idx, (aff, block) in enumerate(top, 1):
            lines = block.splitlines(keepends=True)
            # Renumber MODEL line
            lines[0] = f"MODEL {idx}\n"
            f.writelines(lines)

    modes = [
        {'mode': i, 'affinity': aff, 'rmsd_lb': 0.0, 'rmsd_ub': 0.0}
        for i, (aff, _) in enumerate(top, 1)
    ]
    return modes, top[0][0]


print(f"Box-splitting helpers loaded  (max_size={MAX_BOX_SIZE}Å, overlap={BOX_OVERLAP}Å)")
# Out:
# Box-splitting helpers loaded  (max_size=99.0Å, overlap=15.0Å)

# %%
def _normalize_key(path: Path) -> str:
    """Extract a clean stem from a .pdbqt or .box.txt filename."""
    name = path.name
    if name.endswith('.box.txt'):
        return name[:-len('.box.txt')]
    if name.endswith('.pdbqt'):
        return name[:-len('.pdbqt')]
    return path.stem


def _collect_receptors(
    base_dir: Path,
    prepared_manifest: dict,
    workflow_data: dict | None,
) -> list[dict]:
    """Gather receptor PDBQT + box.txt pairs from manifest, workflow, or directory scan."""
    groups: defaultdict[str, dict] = defaultdict(dict)

    for entry in prepared_manifest.get('proteins', []):
        entry_path = Path(entry.get('path', '')).resolve()
        if not entry_path.exists():
            continue
        key = _normalize_key(entry_path)
        if entry_path.suffix.lower() == '.pdbqt':
            groups[key]['pdbqt'] = entry_path
        elif entry_path.name.lower().endswith('.box.txt'):
            groups[key]['box'] = entry_path

    if workflow_data:
        meeko_outputs = workflow_data.get('meeko_outputs') or {}
        meeko_box_files = workflow_data.get('meeko_box_files') or {}
        for original, pdbqt in meeko_outputs.items():
            box = meeko_box_files.get(original)
            if not pdbqt or not box:
                continue
            pdbqt_path = Path(pdbqt).resolve()
            box_path = Path(box).resolve()
            if not (pdbqt_path.exists() and box_path.exists()):
                continue
            key = _normalize_key(pdbqt_path)
            groups[key].setdefault('pdbqt', pdbqt_path)
            groups[key].setdefault('box', box_path)

    receptors = []
    for key, data in groups.items():
        pdbqt = data.get('pdbqt')
        box = data.get('box')
        if pdbqt and box:
            receptors.append({'name': key, 'pdbqt': pdbqt, 'box': box})

    if not receptors:
        for pdbqt_path in sorted(base_dir.glob('*.pdbqt')):
            box_path = pdbqt_path.with_suffix('.box.txt')
            if box_path.exists():
                receptors.append({
                    'name': _normalize_key(pdbqt_path),
                    'pdbqt': pdbqt_path.resolve(),
                    'box': box_path.resolve(),
                })

    receptors.sort(key=lambda r: r['name'])
    return receptors


def _collect_ligands(
    base_dir: Path,
    prepared_manifest: dict,
    workflow_data: dict | None,
) -> list[dict]:
    """Gather ligand PDBQT files from manifest, workflow, or directory scan."""
    ligands: dict[str, Path] = {}

    for entry in prepared_manifest.get('ligands', []):
        entry_path = Path(entry.get('path', '')).resolve()
        if entry_path.exists() and entry_path.suffix.lower() == '.pdbqt':
            ligands.setdefault(_normalize_key(entry_path), entry_path)

    if workflow_data:
        meeko_ligs = workflow_data.get('meeko_ligand_outputs') or {}
        for original, pdbqt in meeko_ligs.items():
            if not pdbqt:
                continue
            pdbqt_path = Path(pdbqt).resolve()
            if pdbqt_path.exists():
                ligands.setdefault(_normalize_key(pdbqt_path), pdbqt_path)

    ligand_dir = base_dir / 'ligands'
    if not ligands and ligand_dir.exists():
        for pdbqt_path in sorted(ligand_dir.glob('*.pdbqt')):
            ligands.setdefault(_normalize_key(pdbqt_path), pdbqt_path.resolve())

    if not ligands:
        for pdbqt_path in sorted(base_dir.glob('*.pdbqt')):
            if pdbqt_path.with_suffix('.box.txt').exists():
                continue
            ligands.setdefault(_normalize_key(pdbqt_path), pdbqt_path.resolve())

    return [{'name': n, 'pdbqt': p} for n, p in sorted(ligands.items())]


def run_autodock_vina_gpu(
    base_dir: Path | str,
    log_dir: Path | str,
    prepared_manifest: dict,
    protein_workflow_data: dict | None = None,
    ligand_workflow_data: dict | None = None,
    *,
    vina_bin: Path | str = VINA_BIN,
    dock_subdir: str = 'docking',
    thread: int = 8000,
    search_depth: int = 32,
    num_modes: int | None = 10,
    energy_range: int | None = 3,
    seed: int | None = None,
    overwrite: bool = False,
    timeout: int = 0,
    output_base_dir: Path | None = None,
    lig_props_cache: Dict[Path, Dict] | None = None,
    prot_props_cache: Dict[Path, Dict] | None = None,
    progress_state: dict | None = None,
    verbose_log: bool = False,
) -> Tuple[pd.DataFrame, List[DockingResult]]:
    """Run AutoDock Vina-CUDA for all receptor-ligand combinations.

    Uses --ligand_directory batch mode per receptor + sub-box so the
    receptor grid is computed only once per sub-box instead of once per
    ligand.  Sub-box results are merged per ligand.
    """
    base_dir = Path(base_dir).resolve()
    log_dir = Path(log_dir).resolve()
    vina_bin = Path(vina_bin).expanduser().resolve()
    dock_dir = base_dir / dock_subdir

    dock_dir.mkdir(parents=True, exist_ok=True)
    log_dir.mkdir(parents=True, exist_ok=True)

    pd.set_option('display.max_colwidth', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 0)

    # ── Collect inputs ──────────────────────────────────────────────────
    receptors = _collect_receptors(base_dir, prepared_manifest, protein_workflow_data)
    ligands = _collect_ligands(base_dir, prepared_manifest, ligand_workflow_data)
    print(f'Docking receptors: {len(receptors)} | ligands: {len(ligands)}')

    # ── Sanitize non-standard Meeko atom types (CG0, Si, …) ─────────
    lig_paths = [lig['pdbqt'] for lig in ligands]
    n_sanitized = sanitize_ligand_pdbqts(lig_paths)
    if n_sanitized:
        print(f"  🔧 Sanitized {n_sanitized} non-standard atom types across ligand PDBQTs")

    vina_ok = vina_bin.is_file() and os.access(vina_bin, os.X_OK)
    if not vina_ok:
        print(f"WARNING: Vina-GPU executable not found or not executable ('{vina_bin}').")
    if not receptors:
        print('WARNING: No receptor PDBQT + box.txt pairs found; aborting docking step.')
    if not ligands:
        print('WARNING: No ligand PDBQT files found; aborting docking step.')

    raw_results: list[dict] = []
    docking_results: List[DockingResult] = []
    if not vina_ok or not receptors or not ligands:
        return pd.DataFrame(raw_results), docking_results

    # ── Error log ───────────────────────────────────────────────────────
    effective_output_dir = output_base_dir or dock_dir
    error_log = load_error_log(effective_output_dir)
    if OVERWRITE_ERROR_LOG:
        error_log = {}
        save_error_log(effective_output_dir, error_log)

    # ── Docking log ─────────────────────────────────────────────────────
    csv_log_path, existing_combos = init_docking_log(effective_output_dir)
    print(f"Docking log: {csv_log_path} ({len(existing_combos)} existing entries)")

    # ── Helpers ─────────────────────────────────────────────────────────
    def _run_batch(cmd, log_path, batch_timeout=0):
        effective_timeout = batch_timeout if batch_timeout > 0 else None
        try:
            with open(log_path, 'w') as log_f:
                if verbose_log:
                    # Stream Vina output to both log file and terminal
                    proc = subprocess.Popen(
                        cmd, stdout=subprocess.PIPE, stderr=subprocess.STDOUT,
                    )
                    try:
                        for raw_line in proc.stdout:
                            line = raw_line.decode('utf-8', errors='replace')
                            log_f.write(line)
                            print(f"    [vina] {line}", end='')
                        retcode = proc.wait(timeout=effective_timeout)
                    except subprocess.TimeoutExpired:
                        proc.kill()
                        proc.wait()
                        return False, f"Timeout ({batch_timeout}s)"
                else:
                    proc = subprocess.Popen(
                        cmd, stdout=log_f, stderr=subprocess.STDOUT,
                    )
                    try:
                        retcode = proc.wait(timeout=effective_timeout)
                    except subprocess.TimeoutExpired:
                        proc.kill()
                        proc.wait()
                        return False, f"Timeout ({batch_timeout}s)"
            output = log_path.read_text()
            if retcode != 0:
                return False, output.strip()
            return True, output
        except Exception as exc:
            return False, str(exc)

    def _parse_vina_timing(log_path: Path) -> dict:
        """Parse Vina-CUDA log for reading_time and total_runtime (seconds)."""
        timing = {'reading_time_s': None, 'total_runtime_s': None}
        try:
            text = log_path.read_text()
            m = re.search(r'reading time:\s*([\d.]+)', text)
            if m:
                timing['reading_time_s'] = float(m.group(1))
            m = re.search(r'total runtime\s*=\s*([\d.]+)', text)
            if m:
                timing['total_runtime_s'] = float(m.group(1))
        except Exception:
            pass
        return timing

    def _build_batch_cmd(receptor_pdbqt, ligand_dir, box_file, output_dir):
        cmd = [
            str(vina_bin),
            '--receptor', str(receptor_pdbqt),
            '--ligand_directory', str(ligand_dir),
            '--output_directory', str(output_dir),
            '--config', str(box_file),
            '--thread', str(thread),
            '--search_depth', str(search_depth),
            '--rilc_bfgs', '0',
        ]
        if num_modes is not None:
            cmd += ['--num_modes', str(num_modes)]
        if energy_range is not None:
            cmd += ['--energy_range', str(energy_range)]
        if seed is not None:
            cmd += ['--seed', str(seed)]
        return cmd

    total_jobs = len(receptors) * len(ligands)
    print(f"Total docking jobs: {total_jobs}")
    start_all = time.time()
    job_counter = 0

    # ── Process each receptor ───────────────────────────────────────────
    for rec in receptors:
        rec_path = rec['pdbqt']
        box_path = rec['box']
        rec_name = rec['name']

        # ── Determine which ligands need docking for this receptor ──
        ligands_to_dock: List[dict] = []
        for lig in ligands:
            lig_name = lig['name']
            combo_name = f"{lig_name}__{rec_name}"
            stem = f"{rec_path.stem}__{lig['pdbqt'].stem}_vina_out"
            out_path = dock_dir / f"{stem}.pdbqt"
            vina_log_path = log_dir / f"{stem}.log"

            # Skip previously failed
            if not OVERWRITE_ERROR_LOG and combo_name in error_log:
                job_counter += 1
                r = DockingResult(
                    protein_name=rec_name, ligand_name=lig_name,
                    protein_path=rec_path, ligand_path=lig['pdbqt'],
                    output_dir=dock_dir, status="skipped",
                    error_message=f"Previously failed: {error_log[combo_name].get('error', 'unknown')[:100]}",
                )
                docking_results.append(r)
                raw_results.append({
                    'receptor': str(rec_path), 'ligand': str(lig['pdbqt']),
                    'output': str(out_path), 'log': str(vina_log_path),
                    'status': 'skip-failed',
                })
                continue

            # Skip existing
            if out_path.exists() and not overwrite:
                job_counter += 1
                n_poses = 0
                best_aff = None
                models = parse_vina_pdbqt_models(out_path)
                if models:
                    n_poses = len(models)
                    best_aff = models[0][0]
                r = DockingResult(
                    protein_name=rec_name, ligand_name=lig_name,
                    protein_path=rec_path, ligand_path=lig['pdbqt'],
                    output_dir=dock_dir, status="skipped",
                    num_poses=n_poses, best_affinity=best_aff,
                    pose_files=[out_path],
                )
                docking_results.append(r)
                raw_results.append({
                    'receptor': str(rec_path), 'ligand': str(lig['pdbqt']),
                    'output': str(out_path), 'log': str(vina_log_path),
                    'status': 'skip-exists',
                })
                continue

            ligands_to_dock.append(lig)

        if not ligands_to_dock:
            print(f"  ⏩ {rec_name}: all {len(ligands)} ligands skipped")
            continue

        # ── Parse box & split ───────────────────────────────────────────
        box_params = parse_box_file(box_path)
        sub_boxes = split_box(box_params, MAX_BOX_SIZE, BOX_OVERLAP)

        # ── Report original box dimensions ────────────────────────────
        sx = box_params.get('size_x', 0)
        sy = box_params.get('size_y', 0)
        sz = box_params.get('size_z', 0)
        cx = box_params.get('center_x', 0)
        cy = box_params.get('center_y', 0)
        cz = box_params.get('center_z', 0)
        vol = sx * sy * sz
        print(f"  📦 {rec_name}: original box  "
              f"size=({sx:.1f}, {sy:.1f}, {sz:.1f}) Å  "
              f"center=({cx:.1f}, {cy:.1f}, {cz:.1f})  "
              f"vol={vol:,.0f} ų")

        if len(sub_boxes) > 1:
            oversized = [
                f"{ax}={box_params[f'size_{ax}']:.1f}"
                for ax in 'xyz'
                if box_params[f'size_{ax}'] > MAX_BOX_SIZE
            ]
            print(f"  ⚡ {rec_name}: split on ({', '.join(oversized)}) → "
                  f"{len(sub_boxes)} sub-boxes (max={MAX_BOX_SIZE}Å, overlap={BOX_OVERLAP}Å)")
            for si_rpt, sb_rpt in enumerate(sub_boxes):
                sb_sx = sb_rpt.get('size_x', 0)
                sb_sy = sb_rpt.get('size_y', 0)
                sb_sz = sb_rpt.get('size_z', 0)
                sb_cx = sb_rpt.get('center_x', 0)
                sb_cy = sb_rpt.get('center_y', 0)
                sb_cz = sb_rpt.get('center_z', 0)
                print(f"      sub-box {si_rpt}: "
                      f"size=({sb_sx:.1f}, {sb_sy:.1f}, {sb_sz:.1f}) Å  "
                      f"center=({sb_cx:.1f}, {sb_cy:.1f}, {sb_cz:.1f})")
        else:
            print(f"  ✓ {rec_name}: box fits within {MAX_BOX_SIZE}Å limit — no split needed")

        # ── Create staging directory with symlinks to ligands ───────────
        batch_lig_dir = dock_dir / f"_batch_{rec_name}"
        batch_lig_dir.mkdir(exist_ok=True)
        # Symlink all ligands-to-dock into the staging directory
        for old_link in batch_lig_dir.iterdir():
            if old_link.is_symlink():
                old_link.unlink()
        for lig in ligands_to_dock:
            link = batch_lig_dir / lig['pdbqt'].name
            if not link.exists():
                link.symlink_to(lig['pdbqt'])
        sub_out_dirs: List[Path] = []
        sub_log_paths: List[Path] = []
        t0 = time.time()
        n_skipped_subs = 0

        # Pre-compute the set of expected output filenames for current batch
        batch_expected_outs = {f"{lig['pdbqt'].stem}_out.pdbqt" for lig in ligands_to_dock}
        # Map: expected output name → ligand dict (for building filtered staging dirs)
        lig_by_out_name = {f"{lig['pdbqt'].stem}_out.pdbqt": lig for lig in ligands_to_dock}

        for si, sb in enumerate(sub_boxes):
            sub_box_file = dock_dir / f"_batch_{rec_name}_sub{si}.box.txt"
            sub_out_dir = dock_dir / f"_batch_{rec_name}_sub{si}_out"
            sub_log = log_dir / f"_batch_{rec_name}_sub{si}.log"
            sub_out_dir.mkdir(exist_ok=True)

            # Resume: check if this sub-box already ran to completion.
            # Primary check: log contains Vina-CUDA's "total runtime" marker.
            # Fallback: output dir has at least 1 result file.
            sub_complete = False
            if sub_log.exists() and not overwrite:
                try:
                    log_tail = sub_log.read_text()[-500:]
                    if "total runtime" in log_tail:
                        sub_complete = True
                except Exception:
                    pass
            if not sub_complete and not overwrite:
                # Fallback: if output dir has results, treat as complete
                existing_out_count = sum(
                    1 for p in sub_out_dir.glob("*_out.pdbqt")
                    if p.stat().st_size > 0
                )
                if existing_out_count > 0:
                    sub_complete = True

            # Check which current-batch ligands already have output in this sub-box
            existing_out_names = set()
            if sub_complete and not overwrite:
                existing_out_names = {
                    p.name for p in sub_out_dir.glob("*_out.pdbqt")
                    if p.stat().st_size > 0
                }
                missing_outs = batch_expected_outs - existing_out_names
                if not missing_outs:
                    # All current-batch ligands done → fully skip this sub-box
                    sub_out_dirs.append(sub_out_dir)
                    sub_log_paths.append(sub_log)
                    n_skipped_subs += 1
                    continue
                # Partial: some ligands are missing → need to run only those
                sub_complete = False

            if sub_complete:
                sub_out_dirs.append(sub_out_dir)
                sub_log_paths.append(sub_log)
                n_skipped_subs += 1
                continue

            # Determine which ligands to run in this sub-box
            missing_outs = batch_expected_outs - existing_out_names
            n_already = len(batch_expected_outs) - len(missing_outs)

            # If some ligands are already done, create a filtered staging dir
            # with only the missing ones so Vina doesn't re-process them.
            if n_already > 0 and missing_outs:
                run_lig_dir = dock_dir / f"_batch_{rec_name}_sub{si}_pending"
                run_lig_dir.mkdir(exist_ok=True)
                for old_link in run_lig_dir.iterdir():
                    if old_link.is_symlink():
                        old_link.unlink()
                for out_name in missing_outs:
                    lig = lig_by_out_name.get(out_name)
                    if lig:
                        link = run_lig_dir / lig['pdbqt'].name
                        if not link.exists():
                            link.symlink_to(lig['pdbqt'])
                n_to_run = len(missing_outs)
                print(f"    🔄 Sub-box {si}: {n_already} already done, "
                      f"docking {n_to_run} remaining ligands")
            else:
                run_lig_dir = batch_lig_dir
                n_to_run = len(ligands_to_dock)

            if len(sub_boxes) == 1:
                write_box_file(sub_box_file, box_params)
            else:
                write_box_file(sub_box_file, sb)
            # Update progress state for monitor thread
            if progress_state is not None:
                progress_state.update({
                    "receptor": rec_name,
                    "sub_box": si,
                    "n_sub_boxes": len(sub_boxes),
                    "n_ligands": n_to_run,
                    "sub_out_dir": str(sub_out_dir),
                    "sub_log": str(sub_log),
                    "skipped_subs": n_skipped_subs,
                    "batch_expected_outs": missing_outs,
                })

            cmd = _build_batch_cmd(rec_path, run_lig_dir, sub_box_file, sub_out_dir)
            # Timeout: scale with number of ligands
            batch_timeout = timeout * max(n_to_run, 1) if timeout > 0 else 0
            ok, _output = _run_batch(cmd, sub_log, batch_timeout)
            sub_out_dirs.append(sub_out_dir)
            sub_log_paths.append(sub_log)
            if not ok:
                print(f"    ⚠ Sub-box {si} returned non-zero (some ligands may still have output)")
                if not verbose_log:
                    # Print the log tail so the error is visible even without verbose mode
                    log_tail = _output[-1500:] if len(_output) > 1500 else _output
                    print(f"    ── Vina log ({sub_log.name}) ──")
                    for ln in log_tail.splitlines():
                        print(f"    | {ln}")
                    print(f"    ── end log ──")
        if n_skipped_subs:
            print(f"    ♻ Resumed: {n_skipped_subs}/{len(sub_boxes)} sub-boxes already complete")

        batch_elapsed = time.time() - t0

        # ── Parse Vina-reported timing from sub-box logs ─────────────────
        vina_total_runtime = 0.0
        vina_total_reading = 0.0
        vina_timing_available = False
        for sl in sub_log_paths:
            st = _parse_vina_timing(sl)
            if st['total_runtime_s'] is not None:
                vina_total_runtime += st['total_runtime_s']
                vina_timing_available = True
            if st['reading_time_s'] is not None:
                vina_total_reading += st['reading_time_s']

        # Per-ligand average: prefer Vina-reported total_runtime, fall back to wall clock
        timing_source = vina_total_runtime if vina_timing_available else batch_elapsed
        per_ligand_time = timing_source / max(len(ligands_to_dock), 1)

        print(f"  ⏱ {rec_name}: batch completed in {batch_elapsed:.1f}s "
              f"({batch_elapsed / 60:.1f} min)")
        if vina_timing_available:
            vina_compute = vina_total_runtime - vina_total_reading
            print(f"    Vina timing: total={vina_total_runtime:.1f}s  "
                  f"reading={vina_total_reading:.1f}s  "
                  f"compute={vina_compute:.1f}s")
            print(f"    Per-ligand avg: {per_ligand_time:.2f}s  "
                  f"({per_ligand_time / 60:.2f} min)  "
                  f"[{len(ligands_to_dock)} ligands × {len(sub_boxes)} sub-box(es)]")

        # ── Collect results per ligand ──────────────────────────────────
        batch_results: List[DockingResult] = []
        for lig in ligands_to_dock:
            job_counter += 1
            lig_name = lig['name']
            combo_name = f"{lig_name}__{rec_name}"
            stem = f"{rec_path.stem}__{lig['pdbqt'].stem}_vina_out"
            final_out = dock_dir / f"{stem}.pdbqt"
            vina_log_path = log_dir / f"{stem}.log"

            # Find output files from each sub-box
            sub_outputs: List[Path] = []
            for sub_out_dir in sub_out_dirs:
                # Vina-CUDA names output: {ligand_stem}_out.pdbqt
                lig_out = sub_out_dir / f"{lig['pdbqt'].stem}_out.pdbqt"
                if lig_out.exists() and lig_out.stat().st_size > 0:
                    sub_outputs.append(lig_out)

            if sub_outputs:
                if len(sub_outputs) == 1 and len(sub_boxes) == 1:
                    # No merging needed — just copy
                    shutil.copy2(sub_outputs[0], final_out)
                    models = parse_vina_pdbqt_models(final_out)
                    n_poses = len(models)
                    best_aff = models[0][0] if models else None
                else:
                    modes, best_aff = merge_vina_outputs(
                        sub_outputs, final_out, num_modes or 10,
                    )
                    n_poses = len(modes)
                status_str = 'ok'
            else:
                n_poses = 0
                best_aff = None
                status_str = 'fail'

            r = DockingResult(
                protein_name=rec_name, ligand_name=lig_name,
                protein_path=rec_path, ligand_path=lig['pdbqt'],
                output_dir=dock_dir,
                status="success" if status_str == 'ok' else "failed",
                num_poses=n_poses,
                best_affinity=best_aff,
                pose_files=[final_out] if status_str == 'ok' else [],
                error_message="" if status_str == 'ok' else "No output from any sub-box",
                elapsed_time=per_ligand_time,
            )
            batch_results.append(r)
            if r.status == "failed":
                record_failure(effective_output_dir, combo_name, r)
                error_log[combo_name] = {
                    "error": r.error_message,
                    "timestamp": datetime.now().isoformat(),
                    "protein": r.protein_name,
                    "ligand": r.ligand_name,
                }

            docking_results.append(r)

            raw_results.append({
                'receptor': str(rec_path), 'ligand': str(lig['pdbqt']),
                'output': str(final_out), 'log': str(vina_log_path),
                'status': status_str,
            })

        # Append batch results to docking log
        append_log_rows(
            batch_results, csv_log_path, existing_combos,
            lig_props_cache or {}, prot_props_cache or {},
        )

        n_ok = sum(1 for r in batch_results if r.status == "success")
        n_fail = sum(1 for r in batch_results if r.status == "failed")
        best_in_batch = min(
            (r.best_affinity for r in batch_results if r.best_affinity is not None),
            default=None,
        )
        best_str = f"{best_in_batch:.2f}" if best_in_batch is not None else "N/A"
        print(f"  📊 {rec_name}: {n_ok} ok / {n_fail} fail | "
              f"best affinity: {best_str} kcal/mol")

    total_time = time.time() - start_all
    n_success = sum(1 for r in docking_results if r.status == "success")
    n_failed = sum(1 for r in docking_results if r.status == "failed")
    n_skipped = sum(1 for r in docking_results if r.status == "skipped")

    print(f"\nDocking complete in {total_time:.1f}s ({total_time/60:.1f} min)")
    print(f"  Success: {n_success}  |  Failed: {n_failed}  |  Skipped: {n_skipped}")

    save_error_log(effective_output_dir, error_log)

    results_df = pd.DataFrame(raw_results)

    display(results_df)

    try:
        print(results_df['status'].value_counts().to_dict())
    except Exception:
        pass


    return results_df, docking_results

# %% [markdown]
# # MGL-TOOLS

# %% [markdown]
# ## Prepare Ligands

# %%
# # Prepare ligands from first drugs_dir (adjust if needed for each dir)
# ligands_folder = drugs_dirs[0]  # Use first ligand directory for preparation
# 
# ligand_outputs = run_workflow(
#     input_dir=ligands_folder,
#     contains="ligands",
#     output_dir=output_folder_mgltools,
#     skip_pdb_validation=True, 
#     process_postfixes=False,
#     repair_terminals=False,
#     converter="mgltools",
#     convert_ligands=True,  # Enable ligand SDF → PDBQT conversion
#     log_file=Path("logs/ligand_conversion_overview_mgltools.txt"),
# )

# %% [markdown]
# ## Prepare Proteins

# %%
# protein_outputs = run_workflow(
#     input_dir=orai_folder,
#     contains="proteins",
#     output_dir=output_folder_mgltools,
#     skip_pdb_validation=True, 
#     process_postfixes=False,
#     repair_terminals=False,
#     converter="mgltools",
#     convert_proteins=True,  # Enable protein conversion
#     log_file=Path("logs/protein_conversion_overview_mgltools.txt"),
# )

# %% [markdown]
# # MEEKO

# %% [markdown]
# ## Prepare Ligands

# %%
# Prepare ligands from ALL drugs_dirs into output_folder_meeko
# Each dir's ligands go into a per-dir subfolder to avoid collisions,
# then we merge all outputs into a single ligand_outputs dict.

all_lig_pdbqts: List[Path] = []

for drugs_dir in drugs_dirs:
    if not drugs_dir.exists():
        print(f"⚠ Skipping missing directory: {drugs_dir}")
        continue

    dir_tag = drugs_dir.name
    dir_meeko = output_folder_meeko / dir_tag
    dir_meeko.mkdir(parents=True, exist_ok=True)

    # Check if this dir's ligands are already prepared
    _existing = sorted(dir_meeko.glob("*_ligand*.pdbqt"))
    if (dir_meeko / "ligands").exists():
        _existing += sorted((dir_meeko / "ligands").glob("*.pdbqt"))
    if not _existing:
        _existing = sorted(
            p for p in dir_meeko.glob("*.pdbqt")
            if not p.with_suffix(".box.txt").exists()
        )

    if _existing:
        print(f"✓ {dir_tag}: {len(_existing)} existing ligand PDBQTs — skipping prep")
        all_lig_pdbqts.extend(_existing)
    else:
        print(f"⏳ {dir_tag}: preparing ligands via Meeko...")
        dir_lig_out = run_workflow(
            input_dir=drugs_dir,
            contains="ligands",
            output_dir=dir_meeko,
            process_postfixes=False,
            convert_ligands_with_meeko=True,
            log_file=Path(f"logs/ligand_conversion_{dir_tag}.txt"),
        )
        # Collect the PDBQT paths produced
        for pdbqt in (dir_lig_out.get("meeko_ligand_outputs") or {}).values():
            if pdbqt and Path(pdbqt).exists():
                all_lig_pdbqts.append(Path(pdbqt))

# Also pick up any ligands that were previously prepared into the root
# output_folder_meeko (from earlier runs before the per-dir split)
_root_ligs = sorted(
    p for p in output_folder_meeko.glob("*.pdbqt")
    if not p.with_suffix(".box.txt").exists()
    and p.parent == output_folder_meeko  # only root, not subdirs
)
if _root_ligs:
    print(f"✓ root: {len(_root_ligs)} ligand PDBQTs from earlier runs")
    all_lig_pdbqts.extend(_root_ligs)

# De-duplicate (same stem → keep first occurrence)
seen_stems: set = set()
unique_pdbqts: List[Path] = []
for p in all_lig_pdbqts:
    if p.stem not in seen_stems:
        seen_stems.add(p.stem)
        unique_pdbqts.append(p)
all_lig_pdbqts = unique_pdbqts

# Build merged ligand_outputs dict for manifest / docking
ligand_outputs = {
    "meeko_ligand_outputs": {str(p): str(p) for p in all_lig_pdbqts},
    "converted_ligands": {},
    "ligand_files": set(),
    "protein_files": set(),
    "protein_results": {},
    "fixed_proteins": [],
    "log_entries": [],
}

print(f"\n{'=' * 60}")
print(f"Total unique ligand PDBQTs across {len(drugs_dirs)} dirs: {len(all_lig_pdbqts)}")
print(f"{'=' * 60}")
# Out:
# ✓ ligands_sdf_large_approved: 592 existing ligand PDBQTs — skipping prep
#
# ============================================================
# Total unique ligand PDBQTs across 1 dirs: 592
# ============================================================

# %% [markdown]
# ## Prepare Proteins

# %%
# Check if proteins have already been prepared (PDBQT + box.txt pairs exist)
existing_prot_pdbqts = sorted(
    p for p in output_folder_meeko.glob("*.pdbqt")
    if p.with_suffix(".box.txt").exists() or Path(str(p).replace(".pdbqt", ".box.txt")).exists()
)

if existing_prot_pdbqts:
    print(f"✓ Found {len(existing_prot_pdbqts)} existing protein PDBQT+box pairs in {output_folder_meeko} — skipping preparation.")
    # Reconstruct protein_outputs dict matching run_workflow structure
    protein_outputs = {
        "meeko_outputs": {str(p): str(p) for p in existing_prot_pdbqts},
        "meeko_box_files": {str(p): str(p.with_suffix(".box.txt")) for p in existing_prot_pdbqts},
        "converter_protein_outputs": {str(p): str(p) for p in existing_prot_pdbqts},
        "converter_box_files": {str(p): str(p.with_suffix(".box.txt")) for p in existing_prot_pdbqts},
        "protein_results": {},
        "fixed_proteins": [str(p) for p in existing_prot_pdbqts],
        "converted_ligands": {},
        "ligand_files": set(),
        "protein_files": set(),
        "log_entries": [],
    }
    for p in existing_prot_pdbqts:
        box = p.with_suffix(".box.txt")
        print(f"  • {p.name}  +  {box.name}")
else:
    print("No existing protein PDBQTs found — running preparation...")
    protein_outputs = run_workflow(
        input_dir=orai_folder,
        contains="proteins",
        output_dir=output_folder_meeko,
        skip_pdb_validation=False,
        process_postfixes=False,
        repair_terminals=False,
        converter="openbabel",
        convert_proteins=True,
        log_file=Path("logs/protein_conversion_overview_obabel.txt"),
    )
# Out:
# ✓ Found 4 existing protein PDBQT+box pairs in docking_ready_meeko — skipping preparation.
#   • Orai1WT-MDSnap-Fr300_cleaned.pdbqt  +  Orai1WT-MDSnap-Fr300_cleaned.box.txt
#   • Orai1WT-MDSnap-Fr400_cleaned.pdbqt  +  Orai1WT-MDSnap-Fr400_cleaned.box.txt
#   • Orai1WT-MDSnap-Fr499_cleaned.pdbqt  +  Orai1WT-MDSnap-Fr499_cleaned.box.txt
#   • Orai1WT-START-Fr0_cleaned.pdbqt  +  Orai1WT-START-Fr0_cleaned.box.txt

# %%
# Show box dimensions for each prepared protein
box_files = sorted(output_folder_meeko.glob("*.box.txt"))

if not box_files:
    print("No .box.txt files found in", output_folder_meeko)
else:
    rows = []
    for bf in box_files:
        params = parse_box_file(bf)
        sx, sy, sz = params.get("size_x", 0), params.get("size_y", 0), params.get("size_z", 0)
        cx, cy, cz = params.get("center_x", 0), params.get("center_y", 0), params.get("center_z", 0)
        vol = sx * sy * sz
        needs_split = any(s > MAX_BOX_SIZE for s in (sx, sy, sz))
        n_subs = len(split_box(params, MAX_BOX_SIZE, BOX_OVERLAP)) if needs_split else 1
        rows.append({
            "Protein": bf.stem.replace(".box", ""),
            "Size X (Å)": round(sx, 1),
            "Size Y (Å)": round(sy, 1),
            "Size Z (Å)": round(sz, 1),
            "Center X": round(cx, 1),
            "Center Y": round(cy, 1),
            "Center Z": round(cz, 1),
            "Volume (ų)": round(vol, 0),
            "Needs Split": "Yes" if needs_split else "No",
            "Sub-boxes": n_subs,
        })

    df_boxes = pd.DataFrame(rows)
    print(f"Protein box dimensions (MAX_BOX_SIZE={MAX_BOX_SIZE}Å):\n")
    display(df_boxes)
# Out:
# Protein box dimensions (MAX_BOX_SIZE=99.0Å):
#                         Protein  Size X (Å)  Size Y (Å)  Size Z (Å)  Center X  \
# 0  Orai1WT-MDSnap-Fr300_cleaned        97.3        97.9       103.7       0.2
# 1  Orai1WT-MDSnap-Fr400_cleaned        98.6        97.6       103.7      -0.4
# 2  Orai1WT-MDSnap-Fr499_cleaned        98.6        98.1       103.2      -0.9
# 3     Orai1WT-START-Fr0_cleaned       100.2        94.2        94.0       3.9
#
#    Center Y  Center Z  Volume (ų) Needs Split  Sub-boxes
# 0       9.7      -5.8    987812.0         Yes          2
# 1       9.9      -6.5    997942.0         Yes          2
# 2       9.3      -7.5    998219.0         Yes          2
# 3       6.6       1.3    887251.0         Yes          2

# %%
from pathlib import Path
from pprint import pprint

def build_prepared_manifest(output_dir: Path, protein_data: dict | None, ligand_data: dict | None):
    output_dir = Path(output_dir).resolve()
    manifest = {"proteins": [], "ligands": []}

    def record(section: str, source: str, file_path: str | None):
        if not file_path:
            return
        path_obj = Path(file_path).resolve()
        try:
            path_obj.relative_to(output_dir)
        except ValueError:
            return
        manifest[section].append({
            "name": path_obj.name,
            "path": str(path_obj),
            "filetype": path_obj.suffix.lstrip(".").lower() or "unknown",
            "source": source,
        })

    if protein_data:
        for original, prepared in (protein_data.get("protein_results") or {}).items():
            record("proteins", original, prepared)
        for original, pdbqt in (protein_data.get("meeko_outputs") or {}).items():
            record("proteins", f"{original} [pdbqt]", pdbqt)
        for original, box_file in (protein_data.get("meeko_box_files") or {}).items():
            record("proteins", f"{original} [box]", box_file)

    if ligand_data:
        for original, formats in (ligand_data.get("converted_ligands") or {}).items():
            for fmt, path in formats.items():
                record("ligands", f"{original} [{fmt}]", path)
        for original, pdbqt in (ligand_data.get("meeko_ligand_outputs") or {}).items():
            record("ligands", f"{original} [pdbqt]", pdbqt)

    return manifest

# %%
# prepared_manifest = build_prepared_manifest(output_folder_mgltools, protein_outputs, ligand_outputs)
# print(f"Proteins prepared: {len(prepared_manifest['proteins'])}")
# print(f"Ligands prepared: {len(prepared_manifest['ligands'])}")
# pprint(prepared_manifest)

# %%
prepared_manifest = build_prepared_manifest(output_folder_meeko, protein_outputs, ligand_outputs)
print(f"Proteins prepared: {len(prepared_manifest['proteins'])}")
print(f"Ligands prepared: {len(prepared_manifest['ligands'])}")
pprint(prepared_manifest)
# Out:
# Proteins prepared: 8
# Ligands prepared: 592
# {'ligands': [{'filetype': 'pdbqt',
#               'name': '05J_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/05J_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/05J_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '07J_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/07J_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/07J_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '0LI_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/0LI_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/0LI_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '10A_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/10A_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/10A_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '11U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/11U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/11U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '128_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/128_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/128_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '138_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/138_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/138_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '140_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/140_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/140_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '146_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/146_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/146_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '169_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/169_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/169_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '16A_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/16A_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/16A_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '17F_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/17F_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/17F_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '1JY_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/1JY_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/1JY_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '1L3_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/1L3_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/1L3_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '1N1_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/1N1_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/1N1_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '1VU_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/1VU_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/1VU_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '1XJ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/1XJ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/1XJ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '21V_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/21V_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/21V_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '243_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/243_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/243_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '276_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/276_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/276_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '27U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/27U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/27U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2CP_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2CP_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2CP_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2ED_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2ED_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2ED_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2I4_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2I4_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2I4_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2MC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2MC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2MC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2RD_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2RD_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2RD_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2S8_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2S8_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2S8_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2TA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2TA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2TA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '2YB_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/2YB_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/2YB_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '30B_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/30B_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/30B_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '32U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/32U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/32U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '347_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/347_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/347_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '34W_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/34W_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/34W_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '385_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/385_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/385_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '38P_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/38P_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/38P_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3B9_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3B9_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3B9_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3CB_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3CB_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3CB_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3H4_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3H4_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3H4_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3HC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3HC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3HC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3IN_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3IN_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3IN_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3N6_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3N6_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3N6_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3PC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3PC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3PC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '3ZC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/3ZC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/3ZC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '442_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/442_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/442_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '46U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/46U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/46U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4CA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4CA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4CA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4CC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4CC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4CC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4CO_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4CO_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4CO_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4EA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4EA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4EA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4HD_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4HD_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4HD_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4IF_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4IF_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4IF_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '4UH_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/4UH_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/4UH_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '50U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/50U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/50U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '54J_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/54J_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/54J_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '570_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/570_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/570_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '587_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/587_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/587_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '59U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/59U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/59U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5CB_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5CB_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5CB_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5D5_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5D5_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5D5_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5FA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5FA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5FA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5MV_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5MV_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5MV_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5PI_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5PI_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5PI_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5X6_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5X6_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5X6_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '5YM_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/5YM_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/5YM_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '626_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/626_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/626_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '63J_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/63J_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/63J_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '63K_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/63K_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/63K_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '65C_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/65C_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/65C_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '66T_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/66T_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/66T_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6E2_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6E2_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6E2_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6EJ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6EJ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6EJ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6F6_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6F6_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6F6_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6FA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6FA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6FA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6GY_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6GY_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6GY_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6K9_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6K9_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6K9_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6SA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6SA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6SA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '6ZV_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/6ZV_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/6ZV_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '710_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/710_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/710_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '711_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/711_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/711_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '740_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/740_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/740_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '742_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/742_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/742_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '74T_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/74T_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/74T_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7AK_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7AK_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7AK_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7I4_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7I4_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7I4_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7IX_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7IX_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7IX_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7RU_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7RU_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7RU_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7T1_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7T1_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7T1_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7TB_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7TB_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7TB_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7X1_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7X1_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7X1_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '7Y5_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/7Y5_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/7Y5_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '80I_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/80I_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/80I_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '88Z_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/88Z_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/88Z_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8DZ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8DZ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8DZ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8I2_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8I2_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8I2_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8JC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8JC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8JC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8PP_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8PP_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8PP_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8QW_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8QW_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8QW_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8RC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8RC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8RC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8VP_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8VP_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8VP_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8X7_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8X7_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8X7_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '8XJ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/8XJ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/8XJ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '919_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/919_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/919_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '964_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/964_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/964_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '96Q_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/96Q_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/96Q_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '98I_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/98I_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/98I_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9AJ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9AJ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9AJ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9B0_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9B0_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9B0_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9HO_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9HO_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9HO_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9IN_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9IN_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9IN_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9N6_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9N6_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9N6_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9SC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9SC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9SC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': '9TP_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/9TP_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/9TP_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A00_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A00_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A00_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1AAC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1AAC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1AAC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1AF4_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1AF4_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1AF4_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1APA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1APA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1APA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1AZ7_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1AZ7_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1AZ7_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1BLM_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1BLM_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1BLM_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1BPC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1BPC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1BPC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1C3G_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1C3G_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1C3G_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1CB7_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1CB7_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1CB7_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1CEA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1CEA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1CEA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1D8M_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1D8M_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1D8M_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1D8Y_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1D8Y_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1D8Y_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1E_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1E_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1E_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1H3T_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1H3T_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1H3T_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1JMR_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1JMR_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1JMR_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1JS8_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1JS8_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1JS8_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1JSO_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1JSO_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1JSO_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1JSR_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1JSR_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1JSR_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1JTY_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1JTY_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1JTY_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1L66_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1L66_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1L66_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1LVF_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1LVF_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1LVF_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1LXP_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1LXP_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1LXP_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A1LY1_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A1LY1_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A1LY1_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A2E_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A2E_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A2E_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A3D_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A3D_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A3D_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A4I_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A4I_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A4I_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A4P_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A4P_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A4P_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A6L_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A6L_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A6L_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A86_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A86_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A86_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'A8B_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/A8B_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/A8B_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AA2_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AA2_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AA2_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AAF_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AAF_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AAF_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AAO_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AAO_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AAO_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'ABC_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/ABC_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/ABC_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'ACG_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/ACG_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/ACG_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'ACQ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/ACQ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/ACQ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'ADV_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/ADV_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/ADV_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AGA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AGA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AGA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AGH_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AGH_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AGH_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AH4_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AH4_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AH4_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AHZ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/AHZ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/AHZ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'AIK_ideal.pdbqt',
# ...
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UAG_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UAG_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UAG_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UDH_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UDH_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UDH_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UK4_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UK4_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UK4_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UKA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UKA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UKA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'ULA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/ULA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/ULA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UMA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UMA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UMA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UMG_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UMG_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UMG_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UMQ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UMQ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UMQ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UP5_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UP5_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UP5_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'UR2_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/UR2_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/UR2_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'V6G_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/V6G_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/V6G_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'VCA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/VCA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/VCA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'VIV_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/VIV_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/VIV_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'VL1_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/VL1_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/VL1_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'VS2_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/VS2_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/VS2_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'VTQ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/VTQ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/VTQ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'VXI_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/VXI_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/VXI_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'W42_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/W42_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/W42_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'W43_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/W43_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/W43_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'W56_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/W56_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/W56_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'W59_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/W59_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/W59_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'W71_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/W71_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/W71_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'W8R_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/W8R_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/W8R_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'WVN_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/WVN_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/WVN_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'X2N_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/X2N_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/X2N_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'X4U_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/X4U_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/X4U_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XAT_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XAT_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XAT_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XB7_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XB7_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XB7_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XC9_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XC9_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XC9_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XIN_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XIN_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XIN_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XMJ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XMJ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XMJ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XNH_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XNH_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XNH_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XPG_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XPG_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XPG_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'XR1_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/XR1_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/XR1_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'Y9J_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/Y9J_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/Y9J_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'YG7_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/YG7_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/YG7_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'YHR_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/YHR_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/YHR_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'YIS_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/YIS_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/YIS_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'YKQ_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/YKQ_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/YKQ_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'YMA_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/YMA_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/YMA_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'Z6V_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/Z6V_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/Z6V_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'Z90_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/Z90_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/Z90_ideal.pdbqt '
#                         '[pdbqt]'},
#              {'filetype': 'pdbqt',
#               'name': 'ZIY_ideal.pdbqt',
#               'path': '/workspace/master_dev/docking_ready_meeko/ligands_sdf_large_approved/ZIY_ideal.pdbqt',
#               'source': 'docking_ready_meeko/ligands_sdf_large_approved/ZIY_ideal.pdbqt '
#                         '[pdbqt]'}],
#  'proteins': [{'filetype': 'pdbqt',
#                'name': 'Orai1WT-MDSnap-Fr300_cleaned.pdbqt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-MDSnap-Fr300_cleaned.pdbqt',
#                'source': 'docking_ready_meeko/Orai1WT-MDSnap-Fr300_cleaned.pdbqt '
#                          '[pdbqt]'},
#               {'filetype': 'pdbqt',
#                'name': 'Orai1WT-MDSnap-Fr400_cleaned.pdbqt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-MDSnap-Fr400_cleaned.pdbqt',
#                'source': 'docking_ready_meeko/Orai1WT-MDSnap-Fr400_cleaned.pdbqt '
#                          '[pdbqt]'},
#               {'filetype': 'pdbqt',
#                'name': 'Orai1WT-MDSnap-Fr499_cleaned.pdbqt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-MDSnap-Fr499_cleaned.pdbqt',
#                'source': 'docking_ready_meeko/Orai1WT-MDSnap-Fr499_cleaned.pdbqt '
#                          '[pdbqt]'},
#               {'filetype': 'pdbqt',
#                'name': 'Orai1WT-START-Fr0_cleaned.pdbqt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-START-Fr0_cleaned.pdbqt',
#                'source': 'docking_ready_meeko/Orai1WT-START-Fr0_cleaned.pdbqt '
#                          '[pdbqt]'},
#               {'filetype': 'txt',
#                'name': 'Orai1WT-MDSnap-Fr300_cleaned.box.txt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-MDSnap-Fr300_cleaned.box.txt',
#                'source': 'docking_ready_meeko/Orai1WT-MDSnap-Fr300_cleaned.pdbqt '
#                          '[box]'},
#               {'filetype': 'txt',
#                'name': 'Orai1WT-MDSnap-Fr400_cleaned.box.txt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-MDSnap-Fr400_cleaned.box.txt',
#                'source': 'docking_ready_meeko/Orai1WT-MDSnap-Fr400_cleaned.pdbqt '
#                          '[box]'},
#               {'filetype': 'txt',
#                'name': 'Orai1WT-MDSnap-Fr499_cleaned.box.txt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-MDSnap-Fr499_cleaned.box.txt',
#                'source': 'docking_ready_meeko/Orai1WT-MDSnap-Fr499_cleaned.pdbqt '
#                          '[box]'},
#               {'filetype': 'txt',
#                'name': 'Orai1WT-START-Fr0_cleaned.box.txt',
#                'path': '/workspace/master_dev/docking_ready_meeko/Orai1WT-START-Fr0_cleaned.box.txt',
#                'source': 'docking_ready_meeko/Orai1WT-START-Fr0_cleaned.pdbqt '
#                          '[box]'}]}

# %% [markdown]
# # Pre-flight Check

# %%
errors = []

# Check Vina-CUDA executable
if not VINA_BIN.exists():
    errors.append(f"✗ Vina-CUDA executable not found: {VINA_BIN}")
elif not os.access(VINA_BIN, os.X_OK):
    errors.append(f"✗ Vina-CUDA executable not executable: {VINA_BIN}")

# Check inputs exist for each ligand dir
for drugs_dir in drugs_dirs:
    ligand_files = collect_files(output_folder_meeko, [".pdbqt"])
    print(f"  {drugs_dir.name}: {len(ligand_files)} ligand files")
    if not ligand_files:
        errors.append(f"✗ No ligand files in {drugs_dir}")

recep_files = collect_files(receptors_dir, [".pdb", ".pdbqt"])
print(f"  Receptors: {len(recep_files)} files in {receptors_dir}")
if not recep_files:
    errors.append(f"✗ No receptor files in {receptors_dir}")

# Check GPU availability
try:
    gpu_result = subprocess.run(
        ["nvidia-smi", "--query-gpu=gpu_name", "--format=csv,noheader"],
        capture_output=True, text=True, timeout=5,
    )
    gpu_name = gpu_result.stdout.strip()
    if not gpu_name:
        errors.append("✗ No GPU detected via nvidia-smi")
    else:
        print(f"  GPU: {gpu_name}")
except Exception:
    errors.append("✗ nvidia-smi not available — GPU required for Vina-CUDA")

if errors:
    print("\n⚠ ISSUES FOUND:")
    for e in errors:
        print(f"  {e}")
    print("\nFix these before running docking.")
else:
    print("\n✓ All checks passed — ready to dock with Vina-CUDA.")
# Out:
#   ligands_sdf_large_approved: 4 ligand files
#   Receptors: 4 files in /workspace/master_dev/Orai
#   GPU: NVIDIA A100-SXM4-80GB
#
# ✓ All checks passed — ready to dock with Vina-CUDA.

# %%
def _monitor_progress(output_dir: Path, stop_event: threading.Event,
                      poll_interval: float = 10.0, progress_state: dict = None):
    """Background thread that periodically prints docking progress.

    If *progress_state* dict is provided, it reads:
      - receptor:       current receptor name
      - sub_box:        current sub-box index (0-based)
      - n_sub_boxes:    total sub-boxes for this receptor
      - n_ligands:      total ligands being docked in this batch
      - sub_out_dir:    Path to current sub-box output directory
      - sub_log:        Path to current sub-box log file
      - skipped_subs:   number of sub-boxes skipped via resume
      - batch_expected_outs: set of expected output filenames for current batch
    """
    start_time = time.time()

    while not stop_event.is_set():
        stop_event.wait(poll_interval)
        if stop_event.is_set():
            break

        elapsed = time.time() - start_time
        mins, secs = divmod(int(elapsed), 60)
        hrs, mins = divmod(mins, 60)
        time_str = f"{hrs}h{mins:02d}m{secs:02d}s" if hrs else f"{mins}m{secs:02d}s"

        # Count completed merged output files
        n_merged = len(list(output_dir.rglob("*_vina_out.pdbqt")))

        # GPU utilization
        try:
            gpu_info = subprocess.run(
                ["nvidia-smi", "--query-gpu=utilization.gpu,memory.used,memory.total",
                 "--format=csv,noheader,nounits"],
                capture_output=True, text=True, timeout=5
            )
            gpu_line = gpu_info.stdout.strip()
        except Exception:
            gpu_line = "N/A"

        # Sub-box progress details
        detail = ""
        if progress_state:
            rec = progress_state.get("receptor", "")
            si = progress_state.get("sub_box")
            n_subs = progress_state.get("n_sub_boxes", 0)
            n_ligs = progress_state.get("n_ligands", 0)
            sub_out = progress_state.get("sub_out_dir")
            sub_log_path = progress_state.get("sub_log")
            skipped = progress_state.get("skipped_subs", 0)
            expected_outs = progress_state.get("batch_expected_outs")

            if si is not None and sub_out and Path(sub_out).exists():
                # Count only outputs matching the current batch ligands
                if expected_outs:
                    n_done_sub = sum(
                        1 for p in Path(sub_out).glob("*_out.pdbqt")
                        if p.stat().st_size > 0 and p.name in expected_outs
                    )
                else:
                    n_done_sub = sum(
                        1 for p in Path(sub_out).glob("*_out.pdbqt")
                        if p.stat().st_size > 0
                    )
                pct = (n_done_sub / n_ligs * 100) if n_ligs > 0 else 0

                # Try to find current ligand from log tail
                current_lig = ""
                if sub_log_path and Path(sub_log_path).exists():
                    try:
                        log_tail = Path(sub_log_path).read_text()[-2000:]
                        # Look for last "Refining ligand ... results" or "Writing ligand ... output"
                        for marker in ("Writing ligand ", "Refining ligand "):
                            idx = log_tail.rfind(marker)
                            if idx >= 0:
                                after = log_tail[idx + len(marker):]
                                # Extract ligand name from path
                                lig_part = after.split()[0] if after.split() else ""
                                # Get just the stem (last path component without _out)
                                lig_name = lig_part.rstrip("/").rsplit("/", 1)[-1]
                                if lig_name:
                                    current_lig = lig_name
                                break
                    except Exception:
                        pass

                sub_info = f"sub {si+1}/{n_subs}"
                if skipped:
                    sub_info += f" ({skipped} resumed)"
                lig_info = f" | lig: {current_lig}" if current_lig else ""
                detail = f" | {rec} {sub_info} | {n_done_sub}/{n_ligs} ({pct:.0f}%){lig_info}"

        print(f"  ⏱ {time_str} | ✓ {n_merged} merged | GPU: {gpu_line}{detail}")

# %% [markdown]
# ## Smoke Test: 100 Å box with Vina-CUDA

# %%
# ── Smoke test: dock 1 ligand with an explicit 100×100×100 Å box ──────────
# Proves that Vina-CUDA v1.1 (compiled with -DLARGE_BOX) accepts a 100 Å box
# without the "relation too large" error.

import tempfile, textwrap

_smoke_receptor = Path("/workspace/master_dev/docking_ready_meeko/Orai1WT-START-Fr0_cleaned.pdbqt")
_smoke_ligand  = sorted(
    Path("/workspace/master_dev/docking_ready_meeko/ligands_sdf_small_symmetric_approved").glob("*.pdbqt")
)[0]

assert _smoke_receptor.exists(), f"Receptor missing: {_smoke_receptor}"
assert _smoke_ligand.exists(),   f"Ligand missing: {_smoke_ligand}"

# Use the protein's actual center but force all three sizes to exactly 100 Å
_orig_box = parse_box_file(_smoke_receptor.with_suffix(".box.txt"))

with tempfile.TemporaryDirectory(prefix="vina_smoke_") as tmpdir:
    tmpdir = Path(tmpdir)

    # Write a 100×100×100 Å box config
    box_100 = {
        "center_x": _orig_box["center_x"],
        "center_y": _orig_box["center_y"],
        "center_z": _orig_box["center_z"],
        "size_x": 100.0,
        "size_y": 100.0,
        "size_z": 100.0,
    }
    box_file = tmpdir / "box_100.txt"
    write_box_file(box_file, box_100)

    # Create ligand directory with a single ligand
    lig_dir = tmpdir / "ligands"
    lig_dir.mkdir()
    (lig_dir / _smoke_ligand.name).symlink_to(_smoke_ligand)

    out_dir = tmpdir / "output"
    out_dir.mkdir()
    log_file = tmpdir / "smoke.log"

    cmd = [
        str(VINA_BIN),
        "--receptor",         str(_smoke_receptor),
        "--ligand_directory",  str(lig_dir),
        "--output_directory",  str(out_dir),
        "--config",            str(box_file),
        "--thread",            "8000",
        "--search_depth",      "5",    # minimal depth — just testing the grid
        "--num_modes",         "1",
        "--rilc_bfgs",         "0",
    ]

    print(f"Receptor : {_smoke_receptor.name}")
    print(f"Ligand   : {_smoke_ligand.name}")
    print(f"Box      : {box_100['size_x']} × {box_100['size_y']} × {box_100['size_z']} Å")
    print(f"Center   : ({box_100['center_x']:.1f}, {box_100['center_y']:.1f}, {box_100['center_z']:.1f})")
    print(f"Binary   : {VINA_BIN}")
    print()

    t0 = time.time()
    proc = subprocess.run(cmd, capture_output=True, text=True, timeout=300)
    elapsed = time.time() - t0

    # ── Report ────────────────────────────────────────────────────────
    print(f"Exit code: {proc.returncode}  ({elapsed:.1f}s)")

    # Check for the fatal overflow error
    combined_output = proc.stdout + proc.stderr
    if "relation too large" in combined_output.lower():
        print("\n❌ FAIL — 'relation too large' error detected!")
        print(combined_output[-2000:])
    elif proc.returncode != 0:
        print(f"\n⚠ Non-zero exit code ({proc.returncode}).  Last 1000 chars of output:")
        print(combined_output[-1000:])
    else:
        # Check for output file
        out_files = list(out_dir.glob("*_out.pdbqt"))
        if out_files:
            out_size = out_files[0].stat().st_size
            print(f"\n✅ PASS — 100 Å box accepted by Vina-CUDA")
            print(f"   Output: {out_files[0].name} ({out_size:,} bytes)")
            # Show affinity
            models = parse_vina_pdbqt_models(out_files[0])
            if models:
                print(f"   Best affinity: {models[0][0]:.2f} kcal/mol")
        else:
            print("\n⚠ Vina returned 0 but no output file found")
            print(combined_output[-1000:])
# Out:
# Receptor : Orai1WT-START-Fr0_cleaned.pdbqt
# Ligand   : 007_ideal.pdbqt
# Box      : 100.0 × 100.0 × 100.0 Å
# Center   : (3.9, 6.6, 1.3)
# Binary   : /workspace/Vina-CUDA/Vina-CUDA_v1.1/Vina-GPU-2-1-CUDA
# Exit code: 0  (13.2s)
#
# ✅ PASS — 100 Å box accepted by Vina-CUDA
#    Output: 007_ideal_out.pdbqt (1,527 bytes)
#    Best affinity: -5.90 kcal/mol

# %% [markdown]
# # AutoDock Vina-GPU Docking

# %% [markdown]
# ## MGL-Tools Docking (multi-directory loop)

# %%
# def _monitor_progress(output_dir: Path, stop_event: threading.Event, poll_interval: float = 10.0):
#     """Background thread that periodically prints docking progress."""
#     start_time = time.time()
# 
#     while not stop_event.is_set():
#         stop_event.wait(poll_interval)
#         if stop_event.is_set():
#             break
# 
#         elapsed = time.time() - start_time
# 
#         # Count completed output files
#         n_done = len(list(output_dir.rglob("*_vina_out.pdbqt")))
# 
#         # GPU utilization
#         try:
#             gpu_info = subprocess.run(
#                 ["nvidia-smi", "--query-gpu=utilization.gpu,memory.used,memory.total",
#                  "--format=csv,noheader,nounits"],
#                 capture_output=True, text=True, timeout=5
#             )
#             gpu_line = gpu_info.stdout.strip()
#         except Exception:
#             gpu_line = "N/A"
# 
#         mins, secs = divmod(int(elapsed), 60)
#         hrs, mins = divmod(mins, 60)
#         time_str = f"{hrs}h{mins:02d}m{secs:02d}s" if hrs else f"{mins}m{secs:02d}s"
# 
#         print(f"  ⏱ {time_str} | ✓ {n_done} done | GPU: {gpu_line}")
# 
# 
# all_vina_results: List[DockingResult] = []
# 
# for drugs_dir in drugs_dirs:
#     VINA_OUTPUT_DIR = VINA_OUTPUT_BASE / drugs_dir.name
#     VINA_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
# 
#     print(f"\n{'=' * 80}")
#     print(f"Processing ligand directory (Vina-GPU): {drugs_dir.name}")
#     print(f"Output: {VINA_OUTPUT_DIR}")
#     print(f"{'=' * 80}")
# 
#     # Collect ligand files for property pre-computation
#     lig_files = collect_files(drugs_dir, [".pdbqt", ".sdf", ".mol2"])
#     rec_files = collect_files(receptors_dir, [".pdb", ".pdbqt"])
# 
#     print(f"Found {len(rec_files)} receptors and {len(lig_files)} ligands")
# 
#     if not rec_files or not lig_files:
#         print("⚠ No receptors or ligands found, skipping.")
#         continue
# 
#     # Pre-compute molecular properties
#     lig_props_cache, prot_props_cache = precompute_properties(rec_files, lig_files)
# 
#     # Start progress monitor
#     stop_monitor = threading.Event()
#     monitor_thread = threading.Thread(
#         target=_monitor_progress,
#         args=(VINA_OUTPUT_DIR, stop_monitor, 15),
#         daemon=True,
#     )
#     monitor_thread.start()
# 
#     try:
#         results_df, docking_results = run_autodock_vina_gpu(
#             base_dir=output_folder_mgltools,
#             log_dir=wdlogs,
#             prepared_manifest=prepared_manifest,
#             protein_workflow_data=protein_outputs,
#             ligand_workflow_data=ligand_outputs,
#             thread=THREAD,
#             search_depth=SEARCH_DEPTH,
#             num_modes=NUM_MODES,
#             energy_range=ENERGY_RANGE,
#             overwrite=OVERWRITE_EXISTING,
#             timeout=TIMEOUT_PER_COMPLEX,
#             output_base_dir=VINA_OUTPUT_DIR,
#             lig_props_cache=lig_props_cache,
#             prot_props_cache=prot_props_cache,
#         )
#     finally:
#         stop_monitor.set()
#         monitor_thread.join(timeout=5)
# 
#     all_vina_results.extend(docking_results)
# 
#     # Generate and print summary
#     summary = generate_summary(docking_results)
#     print_summary(summary)
# 
#     # Save summary JSON
#     summary_path = VINA_OUTPUT_DIR / "docking_summary.json"
#     with open(summary_path, 'w') as f:
#         json.dump(summary, f, indent=2, default=str)
#     print(f"\nSummary saved: {summary_path}")
# 
# print(f"\n{'=' * 80}")
# print(f"ALL DONE (Vina-GPU) — {len(all_vina_results)} total results across {len(drugs_dirs)} ligand directories")
# print(f"{'=' * 80}")

# %% [markdown]
# ## Meeko Docking (multi-directory loop)

# %%
all_vina_results_meeko: List[DockingResult] = []

# Single output directory for the combined run
VINA_OUTPUT_DIR = VINA_OUTPUT_BASE / "combined_meeko"
VINA_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# The actual docking output goes to base_dir/docking
dock_output_dir = (output_folder_meeko / "docking").resolve()

dir_names = [d.name for d in drugs_dirs if d.exists()]
print(f"{'=' * 80}")
print(f"Combined docking (Meeko / Vina-CUDA)")
print(f"Ligand dirs: {', '.join(dir_names)}")
print(f"Output: {VINA_OUTPUT_DIR}")
print(f"{'=' * 80}")

# ── Build manifest from merged ligand_outputs (prepared in cell above) ────
combined_manifest = build_prepared_manifest(
    output_folder_meeko, protein_outputs, ligand_outputs
)

n_manifest_ligs = sum(
    1 for e in combined_manifest.get("ligands", [])
    if e.get("path", "").endswith(".pdbqt")
)
print(f"Manifest: {len(combined_manifest.get('proteins', []))} protein entries, "
      f"{n_manifest_ligs} ligand PDBQTs")

# ── Collect files for property pre-computation ────────────────────────────
lig_files = collect_files(output_folder_meeko, [".pdbqt"])
rec_files = collect_files(receptors_dir, [".pdb", ".pdbqt"])

print(f"Found {len(rec_files)} receptors and {len(lig_files)} ligands")

if not rec_files or not lig_files:
    print("⚠ No receptors or ligands found — nothing to dock.")
else:
    lig_props_cache, prot_props_cache = precompute_properties(rec_files, lig_files)

    progress_state = {}
    stop_monitor = threading.Event()
    monitor_thread = threading.Thread(
        target=_monitor_progress,
        args=(dock_output_dir, stop_monitor, 15, progress_state),
        daemon=True,
    )
    monitor_thread.start()

    try:
        results_df_meeko, docking_results_meeko = run_autodock_vina_gpu(
            base_dir=output_folder_meeko,
            log_dir=wdlogs,
            prepared_manifest=combined_manifest,
            protein_workflow_data=protein_outputs,
            ligand_workflow_data=ligand_outputs,
            thread=THREAD,
            search_depth=SEARCH_DEPTH,
            num_modes=NUM_MODES,
            energy_range=ENERGY_RANGE,
            overwrite=OVERWRITE_EXISTING,
            timeout=TIMEOUT_PER_COMPLEX,
            output_base_dir=VINA_OUTPUT_DIR,
            lig_props_cache=lig_props_cache,
            prot_props_cache=prot_props_cache,
            progress_state=progress_state,
            verbose_log=True,
        )
    finally:
        stop_monitor.set()
        monitor_thread.join(timeout=5)

    all_vina_results_meeko.extend(docking_results_meeko)

    summary = generate_summary(docking_results_meeko)
    print_summary(summary)

    summary_path = VINA_OUTPUT_DIR / "docking_summary.json"
    with open(summary_path, 'w') as f:
        json.dump(summary, f, indent=2, default=str)
    print(f"\nSummary saved: {summary_path}")

print(f"\n{'=' * 80}")
print(f"ALL DONE (Meeko / Vina-CUDA) — {len(all_vina_results_meeko)} total results "
      f"from {len(dir_names)} ligand directories combined")
print(f"{'=' * 80}")
# Out:
# ================================================================================
# Combined docking (Meeko / Vina-CUDA)
# Ligand dirs: ligands_sdf_large_approved
# Output: /workspace/vina_results/combined_meeko
# ================================================================================
# Manifest: 8 protein entries, 592 ligand PDBQTs
# Found 4 receptors and 4 ligands
# Pre-computing ligand properties...
#   4 ligands analysed
# Pre-computing protein properties...
#   4 proteins analysed
# Docking receptors: 4 | ligands: 592
# Docking log: /workspace/vina_results/combined_meeko/docking_log.csv (4632 existing entries)
# Total docking jobs: 2368
#   📦 Orai1WT-MDSnap-Fr300_cleaned: original box  size=(97.3, 97.9, 103.7) Å  center=(0.2, 9.7, -5.8)  vol=987,812 ų
#   ⚡ Orai1WT-MDSnap-Fr300_cleaned: split on (z=103.7) → 2 sub-boxes (max=99.0Å, overlap=15.0Å)
#       sub-box 0: size=(97.3, 97.9, 99.0) Å  center=(0.2, 9.7, -8.2)
#       sub-box 1: size=(97.3, 97.9, 99.0) Å  center=(0.2, 9.7, -3.5)
#     🔄 Sub-box 0: 563 already done, docking 29 remaining ligands
#     [vina] WARNING: The search space volume1> 27000 Angstrom^3 (See FAQ)
#     [vina]
#     [vina] Using virtual sreening mode
#     [vina]
#     [vina] Output will be in the directory /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out
#   ⏱ 0m15s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 1/2 | 0/29 (0%)
#     [vina] Reading input ... reading time: 3.56953
#     [vina] done.
#     [vina] Setting up the scoring function ... done.
#   ⏱ 0m30s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 1/2 | 0/29 (0%)
#   ⏱ 0m46s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 1/2 | 0/29 (0%)
#   ⏱ 1m02s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 1/2 | 0/29 (0%)
#   ⏱ 1m18s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 1/2 | 0/29 (0%)
#     [vina] Search_depth is fixed to 32
#     [vina] Analyzing the binding site ... done.
#   ⏱ 1m33s | ✓ 0 merged | GPU: 18, 20767, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 1/2 | 0/29 (0%)
#     [vina]
# Perform docking|================done=================|
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/AGH_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/AGH_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/FI8_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/FI8_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/ZIY_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/ZIY_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A4I_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A4I_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SVR_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SVR_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/DR6_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/DR6_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BLM_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BLM_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/TDT_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/TDT_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A1LVF_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A1LVF_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/RR6_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/RR6_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/KAB_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/KAB_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SFA_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SFA_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A1CB7_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A1CB7_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV3_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV3_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/DGD_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/DGD_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/CYU_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/CYU_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV4_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV4_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV2_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV2_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SFT_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SFT_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A1L66_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/A1L66_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/AP8_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/AP8_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/CDL_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/CDL_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/RGA_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/RGA_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SPX_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/SPX_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/QWP_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/QWP_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/8I2_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/8I2_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/E55_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/E55_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV1_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BV1_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BY6_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub0_out/BY6_ideal
#     [vina]
#     [vina] AutoDockVina-GPU3 total runtime = 82.0004 s
#     🔄 Sub-box 1: 563 already done, docking 29 remaining ligands
#     [vina] WARNING: The search space volume1> 27000 Angstrom^3 (See FAQ)
#     [vina]
#     [vina] Using virtual sreening mode
#     [vina]
#     [vina] Output will be in the directory /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out
#     [vina] Reading input ... reading time: 3.59854
#     [vina] done.
#     [vina] Setting up the scoring function ... done.
#   ⏱ 1m49s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%)
#   ⏱ 2m05s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%)
#   ⏱ 2m21s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%)
#   ⏱ 2m37s | ✓ 0 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%)
#     [vina] Search_depth is fixed to 32
#     [vina] Analyzing the binding site ... done.
#   ⏱ 2m52s | ✓ 0 merged | GPU: 0, 5, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%)
#     [vina]
# Perform docking|================done=================|
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/AGH_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/AGH_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/FI8_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/FI8_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/ZIY_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/ZIY_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A4I_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A4I_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SVR_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SVR_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/DR6_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/DR6_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BLM_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BLM_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/TDT_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/TDT_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A1LVF_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A1LVF_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/RR6_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/RR6_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/KAB_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/KAB_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SFA_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SFA_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A1CB7_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A1CB7_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV3_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV3_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/DGD_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/DGD_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/CYU_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/CYU_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV4_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV4_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV2_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV2_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SFT_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SFT_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A1L66_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/A1L66_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/AP8_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/AP8_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/CDL_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/CDL_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/RGA_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/RGA_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SPX_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/SPX_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/QWP_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/QWP_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/8I2_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/8I2_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/E55_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/E55_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV1_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BV1_ideal
#     [vina]
#     [vina] Refining ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BY6_ideal results...
#     [vina] No results found for ligand /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr300_cleaned_sub1_out/BY6_ideal
#     [vina]
#     [vina] AutoDockVina-GPU3 total runtime = 82.1873 s
#   ⏱ Orai1WT-MDSnap-Fr300_cleaned: batch completed in 168.4s (2.8 min)
#     Vina timing: total=164.2s  reading=7.2s  compute=157.0s
#     Per-ligand avg: 0.28s  (0.00 min)  [592 ligands × 2 sub-box(es)]
#   ⏱ 3m08s | ✓ 159 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%) | lig: BY6_ideal
#   ⏱ 3m24s | ✓ 516 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr300_cleaned sub 2/2 | 0/29 (0%) | lig: BY6_ideal
#   📊 Orai1WT-MDSnap-Fr300_cleaned: 563 ok / 29 fail | best affinity: -10.90 kcal/mol
#   📦 Orai1WT-MDSnap-Fr400_cleaned: original box  size=(98.6, 97.6, 103.7) Å  center=(-0.4, 9.9, -6.5)  vol=997,942 ų
#   ⚡ Orai1WT-MDSnap-Fr400_cleaned: split on (z=103.7) → 2 sub-boxes (max=99.0Å, overlap=15.0Å)
#       sub-box 0: size=(98.6, 97.6, 99.0) Å  center=(-0.4, 9.9, -8.8)
#       sub-box 1: size=(98.6, 97.6, 99.0) Å  center=(-0.4, 9.9, -4.1)
#     [vina] WARNING: The search space volume1> 27000 Angstrom^3 (See FAQ)
#     [vina]
#     [vina] Using virtual sreening mode
#     [vina]
#     [vina] Output will be in the directory /workspace/master_dev/docking_ready_meeko/docking/_batch_Orai1WT-MDSnap-Fr400_cleaned_sub0_out
#   ⏱ 3m40s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 3m55s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 4m10s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 4m26s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 4m41s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#     [vina] Reading input ... reading time: 71.6528
#     [vina] done.
#     [vina] Setting up the scoring function ... done.
#   ⏱ 4m56s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 5m11s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 5m27s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 5m42s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 5m57s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 6m12s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 6m27s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 6m43s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 6m58s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 7m13s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 7m28s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 7m44s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 7m59s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 8m14s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 8m29s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 8m45s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 9m00s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 9m15s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 9m30s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 9m46s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 10m01s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 10m16s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 10m31s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 10m46s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 11m02s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 11m17s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 11m32s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 11m48s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 12m03s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 12m18s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 12m33s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 12m49s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 13m04s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 13m19s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 13m34s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 13m50s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 14m05s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 14m20s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 14m35s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 14m50s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 15m06s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 15m21s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 15m36s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 15m51s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 16m07s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 16m22s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 16m37s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 16m52s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 17m08s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 17m23s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 17m38s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 17m53s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 18m09s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 18m24s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 18m39s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 18m54s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 19m10s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 19m25s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 19m40s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 19m55s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 20m11s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 20m26s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 20m41s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 20m56s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 21m12s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 21m27s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 21m42s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 21m57s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 22m13s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 22m28s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 22m43s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 22m58s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 23m14s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 23m29s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 23m44s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 23m59s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 24m15s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 24m30s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 24m45s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 25m00s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 25m16s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 25m31s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 25m46s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 26m01s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 26m17s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 26m32s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 26m47s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 27m02s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 27m18s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 27m33s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 27m48s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 28m03s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 28m19s | ✓ 563 merged | GPU: 0, 1, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#     [vina] Search_depth is fixed to 32
#     [vina] Analyzing the binding site ... done.
#   ⏱ 28m34s | ✓ 563 merged | GPU: 0, 5, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#     [vina]
#     [vina] search_depth: 32 || bfgs_steps: 23
# Perform docking|       =======                       |search_depth: 32 || bfgs_steps: 19
#   ⏱ 28m49s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|          =======                    |search_depth: 32 || bfgs_steps: 21
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 21
# Perform docking|                      =======        |search_depth: 32 || bfgs_steps: 25
#   ⏱ 29m04s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|    =======                          |search_depth: 32 || bfgs_steps: 23
#   ⏱ 29m20s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|           =======                   |search_depth: 32 || bfgs_steps: 20
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 18
# Perform docking|                  =======            |search_depth: 32 || bfgs_steps: 21
# Perform docking|                       =======       |search_depth: 32 || bfgs_steps: 17
#   ⏱ 29m35s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                          =======    |search_depth: 32 || bfgs_steps: 20
# Perform docking|=======                              |search_depth: 32 || bfgs_steps: 19
# Perform docking|    =======                          |search_depth: 32 || bfgs_steps: 22
#   ⏱ 29m50s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|          =======                    |search_depth: 32 || bfgs_steps: 23
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 20
# Perform docking|                   =======           |search_depth: 32 || bfgs_steps: 23
#   ⏱ 30m06s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                          =======    |search_depth: 32 || bfgs_steps: 20
# Perform docking| =======                             |search_depth: 32 || bfgs_steps: 25
#   ⏱ 30m21s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|            =======                  |search_depth: 32 || bfgs_steps: 21
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 17
# Perform docking|                    =======          |search_depth: 32 || bfgs_steps: 16
# Perform docking|                      =======        |search_depth: 32 || bfgs_steps: 17
# Perform docking|                        =======      |search_depth: 32 || bfgs_steps: 16
#   ⏱ 30m36s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                          =======    |search_depth: 32 || bfgs_steps: 17
# Perform docking|                             ======= |search_depth: 32 || bfgs_steps: 19
# Perform docking|    =======                          |search_depth: 32 || bfgs_steps: 20
#   ⏱ 30m52s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|          =======                    |search_depth: 32 || bfgs_steps: 19
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 23
# Perform docking|                        =======      |search_depth: 32 || bfgs_steps: 24
#   ⏱ 31m07s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking| =======                             |search_depth: 32 || bfgs_steps: 19
# Perform docking|     =======                         |search_depth: 32 || bfgs_steps: 15
# Perform docking|       =======                       |search_depth: 32 || bfgs_steps: 30
#   ⏱ 31m22s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 31m37s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                             ======= |search_depth: 32 || bfgs_steps: 23
# Perform docking|        =======                      |search_depth: 32 || bfgs_steps: 30
#   ⏱ 31m53s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 32m08s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking| =======                             |search_depth: 32 || bfgs_steps: 22
# Perform docking|       =======                       |search_depth: 32 || bfgs_steps: 30
#   ⏱ 32m23s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 32m38s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                            =======  |search_depth: 32 || bfgs_steps: 28
#   ⏱ 32m54s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 30
#   ⏱ 33m09s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 33m24s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 29
#   ⏱ 33m39s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|   =======                           |search_depth: 32 || bfgs_steps: 22
# Perform docking|         =======                     |search_depth: 32 || bfgs_steps: 21
#   ⏱ 33m55s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 31
#   ⏱ 34m10s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|          =======                    |search_depth: 32 || bfgs_steps: 29
#   ⏱ 34m25s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 34m41s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|         =======                     |search_depth: 32 || bfgs_steps: 20
#   ⏱ 34m56s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|              =======                |search_depth: 32 || bfgs_steps: 26
# Perform docking|                           =======   |search_depth: 32 || bfgs_steps: 26
#   ⏱ 35m11s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|       =======                       |search_depth: 32 || bfgs_steps: 32
#   ⏱ 35m26s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 35m42s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|       =======                       |search_depth: 32 || bfgs_steps: 19
# Perform docking|             =======                 |search_depth: 32 || bfgs_steps: 20
#   ⏱ 35m57s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 21
# Perform docking|                     =======         |search_depth: 32 || bfgs_steps: 21
# Perform docking|                            =======  |search_depth: 32 || bfgs_steps: 33
#   ⏱ 36m12s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 36m27s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 36m43s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking| =======                             |search_depth: 32 || bfgs_steps: 20
# Perform docking|     =======                         |search_depth: 32 || bfgs_steps: 16
# Perform docking|        =======                      |search_depth: 32 || bfgs_steps: 29
#   ⏱ 36m58s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                        =======      |search_depth: 32 || bfgs_steps: 17
# Perform docking|                           =======   |search_depth: 32 || bfgs_steps: 28
#   ⏱ 37m13s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 37m28s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 25
# Perform docking|                             ======= |search_depth: 32 || bfgs_steps: 21
#   ⏱ 37m44s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|   =======                           |search_depth: 32 || bfgs_steps: 27
#   ⏱ 37m59s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                   =======           |search_depth: 32 || bfgs_steps: 22
# Perform docking|                           =======   |search_depth: 32 || bfgs_steps: 30
#   ⏱ 38m14s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 38m29s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                      =======        |search_depth: 32 || bfgs_steps: 27
#   ⏱ 38m45s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|      =======                        |search_depth: 32 || bfgs_steps: 15
# Perform docking|        =======                      |search_depth: 32 || bfgs_steps: 22
# Perform docking|             =======                 |search_depth: 32 || bfgs_steps: 20
#   ⏱ 39m00s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                   =======           |search_depth: 32 || bfgs_steps: 19
# Perform docking|                        =======      |search_depth: 32 || bfgs_steps: 24
#   ⏱ 39m15s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|    =======                          |search_depth: 32 || bfgs_steps: 21
# Perform docking|         =======                     |search_depth: 32 || bfgs_steps: 15
# Perform docking|            =======                  |search_depth: 32 || bfgs_steps: 18
# Perform docking|              =======                |search_depth: 32 || bfgs_steps: 16
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 18
#   ⏱ 39m30s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                      =======        |search_depth: 32 || bfgs_steps: 30
#   ⏱ 39m46s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 40m01s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                     =======         |search_depth: 32 || bfgs_steps: 33
#   ⏱ 40m17s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 40m32s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                         =======     |search_depth: 32 || bfgs_steps: 26
#   ⏱ 40m47s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|        =======                      |search_depth: 32 || bfgs_steps: 31
#   ⏱ 41m02s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                             ======= |search_depth: 32 || bfgs_steps: 33
#   ⏱ 41m18s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 41m33s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                       =======       |search_depth: 32 || bfgs_steps: 23
# Perform docking| =======                             |search_depth: 32 || bfgs_steps: 18
# Perform docking|     =======                         |search_depth: 32 || bfgs_steps: 30
#   ⏱ 41m48s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 42m04s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                          =======    |search_depth: 32 || bfgs_steps: 30
#   ⏱ 42m19s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 22
#   ⏱ 42m34s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                        =======      |search_depth: 32 || bfgs_steps: 18
# Perform docking|                            =======  |search_depth: 32 || bfgs_steps: 23
# Perform docking|     =======                         |search_depth: 32 || bfgs_steps: 31
#   ⏱ 42m49s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 43m05s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|    =======                          |search_depth: 32 || bfgs_steps: 27
#   ⏱ 43m20s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                 =======             |search_depth: 32 || bfgs_steps: 19
# Perform docking|                    =======          |search_depth: 32 || bfgs_steps: 22
#   ⏱ 43m35s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                          =======    |search_depth: 32 || bfgs_steps: 26
# Perform docking|        =======                      |search_depth: 32 || bfgs_steps: 26
#   ⏱ 43m50s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 44m06s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                           =======   |search_depth: 32 || bfgs_steps: 33
#   ⏱ 44m21s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 44m36s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|=======                              |search_depth: 32 || bfgs_steps: 31
#   ⏱ 44m51s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 45m07s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|   =======                           |search_depth: 32 || bfgs_steps: 30
#   ⏱ 45m22s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                      =======        |search_depth: 32 || bfgs_steps: 20
#   ⏱ 45m37s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|                          =======    |search_depth: 32 || bfgs_steps: 16
# Perform docking|                             ======= |search_depth: 32 || bfgs_steps: 31
#   ⏱ 45m52s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
#   ⏱ 46m08s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking| =======                             |search_depth: 32 || bfgs_steps: 21
# Perform docking|       =======                       |search_depth: 32 || bfgs_steps: 22
#   ⏱ 46m23s | ✓ 563 merged | GPU: 100, 32757, 81920 | Orai1WT-MDSnap-Fr400_cleaned sub 1/2 | 0/592 (0%)
# Perform docking|             =======                 |search_depth: 32 || bfgs_steps: 17
# Perform docking|               =======               |search_depth: 32 || bfgs_steps: 21
# Perform docking|                    =======          |search_depth: 32 || bfgs_steps: 17
# Perform docking|                       =======       |search_depth: 32 || bfgs_steps: 18
# ...
#   LK4_ideal                                | Combos:   4 | Poses:   40
#   LMU_ideal                                | Combos:   4 | Poses:   40
#   LPE_ideal                                | Combos:   4 | Poses:   40
#   LPS_ideal                                | Combos:   4 | Poses:   40
#   LTD_ideal                                | Combos:   4 | Poses:   40
#   LTX_ideal                                | Combos:   4 | Poses:   40
#   LVO_ideal                                | Combos:   4 | Poses:   40
#   LYB_ideal                                | Combos:   4 | Poses:   40
#   MA4_ideal                                | Combos:   4 | Poses:   40
#   MAY_ideal                                | Combos:   4 | Poses:   40
#   MCA_ideal                                | Combos:   4 | Poses:   40
#   MCN_ideal                                | Combos:   4 | Poses:   40
#   MDE_ideal                                | Combos:   4 | Poses:   40
#   MGE_ideal                                | Combos:   4 | Poses:   40
#   MGM_ideal                                | Combos:   4 | Poses:   40
#   MIM_ideal                                | Combos:   4 | Poses:   40
#   MJV_ideal                                | Combos:   4 | Poses:   40
#   MK1_ideal                                | Combos:   4 | Poses:   40
#   MK6_ideal                                | Combos:   4 | Poses:   40
#   MLC_ideal                                | Combos:   4 | Poses:   40
#   MLD_ideal                                | Combos:   4 | Poses:   40
#   MMI_ideal                                | Combos:   4 | Poses:   40
#   MPG_ideal                                | Combos:   4 | Poses:   40
#   MPZ_ideal                                | Combos:   4 | Poses:   40
#   MQ7_ideal                                | Combos:   4 | Poses:   40
#   MRC_ideal                                | Combos:   4 | Poses:   40
#   MS1_ideal                                | Combos:   4 | Poses:   40
#   MS3_ideal                                | Combos:   4 | Poses:   40
#   MWV_ideal                                | Combos:   4 | Poses:   40
#   MXP_ideal                                | Combos:   4 | Poses:   40
#   MYA_ideal                                | Combos:   4 | Poses:   40
#   MYP_ideal                                | Combos:   4 | Poses:   40
#   MYX_ideal                                | Combos:   4 | Poses:   40
#   N3C_ideal                                | Combos:   4 | Poses:   40
#   N7R_ideal                                | Combos:   4 | Poses:   40
#   N8E_ideal                                | Combos:   4 | Poses:   40
#   NAD_ideal                                | Combos:   4 | Poses:   40
#   NAE_ideal                                | Combos:   4 | Poses:   40
#   NAI_ideal                                | Combos:   4 | Poses:   40
#   NAJ_ideal                                | Combos:   4 | Poses:   38
#   NAP_ideal                                | Combos:   4 | Poses:   40
#   NAQ_ideal                                | Combos:   4 | Poses:   40
#   NBC_ideal                                | Combos:   4 | Poses:   40
#   NBP_ideal                                | Combos:   4 | Poses:   40
#   NDA_ideal                                | Combos:   4 | Poses:   40
#   NDC_ideal                                | Combos:   4 | Poses:   40
#   NDP_ideal                                | Combos:   4 | Poses:   40
#   NE6_ideal                                | Combos:   4 | Poses:   40
#   NHM_ideal                                | Combos:   4 | Poses:   40
#   NHO_ideal                                | Combos:   4 | Poses:   40
#   NMX_ideal                                | Combos:   4 | Poses:   40
#   NOV_ideal                                | Combos:   4 | Poses:   40
#   NTU_ideal                                | Combos:   4 | Poses:   40
#   NXX_ideal                                | Combos:   4 | Poses:   40
#   NZQ_ideal                                | Combos:   4 | Poses:   40
#   O8N_ideal                                | Combos:   4 | Poses:   40
#   ODD_ideal                                | Combos:   4 | Poses:   40
#   ODT_ideal                                | Combos:   4 | Poses:   40
#   OFF_ideal                                | Combos:   4 | Poses:   40
#   OHH_ideal                                | Combos:   4 | Poses:   37
#   OHM_ideal                                | Combos:   4 | Poses:   40
#   OHN_ideal                                | Combos:   4 | Poses:   40
#   OKA_ideal                                | Combos:   4 | Poses:   40
#   P0E_ideal                                | Combos:   4 | Poses:   40
#   P1L_ideal                                | Combos:   4 | Poses:   40
#   P30_ideal                                | Combos:   4 | Poses:   40
#   P40_ideal                                | Combos:   4 | Poses:   40
#   P48_ideal                                | Combos:   4 | Poses:   40
#   P5B_ideal                                | Combos:   4 | Poses:   40
#   P5S_ideal                                | Combos:   4 | Poses:   40
#   P89_ideal                                | Combos:   4 | Poses:   40
#   PAD_ideal                                | Combos:   4 | Poses:   40
#   PCF_ideal                                | Combos:   4 | Poses:   40
#   PCM_ideal                                | Combos:   4 | Poses:   40
#   PCW_ideal                                | Combos:   4 | Poses:   40
#   PD7_ideal                                | Combos:   4 | Poses:   40
#   PE5_ideal                                | Combos:   4 | Poses:   40
#   PE7_ideal                                | Combos:   4 | Poses:   40
#   PEE_ideal                                | Combos:   4 | Poses:   40
#   PEF_ideal                                | Combos:   4 | Poses:   40
#   PFS_ideal                                | Combos:   4 | Poses:   40
#   PGM_ideal                                | Combos:   4 | Poses:   40
#   PIE_ideal                                | Combos:   4 | Poses:   40
#   PKF_ideal                                | Combos:   4 | Poses:   40
#   PL3_ideal                                | Combos:   4 | Poses:   40
#   PLC_ideal                                | Combos:   4 | Poses:   40
#   PLM_ideal                                | Combos:   4 | Poses:   40
#   PM4_ideal                                | Combos:   4 | Poses:   40
#   PM5_ideal                                | Combos:   4 | Poses:   40
#   PNF_ideal                                | Combos:   4 | Poses:   40
#   PNT_ideal                                | Combos:   4 | Poses:   40
#   PPX_ideal                                | Combos:   4 | Poses:   40
#   PQN_ideal                                | Combos:   4 | Poses:   40
#   PRT_ideal                                | Combos:   4 | Poses:   40
#   PSI_ideal                                | Combos:   4 | Poses:   40
#   PTG_ideal                                | Combos:   4 | Poses:   40
#   PUA_ideal                                | Combos:   4 | Poses:   40
#   PVC_ideal                                | Combos:   4 | Poses:   40
#   Q8U_ideal                                | Combos:   4 | Poses:   40
#   QCM_ideal                                | Combos:   4 | Poses:   40
#   QDH_ideal                                | Combos:   4 | Poses:   40
#   QFC_ideal                                | Combos:   4 | Poses:   40
#   QO4_ideal                                | Combos:   4 | Poses:   40
#   QWP_ideal                                | Combos:   4 | Poses:    0
#   R03_ideal                                | Combos:   4 | Poses:   40
#   R0Z_ideal                                | Combos:   4 | Poses:   40
#   R19_ideal                                | Combos:   4 | Poses:   40
#   R1H_ideal                                | Combos:   4 | Poses:   40
#   R1L_ideal                                | Combos:   4 | Poses:   40
#   R64_ideal                                | Combos:   4 | Poses:   40
#   R71_ideal                                | Combos:   4 | Poses:   40
#   R78_ideal                                | Combos:   4 | Poses:   40
#   R79_ideal                                | Combos:   4 | Poses:   40
#   RA4_ideal                                | Combos:   4 | Poses:   40
#   RA8_ideal                                | Combos:   4 | Poses:   40
#   RAP_ideal                                | Combos:   4 | Poses:   40
#   RCL_ideal                                | Combos:   4 | Poses:   40
#   RD8_ideal                                | Combos:   4 | Poses:   40
#   RFL_ideal                                | Combos:   4 | Poses:   40
#   RGA_ideal                                | Combos:   4 | Poses:    0
#   RGC_ideal                                | Combos:   4 | Poses:   40
#   RIF_ideal                                | Combos:   4 | Poses:   40
#   RIT_ideal                                | Combos:   4 | Poses:   40
#   ROC_ideal                                | Combos:   4 | Poses:   40
#   RR6_ideal                                | Combos:   4 | Poses:    0
#   RRX_ideal                                | Combos:   4 | Poses:   40
#   RXD_ideal                                | Combos:   4 | Poses:   40
#   RXP_ideal                                | Combos:   4 | Poses:   39
#   RYO_ideal                                | Combos:   4 | Poses:   40
#   RYW_ideal                                | Combos:   4 | Poses:   40
#   S1H_ideal                                | Combos:   4 | Poses:   40
#   S4R_ideal                                | Combos:   4 | Poses:   40
#   SCA_ideal                                | Combos:   4 | Poses:   40
#   SCO_ideal                                | Combos:   4 | Poses:   40
#   SDZ_ideal                                | Combos:   4 | Poses:   40
#   SEI_ideal                                | Combos:   4 | Poses:   40
#   SFA_ideal                                | Combos:   4 | Poses:    0
#   SFP_ideal                                | Combos:   4 | Poses:   40
#   SFT_ideal                                | Combos:   4 | Poses:    0
#   SNA_ideal                                | Combos:   4 | Poses:   40
#   SND_ideal                                | Combos:   4 | Poses:   40
#   SPF_ideal                                | Combos:   4 | Poses:   40
#   SPR_ideal                                | Combos:   4 | Poses:   40
#   SPX_ideal                                | Combos:   4 | Poses:    0
#   SQL_ideal                                | Combos:   4 | Poses:   40
#   SQS_ideal                                | Combos:   4 | Poses:   40
#   SS4_ideal                                | Combos:   4 | Poses:   40
#   STE_ideal                                | Combos:   4 | Poses:   40
#   STI_ideal                                | Combos:   4 | Poses:   40
#   SUD_ideal                                | Combos:   4 | Poses:   40
#   SVR_ideal                                | Combos:   4 | Poses:    0
#   SXH_ideal                                | Combos:   4 | Poses:   40
#   SXO_ideal                                | Combos:   4 | Poses:   40
#   T3X_ideal                                | Combos:   4 | Poses:   40
#   T4T_ideal                                | Combos:   4 | Poses:   40
#   T57_ideal                                | Combos:   4 | Poses:   40
#   T5A_ideal                                | Combos:   4 | Poses:   40
#   T87_ideal                                | Combos:   4 | Poses:   40
#   TAP_ideal                                | Combos:   4 | Poses:   40
#   TCH_ideal                                | Combos:   4 | Poses:   37
#   TD2_ideal                                | Combos:   4 | Poses:   40
#   TDT_ideal                                | Combos:   4 | Poses:    0
#   TEL_ideal                                | Combos:   4 | Poses:   40
#   TF3_ideal                                | Combos:   4 | Poses:   40
#   TGF_ideal                                | Combos:   4 | Poses:   40
#   THT_ideal                                | Combos:   4 | Poses:   40
#   TR1_ideal                                | Combos:   4 | Poses:   40
#   TS4_ideal                                | Combos:   4 | Poses:   40
#   TS5_ideal                                | Combos:   4 | Poses:   40
#   TUD_ideal                                | Combos:   4 | Poses:   40
#   TUI_ideal                                | Combos:   4 | Poses:   40
#   TUX_ideal                                | Combos:   4 | Poses:   40
#   TYK_ideal                                | Combos:   4 | Poses:   40
#   TZ4_ideal                                | Combos:   4 | Poses:   40
#   TZ5_ideal                                | Combos:   4 | Poses:   40
#   U04_ideal                                | Combos:   4 | Poses:   40
#   U10_ideal                                | Combos:   4 | Poses:   40
#   UAG_ideal                                | Combos:   4 | Poses:   40
#   UDH_ideal                                | Combos:   4 | Poses:   40
#   UK4_ideal                                | Combos:   4 | Poses:   40
#   UKA_ideal                                | Combos:   4 | Poses:   40
#   ULA_ideal                                | Combos:   4 | Poses:   40
#   UMA_ideal                                | Combos:   4 | Poses:   40
#   UMG_ideal                                | Combos:   4 | Poses:   40
#   UMQ_ideal                                | Combos:   4 | Poses:   40
#   UP5_ideal                                | Combos:   4 | Poses:   40
#   UR2_ideal                                | Combos:   4 | Poses:   40
#   V6G_ideal                                | Combos:   4 | Poses:   40
#   VCA_ideal                                | Combos:   4 | Poses:   40
#   VIV_ideal                                | Combos:   4 | Poses:   40
#   VL1_ideal                                | Combos:   4 | Poses:   40
#   VS2_ideal                                | Combos:   4 | Poses:   40
#   VTQ_ideal                                | Combos:   4 | Poses:   40
#   VXI_ideal                                | Combos:   4 | Poses:   40
#   W42_ideal                                | Combos:   4 | Poses:   40
#   W43_ideal                                | Combos:   4 | Poses:   40
#   W56_ideal                                | Combos:   4 | Poses:   40
#   W59_ideal                                | Combos:   4 | Poses:   40
#   W71_ideal                                | Combos:   4 | Poses:   40
#   W8R_ideal                                | Combos:   4 | Poses:   40
#   WVN_ideal                                | Combos:   4 | Poses:   40
#   X2N_ideal                                | Combos:   4 | Poses:   40
#   X4U_ideal                                | Combos:   4 | Poses:   40
#   XAT_ideal                                | Combos:   4 | Poses:   40
#   XB7_ideal                                | Combos:   4 | Poses:   40
#   XC9_ideal                                | Combos:   4 | Poses:   40
#   XIN_ideal                                | Combos:   4 | Poses:   37
#   XMJ_ideal                                | Combos:   4 | Poses:   40
#   XNH_ideal                                | Combos:   4 | Poses:   40
#   XPG_ideal                                | Combos:   4 | Poses:   40
#   XR1_ideal                                | Combos:   4 | Poses:   33
#   Y9J_ideal                                | Combos:   4 | Poses:   40
#   YG7_ideal                                | Combos:   4 | Poses:   40
#   YHR_ideal                                | Combos:   4 | Poses:   40
#   YIS_ideal                                | Combos:   4 | Poses:   40
#   YKQ_ideal                                | Combos:   4 | Poses:   40
#   YMA_ideal                                | Combos:   4 | Poses:   40
#   Z6V_ideal                                | Combos:   4 | Poses:   40
#   Z90_ideal                                | Combos:   4 | Poses:   40
#   ZIY_ideal                                | Combos:   4 | Poses:    0
#
# Summary saved: /workspace/vina_results/combined_meeko/docking_summary.json
#
# ================================================================================
# ALL DONE (Meeko / Vina-CUDA) — 2368 total results from 1 ligand directories combined
# ================================================================================

# %% [markdown]
# # Results

# %%
# Combine all results for display — handle case when MGL-Tools docking is skipped
all_vina_results = all_vina_results if 'all_vina_results' in dir() else []
all_combined_results = all_vina_results + all_vina_results_meeko

results_data = []
for r in all_combined_results:
    results_data.append({ 
        "protein": r.protein_name,
        "ligand": r.ligand_name,
        "status": r.status,
        "num_poses": r.num_poses,
        "best_affinity_kcal": r.best_affinity,
        "elapsed_time_s": round(r.elapsed_time, 2),
        "output_dir": str(r.output_dir),
    })

results_df_all = pd.DataFrame(results_data)

print("=" * 80)
print("VINA-GPU DOCKING RESULTS DATAFRAME")
print("=" * 80)
print(f"\nTotal combinations: {len(results_df_all)}")

if not results_df_all.empty:
    print("\nStatus breakdown:")
    print(results_df_all['status'].value_counts().to_string())
    print(f"\nAffinity statistics (successful dockings):")
    success = results_df_all[results_df_all['status'] == 'success']
    if not success.empty and success['best_affinity_kcal'].notna().any():
        print(f"  Mean best affinity: {success['best_affinity_kcal'].mean():.2f} kcal/mol")
        print(f"  Min (best): {success['best_affinity_kcal'].min():.2f} kcal/mol")
        print(f"  Max (worst): {success['best_affinity_kcal'].max():.2f} kcal/mol")
    print(f"\nTiming statistics:")
    docked = results_df_all[results_df_all['status'].isin(['success', 'failed'])]
    if not docked.empty:
        print(f"  Mean time per complex: {docked['elapsed_time_s'].mean():.1f}s")
        print(f"  Total time: {docked['elapsed_time_s'].sum():.1f}s ({docked['elapsed_time_s'].sum()/60:.1f} min)")

display(results_df_all)

# Save combined results CSV
combined_csv = VINA_OUTPUT_BASE / "vina_gpu_combined_results.csv"
results_df_all.to_csv(combined_csv, index=False)
print(f"\nCombined results saved: {combined_csv}")
# Out:
# ================================================================================
# VINA-GPU DOCKING RESULTS DATAFRAME
# ================================================================================
#
# Total combinations: 2368
#
# Status breakdown:
# status
# success    2252
# failed      116
#
# Affinity statistics (successful dockings):
#   Mean best affinity: -7.63 kcal/mol
#   Min (best): -13.40 kcal/mol
#   Max (worst): -3.90 kcal/mol
#
# Timing statistics:
#   Mean time per complex: 18.5s
#   Total time: 43873.1s (731.2 min)
#                            protein     ligand   status  num_poses  \
# 0     Orai1WT-MDSnap-Fr300_cleaned  05J_ideal  success         10
# 1     Orai1WT-MDSnap-Fr300_cleaned  07J_ideal  success         10
# 2     Orai1WT-MDSnap-Fr300_cleaned  0LI_ideal  success         10
# 3     Orai1WT-MDSnap-Fr300_cleaned  10A_ideal  success         10
# 4     Orai1WT-MDSnap-Fr300_cleaned  11U_ideal  success         10
# ...                            ...        ...      ...        ...
# 2363     Orai1WT-START-Fr0_cleaned  YKQ_ideal  success         10
# 2364     Orai1WT-START-Fr0_cleaned  YMA_ideal  success         10
# 2365     Orai1WT-START-Fr0_cleaned  Z6V_ideal  success         10
# 2366     Orai1WT-START-Fr0_cleaned  Z90_ideal  success         10
# 2367     Orai1WT-START-Fr0_cleaned  ZIY_ideal   failed          0
#
#       best_affinity_kcal  elapsed_time_s  \
# 0                   -8.7            0.28
# 1                   -7.7            0.28
# 2                  -10.3            0.28
# 3                   -5.3            0.28
# 4                   -8.5            0.28
# ...                  ...             ...
# 2363               -10.7           24.57
# 2364                -5.4           24.57
# 2365                -8.8           24.57
# 2366               -10.7           24.57
# 2367                 NaN           24.57
#
#                                              output_dir
# 0     /workspace/master_dev/docking_ready_meeko/docking
# 1     /workspace/master_dev/docking_ready_meeko/docking
# 2     /workspace/master_dev/docking_ready_meeko/docking
# 3     /workspace/master_dev/docking_ready_meeko/docking
# 4     /workspace/master_dev/docking_ready_meeko/docking
# ...                                                 ...
# 2363  /workspace/master_dev/docking_ready_meeko/docking
# 2364  /workspace/master_dev/docking_ready_meeko/docking
# 2365  /workspace/master_dev/docking_ready_meeko/docking
# 2366  /workspace/master_dev/docking_ready_meeko/docking
# 2367  /workspace/master_dev/docking_ready_meeko/docking
#
# [2368 rows x 7 columns]
# Combined results saved: /workspace/vina_results/vina_gpu_combined_results.csv

# %% [markdown]
# # Docking Log

# %%
# Display the docking log for the last output directory
for drugs_dir in drugs_dirs:
    for suffix in [drugs_dir.name, drugs_dir.name + "_meeko"]:
        log_dir_check = VINA_OUTPUT_BASE / suffix
        log_path = log_dir_check / DOCKING_LOG_FILENAME

        if not log_path.exists():
            continue

        docking_log_df = pd.read_csv(log_path)

        print("=" * 80)
        print(f"DOCKING LOG: {log_dir_check.name}")
        print("=" * 80)
        print(f"\nLog file: {log_path}")
        print(f"Total entries: {len(docking_log_df)}")

        # Status breakdown
        status_counts = docking_log_df["status"].value_counts()
        print(f"\nStatus breakdown:")
        for status, count in status_counts.items():
            print(f"  {status}: {count}")

        # Show failed entries with reasons
        failed = docking_log_df[docking_log_df["status"] == "failed"]
        if not failed.empty:
            print(f"\n{'─' * 80}")
            print(f"FAILED DOCKINGS ({len(failed)}):")
            print(f"{'─' * 80}")
            for _, row in failed.iterrows():
                reason = row["error_reason"][:120] if pd.notna(row["error_reason"]) else "unknown"
                print(f"  ✗ {row['combo_name']}: {reason}")

        # Ligand property summary
        lig_cols = [c for c in ["ligand_name", "lig_molecular_weight", "lig_heavy_atoms", "lig_total_atoms",
                    "lig_rotatable_bonds", "lig_num_rings", "lig_aromatic_rings",
                    "lig_hbd", "lig_hba", "lig_tpsa", "lig_logp", "lig_formula"] if c in docking_log_df.columns]
        if lig_cols:
            lig_summary = docking_log_df[lig_cols].drop_duplicates(subset=["ligand_name"]).sort_values("ligand_name")
            print(f"\n{'─' * 80}")
            print("LIGAND PROPERTIES:")
            print(f"{'─' * 80}")
            display(lig_summary.reset_index(drop=True))

        # Protein property summary
        prot_cols = [c for c in ["protein_name", "prot_num_residues", "prot_num_atoms", "prot_num_chains"] if c in docking_log_df.columns]
        if prot_cols:
            prot_summary = docking_log_df[prot_cols].drop_duplicates(subset=["protein_name"]).sort_values("protein_name")
            print(f"\n{'─' * 80}")
            print("PROTEIN PROPERTIES:")
            print(f"{'─' * 80}")
            display(prot_summary.reset_index(drop=True))

        # Timing summary
        docked = docking_log_df[docking_log_df["status"].isin(["success", "failed"])]
        if not docked.empty and "elapsed_time_s" in docked.columns:
            print(f"\n{'─' * 80}")
            print("TIMING:")
            print(f"{'─' * 80}")
            print(f"  Mean time per complex: {docked['elapsed_time_s'].mean():.1f}s")
            print(f"  Max time: {docked['elapsed_time_s'].max():.1f}s")
            print(f"  Total: {docked['elapsed_time_s'].sum():.1f}s ({docked['elapsed_time_s'].sum()/60:.1f} min)")

        # Affinity summary
        if "best_affinity_kcal" in docking_log_df.columns:
            success_log = docking_log_df[docking_log_df["status"] == "success"]
            if not success_log.empty and success_log["best_affinity_kcal"].notna().any():
                print(f"\n{'─' * 80}")
                print("AFFINITY:")
                print(f"{'─' * 80}")
                print(f"  Mean best affinity: {success_log['best_affinity_kcal'].mean():.2f} kcal/mol")
                print(f"  Best (most negative): {success_log['best_affinity_kcal'].min():.2f} kcal/mol")
                print(f"  Worst: {success_log['best_affinity_kcal'].max():.2f} kcal/mol")

        print()

# %%
import importlib
import Scripts.compare_meeko_mgltools_docking

importlib.reload(Scripts.compare_meeko_mgltools_docking)

cdt = Scripts.compare_meeko_mgltools_docking.CompareDockingTools(
    meeko_dir=output_folder_meeko / "docking",  # Make sure this path points to where the log files are
    mgltools_dir=output_folder_mgltools / "docking",
    output_dir=wd / "docking_comparison",
)
cdt.analyze()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 8
#       2 import Scripts.compare_meeko_mgltools_docking
#       4 importlib.reload(Scripts.compare_meeko_mgltools_docking)
#       6 cdt = Scripts.compare_meeko_mgltools_docking.CompareDockingTools(
#       7     meeko_dir=output_folder_meeko / "docking",  # Make sure this path points to where the log files are
# ----> 8     mgltools_dir=output_folder_mgltools / "docking",
#       9     output_dir=wd / "docking_comparison",
#      10 )
#      11 cdt.analyze()
#
# NameError: name 'output_folder_mgltools' is not defined

# %%
"""
Compare docked poses from MGLTools vs Meeko using RMSD calculation.
Calculates RMSD between best poses for each protein-ligand pair.
"""
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path

# Directories
MEEKO_DOCKING_DIR = Path(wd / "docking_ready_meeko/docking")
MGLTOOLS_DOCKING_DIR = Path(wd / "docking_ready_mgltools/docking")

def parse_pdbqt_poses(pdbqt_path):
    """Parse a multi-model PDBQT file and extract coordinates for each pose."""
    poses = []
    
    if not pdbqt_path.exists():
        return poses
    
    with open(pdbqt_path, 'r') as f:
        content = f.read()
    
    # Split by MODEL/ENDMDL
    models = re.split(r'MODEL\s+\d+', content)
    
    for model in models:
        if not model.strip():
            continue
        
        atoms = []
        atom_names = []
        
        for line in model.split('\n'):
            if line.startswith('ATOM') or line.startswith('HETATM'):
                try:
                    x = float(line[30:38].strip())
                    y = float(line[38:46].strip())
                    z = float(line[46:54].strip())
                    atom_name = line[12:16].strip()
                    atoms.append([x, y, z])
                    atom_names.append(atom_name)
                except (ValueError, IndexError):
                    continue
        
        if atoms:
            poses.append({
                'coords': np.array(atoms),
                'atom_names': atom_names,
                'num_atoms': len(atoms)
            })
    
    return poses


def calculate_rmsd(coords1, coords2):
    """Calculate RMSD between two coordinate arrays."""
    if coords1.shape != coords2.shape:
        # Try to match by minimum atoms
        min_atoms = min(len(coords1), len(coords2))
        coords1 = coords1[:min_atoms]
        coords2 = coords2[:min_atoms]
    
    diff = coords1 - coords2
    rmsd = np.sqrt(np.mean(np.sum(diff**2, axis=1)))
    return rmsd


def calculate_rmsd_with_alignment(coords1, coords2):
    """Calculate RMSD with Kabsch alignment (optimal superposition)."""
    if coords1.shape != coords2.shape:
        min_atoms = min(len(coords1), len(coords2))
        coords1 = coords1[:min_atoms]
        coords2 = coords2[:min_atoms]
    
    # Center both structures
    centroid1 = np.mean(coords1, axis=0)
    centroid2 = np.mean(coords2, axis=0)
    coords1_centered = coords1 - centroid1
    coords2_centered = coords2 - centroid2
    
    # Kabsch algorithm for optimal rotation
    H = coords1_centered.T @ coords2_centered
    U, S, Vt = np.linalg.svd(H)
    
    # Handle reflection case
    d = np.sign(np.linalg.det(Vt.T @ U.T))
    D = np.diag([1, 1, d])
    
    R = Vt.T @ D @ U.T
    coords2_aligned = coords2_centered @ R
    
    # Calculate RMSD
    diff = coords1_centered - coords2_aligned
    rmsd = np.sqrt(np.mean(np.sum(diff**2, axis=1)))
    return rmsd


def get_normalized_protein_name(name):
    """Normalize protein name by removing _retry1 suffix."""
    return name.replace('_retry1', '')


# Collect all docked pose files
meeko_files = {f.stem.replace('_vina_out', ''): f 
               for f in MEEKO_DOCKING_DIR.glob('*_vina_out.pdbqt')}
mgltools_files = {f.stem.replace('_vina_out', ''): f 
                  for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.pdbqt')}

print(f"Found {len(meeko_files)} Meeko docked poses")
print(f"Found {len(mgltools_files)} MGLTools docked poses")
print()

# Create mapping with normalized protein names
meeko_normalized = {}
for key, path in meeko_files.items():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        meeko_normalized[(protein_norm, ligand)] = path

mgltools_normalized = {}
for key, path in mgltools_files.items():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        mgltools_normalized[(protein_norm, ligand)] = path

# Find common pairs
common_pairs = set(meeko_normalized.keys()) & set(mgltools_normalized.keys())
print(f"Common protein-ligand pairs for RMSD comparison: {len(common_pairs)}")
print()

# Calculate RMSD for each pair
results = []

print("=" * 100)
print("RMSD COMPARISON: MEEKO vs MGLTools DOCKED POSES")
print("=" * 100)
print()
print(f"{'Protein':<30} {'Ligand':<25} {'RMSD (Å)':>12} {'Aligned RMSD':>14} {'Atoms':>8}")
print("-" * 100)

for protein, ligand in sorted(common_pairs):
    meeko_path = meeko_normalized[(protein, ligand)]
    mgltools_path = mgltools_normalized[(protein, ligand)]
    
    # Parse poses (get best pose = first one)
    meeko_poses = parse_pdbqt_poses(meeko_path)
    mgltools_poses = parse_pdbqt_poses(mgltools_path)
    
    if not meeko_poses or not mgltools_poses:
        print(f"{protein:<30} {ligand:<25} {'N/A':>12} {'N/A':>14} {'N/A':>8}")
        continue
    
    # Compare best poses (mode 1)
    meeko_best = meeko_poses[0]
    mgltools_best = mgltools_poses[0]
    
    # Calculate RMSD (direct and aligned)
    try:
        rmsd_direct = calculate_rmsd(meeko_best['coords'], mgltools_best['coords'])
        rmsd_aligned = calculate_rmsd_with_alignment(meeko_best['coords'], mgltools_best['coords'])
        num_atoms = min(meeko_best['num_atoms'], mgltools_best['num_atoms'])
        
        print(f"{protein:<30} {ligand:<25} {rmsd_direct:>12.3f} {rmsd_aligned:>14.3f} {num_atoms:>8}")
        
        results.append({
            'protein': protein,
            'ligand': ligand,
            'rmsd_direct': rmsd_direct,
            'rmsd_aligned': rmsd_aligned,
            'meeko_atoms': meeko_best['num_atoms'],
            'mgltools_atoms': mgltools_best['num_atoms'],
            'atoms_compared': num_atoms
        })
    except Exception as e:
        print(f"{protein:<30} {ligand:<25} {'Error':>12} {str(e)[:14]:>14}")

print()

# Summary statistics
if results:
    df_rmsd = pd.DataFrame(results)
    
    print("=" * 100)
    print("RMSD SUMMARY STATISTICS")
    print("=" * 100)
    print()
    print(f"Total pairs compared: {len(df_rmsd)}")
    print()
    print("Direct RMSD (without alignment):")
    print(f"  Mean:   {df_rmsd['rmsd_direct'].mean():.3f} Å")
    print(f"  Median: {df_rmsd['rmsd_direct'].median():.3f} Å")
    print(f"  Min:    {df_rmsd['rmsd_direct'].min():.3f} Å")
    print(f"  Max:    {df_rmsd['rmsd_direct'].max():.3f} Å")
    print(f"  Std:    {df_rmsd['rmsd_direct'].std():.3f} Å")
    print()
    print("Aligned RMSD (with Kabsch superposition):")
    print(f"  Mean:   {df_rmsd['rmsd_aligned'].mean():.3f} Å")
    print(f"  Median: {df_rmsd['rmsd_aligned'].median():.3f} Å")
    print(f"  Min:    {df_rmsd['rmsd_aligned'].min():.3f} Å")
    print(f"  Max:    {df_rmsd['rmsd_aligned'].max():.3f} Å")
    print(f"  Std:    {df_rmsd['rmsd_aligned'].std():.3f} Å")
    print()
    
    # Classification based on RMSD thresholds
    print("=" * 100)
    print("POSE SIMILARITY CLASSIFICATION (based on aligned RMSD)")
    print("=" * 100)
    print()
    very_similar = (df_rmsd['rmsd_aligned'] < 2.0).sum()
    similar = ((df_rmsd['rmsd_aligned'] >= 2.0) & (df_rmsd['rmsd_aligned'] < 4.0)).sum()
    different = (df_rmsd['rmsd_aligned'] >= 4.0).sum()
    
    print(f"Very similar poses (RMSD < 2.0 Å):     {very_similar} ({100*very_similar/len(df_rmsd):.1f}%)")
    print(f"Similar poses (2.0 Å ≤ RMSD < 4.0 Å): {similar} ({100*similar/len(df_rmsd):.1f}%)")
    print(f"Different poses (RMSD ≥ 4.0 Å):       {different} ({100*different/len(df_rmsd):.1f}%)")
    print()
    
    # Group by ligand
    print("=" * 100)
    print("RMSD BY LIGAND")
    print("=" * 100)
    print()
    for ligand in df_rmsd['ligand'].unique():
        ligand_data = df_rmsd[df_rmsd['ligand'] == ligand]
        print(f"Ligand: {ligand}")
        print(f"  Mean aligned RMSD: {ligand_data['rmsd_aligned'].mean():.3f} Å")
        print(f"  Range: {ligand_data['rmsd_aligned'].min():.3f} - {ligand_data['rmsd_aligned'].max():.3f} Å")
        print()
    
    # Save results
    output_csv = wdlogs / "meeko_vs_mgltools_rmsd_comparison.csv"
    df_rmsd.to_csv(output_csv, index=False)
    print(f"RMSD comparison saved to: {output_csv}")
    
    # Display DataFrame
    display(df_rmsd)

# %%
"""
Comprehensive overview of docked positions for each protein-ligand pair
from both MGLTools and Meeko conversion methods.
"""
import os
import re
import numpy as np
import pandas as pd
from pathlib import Path

# Directories
MEEKO_DOCKING_DIR = Path(wd / "docking_ready_meeko/docking")
MGLTOOLS_DOCKING_DIR = Path(wd / "docking_ready_mgltools/docking")

def parse_vina_log(log_path):
    """Parse Vina log file to get affinity scores for all modes."""
    results = {'modes': []}
    if not log_path.exists():
        return results
    
    with open(log_path, 'r') as f:
        content = f.read()
    
    mode_pattern = r'^\s*(\d+)\s+([-\d.]+)\s+([\d.]+)\s+([\d.]+)\s*$'
    modes = re.findall(mode_pattern, content, re.MULTILINE)
    
    for mode in modes:
        mode_num, affinity, rmsd_lb, rmsd_ub = mode
        results['modes'].append({
            'mode': int(mode_num),
            'affinity': float(affinity),
            'rmsd_lb': float(rmsd_lb),
            'rmsd_ub': float(rmsd_ub)
        })
    return results

def parse_pdbqt_poses(pdbqt_path):
    """Parse PDBQT file to get coordinates and centroid for each pose."""
    poses = []
    if not pdbqt_path.exists():
        return poses
    
    with open(pdbqt_path, 'r') as f:
        content = f.read()
    
    models = re.split(r'MODEL\s+\d+', content)
    
    for model in models:
        if not model.strip():
            continue
        
        atoms = []
        for line in model.split('\n'):
            if line.startswith('ATOM') or line.startswith('HETATM'):
                try:
                    x = float(line[30:38].strip())
                    y = float(line[38:46].strip())
                    z = float(line[46:54].strip())
                    atoms.append([x, y, z])
                except (ValueError, IndexError):
                    continue
        
        if atoms:
            coords = np.array(atoms)
            centroid = np.mean(coords, axis=0)
            poses.append({
                'coords': coords,
                'centroid': centroid,
                'num_atoms': len(atoms),
                'min_coords': coords.min(axis=0),
                'max_coords': coords.max(axis=0)
            })
    
    return poses

def get_normalized_protein_name(name):
    """Normalize protein name by removing _retry1 suffix."""
    return name.replace('_retry1', '')

# Collect files
meeko_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.pdbqt')}
meeko_logs = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.log')}
mgltools_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.pdbqt')}
mgltools_logs = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.log')}

# Create normalized mappings
meeko_normalized = {}
for key in meeko_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        meeko_normalized[(protein_norm, ligand)] = key

mgltools_normalized = {}
for key in mgltools_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        mgltools_normalized[(protein_norm, ligand)] = key

# Find common pairs
common_pairs = set(meeko_normalized.keys()) & set(mgltools_normalized.keys())

print("=" * 120)
print("COMPREHENSIVE OVERVIEW: DOCKED POSITIONS FOR EACH PROTEIN-LIGAND PAIR")
print("=" * 120)
print()

all_data = []

for protein, ligand in sorted(common_pairs):
    print("=" * 120)
    print(f"PROTEIN: {protein}  |  LIGAND: {ligand}")
    print("=" * 120)
    
    # Get file keys
    meeko_key = meeko_normalized[(protein, ligand)]
    mgltools_key = mgltools_normalized[(protein, ligand)]
    
    # Parse poses
    meeko_poses = parse_pdbqt_poses(meeko_pdbqt[meeko_key])
    mgltools_poses = parse_pdbqt_poses(mgltools_pdbqt[mgltools_key])
    
    # Parse logs for affinities
    meeko_log = parse_vina_log(meeko_logs.get(meeko_key, Path('')))
    mgltools_log = parse_vina_log(mgltools_logs.get(mgltools_key, Path('')))
    
    print()
    print(f"{'Mode':<6} {'Method':<10} {'Affinity':>10} {'Centroid X':>12} {'Centroid Y':>12} {'Centroid Z':>12} {'Atoms':>8}")
    print("-" * 80)
    
    # Display up to 9 modes for each method
    max_modes = min(9, max(len(meeko_poses), len(mgltools_poses)))
    
    for mode_idx in range(max_modes):
        # MGLTools pose
        if mode_idx < len(mgltools_poses):
            mgl_pose = mgltools_poses[mode_idx]
            mgl_affinity = mgltools_log['modes'][mode_idx]['affinity'] if mode_idx < len(mgltools_log['modes']) else None
            aff_str = f"{mgl_affinity:.3f}" if mgl_affinity else "N/A"
            print(f"{mode_idx+1:<6} {'MGLTools':<10} {aff_str:>10} {mgl_pose['centroid'][0]:>12.3f} {mgl_pose['centroid'][1]:>12.3f} {mgl_pose['centroid'][2]:>12.3f} {mgl_pose['num_atoms']:>8}")
            
            all_data.append({
                'protein': protein,
                'ligand': ligand,
                'mode': mode_idx + 1,
                'method': 'MGLTools',
                'affinity': mgl_affinity,
                'centroid_x': mgl_pose['centroid'][0],
                'centroid_y': mgl_pose['centroid'][1],
                'centroid_z': mgl_pose['centroid'][2],
                'min_x': mgl_pose['min_coords'][0],
                'min_y': mgl_pose['min_coords'][1],
                'min_z': mgl_pose['min_coords'][2],
                'max_x': mgl_pose['max_coords'][0],
                'max_y': mgl_pose['max_coords'][1],
                'max_z': mgl_pose['max_coords'][2],
                'num_atoms': mgl_pose['num_atoms']
            })
        
        # Meeko pose
        if mode_idx < len(meeko_poses):
            meeko_pose = meeko_poses[mode_idx]
            meeko_affinity = meeko_log['modes'][mode_idx]['affinity'] if mode_idx < len(meeko_log['modes']) else None
            aff_str = f"{meeko_affinity:.3f}" if meeko_affinity else "N/A"
            print(f"{mode_idx+1:<6} {'Meeko':<10} {aff_str:>10} {meeko_pose['centroid'][0]:>12.3f} {meeko_pose['centroid'][1]:>12.3f} {meeko_pose['centroid'][2]:>12.3f} {meeko_pose['num_atoms']:>8}")
            
            all_data.append({
                'protein': protein,
                'ligand': ligand,
                'mode': mode_idx + 1,
                'method': 'Meeko',
                'affinity': meeko_affinity,
                'centroid_x': meeko_pose['centroid'][0],
                'centroid_y': meeko_pose['centroid'][1],
                'centroid_z': meeko_pose['centroid'][2],
                'min_x': meeko_pose['min_coords'][0],
                'min_y': meeko_pose['min_coords'][1],
                'min_z': meeko_pose['min_coords'][2],
                'max_x': meeko_pose['max_coords'][0],
                'max_y': meeko_pose['max_coords'][1],
                'max_z': meeko_pose['max_coords'][2],
                'num_atoms': meeko_pose['num_atoms']
            })
        
        # Calculate distance between centroids for this mode
        if mode_idx < len(mgltools_poses) and mode_idx < len(meeko_poses):
            dist = np.linalg.norm(mgltools_poses[mode_idx]['centroid'] - meeko_poses[mode_idx]['centroid'])
            print(f"       {'Δ Distance':<10} {dist:>10.3f} Å between centroids")
        print()
    
    # Summary for this pair
    if meeko_poses and mgltools_poses:
        best_meeko = meeko_log['modes'][0]['affinity'] if meeko_log['modes'] else None
        best_mgltools = mgltools_log['modes'][0]['affinity'] if mgltools_log['modes'] else None
        
        print(f"  SUMMARY:")
        print(f"    Best MGLTools affinity: {best_mgltools:.3f} kcal/mol" if best_mgltools else "    Best MGLTools affinity: N/A")
        print(f"    Best Meeko affinity:    {best_meeko:.3f} kcal/mol" if best_meeko else "    Best Meeko affinity: N/A")
        
        if best_meeko and best_mgltools:
            delta = best_meeko - best_mgltools
            better = "Meeko" if delta < 0 else "MGLTools"
            print(f"    Δ Affinity: {delta:+.3f} kcal/mol ({better} is better)")
        
        # Distance between best poses
        dist_best = np.linalg.norm(mgltools_poses[0]['centroid'] - meeko_poses[0]['centroid'])
        print(f"    Distance between best pose centroids: {dist_best:.3f} Å")
    print()

# Create DataFrame and display
df_overview = pd.DataFrame(all_data)

print("=" * 120)
print("SUMMARY TABLE: BEST POSES (MODE 1) COMPARISON")
print("=" * 120)
print()

# Pivot for easy comparison
df_best = df_overview[df_overview['mode'] == 1].copy()
df_pivot = df_best.pivot_table(
    index=['protein', 'ligand'],
    columns='method',
    values=['affinity', 'centroid_x', 'centroid_y', 'centroid_z'],
    aggfunc='first'
)

# Calculate centroid distance
comparison_summary = []
for (protein, ligand) in df_best.groupby(['protein', 'ligand']).groups.keys():
    mgl_row = df_best[(df_best['protein'] == protein) & (df_best['ligand'] == ligand) & (df_best['method'] == 'MGLTools')]
    meeko_row = df_best[(df_best['protein'] == protein) & (df_best['ligand'] == ligand) & (df_best['method'] == 'Meeko')]
    
    if len(mgl_row) > 0 and len(meeko_row) > 0:
        mgl = mgl_row.iloc[0]
        meeko = meeko_row.iloc[0]
        
        dist = np.sqrt((mgl['centroid_x'] - meeko['centroid_x'])**2 + 
                      (mgl['centroid_y'] - meeko['centroid_y'])**2 + 
                      (mgl['centroid_z'] - meeko['centroid_z'])**2)
        
        comparison_summary.append({
            'protein': protein,
            'ligand': ligand,
            'mgltools_affinity': mgl['affinity'],
            'meeko_affinity': meeko['affinity'],
            'affinity_delta': meeko['affinity'] - mgl['affinity'],
            'mgltools_centroid': f"({mgl['centroid_x']:.1f}, {mgl['centroid_y']:.1f}, {mgl['centroid_z']:.1f})",
            'meeko_centroid': f"({meeko['centroid_x']:.1f}, {meeko['centroid_y']:.1f}, {meeko['centroid_z']:.1f})",
            'centroid_distance': dist
        })

df_summary = pd.DataFrame(comparison_summary)
display(df_summary)

# Save detailed overview
output_csv = wdlogs / "docked_poses_overview.csv"
df_overview.to_csv(output_csv, index=False)
print(f"\nDetailed overview saved to: {output_csv}")

# %%
"""
Binding Pocket Analysis: Compare poses in the same binding pockets
Only compare MGLTools vs Meeko poses when they dock to similar locations.
"""
import re
import numpy as np
import pandas as pd
from pathlib import Path
from scipy.cluster.hierarchy import fcluster, linkage
from scipy.spatial.distance import pdist

# Directories
MEEKO_DOCKING_DIR = Path(wd / "docking_ready_meeko/docking")
MGLTOOLS_DOCKING_DIR = Path(wd / "docking_ready_mgltools/docking")

# Pocket clustering threshold (Angstroms) - poses within this distance are considered same pocket
POCKET_THRESHOLD = 10.0

def parse_vina_log(log_path):
    """Parse Vina log file to get affinity scores for all modes."""
    results = {'modes': []}
    if not log_path.exists():
        return results
    with open(log_path, 'r') as f:
        content = f.read()
    mode_pattern = r'^\s*(\d+)\s+([-\d.]+)\s+([\d.]+)\s+([\d.]+)\s*$'
    modes = re.findall(mode_pattern, content, re.MULTILINE)
    for mode in modes:
        mode_num, affinity, rmsd_lb, rmsd_ub = mode
        results['modes'].append({
            'mode': int(mode_num),
            'affinity': float(affinity),
            'rmsd_lb': float(rmsd_lb),
            'rmsd_ub': float(rmsd_ub)
        })
    return results

def parse_pdbqt_poses(pdbqt_path):
    """Parse PDBQT file to get coordinates and centroid for each pose."""
    poses = []
    if not pdbqt_path.exists():
        return poses
    with open(pdbqt_path, 'r') as f:
        content = f.read()
    models = re.split(r'MODEL\s+\d+', content)
    for model in models:
        if not model.strip():
            continue
        atoms = []
        for line in model.split('\n'):
            if line.startswith('ATOM') or line.startswith('HETATM'):
                try:
                    x = float(line[30:38].strip())
                    y = float(line[38:46].strip())
                    z = float(line[46:54].strip())
                    atoms.append([x, y, z])
                except (ValueError, IndexError):
                    continue
        if atoms:
            coords = np.array(atoms)
            centroid = np.mean(coords, axis=0)
            poses.append({
                'coords': coords,
                'centroid': centroid,
                'num_atoms': len(atoms)
            })
    return poses

def get_normalized_protein_name(name):
    return name.replace('_retry1', '')

def cluster_poses_by_pocket(all_centroids, threshold=POCKET_THRESHOLD):
    """Cluster poses into binding pockets based on centroid distance."""
    if len(all_centroids) <= 1:
        return [1] * len(all_centroids)
    
    centroids_array = np.array(all_centroids)
    distances = pdist(centroids_array)
    
    if len(distances) == 0:
        return [1] * len(all_centroids)
    
    linkage_matrix = linkage(distances, method='average')
    clusters = fcluster(linkage_matrix, t=threshold, criterion='distance')
    return clusters.tolist()

# Collect files
meeko_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.pdbqt')}
meeko_logs = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.log')}
mgltools_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.pdbqt')}
mgltools_logs = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.log')}

# Create normalized mappings
meeko_normalized = {}
for key in meeko_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        meeko_normalized[(protein_norm, ligand)] = key

mgltools_normalized = {}
for key in mgltools_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        mgltools_normalized[(protein_norm, ligand)] = key

# Find common pairs
common_pairs = set(meeko_normalized.keys()) & set(mgltools_normalized.keys())

print("=" * 120)
print("POSE COUNT OVERVIEW: MGLTools vs Meeko")
print("=" * 120)
print()
print(f"{'Protein':<25} {'Ligand':<25} {'MGLTools':>10} {'Meeko':>10} {'Total':>10}")
print("-" * 90)

pose_counts = []
for protein, ligand in sorted(common_pairs):
    meeko_key = meeko_normalized[(protein, ligand)]
    mgltools_key = mgltools_normalized[(protein, ligand)]
    
    meeko_poses = parse_pdbqt_poses(meeko_pdbqt[meeko_key])
    mgltools_poses = parse_pdbqt_poses(mgltools_pdbqt[mgltools_key])
    
    n_meeko = len(meeko_poses)
    n_mgltools = len(mgltools_poses)
    
    print(f"{protein:<25} {ligand:<25} {n_mgltools:>10} {n_meeko:>10} {n_mgltools + n_meeko:>10}")
    
    pose_counts.append({
        'protein': protein,
        'ligand': ligand,
        'mgltools_poses': n_mgltools,
        'meeko_poses': n_meeko,
        'total_poses': n_mgltools + n_meeko
    })

df_counts = pd.DataFrame(pose_counts)
print("-" * 90)
print(f"{'TOTAL':<25} {'':<25} {df_counts['mgltools_poses'].sum():>10} {df_counts['meeko_poses'].sum():>10} {df_counts['total_poses'].sum():>10}")
print()

# Binding pocket analysis
print("=" * 120)
print(f"BINDING POCKET ANALYSIS (clustering threshold: {POCKET_THRESHOLD} Å)")
print("=" * 120)
print()

pocket_analysis = []
detailed_pocket_data = []

for protein, ligand in sorted(common_pairs):
    meeko_key = meeko_normalized[(protein, ligand)]
    mgltools_key = mgltools_normalized[(protein, ligand)]
    
    meeko_poses = parse_pdbqt_poses(meeko_pdbqt[meeko_key])
    mgltools_poses = parse_pdbqt_poses(mgltools_pdbqt[mgltools_key])
    meeko_log = parse_vina_log(meeko_logs.get(meeko_key, Path('')))
    mgltools_log = parse_vina_log(mgltools_logs.get(mgltools_key, Path('')))
    
    # Combine all centroids for clustering
    all_centroids = []
    pose_info = []
    
    for i, pose in enumerate(mgltools_poses):
        all_centroids.append(pose['centroid'])
        affinity = mgltools_log['modes'][i]['affinity'] if i < len(mgltools_log['modes']) else None
        pose_info.append({'method': 'MGLTools', 'mode': i+1, 'affinity': affinity, 'centroid': pose['centroid']})
    
    for i, pose in enumerate(meeko_poses):
        all_centroids.append(pose['centroid'])
        affinity = meeko_log['modes'][i]['affinity'] if i < len(meeko_log['modes']) else None
        pose_info.append({'method': 'Meeko', 'mode': i+1, 'affinity': affinity, 'centroid': pose['centroid']})
    
    if not all_centroids:
        continue
    
    # Cluster into pockets
    clusters = cluster_poses_by_pocket(all_centroids)
    
    # Assign clusters to poses
    for idx, cluster_id in enumerate(clusters):
        pose_info[idx]['pocket'] = cluster_id
    
    # Analyze pockets
    unique_pockets = sorted(set(clusters))
    
    print(f"\n{'='*100}")
    print(f"PROTEIN: {protein}  |  LIGAND: {ligand}")
    print(f"{'='*100}")
    print(f"Identified {len(unique_pockets)} distinct binding pocket(s)")
    print()
    
    for pocket_id in unique_pockets:
        pocket_poses = [p for p in pose_info if p['pocket'] == pocket_id]
        mgl_in_pocket = [p for p in pocket_poses if p['method'] == 'MGLTools']
        meeko_in_pocket = [p for p in pocket_poses if p['method'] == 'Meeko']
        
        # Calculate pocket centroid
        pocket_centroids = [p['centroid'] for p in pocket_poses]
        pocket_center = np.mean(pocket_centroids, axis=0)
        
        print(f"  POCKET {pocket_id}: Center ({pocket_center[0]:.1f}, {pocket_center[1]:.1f}, {pocket_center[2]:.1f})")
        print(f"    MGLTools poses: {len(mgl_in_pocket)}, Meeko poses: {len(meeko_in_pocket)}")
        
        # Show best affinity from each method in this pocket
        if mgl_in_pocket:
            best_mgl = min(mgl_in_pocket, key=lambda x: x['affinity'] if x['affinity'] else float('inf'))
            print(f"    Best MGLTools: Mode {best_mgl['mode']}, Affinity: {best_mgl['affinity']:.3f} kcal/mol" if best_mgl['affinity'] else "")
        if meeko_in_pocket:
            best_meeko = min(meeko_in_pocket, key=lambda x: x['affinity'] if x['affinity'] else float('inf'))
            print(f"    Best Meeko:    Mode {best_meeko['mode']}, Affinity: {best_meeko['affinity']:.3f} kcal/mol" if best_meeko['affinity'] else "")
        
        # Compare if both methods have poses in this pocket
        if mgl_in_pocket and meeko_in_pocket:
            best_mgl_aff = min(p['affinity'] for p in mgl_in_pocket if p['affinity'])
            best_meeko_aff = min(p['affinity'] for p in meeko_in_pocket if p['affinity'])
            delta = best_meeko_aff - best_mgl_aff
            better = "Meeko" if delta < 0 else "MGLTools"
            print(f"    → SAME POCKET COMPARISON: Δ = {delta:+.3f} kcal/mol ({better} better)")
            
            detailed_pocket_data.append({
                'protein': protein,
                'ligand': ligand,
                'pocket_id': pocket_id,
                'pocket_center_x': pocket_center[0],
                'pocket_center_y': pocket_center[1],
                'pocket_center_z': pocket_center[2],
                'mgltools_poses': len(mgl_in_pocket),
                'meeko_poses': len(meeko_in_pocket),
                'mgltools_best_affinity': best_mgl_aff,
                'meeko_best_affinity': best_meeko_aff,
                'affinity_delta': delta,
                'better_method': better
            })
        else:
            # Only one method found this pocket
            method_only = "MGLTools" if mgl_in_pocket else "Meeko"
            print(f"    → UNIQUE POCKET: Only found by {method_only}")
            
            best_aff = None
            if mgl_in_pocket:
                best_aff = min(p['affinity'] for p in mgl_in_pocket if p['affinity'])
            elif meeko_in_pocket:
                best_aff = min(p['affinity'] for p in meeko_in_pocket if p['affinity'])
            
            detailed_pocket_data.append({
                'protein': protein,
                'ligand': ligand,
                'pocket_id': pocket_id,
                'pocket_center_x': pocket_center[0],
                'pocket_center_y': pocket_center[1],
                'pocket_center_z': pocket_center[2],
                'mgltools_poses': len(mgl_in_pocket),
                'meeko_poses': len(meeko_in_pocket),
                'mgltools_best_affinity': min((p['affinity'] for p in mgl_in_pocket if p['affinity']), default=None),
                'meeko_best_affinity': min((p['affinity'] for p in meeko_in_pocket if p['affinity']), default=None),
                'affinity_delta': None,
                'better_method': f"Only {method_only}"
            })
        print()
    
    pocket_analysis.append({
        'protein': protein,
        'ligand': ligand,
        'num_pockets': len(unique_pockets),
        'shared_pockets': sum(1 for p in unique_pockets if 
                             any(x['pocket']==p and x['method']=='MGLTools' for x in pose_info) and
                             any(x['pocket']==p and x['method']=='Meeko' for x in pose_info)),
        'mgltools_only_pockets': sum(1 for p in unique_pockets if 
                                     any(x['pocket']==p and x['method']=='MGLTools' for x in pose_info) and
                                     not any(x['pocket']==p and x['method']=='Meeko' for x in pose_info)),
        'meeko_only_pockets': sum(1 for p in unique_pockets if 
                                  any(x['pocket']==p and x['method']=='Meeko' for x in pose_info) and
                                  not any(x['pocket']==p and x['method']=='MGLTools' for x in pose_info))
    })

# Summary tables
print("\n" + "=" * 120)
print("SUMMARY: POCKET DISTRIBUTION BY PROTEIN-LIGAND PAIR")
print("=" * 120)
df_pocket_summary = pd.DataFrame(pocket_analysis)
display(df_pocket_summary)

print("\n" + "=" * 120)
print("DETAILED POCKET COMPARISON (where both methods found the same pocket)")
print("=" * 120)
df_pocket_detail = pd.DataFrame(detailed_pocket_data)
df_shared = df_pocket_detail[df_pocket_detail['affinity_delta'].notna()]
if len(df_shared) > 0:
    display(df_shared)
    
    print("\n" + "=" * 80)
    print("SAME-POCKET COMPARISON STATISTICS")
    print("=" * 80)
    meeko_wins = (df_shared['better_method'] == 'Meeko').sum()
    mgl_wins = (df_shared['better_method'] == 'MGLTools').sum()
    print(f"Shared pockets analyzed: {len(df_shared)}")
    print(f"Meeko better: {meeko_wins} ({100*meeko_wins/len(df_shared):.1f}%)")
    print(f"MGLTools better: {mgl_wins} ({100*mgl_wins/len(df_shared):.1f}%)")
    print(f"Mean Δ affinity: {df_shared['affinity_delta'].mean():.3f} kcal/mol")
else:
    print("No shared pockets found between methods.")

# Save results
df_pocket_detail.to_csv(wdlogs / "binding_pocket_analysis.csv", index=False)
print(f"\nBinding pocket analysis saved to: binding_pocket_analysis.csv")

# %%
"""
Visualization: Compare MGLTools vs Meeko Docked Poses by Binding Pocket
- Number of poses per pocket for each method
- RMSD comparison for first n-ranked poses (n = min poses from both methods)
"""
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.cluster.hierarchy import fcluster, linkage
from scipy.spatial.distance import pdist

# Directories
MEEKO_DOCKING_DIR = Path(wd / "docking_ready_meeko/docking")
MGLTOOLS_DOCKING_DIR = Path(wd / "docking_ready_mgltools/docking")
POCKET_THRESHOLD = 10.0

def parse_pdbqt_poses(pdbqt_path):
    """Parse PDBQT file to get coordinates and centroid for each pose."""
    poses = []
    if not pdbqt_path.exists():
        return poses
    with open(pdbqt_path, 'r') as f:
        content = f.read()
    models = re.split(r'MODEL\s+\d+', content)
    for model in models:
        if not model.strip():
            continue
        atoms = []
        for line in model.split('\n'):
            if line.startswith('ATOM') or line.startswith('HETATM'):
                try:
                    x = float(line[30:38].strip())
                    y = float(line[38:46].strip())
                    z = float(line[46:54].strip())
                    atoms.append([x, y, z])
                except (ValueError, IndexError):
                    continue
        if atoms:
            coords = np.array(atoms)
            centroid = np.mean(coords, axis=0)
            poses.append({'coords': coords, 'centroid': centroid, 'num_atoms': len(atoms)})
    return poses

def parse_vina_log(log_path):
    """Parse Vina log file to get affinity scores."""
    results = {'modes': []}
    if not log_path.exists():
        return results
    with open(log_path, 'r') as f:
        content = f.read()
    mode_pattern = r'^\s*(\d+)\s+([\-\d.]+)\s+([\d.]+)\s+([\d.]+)\s*$'
    modes = re.findall(mode_pattern, content, re.MULTILINE)
    for mode in modes:
        mode_num, affinity, rmsd_lb, rmsd_ub = mode
        results['modes'].append({
            'mode': int(mode_num),
            'affinity': float(affinity),
            'rmsd_lb': float(rmsd_lb),
            'rmsd_ub': float(rmsd_ub)
        })
    return results

def get_normalized_protein_name(name):
    return name.replace('_retry1', '')

def cluster_poses_by_pocket(all_centroids, threshold=POCKET_THRESHOLD):
    if len(all_centroids) <= 1:
        return [1] * len(all_centroids)
    centroids_array = np.array(all_centroids)
    distances = pdist(centroids_array)
    if len(distances) == 0:
        return [1] * len(all_centroids)
    linkage_matrix = linkage(distances, method='average')
    clusters = fcluster(linkage_matrix, t=threshold, criterion='distance')
    return clusters.tolist()

def calculate_rmsd_aligned(coords1, coords2):
    """Calculate RMSD with Kabsch alignment."""
    if coords1.shape != coords2.shape:
        min_atoms = min(len(coords1), len(coords2))
        coords1 = coords1[:min_atoms]
        coords2 = coords2[:min_atoms]
    centroid1 = np.mean(coords1, axis=0)
    centroid2 = np.mean(coords2, axis=0)
    coords1_centered = coords1 - centroid1
    coords2_centered = coords2 - centroid2
    H = coords1_centered.T @ coords2_centered
    U, S, Vt = np.linalg.svd(H)
    d = np.sign(np.linalg.det(Vt.T @ U.T))
    D = np.diag([1, 1, d])
    R = Vt.T @ D @ U.T
    coords2_aligned = coords2_centered @ R
    diff = coords1_centered - coords2_aligned
    rmsd = np.sqrt(np.mean(np.sum(diff**2, axis=1)))
    return rmsd

# Collect files
meeko_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.pdbqt')}
meeko_logs = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.log')}
mgltools_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.pdbqt')}
mgltools_logs = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.log')}

# Create normalized mappings
meeko_normalized = {}
for key in meeko_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        meeko_normalized[(protein_norm, ligand)] = key

mgltools_normalized = {}
for key in mgltools_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        mgltools_normalized[(protein_norm, ligand)] = key

common_pairs = set(meeko_normalized.keys()) & set(mgltools_normalized.keys())

# Analyze each protein-ligand pair
pocket_pose_counts = []  # For bar chart: poses per pocket
rmsd_data = []           # For RMSD comparison

for protein, ligand in sorted(common_pairs):
    meeko_key = meeko_normalized[(protein, ligand)]
    mgltools_key = mgltools_normalized[(protein, ligand)]
    
    meeko_poses = parse_pdbqt_poses(meeko_pdbqt[meeko_key])
    mgltools_poses = parse_pdbqt_poses(mgltools_pdbqt[mgltools_key])
    meeko_log = parse_vina_log(meeko_logs.get(meeko_key, Path('')))
    mgltools_log = parse_vina_log(mgltools_logs.get(mgltools_key, Path('')))
    
    if not meeko_poses or not mgltools_poses:
        continue
    
    # Combine all centroids for clustering
    all_centroids = []
    pose_info = []
    
    for i, pose in enumerate(mgltools_poses):
        all_centroids.append(pose['centroid'])
        affinity = mgltools_log['modes'][i]['affinity'] if i < len(mgltools_log['modes']) else None
        pose_info.append({'method': 'MGLTools', 'mode': i+1, 'affinity': affinity, 
                          'centroid': pose['centroid'], 'coords': pose['coords']})
    
    for i, pose in enumerate(meeko_poses):
        all_centroids.append(pose['centroid'])
        affinity = meeko_log['modes'][i]['affinity'] if i < len(meeko_log['modes']) else None
        pose_info.append({'method': 'Meeko', 'mode': i+1, 'affinity': affinity,
                          'centroid': pose['centroid'], 'coords': pose['coords']})
    
    # Cluster into pockets
    clusters = cluster_poses_by_pocket(all_centroids)
    for idx, cluster_id in enumerate(clusters):
        pose_info[idx]['pocket'] = cluster_id
    
    # Analyze each pocket
    unique_pockets = sorted(set(clusters))
    
    for pocket_id in unique_pockets:
        mgl_pocket_poses = sorted([p for p in pose_info if p['pocket'] == pocket_id and p['method'] == 'MGLTools'],
                                   key=lambda x: x['mode'])
        meeko_pocket_poses = sorted([p for p in pose_info if p['pocket'] == pocket_id and p['method'] == 'Meeko'],
                                     key=lambda x: x['mode'])
        
        n_mgl = len(mgl_pocket_poses)
        n_meeko = len(meeko_pocket_poses)
        
        pocket_pose_counts.append({
            'protein': protein,
            'ligand': ligand,
            'pocket': pocket_id,
            'pair_pocket': f"{protein}_{ligand}_P{pocket_id}",
            'mgltools_poses': n_mgl,
            'meeko_poses': n_meeko
        })
        
        # Calculate RMSD for first n-ranked poses (n = min of both)
        if n_mgl > 0 and n_meeko > 0:
            n_compare = min(n_mgl, n_meeko)
            for rank in range(n_compare):
                mgl_pose = mgl_pocket_poses[rank]
                meeko_pose = meeko_pocket_poses[rank]
                try:
                    rmsd = calculate_rmsd_aligned(mgl_pose['coords'], meeko_pose['coords'])
                    rmsd_data.append({
                        'protein': protein,
                        'ligand': ligand,
                        'pocket': pocket_id,
                        'pair_pocket': f"{protein}_{ligand}_P{pocket_id}",
                        'rank': rank + 1,
                        'rmsd': rmsd,
                        'mgltools_affinity': mgl_pose['affinity'],
                        'meeko_affinity': meeko_pose['affinity']
                    })
                except Exception:
                    pass

df_pocket_counts = pd.DataFrame(pocket_pose_counts)
df_rmsd = pd.DataFrame(rmsd_data)

print(f"Total pockets analyzed: {len(df_pocket_counts)}")
print(f"Total RMSD comparisons: {len(df_rmsd)}")

# ============ FIGURE 1: Poses per Pocket (Grouped Bar Chart) ============
fig1, ax1 = plt.subplots(figsize=(14, 6))

x = np.arange(len(df_pocket_counts))
width = 0.35

bars1 = ax1.bar(x - width/2, df_pocket_counts['mgltools_poses'], width, 
                label='MGLTools', color='#2ecc71', edgecolor='black')
bars2 = ax1.bar(x + width/2, df_pocket_counts['meeko_poses'], width, 
                label='Meeko', color='#3498db', edgecolor='black')

ax1.set_xlabel('Protein-Ligand Pair / Pocket', fontsize=12)
ax1.set_ylabel('Number of Poses', fontsize=12)
ax1.set_title('Number of Docked Poses per Binding Pocket: MGLTools vs Meeko', fontsize=14, fontweight='bold')
ax1.set_xticks(x)
ax1.set_xticklabels(df_pocket_counts['pair_pocket'], rotation=45, ha='right', fontsize=8)
ax1.legend(fontsize=11)
ax1.grid(axis='y', alpha=0.3)

for bar in bars1:
    height = bar.get_height()
    if height > 0:
        ax1.annotate(f'{int(height)}', xy=(bar.get_x() + bar.get_width()/2, height),
                     xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', fontsize=7)
for bar in bars2:
    height = bar.get_height()
    if height > 0:
        ax1.annotate(f'{int(height)}', xy=(bar.get_x() + bar.get_width()/2, height),
                     xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', fontsize=7)

plt.tight_layout()
plt.show()

# ============ FIGURE 2: RMSD by Rank for Each Pocket ============
if len(df_rmsd) > 0:
    unique_pair_pockets = df_rmsd['pair_pocket'].unique()
    n_pockets = len(unique_pair_pockets)
    
    if n_pockets <= 6:
        ncols = min(3, n_pockets)
        nrows = (n_pockets + ncols - 1) // ncols
    else:
        ncols = 4
        nrows = (n_pockets + ncols - 1) // ncols
    
    fig2, axes2 = plt.subplots(nrows, ncols, figsize=(4*ncols, 4*nrows), squeeze=False)
    axes2_flat = axes2.flatten()
    
    for idx, pair_pocket in enumerate(sorted(unique_pair_pockets)):
        ax = axes2_flat[idx]
        pocket_df = df_rmsd[df_rmsd['pair_pocket'] == pair_pocket].sort_values('rank')
        
        ranks = pocket_df['rank'].values
        rmsds = pocket_df['rmsd'].values
        
        bars = ax.bar(ranks, rmsds, color='#e74c3c', edgecolor='black', alpha=0.8)
        ax.axhline(y=2.0, color='green', linestyle='--', linewidth=1.5, label='2.0 Å threshold')
        ax.axhline(y=4.0, color='orange', linestyle='--', linewidth=1.5, label='4.0 Å threshold')
        
        ax.set_xlabel('Pose Rank', fontsize=10)
        ax.set_ylabel('RMSD (Å)', fontsize=10)
        ax.set_title(pair_pocket, fontsize=10, fontweight='bold')
        ax.set_xticks(ranks)
        ax.grid(axis='y', alpha=0.3)
        
        for bar, rmsd in zip(bars, rmsds):
            ax.annotate(f'{rmsd:.2f}', xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                        xytext=(0, 3), textcoords='offset points', ha='center', va='bottom', fontsize=8)
    
    # Hide unused subplots
    for idx in range(n_pockets, len(axes2_flat)):
        axes2_flat[idx].set_visible(False)
    
    axes2_flat[0].legend(loc='upper right', fontsize=8)
    fig2.suptitle('RMSD between MGLTools and Meeko Poses by Rank (Aligned)', fontsize=14, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.show()

# ============ FIGURE 3: Summary Box Plot of RMSD by Pocket ============
if len(df_rmsd) > 0:
    fig3, ax3 = plt.subplots(figsize=(12, 5))
    
    pockets_order = sorted(df_rmsd['pair_pocket'].unique())
    rmsd_by_pocket = [df_rmsd[df_rmsd['pair_pocket'] == p]['rmsd'].values for p in pockets_order]
    
    bp = ax3.boxplot(rmsd_by_pocket, labels=pockets_order, patch_artist=True)
    
    for patch in bp['boxes']:
        patch.set_facecolor('#9b59b6')
        patch.set_alpha(0.7)
    
    ax3.axhline(y=2.0, color='green', linestyle='--', linewidth=2, label='2.0 Å (very similar)')
    ax3.axhline(y=4.0, color='orange', linestyle='--', linewidth=2, label='4.0 Å (similar)')
    
    ax3.set_xlabel('Protein-Ligand Pair / Pocket', fontsize=12)
    ax3.set_ylabel('RMSD (Å)', fontsize=12)
    ax3.set_title('RMSD Distribution: MGLTools vs Meeko Poses per Pocket', fontsize=14, fontweight='bold')
    ax3.set_xticklabels(pockets_order, rotation=45, ha='right', fontsize=9)
    ax3.legend(fontsize=10)
    ax3.grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# ============ FIGURE 4: Heatmap of RMSD by Protein-Ligand and Rank ============
if len(df_rmsd) > 0:
    pivot_df = df_rmsd.pivot_table(index='pair_pocket', columns='rank', values='rmsd', aggfunc='mean')
    
    fig4, ax4 = plt.subplots(figsize=(10, max(6, len(pivot_df)*0.4)))
    
    im = ax4.imshow(pivot_df.values, cmap='RdYlGn_r', aspect='auto', vmin=0, vmax=max(6, pivot_df.values.max()))
    
    ax4.set_xticks(np.arange(len(pivot_df.columns)))
    ax4.set_yticks(np.arange(len(pivot_df.index)))
    ax4.set_xticklabels([f'Rank {c}' for c in pivot_df.columns], fontsize=10)
    ax4.set_yticklabels(pivot_df.index, fontsize=9)
    
    for i in range(len(pivot_df.index)):
        for j in range(len(pivot_df.columns)):
            val = pivot_df.values[i, j]
            if not np.isnan(val):
                ax4.text(j, i, f'{val:.2f}', ha='center', va='center', 
                         color='white' if val > 3 else 'black', fontsize=9, fontweight='bold')
    
    cbar = plt.colorbar(im, ax=ax4)
    cbar.set_label('RMSD (Å)', fontsize=11)
    
    ax4.set_xlabel('Pose Rank', fontsize=12)
    ax4.set_ylabel('Protein-Ligand Pair / Pocket', fontsize=12)
    ax4.set_title('RMSD Heatmap: MGLTools vs Meeko by Rank and Pocket', fontsize=14, fontweight='bold')
    
    plt.tight_layout()
    plt.show()

# Summary statistics
print("\n" + "="*80)
print("SUMMARY STATISTICS")
print("="*80)
print(f"\nPose counts per pocket:")
display(df_pocket_counts)

if len(df_rmsd) > 0:
    print(f"\nRMSD Statistics (all comparisons):")
    print(f"  Mean RMSD: {df_rmsd['rmsd'].mean():.3f} Å")
    print(f"  Median RMSD: {df_rmsd['rmsd'].median():.3f} Å")
    print(f"  Min RMSD: {df_rmsd['rmsd'].min():.3f} Å")
    print(f"  Max RMSD: {df_rmsd['rmsd'].max():.3f} Å")
    print(f"\nRMSD by Rank:")
    print(df_rmsd.groupby('rank')['rmsd'].agg(['mean', 'std', 'count']).round(3))
    print(f"\nDetailed RMSD data:")
    display(df_rmsd)

# %%
"""
Pocket Overview: Compare binding pocket distribution between MGLTools and Meeko
- Total pockets per file type
- Overlapping vs unique pockets
- Distance between unique pockets
- Pose counts per pocket type
"""
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.cluster.hierarchy import fcluster, linkage
from scipy.spatial.distance import pdist
from collections import defaultdict

# Directories
MEEKO_DOCKING_DIR = Path(wd / "docking_ready_meeko/docking")
MGLTOOLS_DOCKING_DIR = Path(wd / "docking_ready_mgltools/docking")
POCKET_THRESHOLD = 10.0

def parse_pdbqt_poses(pdbqt_path):
    poses = []
    if not pdbqt_path.exists():
        return poses
    with open(pdbqt_path, 'r') as f:
        content = f.read()
    models = re.split(r'MODEL\s+\d+', content)
    for model in models:
        if not model.strip():
            continue
        atoms = []
        for line in model.split('\n'):
            if line.startswith('ATOM') or line.startswith('HETATM'):
                try:
                    x = float(line[30:38].strip())
                    y = float(line[38:46].strip())
                    z = float(line[46:54].strip())
                    atoms.append([x, y, z])
                except (ValueError, IndexError):
                    continue
        if atoms:
            coords = np.array(atoms)
            centroid = np.mean(coords, axis=0)
            poses.append({'coords': coords, 'centroid': centroid, 'num_atoms': len(atoms)})
    return poses

def get_normalized_protein_name(name):
    return name.replace('_retry1', '')

def cluster_poses_by_pocket(all_centroids, threshold=POCKET_THRESHOLD):
    if len(all_centroids) <= 1:
        return [1] * len(all_centroids)
    centroids_array = np.array(all_centroids)
    distances = pdist(centroids_array)
    if len(distances) == 0:
        return [1] * len(all_centroids)
    linkage_matrix = linkage(distances, method='average')
    clusters = fcluster(linkage_matrix, t=threshold, criterion='distance')
    return clusters.tolist()

# Collect files
meeko_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.pdbqt')}
mgltools_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.pdbqt')}

# Create normalized mappings
meeko_normalized = {}
for key in meeko_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        meeko_normalized[(protein_norm, ligand)] = key

mgltools_normalized = {}
for key in mgltools_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        mgltools_normalized[(protein_norm, ligand)] = key

common_pairs = set(meeko_normalized.keys()) & set(mgltools_normalized.keys())

# Analyze pockets for each protein-ligand pair
all_pocket_data = []
pair_summaries = []

for protein, ligand in sorted(common_pairs):
    meeko_key = meeko_normalized[(protein, ligand)]
    mgltools_key = mgltools_normalized[(protein, ligand)]
    
    meeko_poses = parse_pdbqt_poses(meeko_pdbqt[meeko_key])
    mgltools_poses = parse_pdbqt_poses(mgltools_pdbqt[mgltools_key])
    
    if not meeko_poses or not mgltools_poses:
        continue
    
    # Combine all centroids for clustering
    all_centroids = []
    pose_info = []
    
    for i, pose in enumerate(mgltools_poses):
        all_centroids.append(pose['centroid'])
        pose_info.append({'method': 'MGLTools', 'mode': i+1, 'centroid': pose['centroid']})
    
    for i, pose in enumerate(meeko_poses):
        all_centroids.append(pose['centroid'])
        pose_info.append({'method': 'Meeko', 'mode': i+1, 'centroid': pose['centroid']})
    
    # Cluster into pockets
    clusters = cluster_poses_by_pocket(all_centroids)
    for idx, cluster_id in enumerate(clusters):
        pose_info[idx]['pocket'] = cluster_id
    
    unique_pockets = sorted(set(clusters))
    
    mgl_only_pockets = 0
    meeko_only_pockets = 0
    shared_pockets = 0
    
    for pocket_id in unique_pockets:
        mgl_in_pocket = [p for p in pose_info if p['pocket'] == pocket_id and p['method'] == 'MGLTools']
        meeko_in_pocket = [p for p in pose_info if p['pocket'] == pocket_id and p['method'] == 'Meeko']
        
        pocket_centroids = [p['centroid'] for p in pose_info if p['pocket'] == pocket_id]
        pocket_center = np.mean(pocket_centroids, axis=0)
        
        has_mgl = len(mgl_in_pocket) > 0
        has_meeko = len(meeko_in_pocket) > 0
        
        if has_mgl and has_meeko:
            pocket_type = 'Shared'
            shared_pockets += 1
        elif has_mgl:
            pocket_type = 'MGLTools Only'
            mgl_only_pockets += 1
        else:
            pocket_type = 'Meeko Only'
            meeko_only_pockets += 1
        
        all_pocket_data.append({
            'protein': protein,
            'ligand': ligand,
            'pair': f"{protein}_{ligand}",
            'pocket_id': pocket_id,
            'pocket_type': pocket_type,
            'mgltools_poses': len(mgl_in_pocket),
            'meeko_poses': len(meeko_in_pocket),
            'total_poses': len(mgl_in_pocket) + len(meeko_in_pocket),
            'center_x': pocket_center[0],
            'center_y': pocket_center[1],
            'center_z': pocket_center[2]
        })
    
    pair_summaries.append({
        'protein': protein,
        'ligand': ligand,
        'pair': f"{protein}_{ligand}",
        'total_pockets': len(unique_pockets),
        'shared_pockets': shared_pockets,
        'mgltools_only': mgl_only_pockets,
        'meeko_only': meeko_only_pockets
    })

df_pockets = pd.DataFrame(all_pocket_data)
df_pairs = pd.DataFrame(pair_summaries)

# ============ FIGURE 1: Overview - Pockets per File Type ============
fig1, axes1 = plt.subplots(1, 3, figsize=(15, 5))

# 1a: Total pockets contributed by each method
total_shared = df_pairs['shared_pockets'].sum()
total_mgl_only = df_pairs['mgltools_only'].sum()
total_meeko_only = df_pairs['meeko_only'].sum()

# Pockets that MGLTools finds (shared + mgl_only)
mgl_total = total_shared + total_mgl_only
meeko_total = total_shared + total_meeko_only

ax1a = axes1[0]
methods = ['MGLTools', 'Meeko']
pocket_counts = [mgl_total, meeko_total]
colors = ['#2ecc71', '#3498db']
bars = ax1a.bar(methods, pocket_counts, color=colors, edgecolor='black', linewidth=1.5)
ax1a.set_ylabel('Number of Pockets Found', fontsize=12)
ax1a.set_title('Total Pockets per File Type', fontsize=13, fontweight='bold')
for bar, count in zip(bars, pocket_counts):
    ax1a.annotate(f'{count}', xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                  xytext=(0, 5), textcoords='offset points', ha='center', fontsize=14, fontweight='bold')
ax1a.grid(axis='y', alpha=0.3)

# 1b: Pocket breakdown (Shared vs Unique)
ax1b = axes1[1]
categories = ['Shared\n(Both)', 'MGLTools\nOnly', 'Meeko\nOnly']
counts = [total_shared, total_mgl_only, total_meeko_only]
colors_breakdown = ['#9b59b6', '#2ecc71', '#3498db']
bars = ax1b.bar(categories, counts, color=colors_breakdown, edgecolor='black', linewidth=1.5)
ax1b.set_ylabel('Number of Pockets', fontsize=12)
ax1b.set_title('Pocket Classification', fontsize=13, fontweight='bold')
for bar, count in zip(bars, counts):
    ax1b.annotate(f'{count}', xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                  xytext=(0, 5), textcoords='offset points', ha='center', fontsize=14, fontweight='bold')
ax1b.grid(axis='y', alpha=0.3)

# 1c: Pie chart of pocket distribution
ax1c = axes1[2]
sizes = [total_shared, total_mgl_only, total_meeko_only]
labels = [f'Shared\n({total_shared})', f'MGLTools Only\n({total_mgl_only})', f'Meeko Only\n({total_meeko_only})']
explode = (0.05, 0.05, 0.05)
ax1c.pie(sizes, explode=explode, labels=labels, colors=colors_breakdown, autopct='%1.1f%%',
         shadow=True, startangle=90, textprops={'fontsize': 11})
ax1c.set_title('Pocket Distribution', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.show()

# ============ FIGURE 2: Pockets per Protein-Ligand Pair (Stacked) ============
fig2, ax2 = plt.subplots(figsize=(14, 6))

x = np.arange(len(df_pairs))
width = 0.6

bars_shared = ax2.bar(x, df_pairs['shared_pockets'], width, label='Shared', color='#9b59b6', edgecolor='black')
bars_mgl = ax2.bar(x, df_pairs['mgltools_only'], width, bottom=df_pairs['shared_pockets'], 
                   label='MGLTools Only', color='#2ecc71', edgecolor='black')
bars_meeko = ax2.bar(x, df_pairs['meeko_only'], width, 
                     bottom=df_pairs['shared_pockets'] + df_pairs['mgltools_only'],
                     label='Meeko Only', color='#3498db', edgecolor='black')

ax2.set_xlabel('Protein-Ligand Pair', fontsize=12)
ax2.set_ylabel('Number of Pockets', fontsize=12)
ax2.set_title('Pocket Distribution per Protein-Ligand Pair', fontsize=14, fontweight='bold')
ax2.set_xticks(x)
ax2.set_xticklabels(df_pairs['pair'], rotation=45, ha='right', fontsize=9)
ax2.legend(fontsize=11)
ax2.grid(axis='y', alpha=0.3)

# Add total count on top
for i, (s, m, e) in enumerate(zip(df_pairs['shared_pockets'], df_pairs['mgltools_only'], df_pairs['meeko_only'])):
    total = s + m + e
    ax2.annotate(f'{total}', xy=(i, total), xytext=(0, 3), textcoords='offset points', 
                 ha='center', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

# ============ FIGURE 3: Poses per Pocket Type ============
fig3, axes3 = plt.subplots(1, 2, figsize=(14, 5))

# 3a: Total poses by pocket type
ax3a = axes3[0]
pose_by_type = df_pockets.groupby('pocket_type').agg({
    'mgltools_poses': 'sum',
    'meeko_poses': 'sum',
    'total_poses': 'sum'
}).reindex(['Shared', 'MGLTools Only', 'Meeko Only'])

x_types = np.arange(len(pose_by_type))
width = 0.35

bars_mgl = ax3a.bar(x_types - width/2, pose_by_type['mgltools_poses'], width, 
                    label='MGLTools Poses', color='#2ecc71', edgecolor='black')
bars_meeko = ax3a.bar(x_types + width/2, pose_by_type['meeko_poses'], width,
                      label='Meeko Poses', color='#3498db', edgecolor='black')

ax3a.set_xlabel('Pocket Type', fontsize=12)
ax3a.set_ylabel('Total Number of Poses', fontsize=12)
ax3a.set_title('Docked Poses by Pocket Type', fontsize=13, fontweight='bold')
ax3a.set_xticks(x_types)
ax3a.set_xticklabels(['Shared', 'MGLTools\nOnly', 'Meeko\nOnly'], fontsize=10)
ax3a.legend(fontsize=10)
ax3a.grid(axis='y', alpha=0.3)

for bar in bars_mgl:
    h = bar.get_height()
    if h > 0:
        ax3a.annotate(f'{int(h)}', xy=(bar.get_x() + bar.get_width()/2, h),
                      xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')
for bar in bars_meeko:
    h = bar.get_height()
    if h > 0:
        ax3a.annotate(f'{int(h)}', xy=(bar.get_x() + bar.get_width()/2, h),
                      xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

# 3b: Average poses per pocket by type
ax3b = axes3[1]
avg_by_type = df_pockets.groupby('pocket_type').agg({
    'mgltools_poses': 'mean',
    'meeko_poses': 'mean'
}).reindex(['Shared', 'MGLTools Only', 'Meeko Only'])

bars_mgl_avg = ax3b.bar(x_types - width/2, avg_by_type['mgltools_poses'], width,
                        label='MGLTools Poses', color='#2ecc71', edgecolor='black')
bars_meeko_avg = ax3b.bar(x_types + width/2, avg_by_type['meeko_poses'], width,
                          label='Meeko Poses', color='#3498db', edgecolor='black')

ax3b.set_xlabel('Pocket Type', fontsize=12)
ax3b.set_ylabel('Average Poses per Pocket', fontsize=12)
ax3b.set_title('Average Poses per Pocket by Type', fontsize=13, fontweight='bold')
ax3b.set_xticks(x_types)
ax3b.set_xticklabels(['Shared', 'MGLTools\nOnly', 'Meeko\nOnly'], fontsize=10)
ax3b.legend(fontsize=10)
ax3b.grid(axis='y', alpha=0.3)

for bar in bars_mgl_avg:
    h = bar.get_height()
    if h > 0:
        ax3b.annotate(f'{h:.1f}', xy=(bar.get_x() + bar.get_width()/2, h),
                      xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10)
for bar in bars_meeko_avg:
    h = bar.get_height()
    if h > 0:
        ax3b.annotate(f'{h:.1f}', xy=(bar.get_x() + bar.get_width()/2, h),
                      xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10)

plt.tight_layout()
plt.show()

# ============ FIGURE 4: Distance Between Unique Pockets ============
# Calculate distances between unique pockets within each protein-ligand pair
distance_data = []

for pair in df_pockets['pair'].unique():
    pair_pockets = df_pockets[df_pockets['pair'] == pair]
    
    mgl_only = pair_pockets[pair_pockets['pocket_type'] == 'MGLTools Only']
    meeko_only = pair_pockets[pair_pockets['pocket_type'] == 'Meeko Only']
    shared = pair_pockets[pair_pockets['pocket_type'] == 'Shared']
    
    # Distance between MGLTools-only and Meeko-only pockets
    for _, mgl_pocket in mgl_only.iterrows():
        mgl_center = np.array([mgl_pocket['center_x'], mgl_pocket['center_y'], mgl_pocket['center_z']])
        
        for _, meeko_pocket in meeko_only.iterrows():
            meeko_center = np.array([meeko_pocket['center_x'], meeko_pocket['center_y'], meeko_pocket['center_z']])
            dist = np.linalg.norm(mgl_center - meeko_center)
            distance_data.append({
                'pair': pair,
                'comparison': 'MGLTools-only vs Meeko-only',
                'distance': dist
            })
        
        # Distance from MGLTools-only to nearest shared pocket
        for _, shared_pocket in shared.iterrows():
            shared_center = np.array([shared_pocket['center_x'], shared_pocket['center_y'], shared_pocket['center_z']])
            dist = np.linalg.norm(mgl_center - shared_center)
            distance_data.append({
                'pair': pair,
                'comparison': 'MGLTools-only vs Shared',
                'distance': dist
            })
    
    # Distance from Meeko-only to nearest shared pocket
    for _, meeko_pocket in meeko_only.iterrows():
        meeko_center = np.array([meeko_pocket['center_x'], meeko_pocket['center_y'], meeko_pocket['center_z']])
        
        for _, shared_pocket in shared.iterrows():
            shared_center = np.array([shared_pocket['center_x'], shared_pocket['center_y'], shared_pocket['center_z']])
            dist = np.linalg.norm(meeko_center - shared_center)
            distance_data.append({
                'pair': pair,
                'comparison': 'Meeko-only vs Shared',
                'distance': dist
            })

df_distances = pd.DataFrame(distance_data)

if len(df_distances) > 0:
    fig4, axes4 = plt.subplots(1, 2, figsize=(14, 5))
    
    # 4a: Box plot of distances by comparison type
    ax4a = axes4[0]
    comparison_types = df_distances['comparison'].unique()
    distance_groups = [df_distances[df_distances['comparison'] == c]['distance'].values for c in comparison_types]
    
    bp = ax4a.boxplot(distance_groups, labels=[c.replace(' vs ', '\nvs\n') for c in comparison_types], 
                      patch_artist=True)
    colors_box = ['#e74c3c', '#f39c12', '#1abc9c']
    for patch, color in zip(bp['boxes'], colors_box[:len(bp['boxes'])]):
        patch.set_facecolor(color)
        patch.set_alpha(0.7)
    
    ax4a.axhline(y=POCKET_THRESHOLD, color='red', linestyle='--', linewidth=2, 
                 label=f'Clustering threshold ({POCKET_THRESHOLD} Å)')
    ax4a.set_ylabel('Distance (Å)', fontsize=12)
    ax4a.set_title('Distance Between Unique Pockets', fontsize=13, fontweight='bold')
    ax4a.legend(fontsize=9)
    ax4a.grid(axis='y', alpha=0.3)
    
    # 4b: Histogram of all unique pocket distances
    ax4b = axes4[1]
    all_distances = df_distances['distance'].values
    ax4b.hist(all_distances, bins=20, color='#e74c3c', edgecolor='black', alpha=0.7)
    ax4b.axvline(x=POCKET_THRESHOLD, color='red', linestyle='--', linewidth=2,
                 label=f'Clustering threshold ({POCKET_THRESHOLD} Å)')
    ax4b.axvline(x=np.mean(all_distances), color='blue', linestyle='-', linewidth=2,
                 label=f'Mean ({np.mean(all_distances):.1f} Å)')
    ax4b.set_xlabel('Distance (Å)', fontsize=12)
    ax4b.set_ylabel('Frequency', fontsize=12)
    ax4b.set_title('Distribution of Distances Between Unique Pockets', fontsize=13, fontweight='bold')
    ax4b.legend(fontsize=10)
    ax4b.grid(axis='y', alpha=0.3)
    
    plt.tight_layout()
    plt.show()
else:
    print("No unique pockets to compare distances.")

# ============ FIGURE 5: Venn-style visualization per pair ============
fig5, ax5 = plt.subplots(figsize=(12, 6))

# Create grouped data for Venn-like comparison
pairs = df_pairs['pair'].values
shared_counts = df_pairs['shared_pockets'].values
mgl_counts = df_pairs['mgltools_only'].values
meeko_counts = df_pairs['meeko_only'].values

x = np.arange(len(pairs))
width = 0.25

ax5.bar(x - width, mgl_counts, width, label='MGLTools Only', color='#2ecc71', edgecolor='black')
ax5.bar(x, shared_counts, width, label='Shared (Overlapping)', color='#9b59b6', edgecolor='black')
ax5.bar(x + width, meeko_counts, width, label='Meeko Only', color='#3498db', edgecolor='black')

ax5.set_xlabel('Protein-Ligand Pair', fontsize=12)
ax5.set_ylabel('Number of Pockets', fontsize=12)
ax5.set_title('Overlapping vs Unique Pockets per Pair', fontsize=14, fontweight='bold')
ax5.set_xticks(x)
ax5.set_xticklabels(pairs, rotation=45, ha='right', fontsize=9)
ax5.legend(fontsize=11)
ax5.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# ============ SUMMARY TABLES ============
print("=" * 100)
print("SUMMARY: POCKET OVERVIEW BY FILE TYPE")
print("=" * 100)
print()
print(f"Total unique pockets identified: {len(df_pockets)}")
print(f"  - Shared pockets (found by both): {total_shared} ({100*total_shared/len(df_pockets):.1f}%)")
print(f"  - MGLTools-only pockets: {total_mgl_only} ({100*total_mgl_only/len(df_pockets):.1f}%)")
print(f"  - Meeko-only pockets: {total_meeko_only} ({100*total_meeko_only/len(df_pockets):.1f}%)")
print()
print(f"Pockets found by MGLTools: {mgl_total}")
print(f"Pockets found by Meeko: {meeko_total}")
print()

print("Per Protein-Ligand Pair Summary:")
display(df_pairs)

print("\nDetailed Pocket Data:")
display(df_pockets)

if len(df_distances) > 0:
    print("\nDistance Statistics Between Unique Pockets:")
    print(df_distances.groupby('comparison')['distance'].agg(['mean', 'std', 'min', 'max', 'count']).round(2))

# %% [markdown]
# # Clustering

# %%
"""
Comprehensive Pocket Clustering Analysis: MGLTools vs Meeko
- Cluster pockets and show differences
- Poses per file type in shared vs unique pockets
- Pocket separation distances in the environment
- Ratio of poses in shared vs unique pockets per file format
"""
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from scipy.cluster.hierarchy import fcluster, linkage, dendrogram
from scipy.spatial.distance import pdist, squareform
from collections import defaultdict

# Directories
MEEKO_DOCKING_DIR = Path(wd / "docking_ready_meeko/docking")
MGLTOOLS_DOCKING_DIR = Path(wd / "docking_ready_mgltools/docking")
POCKET_THRESHOLD = 10.0

def parse_pdbqt_poses(pdbqt_path):
    poses = []
    if not pdbqt_path.exists():
        return poses
    with open(pdbqt_path, 'r') as f:
        content = f.read()
    models = re.split(r'MODEL\s+\d+', content)
    for model in models:
        if not model.strip():
            continue
        atoms = []
        for line in model.split('\n'):
            if line.startswith('ATOM') or line.startswith('HETATM'):
                try:
                    x = float(line[30:38].strip())
                    y = float(line[38:46].strip())
                    z = float(line[46:54].strip())
                    atoms.append([x, y, z])
                except (ValueError, IndexError):
                    continue
        if atoms:
            coords = np.array(atoms)
            centroid = np.mean(coords, axis=0)
            poses.append({'coords': coords, 'centroid': centroid, 'num_atoms': len(atoms)})
    return poses

def get_normalized_protein_name(name):
    return name.replace('_retry1', '')

def cluster_poses_by_pocket(all_centroids, threshold=POCKET_THRESHOLD):
    if len(all_centroids) <= 1:
        return [1] * len(all_centroids)
    centroids_array = np.array(all_centroids)
    distances = pdist(centroids_array)
    if len(distances) == 0:
        return [1] * len(all_centroids)
    linkage_matrix = linkage(distances, method='average')
    clusters = fcluster(linkage_matrix, t=threshold, criterion='distance')
    return clusters.tolist()

# Collect files
meeko_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MEEKO_DOCKING_DIR.glob('*_vina_out.pdbqt')}
mgltools_pdbqt = {f.stem.replace('_vina_out', ''): f for f in MGLTOOLS_DOCKING_DIR.glob('*_vina_out.pdbqt')}

# Create normalized mappings
meeko_normalized = {}
for key in meeko_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        meeko_normalized[(protein_norm, ligand)] = key

mgltools_normalized = {}
for key in mgltools_pdbqt.keys():
    parts = key.split('__')
    if len(parts) == 2:
        protein_norm = get_normalized_protein_name(parts[0])
        ligand = parts[1]
        mgltools_normalized[(protein_norm, ligand)] = key

common_pairs = set(meeko_normalized.keys()) & set(mgltools_normalized.keys())

# Analyze all pockets across all pairs
all_pocket_data = []
all_pose_data = []
pair_pocket_summaries = []

for protein, ligand in sorted(common_pairs):
    meeko_key = meeko_normalized[(protein, ligand)]
    mgltools_key = mgltools_normalized[(protein, ligand)]
    
    meeko_poses = parse_pdbqt_poses(meeko_pdbqt[meeko_key])
    mgltools_poses = parse_pdbqt_poses(mgltools_pdbqt[mgltools_key])
    
    if not meeko_poses or not mgltools_poses:
        continue
    
    # Combine all centroids for clustering
    all_centroids = []
    pose_info = []
    
    for i, pose in enumerate(mgltools_poses):
        all_centroids.append(pose['centroid'])
        pose_info.append({
            'method': 'MGLTools', 
            'mode': i+1, 
            'centroid': pose['centroid'],
            'protein': protein,
            'ligand': ligand
        })
    
    for i, pose in enumerate(meeko_poses):
        all_centroids.append(pose['centroid'])
        pose_info.append({
            'method': 'Meeko', 
            'mode': i+1, 
            'centroid': pose['centroid'],
            'protein': protein,
            'ligand': ligand
        })
    
    # Cluster into pockets
    clusters = cluster_poses_by_pocket(all_centroids)
    for idx, cluster_id in enumerate(clusters):
        pose_info[idx]['pocket'] = cluster_id
    
    unique_pockets = sorted(set(clusters))
    
    # Analyze each pocket
    shared_poses_mgl = 0
    shared_poses_meeko = 0
    unique_poses_mgl = 0
    unique_poses_meeko = 0
    
    for pocket_id in unique_pockets:
        mgl_in_pocket = [p for p in pose_info if p['pocket'] == pocket_id and p['method'] == 'MGLTools']
        meeko_in_pocket = [p for p in pose_info if p['pocket'] == pocket_id and p['method'] == 'Meeko']
        
        pocket_centroids = [p['centroid'] for p in pose_info if p['pocket'] == pocket_id]
        pocket_center = np.mean(pocket_centroids, axis=0)
        
        has_mgl = len(mgl_in_pocket) > 0
        has_meeko = len(meeko_in_pocket) > 0
        
        if has_mgl and has_meeko:
            pocket_type = 'Shared'
            shared_poses_mgl += len(mgl_in_pocket)
            shared_poses_meeko += len(meeko_in_pocket)
        elif has_mgl:
            pocket_type = 'MGLTools Only'
            unique_poses_mgl += len(mgl_in_pocket)
        else:
            pocket_type = 'Meeko Only'
            unique_poses_meeko += len(meeko_in_pocket)
        
        all_pocket_data.append({
            'protein': protein,
            'ligand': ligand,
            'pair': f"{protein}_{ligand}",
            'pocket_id': pocket_id,
            'pocket_type': pocket_type,
            'mgltools_poses': len(mgl_in_pocket),
           'meeko_poses': len(meeko_in_pocket),
            'total_poses': len(mgl_in_pocket) + len(meeko_in_pocket),
            'center_x': pocket_center[0],
            'center_y': pocket_center[1],
            'center_z': pocket_center[2]
        })
        
        # Store individual pose data
        for p in mgl_in_pocket + meeko_in_pocket:
            all_pose_data.append({
                'protein': protein,
                'ligand': ligand,
                'pair': f"{protein}_{ligand}",
                'pocket_id': pocket_id,
                'pocket_type': pocket_type,
                'method': p['method'],
                'mode': p['mode'],
                'centroid_x': p['centroid'][0],
                'centroid_y': p['centroid'][1],
                'centroid_z': p['centroid'][2]
            })
    
    pair_pocket_summaries.append({
        'protein': protein,
        'ligand': ligand,
        'pair': f"{protein}_{ligand}",
        'total_pockets': len(unique_pockets),
        'shared_pockets': sum(1 for p in all_pocket_data if p['pair'] == f"{protein}_{ligand}" and p['pocket_type'] == 'Shared'),
        'mgltools_only_pockets': sum(1 for p in all_pocket_data if p['pair'] == f"{protein}_{ligand}" and p['pocket_type'] == 'MGLTools Only'),
        'meeko_only_pockets': sum(1 for p in all_pocket_data if p['pair'] == f"{protein}_{ligand}" and p['pocket_type'] == 'Meeko Only'),
        'shared_poses_mgl': shared_poses_mgl,
        'shared_poses_meeko': shared_poses_meeko,
        'unique_poses_mgl': unique_poses_mgl,
        'unique_poses_meeko': unique_poses_meeko
    })

df_pockets = pd.DataFrame(all_pocket_data)
df_poses = pd.DataFrame(all_pose_data)
df_summaries = pd.DataFrame(pair_pocket_summaries)

# ============ GLOBAL STATISTICS ============
total_shared_pockets = len(df_pockets[df_pockets['pocket_type'] == 'Shared'])
total_mgl_only_pockets = len(df_pockets[df_pockets['pocket_type'] == 'MGLTools Only'])
total_meeko_only_pockets = len(df_pockets[df_pockets['pocket_type'] == 'Meeko Only'])
total_pockets = len(df_pockets)

# Poses in shared vs unique pockets
shared_pocket_df = df_pockets[df_pockets['pocket_type'] == 'Shared']
mgl_only_pocket_df = df_pockets[df_pockets['pocket_type'] == 'MGLTools Only']
meeko_only_pocket_df = df_pockets[df_pockets['pocket_type'] == 'Meeko Only']

mgl_poses_in_shared = shared_pocket_df['mgltools_poses'].sum()
meeko_poses_in_shared = shared_pocket_df['meeko_poses'].sum()
mgl_poses_in_unique = mgl_only_pocket_df['mgltools_poses'].sum()
meeko_poses_in_unique = meeko_only_pocket_df['meeko_poses'].sum()

total_mgl_poses = mgl_poses_in_shared + mgl_poses_in_unique
total_meeko_poses = meeko_poses_in_shared + meeko_poses_in_unique

print("=" * 100)
print("COMPREHENSIVE POCKET CLUSTERING ANALYSIS: MGLTools vs Meeko")
print("=" * 100)
print()
print(f"Clustering threshold: {POCKET_THRESHOLD} Å")
print(f"Protein-ligand pairs analyzed: {len(common_pairs)}")
print()

print("=" * 80)
print("POCKET OVERVIEW")
print("=" * 80)
print(f"Total pockets identified: {total_pockets}")
print(f"  - Shared pockets (both methods): {total_shared_pockets} ({100*total_shared_pockets/total_pockets:.1f}%)")
print(f"  - MGLTools-only pockets: {total_mgl_only_pockets} ({100*total_mgl_only_pockets/total_pockets:.1f}%)")
print(f"  - Meeko-only pockets: {total_meeko_only_pockets} ({100*total_meeko_only_pockets/total_pockets:.1f}%)")
print()

print("=" * 80)
print("POSES IN SHARED vs UNIQUE POCKETS")
print("=" * 80)
print()
print("MGLTools File Format:")
print(f"  - Poses in SHARED pockets: {mgl_poses_in_shared}")
print(f"  - Poses in UNIQUE pockets: {mgl_poses_in_unique}")
print(f"  - Total MGLTools poses: {total_mgl_poses}")
print(f"  - Ratio (Shared/Unique): {mgl_poses_in_shared/max(1, mgl_poses_in_unique):.2f}")
print(f"  - % in Shared pockets: {100*mgl_poses_in_shared/max(1, total_mgl_poses):.1f}%")
print()
print("Meeko File Format:")
print(f"  - Poses in SHARED pockets: {meeko_poses_in_shared}")
print(f"  - Poses in UNIQUE pockets: {meeko_poses_in_unique}")
print(f"  - Total Meeko poses: {total_meeko_poses}")
print(f"  - Ratio (Shared/Unique): {meeko_poses_in_shared/max(1, meeko_poses_in_unique):.2f}")
print(f"  - % in Shared pockets: {100*meeko_poses_in_shared/max(1, total_meeko_poses):.1f}%")
print()

# ============ FIGURE 1: Pocket Clustering Overview ============
fig1, axes1 = plt.subplots(2, 2, figsize=(14, 12))

# 1a: Pocket type distribution
ax1a = axes1[0, 0]
pocket_types = ['Shared\n(Both)', 'MGLTools\nOnly', 'Meeko\nOnly']
pocket_counts = [total_shared_pockets, total_mgl_only_pockets, total_meeko_only_pockets]
colors = ['#9b59b6', '#2ecc71', '#3498db']
bars = ax1a.bar(pocket_types, pocket_counts, color=colors, edgecolor='black', linewidth=1.5)
ax1a.set_ylabel('Number of Pockets', fontsize=12)
ax1a.set_title('Pocket Distribution by Type', fontsize=13, fontweight='bold')
for bar, count in zip(bars, pocket_counts):
    ax1a.annotate(f'{count}\n({100*count/total_pockets:.1f}%)', 
                  xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                  xytext=(0, 5), textcoords='offset points', ha='center', fontsize=11, fontweight='bold')
ax1a.grid(axis='y', alpha=0.3)

# 1b: Poses per pocket type and file format
ax1b = axes1[0, 1]
x = np.arange(3)
width = 0.35

pose_counts_mgl = [mgl_poses_in_shared, mgl_poses_in_unique, 0]
pose_counts_meeko = [meeko_poses_in_shared, 0, meeko_poses_in_unique]

bars_mgl = ax1b.bar(x - width/2, pose_counts_mgl, width, label='MGLTools', color='#2ecc71', edgecolor='black')
bars_meeko = ax1b.bar(x + width/2, pose_counts_meeko, width, label='Meeko', color='#3498db', edgecolor='black')

ax1b.set_xlabel('Pocket Type', fontsize=12)
ax1b.set_ylabel('Number of Poses', fontsize=12)
ax1b.set_title('Poses per File Type in Each Pocket Category', fontsize=13, fontweight='bold')
ax1b.set_xticks(x)
ax1b.set_xticklabels(['Shared', 'MGLTools Only', 'Meeko Only'])
ax1b.legend(fontsize=11)
ax1b.grid(axis='y', alpha=0.3)

for bar in bars_mgl:
    h = bar.get_height()
    if h > 0:
        ax1b.annotate(f'{int(h)}', xy=(bar.get_x() + bar.get_width()/2, h),
                      xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')
for bar in bars_meeko:
    h = bar.get_height()
    if h > 0:
        ax1b.annotate(f'{int(h)}', xy=(bar.get_x() + bar.get_width()/2, h),
                      xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

# 1c: Ratio of poses in shared vs unique pockets
ax1c = axes1[1, 0]
methods = ['MGLTools', 'Meeko']
shared_ratios = [mgl_poses_in_shared/max(1, total_mgl_poses)*100, 
                 meeko_poses_in_shared/max(1, total_meeko_poses)*100]
unique_ratios = [mgl_poses_in_unique/max(1, total_mgl_poses)*100,
                 meeko_poses_in_unique/max(1, total_meeko_poses)*100]

x = np.arange(len(methods))
width = 0.35

bars_shared = ax1c.bar(x - width/2, shared_ratios, width, label='In Shared Pockets', color='#9b59b6', edgecolor='black')
bars_unique = ax1c.bar(x + width/2, unique_ratios, width, label='In Unique Pockets', color='#e74c3c', edgecolor='black')

ax1c.set_ylabel('% of Total Poses', fontsize=12)
ax1c.set_title('Pose Distribution: Shared vs Unique Pockets', fontsize=13, fontweight='bold')
ax1c.set_xticks(x)
ax1c.set_xticklabels(methods, fontsize=11)
ax1c.legend(fontsize=10)
ax1c.grid(axis='y', alpha=0.3)
ax1c.set_ylim(0, 110)

for bar in bars_shared:
    h = bar.get_height()
    ax1c.annotate(f'{h:.1f}%', xy=(bar.get_x() + bar.get_width()/2, h),
                  xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')
for bar in bars_unique:
    h = bar.get_height()
    ax1c.annotate(f'{h:.1f}%', xy=(bar.get_x() + bar.get_width()/2, h),
                  xytext=(0, 3), textcoords='offset points', ha='center', fontsize=10, fontweight='bold')

# 1d: Pie chart - Overall pose distribution
ax1d = axes1[1, 1]
pose_categories = [mgl_poses_in_shared, meeko_poses_in_shared, mgl_poses_in_unique, meeko_poses_in_unique]
category_labels = [f'MGLTools\nin Shared\n({mgl_poses_in_shared})',
                   f'Meeko\nin Shared\n({meeko_poses_in_shared})',
                   f'MGLTools\nUnique\n({mgl_poses_in_unique})',
                   f'Meeko\nUnique\n({meeko_poses_in_unique})']
colors_pie = ['#27ae60', '#2980b9', '#16a085', '#1abc9c']
explode = (0.02, 0.02, 0.05, 0.05)

ax1d.pie(pose_categories, explode=explode, labels=category_labels, colors=colors_pie,
         autopct='%1.1f%%', shadow=True, startangle=90, textprops={'fontsize': 9})
ax1d.set_title('Overall Pose Distribution', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.show()

# ============ FIGURE 2: Pocket Separation Distances ============
# Calculate distances between all pocket centers
pocket_centers = df_pockets[['center_x', 'center_y', 'center_z']].values
pocket_types_arr = df_pockets['pocket_type'].values
pocket_pairs_arr = df_pockets['pair'].values

if len(pocket_centers) > 1:
    distance_matrix = squareform(pdist(pocket_centers))
    
    # Distances within same pair vs across pairs
    within_pair_distances = []
    across_pair_distances = []
    
    for i in range(len(pocket_centers)):
        for j in range(i+1, len(pocket_centers)):
            dist = distance_matrix[i, j]
            if pocket_pairs_arr[i] == pocket_pairs_arr[j]:
                within_pair_distances.append({
                    'distance': dist,
                    'type1': pocket_types_arr[i],
                    'type2': pocket_types_arr[j],
                    'pair': pocket_pairs_arr[i]
                })
            else:
                across_pair_distances.append({
                    'distance': dist,
                    'type1': pocket_types_arr[i],
                    'type2': pocket_types_arr[j]
                })
    
    df_within = pd.DataFrame(within_pair_distances)
    df_across = pd.DataFrame(across_pair_distances)
    
    fig2, axes2 = plt.subplots(1, 3, figsize=(16, 5))
    
    # 2a: Within-pair pocket distances
    ax2a = axes2[0]
    if len(df_within) > 0:
        ax2a.hist(df_within['distance'], bins=20, color='#3498db', edgecolor='black', alpha=0.7)
        ax2a.axvline(x=POCKET_THRESHOLD, color='red', linestyle='--', linewidth=2,
                     label=f'Clustering threshold ({POCKET_THRESHOLD} Å)')
        ax2a.axvline(x=df_within['distance'].mean(), color='green', linestyle='-', linewidth=2,
                     label=f'Mean ({df_within["distance"].mean():.1f} Å)')
    ax2a.set_xlabel('Distance (Å)', fontsize=12)
    ax2a.set_ylabel('Frequency', fontsize=12)
    ax2a.set_title('Pocket Separation (Same Protein-Ligand Pair)', fontsize=12, fontweight='bold')
    ax2a.legend(fontsize=9)
    ax2a.grid(axis='y', alpha=0.3)
    
    # 2b: Comparison by pocket type combination
    ax2b = axes2[1]
    if len(df_within) > 0:
        df_within['type_combo'] = df_within.apply(
            lambda x: f"{min(x['type1'], x['type2'])} - {max(x['type1'], x['type2'])}", axis=1)
        type_combos = df_within['type_combo'].unique()
        distances_by_combo = [df_within[df_within['type_combo'] == tc]['distance'].values for tc in type_combos]
        
        bp = ax2b.boxplot(distances_by_combo, labels=[tc.replace(' - ', '\n-\n') for tc in type_combos],
                          patch_artist=True)
        colors_box = plt.cm.Set2(np.linspace(0, 1, len(bp['boxes'])))
        for patch, color in zip(bp['boxes'], colors_box):
            patch.set_facecolor(color)
            patch.set_alpha(0.7)
        
        ax2b.axhline(y=POCKET_THRESHOLD, color='red', linestyle='--', linewidth=2)
    ax2b.set_ylabel('Distance (Å)', fontsize=12)
    ax2b.set_title('Pocket Distance by Type Combination', fontsize=12, fontweight='bold')
    ax2b.grid(axis='y', alpha=0.3)
    
    # 2c: 3D scatter of pocket centers (if matplotlib supports it)
    ax2c = axes2[2]
    ax2c = fig2.add_subplot(1, 3, 3, projection='3d')
    
    colors_3d = {'Shared': '#9b59b6', 'MGLTools Only': '#2ecc71', 'Meeko Only': '#3498db'}
    for pocket_type in ['Shared', 'MGLTools Only', 'Meeko Only']:
        mask = df_pockets['pocket_type'] == pocket_type
        ax2c.scatter(df_pockets.loc[mask, 'center_x'],
                     df_pockets.loc[mask, 'center_y'],
                     df_pockets.loc[mask, 'center_z'],
                     c=colors_3d[pocket_type], label=pocket_type, s=50, alpha=0.7)
    
    ax2c.set_xlabel('X (Å)')
    ax2c.set_ylabel('Y (Å)')
    ax2c.set_zlabel('Z (Å)')
    ax2c.set_title('Pocket Centers in 3D Space', fontsize=12, fontweight='bold')
    ax2c.legend(fontsize=9)
    
    plt.tight_layout()
    plt.show()

# ============ FIGURE 3: Per-Pair Cluster Analysis ============
fig3, axes3 = plt.subplots(2, 2, figsize=(16, 12))

# 3a: Poses per pocket per pair (stacked by type)
ax3a = axes3[0, 0]
pairs = df_summaries['pair'].values
x = np.arange(len(pairs))
width = 0.6

# Stack: shared MGLTools, shared Meeko, unique MGLTools, unique Meeko
ax3a.bar(x, df_summaries['shared_poses_mgl'], width, label='MGLTools (Shared)', color='#27ae60', edgecolor='black')
ax3a.bar(x, df_summaries['shared_poses_meeko'], width, bottom=df_summaries['shared_poses_mgl'],
         label='Meeko (Shared)', color='#2980b9', edgecolor='black')
ax3a.bar(x, df_summaries['unique_poses_mgl'], width, 
         bottom=df_summaries['shared_poses_mgl'] + df_summaries['shared_poses_meeko'],
         label='MGLTools (Unique)', color='#16a085', edgecolor='black')
ax3a.bar(x, df_summaries['unique_poses_meeko'], width,
         bottom=df_summaries['shared_poses_mgl'] + df_summaries['shared_poses_meeko'] + df_summaries['unique_poses_mgl'],
         label='Meeko (Unique)', color='#1abc9c', edgecolor='black')

ax3a.set_xlabel('Protein-Ligand Pair', fontsize=11)
ax3a.set_ylabel('Number of Poses', fontsize=11)
ax3a.set_title('Pose Distribution per Pair (Shared vs Unique)', fontsize=12, fontweight='bold')
ax3a.set_xticks(x)
ax3a.set_xticklabels(pairs, rotation=45, ha='right', fontsize=8)
ax3a.legend(fontsize=9, loc='upper right')
ax3a.grid(axis='y', alpha=0.3)

# 3b: Number of pockets per pair by type
ax3b = axes3[0, 1]
width = 0.25
ax3b.bar(x - width, df_summaries['mgltools_only_pockets'], width, label='MGLTools Only', color='#2ecc71', edgecolor='black')
ax3b.bar(x, df_summaries['shared_pockets'], width, label='Shared', color='#9b59b6', edgecolor='black')
ax3b.bar(x + width, df_summaries['meeko_only_pockets'], width, label='Meeko Only', color='#3498db', edgecolor='black')

ax3b.set_xlabel('Protein-Ligand Pair', fontsize=11)
ax3b.set_ylabel('Number of Pockets', fontsize=11)
ax3b.set_title('Pockets per Pair by Type', fontsize=12, fontweight='bold')
ax3b.set_xticks(x)
ax3b.set_xticklabels(pairs, rotation=45, ha='right', fontsize=8)
ax3b.legend(fontsize=10)
ax3b.grid(axis='y', alpha=0.3)

# 3c: Ratio heatmap - shared vs unique poses per pair
ax3c = axes3[1, 0]
ratio_data = []
for _, row in df_summaries.iterrows():
    total_mgl = row['shared_poses_mgl'] + row['unique_poses_mgl']
    total_meeko = row['shared_poses_meeko'] + row['unique_poses_meeko']
    ratio_data.append({
        'pair': row['pair'],
        'mgl_shared_pct': 100 * row['shared_poses_mgl'] / max(1, total_mgl),
        'meeko_shared_pct': 100 * row['shared_poses_meeko'] / max(1, total_meeko),
        'mgl_unique_pct': 100 * row['unique_poses_mgl'] / max(1, total_mgl),
        'meeko_unique_pct': 100 * row['unique_poses_meeko'] / max(1, total_meeko)
    })

df_ratios = pd.DataFrame(ratio_data)
heatmap_data = df_ratios[['mgl_shared_pct', 'mgl_unique_pct', 'meeko_shared_pct', 'meeko_unique_pct']].values

im = ax3c.imshow(heatmap_data, cmap='RdYlGn', aspect='auto', vmin=0, vmax=100)
ax3c.set_xticks(np.arange(4))
ax3c.set_xticklabels(['MGLTools\nShared', 'MGLTools\nUnique', 'Meeko\nShared', 'Meeko\nUnique'], fontsize=9)
ax3c.set_yticks(np.arange(len(df_ratios)))
ax3c.set_yticklabels(df_ratios['pair'], fontsize=8)

for i in range(len(df_ratios)):
    for j in range(4):
        val = heatmap_data[i, j]
        ax3c.text(j, i, f'{val:.0f}%', ha='center', va='center',
                  color='white' if val > 60 or val < 40 else 'black', fontsize=9, fontweight='bold')

cbar = plt.colorbar(im, ax=ax3c)
cbar.set_label('% of Poses', fontsize=10)
ax3c.set_title('Pose % in Shared vs Unique Pockets by Pair', fontsize=12, fontweight='bold')

# 3d: Summary table visualization
ax3d = axes3[1, 1]
ax3d.axis('off')

summary_text = f"""
SUMMARY: POSES IN SHARED vs UNIQUE POCKETS

┌─────────────────┬────────────────┬────────────────┐
│                 │   MGLTools     │     Meeko      │
├─────────────────┼────────────────┼────────────────┤
│ Total Poses     │ {total_mgl_poses:>10}     │ {total_meeko_poses:>10}     │
│ In Shared       │ {mgl_poses_in_shared:>10}     │ {meeko_poses_in_shared:>10}     │
│ In Unique       │ {mgl_poses_in_unique:>10}     │ {meeko_poses_in_unique:>10}     │
│ % Shared        │ {100*mgl_poses_in_shared/max(1,total_mgl_poses):>9.1f}%    │ {100*meeko_poses_in_shared/max(1,total_meeko_poses):>9.1f}%    │
│ % Unique        │ {100*mgl_poses_in_unique/max(1,total_mgl_poses):>9.1f}%    │ {100*meeko_poses_in_unique/max(1,total_meeko_poses):>9.1f}%    │
│ Ratio Sh/Uniq   │ {mgl_poses_in_shared/max(1,mgl_poses_in_unique):>10.2f}    │ {meeko_poses_in_shared/max(1,meeko_poses_in_unique):>10.2f}    │
└─────────────────┴────────────────┴────────────────┘

POCKET STATISTICS:
• Total Pockets: {total_pockets}
• Shared: {total_shared_pockets} ({100*total_shared_pockets/total_pockets:.1f}%)
• MGLTools Only: {total_mgl_only_pockets} ({100*total_mgl_only_pockets/total_pockets:.1f}%)
• Meeko Only: {total_meeko_only_pockets} ({100*total_meeko_only_pockets/total_pockets:.1f}%)
"""

ax3d.text(0.1, 0.95, summary_text, transform=ax3d.transAxes, fontsize=11,
          verticalalignment='top', fontfamily='monospace',
          bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout()
plt.show()

# ============ FIGURE 4: Detailed Pose Count per Cluster ============
fig4, ax4 = plt.subplots(figsize=(16, 6))

# Sort pockets by total poses
df_pockets_sorted = df_pockets.sort_values('total_poses', ascending=False).reset_index(drop=True)

x = np.arange(len(df_pockets_sorted))
width = 0.35

# Color by pocket type
type_colors = {'Shared': '#9b59b6', 'MGLTools Only': '#2ecc71', 'Meeko Only': '#3498db'}
bar_colors_mgl = [type_colors[t] for t in df_pockets_sorted['pocket_type']]
bar_colors_meeko = [type_colors[t] for t in df_pockets_sorted['pocket_type']]

bars_mgl = ax4.bar(x - width/2, df_pockets_sorted['mgltools_poses'], width, 
                   label='MGLTools Poses', color='#2ecc71', edgecolor='black', alpha=0.8)
bars_meeko = ax4.bar(x + width/2, df_pockets_sorted['meeko_poses'], width,
                     label='Meeko Poses', color='#3498db', edgecolor='black', alpha=0.8)

# Mark pocket types with different edge colors
for i, (bar_m, bar_e, ptype) in enumerate(zip(bars_mgl, bars_meeko, df_pockets_sorted['pocket_type'])):
    if ptype == 'Shared':
        bar_m.set_edgecolor('#9b59b6')
        bar_e.set_edgecolor('#9b59b6')
        bar_m.set_linewidth(2)
        bar_e.set_linewidth(2)

ax4.set_xlabel('Pocket (sorted by total poses)', fontsize=12)
ax4.set_ylabel('Number of Poses', fontsize=12)
ax4.set_title('Poses per Cluster/Pocket (All Pairs Combined)', fontsize=14, fontweight='bold')
ax4.set_xticks(x[::max(1, len(x)//20)])  # Show every nth tick
ax4.set_xticklabels([f"P{i+1}" for i in x[::max(1, len(x)//20)]], fontsize=8)
ax4.legend(fontsize=11)
ax4.grid(axis='y', alpha=0.3)

# Add legend for pocket types
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='#9b59b6', edgecolor='black', label='Shared Pocket'),
                   Patch(facecolor='#2ecc71', edgecolor='black', label='MGLTools Only'),
                   Patch(facecolor='#3498db', edgecolor='black', label='Meeko Only')]
ax4.legend(handles=legend_elements + ax4.get_legend_handles_labels()[0][:2], 
           loc='upper right', fontsize=9)

plt.tight_layout()
plt.show()

# ============ DETAILED TABLES ============
print("\n" + "=" * 100)
print("DETAILED POCKET DATA")
print("=" * 100)
display(df_pockets[['pair', 'pocket_id', 'pocket_type', 'mgltools_poses', 'meeko_poses', 'total_poses']])

print("\n" + "=" * 100)
print("PER-PAIR SUMMARY")
print("=" * 100)
display(df_summaries)

print("\n" + "=" * 100)
print("POSE RATIOS (Shared/Unique) BY PAIR")
print("=" * 100)
display(df_ratios.round(1))
