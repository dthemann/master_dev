# %%
# %run pose_busters.py \
    --docking-dir equibind_guided:/home/manndo/master_dev/equibind_pocket_guided_uff \
    --proteins-dir /home/manndo/master_dev/Orai \
    --filter _cleaned \
    --mode dock \
    --output-dir /home/manndo/master_dev/posebusters_results/dock/uff_test
# Out:
# Working directory: /home/manndo/master_dev
# PoseBusters mode: dock
#
# Docking directories (1):
#   equibind_guided: /home/manndo/master_dev/equibind_pocket_guided
#
# Proteins directory: /home/manndo/master_dev/Orai
# Protein filter active: only names containing '_cleaned'
#
# ...
# DOCKING POSES OVERVIEW
# ...
#
#   20 protein-ligand combinations | 4 proteins | 5 ligands
#   Equibind_Guided: 2,422 poses
#   Combined Total: 2,422 poses
#   Saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
#
# ...
# FILTERED SUBSET (combinations present in all methods)
# ...
#   Common protein-ligand combinations: 20
#   equibind_guided: 20 combos, 2,422 poses
#   Total: 2,422 poses across 1 method(s)
#
# Protein PDB files: 12 found in /home/manndo/master_dev/Orai
#   Protein resolution: 4/4 matched
# Output directory: /home/manndo/master_dev/posebusters_results/dock/uff_test
#
# ...
#   2422 poses to analyse
#
# Running PoseBusters validation (mode='dock', overwrite=False)...
# ...

# %%
de

# %%
# ============================================================================
# CLI ARGUMENTS
# ============================================================================
# Usage:
#   python pose_busters.py \
#       --docking-dir autodock:/path/to/autodock_poses \
#       --docking-dir diffdock:/path/to/diffdock_poses \
#       [--proteins-dir /path/to/proteins]  (required when --mode dock) \
#       [--wd /path/to/workspace] [--filter _cleaned] [--overwrite] \
#       [--mode dock] [--output-dir /path/to/output]
#
# --docking-dir   One or more method:path pairs (repeatable). Example:
#                   --docking-dir autodock:/data/autodock_poses
#                   --docking-dir diffdock:/data/diffdock_results
# --proteins-dir  Path to the directory containing protein PDB files.
#                 Required when --mode dock.
# --wd            Working directory (default: /home/manndo/master_dev)
# --filter        Optional substring filter for protein names
# --overwrite     Discard previous results and re-run all poses
# --mode          PoseBusters mode: "dock" (with protein) or "mol" (ligand only)
# --output-dir    Output directory for results (default: <wd>/posebusters_results/<mode>)

# %%
# %run pose_busters.py \
    --docking-dir autodock:/home/manndo/master_dev/docking_ready_mgltools/docking \
    --proteins-dir /home/manndo/master_dev/Orai \
    --filter _cleaned \
    --mode dock \
    --output-dir /home/manndo/master_dev/posebusters_results/dock
# Out:
# Working directory: /home/manndo/master_dev
# PoseBusters mode: dock
#
# Docking directories (1):
#   autodock: /home/manndo/master_dev/docking_ready_mgltools/docking
#
# Proteins directory: /home/manndo/master_dev/Orai
# Protein filter active: only names containing '_cleaned'
#
# ...
# DOCKING POSES OVERVIEW
# ...
#
#   16 protein-ligand combinations | 4 proteins | 4 ligands
#   Autodock: 480 poses
#   Combined Total: 480 poses
#   Saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
#
# ...
# FILTERED SUBSET (combinations present in all methods)
# ...
#   Common protein-ligand combinations: 16
#   autodock: 16 combos, 480 poses
#   Total: 480 poses across 1 method(s)
#
# Protein PDB files: 12 found in /home/manndo/master_dev/Orai
#   Protein resolution: 4/4 matched
# Output directory: /home/manndo/master_dev/posebusters_results/dock
#
# ...
#   Converting Orai1WT-MDSnap-Fr499_cleaned__Synta-66-OPT-Singlet_vina_out.pdbqt to SDF...
# ...

# %%
# %run pose_busters.py \
    --docking-dir diffdock:/home/manndo/master_dev/diffdock_results \
    --proteins-dir /home/manndo/master_dev/Orai \
    --filter _cleaned \
    --mode dock \
    --output-dir /home/manndo/master_dev/posebusters_results/dock
# Out:
# Working directory: /home/manndo/master_dev
# PoseBusters mode: dock
#
# Docking directories (1):
#   diffdock: /home/manndo/master_dev/diffdock_results
#
# Proteins directory: /home/manndo/master_dev/Orai
# Protein filter active: only names containing '_cleaned'
#
# ...
# DOCKING POSES OVERVIEW
# ...
#
#   16 protein-ligand combinations | 4 proteins | 4 ligands
#   Diffdock: 1,006 poses
#   Combined Total: 1,006 poses
#   Saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
#
# ...
# FILTERED SUBSET (combinations present in all methods)
# ...
#   Common protein-ligand combinations: 16
#   diffdock: 16 combos, 1,006 poses
#   Total: 1,006 poses across 1 method(s)
#
# Protein PDB files: 12 found in /home/manndo/master_dev/Orai
#   Protein resolution: 4/4 matched
# Output directory: /home/manndo/master_dev/posebusters_results/dock
#
# ...
# [23:43:04] ERROR: Cannot process coordinates on line 5
# [23:43:04] ERROR: moving to the beginning of the next molecule
# ...

# %%
# %run pose_busters.py \
    --docking-dir equibind_guided:/home/manndo/master_dev/equibind_pocket_guided \
    --proteins-dir /home/manndo/master_dev/Orai \
    --filter _cleaned \
    --mode dock \
    --output-dir /home/manndo/master_dev/posebusters_results/dock
# Out:
# Working directory: /home/manndo/master_dev
# PoseBusters mode: dock
#
# Docking directories (1):
#   equibind_guided: /home/manndo/master_dev/equibind_pocket_guided
#
# Proteins directory: /home/manndo/master_dev/Orai
# Protein filter active: only names containing '_cleaned'
#
# ...
# DOCKING POSES OVERVIEW
# ...
#
#   20 protein-ligand combinations | 4 proteins | 5 ligands
#   Equibind_Guided: 2,420 poses
#   Combined Total: 2,420 poses
#   Saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
#
# ...
# FILTERED SUBSET (combinations present in all methods)
# ...
#   Common protein-ligand combinations: 20
#   equibind_guided: 20 combos, 2,420 poses
#   Total: 2,420 poses across 1 method(s)
#
# Protein PDB files: 12 found in /home/manndo/master_dev/Orai
#   Protein resolution: 4/4 matched
# Output directory: /home/manndo/master_dev/posebusters_results/dock
#
# ...
#   2420 poses to analyse
#
# Running PoseBusters validation (mode='dock', overwrite=False)...
# ...

# %%
# %run pose_busters.py \
    --docking-dir equibind_guided:/home/manndo/master_dev/equibind_docked_poses \
    --proteins-dir /home/manndo/master_dev/Orai \
    --filter _cleaned \
    --mode dock \
    --output-dir /home/manndo/master_dev/posebusters_results/dock
# Out:
# Working directory: /home/manndo/master_dev
# PoseBusters mode: dock
#
# Docking directories (1):
#   equibind_guided: /home/manndo/master_dev/equibind_docked_poses
#
# Proteins directory: /home/manndo/master_dev/Orai
# Protein filter active: only names containing '_cleaned'
#
# ...
# DOCKING POSES OVERVIEW
# ...
#
#   20 protein-ligand combinations | 4 proteins | 5 ligands
#   Equibind_Guided: 72 poses
#   Combined Total: 72 poses
#   Saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
#
# ...
# FILTERED SUBSET (combinations present in all methods)
# ...
#   Common protein-ligand combinations: 20
#   equibind_guided: 20 combos, 72 poses
#   Total: 72 poses across 1 method(s)
#
# Protein PDB files: 12 found in /home/manndo/master_dev/Orai
#   Protein resolution: 4/4 matched
# Output directory: /home/manndo/master_dev/posebusters_results/dock
#
# ...
#   72 poses to analyse
#
# Running PoseBusters validation (mode='dock', overwrite=False)...
# ...

# %%
# %run pose_busters.py \
    --docking-dir equibind_guided:/home/manndo/master_dev/equibind_conformer_poses \
    --proteins-dir /home/manndo/master_dev/Orai \
    --filter _cleaned \
    --mode dock \
    --output-dir /home/manndo/master_dev/posebusters_results/dock
# Out:
# Working directory: /home/manndo/master_dev
# PoseBusters mode: dock
#
# Docking directories (1):
#   equibind_guided: /home/manndo/master_dev/equibind_conformer_poses
#
# Proteins directory: /home/manndo/master_dev/Orai
# Protein filter active: only names containing '_cleaned'
#
# ...
# DOCKING POSES OVERVIEW
# ...
#
#   1 protein-ligand combinations | 1 proteins | 1 ligands
#   Equibind_Guided: 9 poses
#   Combined Total: 9 poses
#   Saved to: /home/manndo/master_dev/posebusters_results/pose_counts_overview.csv
#
# ...
# FILTERED SUBSET (combinations present in all methods)
# ...
#   Common protein-ligand combinations: 1
#   equibind_guided: 1 combos, 9 poses
#   Total: 9 poses across 1 method(s)
#
# Protein PDB files: 12 found in /home/manndo/master_dev/Orai
#   Protein resolution: 1/1 matched
# Output directory: /home/manndo/master_dev/posebusters_results/dock
#
# ...
#   9 poses to analyse
#
# Running PoseBusters validation (mode='dock', overwrite=False)...
# ...

# %%
# %run pose_busters_analysis.py \
    --results-dir /home/manndo/master_dev/posebusters_results/dock \
    --output-dir /home/manndo/master_dev/posebusters_results/analysis
# Out:
# Results directory: /home/manndo/master_dev/posebusters_results/dock
# Output directory:  /home/manndo/master_dev/posebusters_results/analysis
#
# ...
# POSEBUSTERS RESULTS ANALYSIS
# ...
#
# Loading: /home/manndo/master_dev/posebusters_results/dock/posebusters_filtered_results.csv
# Total entries: 3983
# ...

# %%
de
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 de
#
# NameError: name 'de' is not defined

# %%
# %run pose_clustering_v3.py

# %%
# %run pose_busters.py

# %% [markdown]
# # Final
