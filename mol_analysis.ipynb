# %%
# %run pose_busters_analysis.py \
    --results-dir /home/manndo/master_dev/posebusters_results/mol \
    --output-dir /home/manndo/master_dev/posebusters_results/analysis
# Out:
# Results directory: /home/manndo/master_dev/posebusters_results/mol
# Output directory:  /home/manndo/master_dev/posebusters_results/analysis
#
# ...
# POSEBUSTERS RESULTS ANALYSIS
# ...
#
# Loading: /home/manndo/master_dev/posebusters_results/mol/posebusters_filtered_results.csv
# Total entries: 9885
# ...

# %%
# ### Jupyter Notebook
# ```python
# %run pose_clustering.py \
#     --results-csv /path/to/posebusters_filtered_results.csv \
#     --mode hybrid \
#     --hybrid-weight 0.7 \
#     --output-dir /path/to/output
# ```
#--mode`          Distance mode: `centroid`, `rmsd`, or `hybrid` (default: `hybrid`)

# %%
# %run pose_clustering.py \
    --results-csv /home/manndo/master_dev/posebusters_results/mol/posebusters_filtered_results.csv \
    --mode centroid \
    --output-dir /home/manndo/master_dev/posebusters_results/analysis/clustering
# Out:
# ...
# POSE CLUSTERING v3  —  mode = CENTROID
#   Output:  /home/manndo/master_dev/posebusters_results/analysis/clustering/centroid
# ...
#
# Loading PoseBusters results from:
#   /home/manndo/master_dev/posebusters_results/mol/posebusters_filtered_results.csv
#   Total rows in CSV: 9885
#   Rows after filtering to ['autodock', 'diffdock', 'equibind_guided']: 9082
#   Boolean test columns detected (15): ['mol_pred_loaded', 'sanitization', 'inchi_convertible', 'all_atoms_connected', 'no_radicals', 'bond_lengths', 'bond_angles', 'internal_steric_clash', 'aromatic_ring_flatness', 'non-aromatic_ring_non-flatness', 'double_bond_flatness', 'internal_energy', 'passes_valence_checks', 'passes_kekulization', 'no_radicals_before_sanitization']
#   Poses passing ALL PoseBusters tests: 6886 / 9082
#     autodock: 720 passed / 960 total
#     diffdock: 1082 passed / 1489 total
#     equibind_guided: 5084 passed / 6633 total
#
# ...
# Extracting heavy-atom features from PoseBusters-PASSED poses ...
# ...
#
# ...
